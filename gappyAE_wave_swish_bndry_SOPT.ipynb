# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle
import torch
import torch.nn as nn

# %%
# Given parameters
nx = 60
ny = 60
tf = 5.0
dt = 1.0e-2
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims = (ny,nx)

# latent space dim.
f_list=np.array([3,4,5,6])
print('Latent Sapce Dim. {}'.format(f_list))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_SOPT_result = "./wave_result/ex23_AE_swish_bndry_SOPT_gappy_result_seed_{}.p".format(seed)

# Gauss-Newton params
maxitr=4
tol=1e-8

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# Latent Sapce Dim. [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %%
# S-OPT
file_path_SOPT="/home/test/pylibROM_docker/pylibROM/tests/model/ex23_AE_bndry_SOPT_no_oversampling.p"
with open(file=file_path_SOPT, mode='rb') as ff:  
        msmt_idx_list = pickle.load(ff)

# %%
for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))

    # file path
    file_path_residual_SVD="./wave_model/ex23_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)

    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig("./wave_result/ex23_AE_{}_swish_bndry_SOPT_{}_samples_seed_{}.png".format(f,num_msmt,seed))
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [   2   13   36   43   48  420 1320 1859 1860 3555 3582 3599]
# Dim. of latent space is 4
# # of measurments: 12
# [   0    9   13   25   30   36   40   45 1019 2940 3239 3480]
# Dim. of latent space is 5
# # of measurments: 12
# [   0    7   14   19   38   42   51 1320 1619 2760 3239 3551]
# Dim. of latent space is 6
# # of measurments: 12
# [   1    6   19   24   36   46  779 1620 1800 3000 3240 3419]

# %% [markdown]
# # gappyAE

# %%
solution=np.zeros((len(f_list),len(FOM_parameters),nt+1,nx*ny))
reduced=np.zeros((len(f_list),len(FOM_parameters),nt+1,f_list[-1]))
avg_rel_err=np.zeros((len(f_list),len(FOM_parameters)))
rel_err=np.zeros((len(f_list),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(f_list),len(FOM_parameters)))

for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))
    
    # file path
    file_name_AE="./wave_model/ex23_AE_{}_swish_seed_{}.p".format(f,seed)
    file_path_residual_SVD="./wave_model/ex23_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)
    
    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
    
    # precompute
    with open(file=file_path_residual_SVD, mode='rb') as fff:
        SVD=pickle.load(fff)
    U=SVD['U']
    phi_r=U[:,:num_msmt]
    ZTphi_r=phi_r[msmt_idx]
    ZTphi_r_pinv=np.linalg.pinv(ZTphi_r)
    phi_rZTphi_r_pinv=phi_r.dot(ZTphi_r_pinv)
    
    with open(file=file_name_AE, mode='rb') as ff:    
        AE = pickle.load(ff)

    en_wu1=AE['en_wu1']
    en_bu1=AE['en_bu1']
    en_wu2=AE['en_wu2']
    de_wu1=AE['de_wu1']
    de_bu1=AE['de_bu1']
    de_wu2=AE['de_wu2']
    de_wu1T=AE['de_wu1T']
    de_wu2T=AE['de_wu2T']
    de_wu2_sp=AE['de_wu2_sp']
    de_wu2T_sp=AE['de_wu2T_sp']
    u_ref=AE['u_ref']

    latent_dim=de_wu1.shape[1]
    
    # numpy version of AE
    def sigmoid_np(input):
        return (1.0/(1.0+np.exp(-input))).astype('float32')

    def encoder_u_np_forward(x):
        z1 = en_wu1.dot(x) + en_bu1
        a1 = z1 * sigmoid_np(z1)
        y = en_wu2.dot(a1)   
        return y

    def decoder_u_np_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = de_wu2.dot(a1)  
        return y

    def decoder_u_sp_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(de_wu2_sp,a1)
        return y

    def decoder_u_np_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = de_wu2.dot(a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(de_wu2T)   
        return y,dydxT

    def decoder_u_sp_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(de_wu2_sp,a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,de_wu2T_sp)
        return y,dydxT
    
    m,M2=de_wu2.shape

    class Decoder_U_FC(nn.Module):

        def __init__(self,):
            super(Decoder_U_FC, self).__init__()
            self.fc1 = nn.Linear(latent_dim,M2)
            self.fc1.weight = nn.Parameter(torch.ones(de_wu1.shape))
            self.fc1.bias = nn.Parameter(torch.ones(de_bu1.shape))
    #         self.fc1.weight = nn.Parameter(torch.tensor(de_wu1))
    #         self.fc1.bias = nn.Parameter(torch.tensor(de_bu1))

            self.fc2 = nn.Linear(M2,m,bias=False)
            self.fc2.weight = nn.Parameter(torch.ones(de_wu2.shape))
    #         self.fc2.weight = nn.Parameter(torch.tensor(de_wu2))

        def forward(self, x):
            x = self.fc1(x)
            x = self.fc2(x)
            return x

    model = Decoder_U_FC()

    x_in=torch.ones(latent_dim)
    y_out=model(x_in)

    p_hr=msmt_idx

    upstream=torch.zeros_like(y_out)
    upstream[p_hr]=1.0

    y_out.backward(upstream)

    # masks for subnet
    wu1_mask=model.fc1.weight.grad
    wu2_mask=model.fc2.weight.grad

    bu1_mask=model.fc1.bias.grad

    # subnet sparse weight
    idx1=wu1_mask.to_sparse()._indices()
    i1=idx1.numpy()[0]
    j1=idx1.numpy()[1]
    v1=de_wu1[i1,j1]
    wu1_sb_sp=sp.csr_matrix(sp.csr_matrix((v1,(i1,j1)),shape=wu1_mask.shape).toarray())

    idx2=wu2_mask.to_sparse()._indices()
    i2=idx2.numpy()[0]
    j2=idx2.numpy()[1]
    v2=de_wu2[i2,j2]
    wu2_sb_sp=sp.csr_matrix(sp.csr_matrix((v2,(i2,j2)),shape=wu2_mask.shape).toarray())

    # subnet compressed weight
    i1,j1,v1=sp.find(wu1_sb_sp)
    i1_unique,i1_inverse=np.unique(i1,return_inverse=True)
    i1_comp=np.arange(i1_unique.size)
    i1_comp=i1_comp[i1_inverse]
    j1_unique,j1_inverse=np.unique(j1,return_inverse=True)
    j1_comp=np.arange(j1_unique.size)
    j1_comp=j1_comp[j1_inverse]
    wu1_sb_comp_sp=sp.csr_matrix((v1,(i1_comp,j1_comp)),shape=(i1_unique.size,j1_unique.size))

    i2,j2,v2=sp.find(wu2_sb_sp)
    i2_unique,i2_inverse=np.unique(i2,return_inverse=True)
    i2_comp=np.arange(i2_unique.size)
    i2_comp=i2_comp[i2_inverse]
    j2_unique,j2_inverse=np.unique(j2,return_inverse=True)
    j2_comp=np.arange(j2_unique.size)
    j2_comp=j2_comp[j2_inverse]
    wu2_sb_comp_sp=sp.csr_matrix((v2,(i2_comp,j2_comp)),shape=(i2_unique.size,j2_unique.size))

    wu1_sb_comp_dense=wu1_sb_comp_sp.toarray()
    wu1_sb_comp_dense=wu1_sb_comp_dense[j2_unique]
    wu2_sb_comp_dense=wu2_sb_comp_sp.toarray()

    wu1_sb_comp_denseT=wu1_sb_comp_dense.T
    wu2_sb_comp_denseT=wu2_sb_comp_dense.T

    # subnet compressed bias
    bu1_sb_comp_dense=de_bu1[i1_unique]
    bu1_sb_comp_dense=bu1_sb_comp_dense[j2_unique]

    # Using sparse matrix
    wu2_sb_comp_sp=sp.csr_matrix(wu2_sb_comp_dense,dtype='float32')
    wu2_sb_comp_spT=sp.csr_matrix(wu2_sb_comp_denseT,dtype='float32')

    def decoder_u_sb_np_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = wu2_sb_comp_dense.dot(a1)  
        return y

    def decoder_u_sb_np_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = wu2_sb_comp_dense.dot(a1) 

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(wu2_sb_comp_denseT)
        return y,dydxT

    def decoder_u_sb_sp_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)
        return y

    def decoder_u_sb_sp_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,wu2_sb_comp_spT)
        return y,dydxT

    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('./wave_data/ex23_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1).astype('float32')

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_hat0=encoder_u_np_forward(u0.astype('float32')-u_ref)

        # gappyAE
        t_start_gappyAE=time.time()

        # solution
        u_reduced=np.zeros((nt+1,latent_dim))
        u_gappyAE=np.zeros((nt+1,ny*nx))

        # IC
        u_reduced[0]=np.copy(u_hat0)
        u_gappyAE[0]=np.copy(u0)

        for k in range(nt):
#             print("")
#             print(k,"th time step:")

            u_hatw=np.copy(u_reduced[k])

            umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

            umw += u_ref[msmt_idx]

            J_r=-Jg_umT.T
            J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

            r_um_hat = um[k+1]-umw

            res = np.linalg.norm(J_pinv.dot(r_um_hat))
#             res = np.linalg.norm(r_um_hat)
            res_hist=[res]
            for itr in range(maxitr):
                du_hatw = J_pinv.dot(r_um_hat)

                u_hatw -= du_hatw

                umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

                umw += u_ref[msmt_idx]

                J_r=-Jg_umT.T
                J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

                r_um_hat = um[k+1]-umw

                res = np.linalg.norm(J_pinv.dot(r_um_hat))
#                 res = np.linalg.norm(r_um_hat)
                res_hist.append(res)
#                 print(itr,"th Newton iteration", "res:", "{:.8e}".format(res))

                if res<tol:
                    break

            u_reduced[k+1]=u_hatw.copy()
            u_gappyAE[k+1]=u_ref+decoder_u_sp_forward(u_reduced[k+1])

        # elapsed time    
        t_elapsed_gappyAE=time.time()-t_start_gappyAE
        print('Time elapsed: {} sec'.format(t_elapsed_gappyAE))

        # error
        u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                         /np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
                     /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
        print()

        # save result
        solution[ii,jj]=u_gappyAE
        reduced[ii,jj,:,:f]=u_reduced
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyAE
        elapsed_time[ii,jj]=t_elapsed_gappyAE
    
results={'solution':solution,'reduced':reduced,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_SOPT_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [   2   13   36   43   48  420 1320 1859 1860 3555 3582 3599]
# Param is 75
# Time elapsed: 15.174436092376709 sec
# average relative error of u: 1.4469298032996354%
# maximum relative error of u: 2.552432924292398%
#
# Param is 76
# Time elapsed: 15.377259731292725 sec
# average relative error of u: 1.3729020513368022%
# maximum relative error of u: 2.418954780390815%
#
# Param is 77
# Time elapsed: 15.525709867477417 sec
# average relative error of u: 1.3053181404342877%
# maximum relative error of u: 2.289177456797019%
#
# Param is 78
# Time elapsed: 15.392182111740112 sec
# average relative error of u: 1.244601271080479%
# maximum relative error of u: 2.163694477502428%
#
# Param is 79
# Time elapsed: 14.603139162063599 sec
# average relative error of u: 1.1911821407474519%
# maximum relative error of u: 2.04281276993369%
#
# Param is 80
# Time elapsed: 14.327486276626587 sec
# average relative error of u: 1.1454478540563429%
# maximum relative error of u: 1.9275313955006579%
#
# Param is 81
# Time elapsed: 13.990821123123169 sec
# average relative error of u: 1.1077283724432472%
# maximum relative error of u: 1.8184964203278122%
#
# Param is 82
# Time elapsed: 13.93008303642273 sec
# average relative error of u: 1.0782489610372898%
# maximum relative error of u: 1.7166464307315685%
#
# Param is 83
# Time elapsed: 14.533133745193481 sec
# average relative error of u: 1.0570944308275523%
# maximum relative error of u: 1.6517930578319%
#
# Param is 84
# Time elapsed: 15.180488348007202 sec
# average relative error of u: 1.0441841649476769%
# maximum relative error of u: 1.67968996328061%
#
# Param is 85
# Time elapsed: 14.593380212783813 sec
# average relative error of u: 1.0392811472824455%
# maximum relative error of u: 1.713643857556197%
#
# Param is 86
# Time elapsed: 15.504173278808594 sec
# average relative error of u: 1.0419637988771786%
# maximum relative error of u: 1.753345884833243%
#
# Param is 87
# Time elapsed: 15.866939544677734 sec
# average relative error of u: 1.051695673611082%
# maximum relative error of u: 1.8013132337762001%
#
# Param is 88
# Time elapsed: 15.1613450050354 sec
# average relative error of u: 1.067837558021492%
# maximum relative error of u: 1.8607175960279072%
#
# Param is 89
# Time elapsed: 15.208886623382568 sec
# average relative error of u: 1.089748361126252%
# maximum relative error of u: 1.9276675623708315%
#
# Param is 90
# Time elapsed: 14.86969256401062 sec
# average relative error of u: 1.1167717371356067%
# maximum relative error of u: 2.061709255166565%
#
# Param is 91
# Time elapsed: 15.336478233337402 sec
# average relative error of u: 1.148321525289371%
# maximum relative error of u: 2.2077453632730912%
#
# Param is 92
# Time elapsed: 15.123235940933228 sec
# average relative error of u: 1.183853860991594%
# maximum relative error of u: 2.363340979052857%
#
# Param is 93
# Time elapsed: 15.659363269805908 sec
# average relative error of u: 1.2229034362744688%
# maximum relative error of u: 2.5282113036520415%
#
# Param is 94
# Time elapsed: 16.035167694091797 sec
# average relative error of u: 1.2650516307567772%
# maximum relative error of u: 2.7020823493511696%
#
# Param is 95
# Time elapsed: 16.542189598083496 sec
# average relative error of u: 1.3099339587503878%
# maximum relative error of u: 2.884706530511452%
#
# Param is 96
# Time elapsed: 16.248968839645386 sec
# average relative error of u: 1.3572276458532602%
# maximum relative error of u: 3.0758422316114418%
#
# Param is 97
# Time elapsed: 15.444481611251831 sec
# average relative error of u: 1.4066425194398715%
# maximum relative error of u: 3.275223286764597%
#
# Param is 98
# Time elapsed: 15.479915618896484 sec
# average relative error of u: 1.4579370269329341%
# maximum relative error of u: 3.485961693467053%
#
# Param is 99
# Time elapsed: 11.94841742515564 sec
# average relative error of u: 1.5108771739216802%
# maximum relative error of u: 3.7053790957732304%
#
# Param is 100
# Time elapsed: 9.661604642868042 sec
# average relative error of u: 1.5652783181606396%
# maximum relative error of u: 3.9319158395180214%
#
# Param is 101
# Time elapsed: 10.86735987663269 sec
# average relative error of u: 1.6209811520680573%
# maximum relative error of u: 4.165215912956308%
#
# Param is 102
# Time elapsed: 11.869948625564575 sec
# average relative error of u: 1.6778480429985452%
# maximum relative error of u: 4.404942644805978%
#
# Param is 103
# Time elapsed: 14.33481740951538 sec
# average relative error of u: 1.7357869921300302%
# maximum relative error of u: 4.6506624248015305%
#
# Param is 104
# Time elapsed: 13.705278873443604 sec
# average relative error of u: 1.7947634893234916%
# maximum relative error of u: 4.901924306608498%
#
# Param is 105
# Time elapsed: 14.133263111114502 sec
# average relative error of u: 1.8547539407655835%
# maximum relative error of u: 5.158228752560207%
#
# Param is 106
# Time elapsed: 13.763150691986084 sec
# average relative error of u: 1.9156504178131755%
# maximum relative error of u: 5.418961480631275%
#
# Param is 107
# Time elapsed: 14.798474550247192 sec
# average relative error of u: 1.9777356999562203%
# maximum relative error of u: 5.6833979292117%
#
# Param is 108
# Time elapsed: 14.788196086883545 sec
# average relative error of u: 2.0419313096299954%
# maximum relative error of u: 5.9506257037981385%
#
# Param is 109
# Time elapsed: 15.210204839706421 sec
# average relative error of u: 2.1069524514675892%
# maximum relative error of u: 6.2280822312844295%
#
# Param is 110
# Time elapsed: 15.334079027175903 sec
# average relative error of u: 2.1723748269929692%
# maximum relative error of u: 6.513806017042641%
#
# Param is 111
# Time elapsed: 15.49814510345459 sec
# average relative error of u: 2.241613650462471%
# maximum relative error of u: 6.8045485804864%
#
# Param is 112
# Time elapsed: 15.367667198181152 sec
# average relative error of u: 2.315657758083126%
# maximum relative error of u: 7.100071168138896%
#
# Param is 113
# Time elapsed: 16.153247356414795 sec
# average relative error of u: 2.3862954663719016%
# maximum relative error of u: 7.400162215484984%
#
# Param is 114
# Time elapsed: 14.910184144973755 sec
# average relative error of u: 2.458802618123563%
# maximum relative error of u: 7.704608143931566%
#
# Param is 115
# Time elapsed: 15.348676919937134 sec
# average relative error of u: 2.5460936428419907%
# maximum relative error of u: 8.01322441307788%
#
# Param is 116
# Time elapsed: 14.994033813476562 sec
# average relative error of u: 2.6275860196765444%
# maximum relative error of u: 8.325892230953805%
#
# Param is 117
# Time elapsed: 15.229832172393799 sec
# average relative error of u: 2.7077415226897097%
# maximum relative error of u: 8.64246488023729%
#
# Param is 118
# Time elapsed: 14.954376697540283 sec
# average relative error of u: 2.7957947755919057%
# maximum relative error of u: 8.962901559622681%
#
# Param is 119
# Time elapsed: 15.549463987350464 sec
# average relative error of u: 2.9006325137620097%
# maximum relative error of u: 9.287147009146096%
#
# Param is 120
# Time elapsed: 15.920512199401855 sec
# average relative error of u: 2.9910341775130735%
# maximum relative error of u: 9.615211140874596%
#
# Param is 121
# Time elapsed: 16.439180612564087 sec
# average relative error of u: 3.0841329894230385%
# maximum relative error of u: 9.946980606828335%
#
# Param is 122
# Time elapsed: 15.98939299583435 sec
# average relative error of u: 3.196360307065661%
# maximum relative error of u: 10.282379109218647%
#
# Param is 123
# Time elapsed: 16.398260354995728 sec
# average relative error of u: 3.3129696737266277%
# maximum relative error of u: 10.621083711772652%
#
# Param is 124
# Time elapsed: 15.759400606155396 sec
# average relative error of u: 3.4185197765577158%
# maximum relative error of u: 10.962771024996986%
#
# Param is 125
# Time elapsed: 15.655592918395996 sec
# average relative error of u: 3.528073116711953%
# maximum relative error of u: 11.307005801222706%
#
# Dim. of latent space is 4
# # of measurments: 12
# [   0    9   13   25   30   36   40   45 1019 2940 3239 3480]
# Param is 75
# Time elapsed: 17.091346263885498 sec
# average relative error of u: 0.9623817578705328%
# maximum relative error of u: 1.871629001319474%
#
# Param is 76
# Time elapsed: 17.359009265899658 sec
# average relative error of u: 0.922875744188598%
# maximum relative error of u: 1.786159944242383%
#
# Param is 77
# Time elapsed: 17.59081268310547 sec
# average relative error of u: 0.8865833985541262%
# maximum relative error of u: 1.7050706325159082%
#
# Param is 78
# Time elapsed: 17.325758934020996 sec
# average relative error of u: 0.8533736637801603%
# maximum relative error of u: 1.6282543494866415%
#
# Param is 79
# Time elapsed: 17.34634804725647 sec
# average relative error of u: 0.8230855431314021%
# maximum relative error of u: 1.555539818459294%
#
# Param is 80
# Time elapsed: 17.22906255722046 sec
# average relative error of u: 0.7955663920639627%
# maximum relative error of u: 1.4864981414250475%
#
# Param is 81
# Time elapsed: 17.163971424102783 sec
# average relative error of u: 0.7706368201697739%
# maximum relative error of u: 1.4212583830202064%
#
# Param is 82
# Time elapsed: 16.4213125705719 sec
# average relative error of u: 0.7481179372697089%
# maximum relative error of u: 1.3659031266398578%
#
# Param is 83
# Time elapsed: 16.334285259246826 sec
# average relative error of u: 0.7278122355156348%
# maximum relative error of u: 1.3312664736013968%
#
# Param is 84
# Time elapsed: 16.688629627227783 sec
# average relative error of u: 0.7095351618731496%
# maximum relative error of u: 1.2984441452078095%
#
# Param is 85
# Time elapsed: 16.7008318901062 sec
# average relative error of u: 0.6930856201929018%
# maximum relative error of u: 1.26707884910302%
#
# Param is 86
# Time elapsed: 16.758862018585205 sec
# average relative error of u: 0.6782721677234145%
# maximum relative error of u: 1.2369070298430538%
#
# Param is 87
# Time elapsed: 16.659326791763306 sec
# average relative error of u: 0.6649026293432528%
# maximum relative error of u: 1.207737965535554%
#
# Param is 88
# Time elapsed: 16.659167289733887 sec
# average relative error of u: 0.6527903189055795%
# maximum relative error of u: 1.1792891823042677%
#
# Param is 89
# Time elapsed: 16.45966911315918 sec
# average relative error of u: 0.6417626969921991%
# maximum relative error of u: 1.1514513027925484%
#
# Param is 90
# Time elapsed: 16.593738555908203 sec
# average relative error of u: 0.6316526027847307%
# maximum relative error of u: 1.1239684276043862%
#
# Param is 91
# Time elapsed: 16.496779680252075 sec
# average relative error of u: 0.6223136821918377%
# maximum relative error of u: 1.0967315175034613%
#
# Param is 92
# Time elapsed: 16.518049955368042 sec
# average relative error of u: 0.6135964438729857%
# maximum relative error of u: 1.0694826085449665%
#
# Param is 93
# Time elapsed: 16.194816827774048 sec
# average relative error of u: 0.605389025246468%
# maximum relative error of u: 1.0551186562522983%
#
# Param is 94
# Time elapsed: 15.598822116851807 sec
# average relative error of u: 0.5975826483882921%
# maximum relative error of u: 1.0709343581061754%
#
# Param is 95
# Time elapsed: 15.898519515991211 sec
# average relative error of u: 0.5900850046209207%
# maximum relative error of u: 1.0837373450334662%
#
# Param is 96
# Time elapsed: 16.2819344997406 sec
# average relative error of u: 0.5828309534303968%
# maximum relative error of u: 1.0931918766934172%
#
# Param is 97
# Time elapsed: 16.86524724960327 sec
# average relative error of u: 0.5757523211034493%
# maximum relative error of u: 1.0995772316635966%
#
# Param is 98
# Time elapsed: 15.950059175491333 sec
# average relative error of u: 0.5688338768811821%
# maximum relative error of u: 1.1024933422783325%
#
# Param is 99
# Time elapsed: 14.558586359024048 sec
# average relative error of u: 0.5620437922173321%
# maximum relative error of u: 1.1024516856620845%
#
# Param is 100
# Time elapsed: 14.309312343597412 sec
# average relative error of u: 0.5553877080372173%
# maximum relative error of u: 1.099041372360972%
#
# Param is 101
# Time elapsed: 14.641795635223389 sec
# average relative error of u: 0.548891844089199%
# maximum relative error of u: 1.0925369995873546%
#
# Param is 102
# Time elapsed: 14.54790711402893 sec
# average relative error of u: 0.5426047345774834%
# maximum relative error of u: 1.08304638853549%
#
# Param is 103
# Time elapsed: 14.994399070739746 sec
# average relative error of u: 0.5365725818317054%
# maximum relative error of u: 1.0702891390090579%
#
# Param is 104
# Time elapsed: 15.465455532073975 sec
# average relative error of u: 0.5309074720632316%
# maximum relative error of u: 1.0548415965190123%
#
# Param is 105
# Time elapsed: 17.223615169525146 sec
# average relative error of u: 0.5257098216069829%
# maximum relative error of u: 1.0360157403179142%
#
# Param is 106
# Time elapsed: 17.405365705490112 sec
# average relative error of u: 0.5211194956965102%
# maximum relative error of u: 1.014706218036562%
#
# Param is 107
# Time elapsed: 16.772481203079224 sec
# average relative error of u: 0.5172786244226971%
# maximum relative error of u: 0.9906342092185405%
#
# Param is 108
# Time elapsed: 16.389004945755005 sec
# average relative error of u: 0.5143792560288708%
# maximum relative error of u: 0.96393159771798%
#
# Param is 109
# Time elapsed: 16.698925971984863 sec
# average relative error of u: 0.5125996950127044%
# maximum relative error of u: 0.9351992230466295%
#
# Param is 110
# Time elapsed: 16.723931789398193 sec
# average relative error of u: 0.5121690786772382%
# maximum relative error of u: 0.9293647897061887%
#
# Param is 111
# Time elapsed: 15.772136688232422 sec
# average relative error of u: 0.5132998475066266%
# maximum relative error of u: 0.9405357764487526%
#
# Param is 112
# Time elapsed: 16.649123668670654 sec
# average relative error of u: 0.5162142191174869%
# maximum relative error of u: 0.9658736852517259%
#
# Param is 113
# Time elapsed: 16.435035228729248 sec
# average relative error of u: 0.5211469194337899%
# maximum relative error of u: 0.9980020081876222%
#
# Param is 114
# Time elapsed: 16.260117053985596 sec
# average relative error of u: 0.5283274454548401%
# maximum relative error of u: 1.0316095116891137%
#
# Param is 115
# Time elapsed: 16.398091316223145 sec
# average relative error of u: 0.5379946081434829%
# maximum relative error of u: 1.0762433114395022%
#
# Param is 116
# Time elapsed: 15.858901739120483 sec
# average relative error of u: 0.5503705533115152%
# maximum relative error of u: 1.146911652237652%
#
# Param is 117
# Time elapsed: 16.171375036239624 sec
# average relative error of u: 0.5656730485602206%
# maximum relative error of u: 1.2211289151726235%
#
# Param is 118
# Time elapsed: 16.369093894958496 sec
# average relative error of u: 0.5841434479981421%
# maximum relative error of u: 1.2995029280902235%
#
# Param is 119
# Time elapsed: 16.55790424346924 sec
# average relative error of u: 0.6060119981170513%
# maximum relative error of u: 1.3830950735043572%
#
# Param is 120
# Time elapsed: 16.45922589302063 sec
# average relative error of u: 0.6315223611170249%
# maximum relative error of u: 1.4697969388877214%
#
# Param is 121
# Time elapsed: 17.94520354270935 sec
# average relative error of u: 0.6609062656805123%
# maximum relative error of u: 1.5598170146999666%
#
# Param is 122
# Time elapsed: 18.74230122566223 sec
# average relative error of u: 0.6944357954898841%
# maximum relative error of u: 1.6524726013707751%
#
# Param is 123
# Time elapsed: 17.81817078590393 sec
# average relative error of u: 0.732340135948592%
# maximum relative error of u: 1.7478286259406999%
#
# Param is 124
# Time elapsed: 17.52076482772827 sec
# average relative error of u: 0.7748968177161433%
# maximum relative error of u: 1.8457996081734702%
#
# Param is 125
# Time elapsed: 17.985687971115112 sec
# average relative error of u: 0.8223383114655017%
# maximum relative error of u: 1.9461743337095054%
#
# Dim. of latent space is 5
# # of measurments: 12
# [   0    7   14   19   38   42   51 1320 1619 2760 3239 3551]
# Param is 75
# Time elapsed: 18.7551908493042 sec
# average relative error of u: 0.819687816531647%
# maximum relative error of u: 1.7628133310774656%
#
# Param is 76
# Time elapsed: 18.436357021331787 sec
# average relative error of u: 0.7758936964461374%
# maximum relative error of u: 1.6588275518804942%
#
# Param is 77
# Time elapsed: 18.427024364471436 sec
# average relative error of u: 0.7352825364805032%
# maximum relative error of u: 1.5581094843130754%
#
# Param is 78
# Time elapsed: 18.388537645339966 sec
# average relative error of u: 0.6976629193321582%
# maximum relative error of u: 1.461010329120009%
#
# Param is 79
# Time elapsed: 18.35269522666931 sec
# average relative error of u: 0.6628744687493328%
# maximum relative error of u: 1.3679981714691454%
#
# Param is 80
# Time elapsed: 18.170487880706787 sec
# average relative error of u: 0.6307956529629808%
# maximum relative error of u: 1.2790498094017761%
#
# Param is 81
# Time elapsed: 19.018646478652954 sec
# average relative error of u: 0.6013185023439127%
# maximum relative error of u: 1.1947033294153153%
#
# Param is 82
# Time elapsed: 18.592044591903687 sec
# average relative error of u: 0.5743779720641822%
# maximum relative error of u: 1.149857224719208%
#
# Param is 83
# Time elapsed: 18.74541664123535 sec
# average relative error of u: 0.5499094591277351%
# maximum relative error of u: 1.110473438121408%
#
# Param is 84
# Time elapsed: 18.660907983779907 sec
# average relative error of u: 0.5278635103680025%
# maximum relative error of u: 1.0708305463336063%
#
# Param is 85
# Time elapsed: 18.988954067230225 sec
# average relative error of u: 0.5081678781298841%
# maximum relative error of u: 1.0308097225603174%
#
# Param is 86
# Time elapsed: 18.99635624885559 sec
# average relative error of u: 0.49074585718671515%
# maximum relative error of u: 0.990769474269882%
#
# Param is 87
# Time elapsed: 19.145560264587402 sec
# average relative error of u: 0.4754971441389559%
# maximum relative error of u: 0.9508102416459701%
#
# Param is 88
# Time elapsed: 19.14155912399292 sec
# average relative error of u: 0.4622942259120295%
# maximum relative error of u: 0.9111503484737941%
#
# Param is 89
# Time elapsed: 19.347766876220703 sec
# average relative error of u: 0.4509821344242033%
# maximum relative error of u: 0.8717766296817638%
#
# Param is 90
# Time elapsed: 19.07791519165039 sec
# average relative error of u: 0.4413619101834661%
# maximum relative error of u: 0.843024407088271%
#
# Param is 91
# Time elapsed: 18.54868173599243 sec
# average relative error of u: 0.4332285756543387%
# maximum relative error of u: 0.8202174816867972%
#
# Param is 92
# Time elapsed: 18.542152881622314 sec
# average relative error of u: 0.42634380262511207%
# maximum relative error of u: 0.7998296935973261%
#
# Param is 93
# Time elapsed: 16.108013153076172 sec
# average relative error of u: 0.42047302808075293%
# maximum relative error of u: 0.8118912846382051%
#
# Param is 94
# Time elapsed: 14.777331590652466 sec
# average relative error of u: 0.4153561238842747%
# maximum relative error of u: 0.8199976986671289%
#
# Param is 95
# Time elapsed: 14.811488389968872 sec
# average relative error of u: 0.41074932060888997%
# maximum relative error of u: 0.8239604174616943%
#
# Param is 96
# Time elapsed: 13.894566297531128 sec
# average relative error of u: 0.4064294607030152%
# maximum relative error of u: 0.8240322507298737%
#
# Param is 97
# Time elapsed: 15.684253931045532 sec
# average relative error of u: 0.4021713813036355%
# maximum relative error of u: 0.8197953573351471%
#
# Param is 98
# Time elapsed: 15.76608657836914 sec
# average relative error of u: 0.3977801661428378%
# maximum relative error of u: 0.8113676880765133%
#
# Param is 99
# Time elapsed: 14.871624231338501 sec
# average relative error of u: 0.39310119077901423%
# maximum relative error of u: 0.7987510034347791%
#
# Param is 100
# Time elapsed: 16.269713640213013 sec
# average relative error of u: 0.387993181309401%
# maximum relative error of u: 0.7818522351921551%
#
# Param is 101
# Time elapsed: 16.56604552268982 sec
# average relative error of u: 0.3823744046611022%
# maximum relative error of u: 0.7609676035016939%
#
# Param is 102
# Time elapsed: 16.628427505493164 sec
# average relative error of u: 0.3761731639091633%
# maximum relative error of u: 0.736731089940866%
#
# Param is 103
# Time elapsed: 16.3099627494812 sec
# average relative error of u: 0.3693900149196031%
# maximum relative error of u: 0.7243594299571626%
#
# Param is 104
# Time elapsed: 16.962239742279053 sec
# average relative error of u: 0.3620616520413207%
# maximum relative error of u: 0.7088956725853162%
#
# Param is 105
# Time elapsed: 16.111625909805298 sec
# average relative error of u: 0.35429106377636826%
# maximum relative error of u: 0.6905896901028563%
#
# Param is 106
# Time elapsed: 22.273935556411743 sec
# average relative error of u: 0.3462352274714759%
# maximum relative error of u: 0.6693013634445633%
#
# Param is 107
# Time elapsed: 28.799587726593018 sec
# average relative error of u: 0.33814998471279323%
# maximum relative error of u: 0.6449470827095803%
#
# Param is 108
# Time elapsed: 28.693460702896118 sec
# average relative error of u: 0.3303662058342405%
# maximum relative error of u: 0.617994648658956%
#
# Param is 109
# Time elapsed: 30.65467929840088 sec
# average relative error of u: 0.3233169985539852%
# maximum relative error of u: 0.5934371527427098%
#
# Param is 110
# Time elapsed: 30.332715034484863 sec
# average relative error of u: 0.31754866332564596%
# maximum relative error of u: 0.5924121563854525%
#
# Param is 111
# Time elapsed: 29.608611822128296 sec
# average relative error of u: 0.31369434900571086%
# maximum relative error of u: 0.5908145808033098%
#
# Param is 112
# Time elapsed: 31.36000633239746 sec
# average relative error of u: 0.312468147943952%
# maximum relative error of u: 0.5888550872496229%
#
# Param is 113
# Time elapsed: 47.097827434539795 sec
# average relative error of u: 0.31460560036510826%
# maximum relative error of u: 0.6211715038510512%
#
# Param is 114
# Time elapsed: 45.64235186576843 sec
# average relative error of u: 0.3208091171688262%
# maximum relative error of u: 0.6648695288012635%
#
# Param is 115
# Time elapsed: 40.11699199676514 sec
# average relative error of u: 0.33163098309586414%
# maximum relative error of u: 0.713587022220744%
#
# Param is 116
# Time elapsed: 58.11905097961426 sec
# average relative error of u: 0.34749181387323075%
# maximum relative error of u: 0.7670640483076131%
#
# Param is 117
# Time elapsed: 32.706600189208984 sec
# average relative error of u: 0.3685412631907094%
# maximum relative error of u: 0.8249682596259923%
#
# Param is 118
# Time elapsed: 24.216398000717163 sec
# average relative error of u: 0.39480079560124437%
# maximum relative error of u: 0.8869765562258325%
#
# Param is 119
# Time elapsed: 52.005348682403564 sec
# average relative error of u: 0.4261079418037996%
# maximum relative error of u: 0.9529676334379834%
#
# Param is 120
# Time elapsed: 53.50490856170654 sec
# average relative error of u: 0.4622248104134141%
# maximum relative error of u: 1.0228026937323422%
#
# Param is 121
# Time elapsed: 50.40929341316223 sec
# average relative error of u: 0.5028952158157557%
# maximum relative error of u: 1.0958973467149513%
#
# Param is 122
# Time elapsed: 24.443742990493774 sec
# average relative error of u: 0.5478127339055281%
# maximum relative error of u: 1.1725888807748261%
#
# Param is 123
# Time elapsed: 33.16926884651184 sec
# average relative error of u: 0.5967236670327724%
# maximum relative error of u: 1.2644618362376496%
#
# Param is 124
# Time elapsed: 30.243926525115967 sec
# average relative error of u: 0.6494067491499715%
# maximum relative error of u: 1.3674607982969098%
#
# Param is 125
# Time elapsed: 26.61107563972473 sec
# average relative error of u: 0.705641620944817%
# maximum relative error of u: 1.4761172303665433%
#
# Dim. of latent space is 6
# # of measurments: 12
# [   1    6   19   24   36   46  779 1620 1800 3000 3240 3419]
# Param is 75
# Time elapsed: 29.207662343978882 sec
# average relative error of u: 0.65489635647371%
# maximum relative error of u: 1.4074983653638131%
#
# Param is 76
# Time elapsed: 25.332608461380005 sec
# average relative error of u: 0.6182781244373181%
# maximum relative error of u: 1.3654427369899576%
#
# Param is 77
# Time elapsed: 25.2703218460083 sec
# average relative error of u: 0.5866625729961308%
# maximum relative error of u: 1.3245054442134019%
#
# Param is 78
# Time elapsed: 29.217216730117798 sec
# average relative error of u: 0.5597742411771016%
# maximum relative error of u: 1.2846722728674225%
#
# Param is 79
# Time elapsed: 27.28546667098999 sec
# average relative error of u: 0.5372847961195464%
# maximum relative error of u: 1.2460010189537145%
#
# Param is 80
# Time elapsed: 25.25200605392456 sec
# average relative error of u: 0.5187592324833452%
# maximum relative error of u: 1.208089812332775%
#
# Param is 81
# Time elapsed: 28.44622802734375 sec
# average relative error of u: 0.503732331799329%
# maximum relative error of u: 1.1710198551724307%
#
# Param is 82
# Time elapsed: 28.551342010498047 sec
# average relative error of u: 0.49168458542769067%
# maximum relative error of u: 1.1345593797123537%
#
# Param is 83
# Time elapsed: 29.215829849243164 sec
# average relative error of u: 0.48208681251391955%
# maximum relative error of u: 1.098768913009313%
#
# Param is 84
# Time elapsed: 27.31383991241455 sec
# average relative error of u: 0.47443186317338304%
# maximum relative error of u: 1.0636278408457494%
#
# Param is 85
# Time elapsed: 27.63583517074585 sec
# average relative error of u: 0.4682233633440101%
# maximum relative error of u: 1.028795376501086%
#
# Param is 86
# Time elapsed: 27.885528802871704 sec
# average relative error of u: 0.4630506657650837%
# maximum relative error of u: 1.0028758502775752%
#
# Param is 87
# Time elapsed: 28.83910298347473 sec
# average relative error of u: 0.45851686576732065%
# maximum relative error of u: 1.0384274785681504%
#
# Param is 88
# Time elapsed: 29.37306571006775 sec
# average relative error of u: 0.4543488487671761%
# maximum relative error of u: 1.0665163620519824%
#
# Param is 89
# Time elapsed: 30.007118463516235 sec
# average relative error of u: 0.4502864985474151%
# maximum relative error of u: 1.0863766508798753%
#
# Param is 90
# Time elapsed: 28.446212768554688 sec
# average relative error of u: 0.4461562254639769%
# maximum relative error of u: 1.098153101505146%
#
# Param is 91
# Time elapsed: 27.96208143234253 sec
# average relative error of u: 0.44184710969166824%
# maximum relative error of u: 1.1022643038886408%
#
# Param is 92
# Time elapsed: 26.76167106628418 sec
# average relative error of u: 0.4372842652469958%
# maximum relative error of u: 1.1107196664537176%
#
# Param is 93
# Time elapsed: 26.058412313461304 sec
# average relative error of u: 0.43243522074292606%
# maximum relative error of u: 1.1130412128196892%
#
# Param is 94
# Time elapsed: 25.96598720550537 sec
# average relative error of u: 0.4273345148080988%
# maximum relative error of u: 1.1087078704040638%
#
# Param is 95
# Time elapsed: 28.276437759399414 sec
# average relative error of u: 0.4219990526926774%
# maximum relative error of u: 1.097519549348026%
#
# Param is 96
# Time elapsed: 28.237158060073853 sec
# average relative error of u: 0.41652795754483823%
# maximum relative error of u: 1.0806072967490317%
#
# Param is 97
# Time elapsed: 27.826143980026245 sec
# average relative error of u: 0.41098188919908485%
# maximum relative error of u: 1.0577246216815213%
#
# Param is 98
# Time elapsed: 24.323566913604736 sec
# average relative error of u: 0.4054189493463198%
# maximum relative error of u: 1.0290728011997545%
#
# Param is 99
# Time elapsed: 28.976770639419556 sec
# average relative error of u: 0.3999187474753713%
# maximum relative error of u: 0.9959178721921798%
#
# Param is 100
# Time elapsed: 27.794593572616577 sec
# average relative error of u: 0.3945483495420763%
# maximum relative error of u: 0.9640476875667316%
#
# Param is 101
# Time elapsed: 28.729841709136963 sec
# average relative error of u: 0.3892935603974688%
# maximum relative error of u: 0.986743818276193%
#
# Param is 102
# Time elapsed: 28.481417894363403 sec
# average relative error of u: 0.38421199442522275%
# maximum relative error of u: 1.0126695959861027%
#
# Param is 103
# Time elapsed: 25.370227575302124 sec
# average relative error of u: 0.37928203994142196%
# maximum relative error of u: 1.0411772917163864%
#
# Param is 104
# Time elapsed: 27.329655170440674 sec
# average relative error of u: 0.37451827717117997%
# maximum relative error of u: 1.0727272498697742%
#
# Param is 105
# Time elapsed: 27.444159746170044 sec
# average relative error of u: 0.36985641421327425%
# maximum relative error of u: 1.1066846687794527%
#
# Param is 106
# Time elapsed: 28.843957662582397 sec
# average relative error of u: 0.3653424958181766%
# maximum relative error of u: 1.1427497896196717%
#
# Param is 107
# Time elapsed: 28.808743953704834 sec
# average relative error of u: 0.36101427114686946%
# maximum relative error of u: 1.1793897184284212%
#
# Param is 108
# Time elapsed: 28.927814960479736 sec
# average relative error of u: 0.35688590991296953%
# maximum relative error of u: 1.2160663328361254%
#
# Param is 109
# Time elapsed: 30.265462160110474 sec
# average relative error of u: 0.3531151307238283%
# maximum relative error of u: 1.250336376236989%
#
# Param is 110
# Time elapsed: 25.86639165878296 sec
# average relative error of u: 0.3498628113471806%
# maximum relative error of u: 1.2800056697289361%
#
# Param is 111
# Time elapsed: 26.902595043182373 sec
# average relative error of u: 0.3473591556277406%
# maximum relative error of u: 1.3018570549835689%
#
# Param is 112
# Time elapsed: 27.978479623794556 sec
# average relative error of u: 0.34595117288980703%
# maximum relative error of u: 1.3134987990292035%
#
# Param is 113
# Time elapsed: 30.170506954193115 sec
# average relative error of u: 0.34604684306443867%
# maximum relative error of u: 1.3469477971170327%
#
# Param is 114
# Time elapsed: 29.209534406661987 sec
# average relative error of u: 0.3481912017679583%
# maximum relative error of u: 1.383518409560966%
#
# Param is 115
# Time elapsed: 29.5453679561615 sec
# average relative error of u: 0.35299137032517885%
# maximum relative error of u: 1.406059904362844%
#
# Param is 116
# Time elapsed: 27.319988250732422 sec
# average relative error of u: 0.36119916743636443%
# maximum relative error of u: 1.4098418002104913%
#
# Param is 117
# Time elapsed: 26.35418391227722 sec
# average relative error of u: 0.37357962359525065%
# maximum relative error of u: 1.389477072606181%
#
# Param is 118
# Time elapsed: 27.833223342895508 sec
# average relative error of u: 0.39094717956049146%
# maximum relative error of u: 1.3381149563808956%
#
# Param is 119
# Time elapsed: 27.86728000640869 sec
# average relative error of u: 0.4140665020755845%
# maximum relative error of u: 1.2509269444212463%
#
# Param is 120
# Time elapsed: 25.371546030044556 sec
# average relative error of u: 0.4436108683703347%
# maximum relative error of u: 1.216357326878796%
#
# Param is 121
# Time elapsed: 27.799987316131592 sec
# average relative error of u: 0.4799584407272281%
# maximum relative error of u: 1.3345305858655419%
#
# Param is 122
# Time elapsed: 23.995726108551025 sec
# average relative error of u: 0.523256573617892%
# maximum relative error of u: 1.4618594348572287%
#
# Param is 123
# Time elapsed: 24.59940218925476 sec
# average relative error of u: 0.5733594001400939%
# maximum relative error of u: 1.5987423005374073%
#
# Param is 124
# Time elapsed: 29.083373069763184 sec
# average relative error of u: 0.6299134304944096%
# maximum relative error of u: 1.7445879985215584%
#
# Param is 125
# Time elapsed: 29.32793378829956 sec
# average relative error of u: 0.6925853120101342%
# maximum relative error of u: 1.898780625928626%

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

idx=[0,1,2,3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_AE_bndry_SOPT_avg_rel_err_seed_{}.png".format(seed))

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_AE_bndry_SOPT_max_rel_err_seed_{}.png".format(seed))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# idx=[0,1,2,3]
idx = [3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
plt.show()

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
plt.show()

# %%
print(f_list)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=3; j=-1        
f=f_list[i]
param=FOM_parameters[j]

u_gappyAE=results['solution'][i,j]

ex = np.load('./wave_data/ex23_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("Latent Dim: {}, Param: {}".format(f,param))
plt.show()

# error
u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                 /np.linalg.norm(u_full,ord=2,axis=1)*100
u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
             /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
print("average relative error of u: {}%".format(u_avg_rel_err))
print()
print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
    
# plot original data
vmin=-1; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy AE @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_AE_{}_param_{}_bndry_SOPT_SOL_seed_{}.png".format(f,param,seed))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_param_{}_ground_truth.png".format(param))
# Out:
# average relative error of u: 0.6925853120101342%
#
# maximum relative error of u: 1.898780625928626%

# %%
i=3; j=-1
f=f_list[i]; param=FOM_parameters[j]
print("f={}".format(f))
print("param={}".format(param))
plt.plot(results['reduced'][i,j][:,:f])
plt.legend(np.arange(f))
plt.show()
# Out:
# f=6
# param=125
