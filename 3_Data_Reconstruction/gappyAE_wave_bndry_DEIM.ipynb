# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle
import torch
import torch.nn as nn

# %%
# Given parameters
nx = 60
ny = 60
tf = 5.0
dt = 1.0e-2
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims = (ny,nx)

# latent space dim.
f_list=np.array([3,4,5,6])
print('Latent Sapce Dim. {}'.format(f_list))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_DEIM_result = "./wave_result/ex23_AE_swish_bndry_DEIM_gappy_result_seed_{}.p".format(seed)

# Gauss-Newton params
maxitr=4
tol=1e-8

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# Latent Sapce Dim. [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %%
def DEIM(phi_f, nfeval, unseen=np.array([])):
    
    ninf=np.NINF
    n,m=np.shape(phi_f)
    
    l=0
    u=np.reshape(phi_f[:,l],(n,1))
    r=np.abs(u)
    if len(unseen) >0 :
        r[unseen]=ninf
    p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
    p=p_temp
    U=u
    
    ns=int(np.ceil((nfeval-1)/(m-1)))
    for l in range(1,m):
        u=np.reshape(phi_f[:,l],(n,1))
        for k in range(ns):
            if len(p)==nfeval:
                return p
            c=np.linalg.lstsq(U[p,:],u[p,:],rcond=None)[0]
            r=np.abs(u-U@c)
            r[p]=ninf
            if len(unseen) > 0:
                r[unseen]=ninf
            p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
            p=np.sort(np.append(p,p_temp))
        U=np.concatenate((U,u),axis=1)
         
    return p

# %%
for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))
    
    # file path
    file_name_AE="./wave_model/ex23_AE_{}_swish_seed_{}.p".format(f,seed)
    file_path_residual_SVD="./wave_model/ex23_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)
    
    # DEIM
    with open(file=file_path_residual_SVD, mode='rb') as fff:
        SVD=pickle.load(fff)
    U=SVD['U']; S=SVD['S']
    num_msmt=12
#     plt.semilogy(S)
#     plt.show()
#     print("accuracy = {}".format(np.sum(S[:num_msmt]**2)/np.sum(S**2)*100))
    phi_r=U[:,:num_msmt]
    msmt_idx=DEIM(phi_r,num_msmt,inner_raveled_indicies)
    msmt_idx.sort()

    # precompute
    ZTphi_r=phi_r[msmt_idx]
    ZTphi_r_pinv=np.linalg.pinv(ZTphi_r)
    phi_rZTphi_r_pinv=phi_r.dot(ZTphi_r_pinv)

    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(len(msmt_idx)))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig("./wave_result/ex23_AE_{}_swish_bndry_DEIM_{}_samples_seed_{}.png".format(f,num_msmt,seed))
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [   0    9   19   41   46   59  840 1680 1859 2100 3583 3599]
# Dim. of latent space is 4
# # of measurments: 12
# [   0   14   24   42   53  420  899 1800 2940 3480 3580 3598]
# Dim. of latent space is 5
# # of measurments: 12
# [   0    7   14   18   49   53 1440 2760 2999 3539 3551 3579]
# Dim. of latent space is 6
# # of measurments: 12
# [   1    6   21   29 1080 2040 2460 2880 2999 3240 3552 3599]

# %% [markdown]
# # gappyAE

# %%
solution=np.zeros((len(f_list),len(FOM_parameters),nt+1,nx*ny))
reduced=np.zeros((len(f_list),len(FOM_parameters),nt+1,f_list[-1]))
avg_rel_err=np.zeros((len(f_list),len(FOM_parameters)))
rel_err=np.zeros((len(f_list),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(f_list),len(FOM_parameters)))

for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))
    
    # file path
    file_name_AE="./wave_model/ex23_AE_{}_swish_seed_{}.p".format(f,seed)
    file_path_residual_SVD="./wave_model/ex23_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)
    
    # DEIM
    with open(file=file_path_residual_SVD, mode='rb') as fff:
        SVD=pickle.load(fff)
    U=SVD['U']; S=SVD['S']
    num_msmt=12
#     plt.semilogy(S)
#     plt.show()
#     print("accuracy = {}".format(np.sum(S[:num_msmt]**2)/np.sum(S**2)*100))
    phi_r=U[:,:num_msmt]
    msmt_idx=DEIM(phi_r,num_msmt,inner_raveled_indicies)
    msmt_idx.sort()

    # precompute
    ZTphi_r=phi_r[msmt_idx]
    ZTphi_r_pinv=np.linalg.pinv(ZTphi_r)
    phi_rZTphi_r_pinv=phi_r.dot(ZTphi_r_pinv)

    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(len(msmt_idx)))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
    
    with open(file=file_name_AE, mode='rb') as ff:    
        AE = pickle.load(ff)

    en_wu1=AE['en_wu1']
    en_bu1=AE['en_bu1']
    en_wu2=AE['en_wu2']
    de_wu1=AE['de_wu1']
    de_bu1=AE['de_bu1']
    de_wu2=AE['de_wu2']
    de_wu1T=AE['de_wu1T']
    de_wu2T=AE['de_wu2T']
    de_wu2_sp=AE['de_wu2_sp']
    de_wu2T_sp=AE['de_wu2T_sp']
    u_ref=AE['u_ref']

    latent_dim=de_wu1.shape[1]
    
    # numpy version of AE
    def sigmoid_np(input):
        return (1.0/(1.0+np.exp(-input))).astype('float32')

    def encoder_u_np_forward(x):
        z1 = en_wu1.dot(x) + en_bu1
        a1 = z1 * sigmoid_np(z1)
        y = en_wu2.dot(a1)   
        return y

    def decoder_u_np_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = de_wu2.dot(a1)  
        return y

    def decoder_u_sp_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(de_wu2_sp,a1)
        return y

    def decoder_u_np_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = de_wu2.dot(a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(de_wu2T)   
        return y,dydxT

    def decoder_u_sp_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(de_wu2_sp,a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,de_wu2T_sp)
        return y,dydxT
    
    m,M2=de_wu2.shape

    class Decoder_U_FC(nn.Module):

        def __init__(self,):
            super(Decoder_U_FC, self).__init__()
            self.fc1 = nn.Linear(latent_dim,M2)
            self.fc1.weight = nn.Parameter(torch.ones(de_wu1.shape))
            self.fc1.bias = nn.Parameter(torch.ones(de_bu1.shape))
    #         self.fc1.weight = nn.Parameter(torch.tensor(de_wu1))
    #         self.fc1.bias = nn.Parameter(torch.tensor(de_bu1))

            self.fc2 = nn.Linear(M2,m,bias=False)
            self.fc2.weight = nn.Parameter(torch.ones(de_wu2.shape))
    #         self.fc2.weight = nn.Parameter(torch.tensor(de_wu2))

        def forward(self, x):
            x = self.fc1(x)
            x = self.fc2(x)
            return x

    model = Decoder_U_FC()

    x_in=torch.ones(latent_dim)
    y_out=model(x_in)

    p_hr=msmt_idx

    upstream=torch.zeros_like(y_out)
    upstream[p_hr]=1.0

    y_out.backward(upstream)

    # masks for subnet
    wu1_mask=model.fc1.weight.grad
    wu2_mask=model.fc2.weight.grad

    bu1_mask=model.fc1.bias.grad

    # subnet sparse weight
    idx1=wu1_mask.to_sparse()._indices()
    i1=idx1.numpy()[0]
    j1=idx1.numpy()[1]
    v1=de_wu1[i1,j1]
    wu1_sb_sp=sp.csr_matrix(sp.csr_matrix((v1,(i1,j1)),shape=wu1_mask.shape).toarray())

    idx2=wu2_mask.to_sparse()._indices()
    i2=idx2.numpy()[0]
    j2=idx2.numpy()[1]
    v2=de_wu2[i2,j2]
    wu2_sb_sp=sp.csr_matrix(sp.csr_matrix((v2,(i2,j2)),shape=wu2_mask.shape).toarray())

    # subnet compressed weight
    i1,j1,v1=sp.find(wu1_sb_sp)
    i1_unique,i1_inverse=np.unique(i1,return_inverse=True)
    i1_comp=np.arange(i1_unique.size)
    i1_comp=i1_comp[i1_inverse]
    j1_unique,j1_inverse=np.unique(j1,return_inverse=True)
    j1_comp=np.arange(j1_unique.size)
    j1_comp=j1_comp[j1_inverse]
    wu1_sb_comp_sp=sp.csr_matrix((v1,(i1_comp,j1_comp)),shape=(i1_unique.size,j1_unique.size))

    i2,j2,v2=sp.find(wu2_sb_sp)
    i2_unique,i2_inverse=np.unique(i2,return_inverse=True)
    i2_comp=np.arange(i2_unique.size)
    i2_comp=i2_comp[i2_inverse]
    j2_unique,j2_inverse=np.unique(j2,return_inverse=True)
    j2_comp=np.arange(j2_unique.size)
    j2_comp=j2_comp[j2_inverse]
    wu2_sb_comp_sp=sp.csr_matrix((v2,(i2_comp,j2_comp)),shape=(i2_unique.size,j2_unique.size))

    wu1_sb_comp_dense=wu1_sb_comp_sp.toarray()
    wu1_sb_comp_dense=wu1_sb_comp_dense[j2_unique]
    wu2_sb_comp_dense=wu2_sb_comp_sp.toarray()

    wu1_sb_comp_denseT=wu1_sb_comp_dense.T
    wu2_sb_comp_denseT=wu2_sb_comp_dense.T

    # subnet compressed bias
    bu1_sb_comp_dense=de_bu1[i1_unique]
    bu1_sb_comp_dense=bu1_sb_comp_dense[j2_unique]

    # Using sparse matrix
    wu2_sb_comp_sp=sp.csr_matrix(wu2_sb_comp_dense,dtype='float32')
    wu2_sb_comp_spT=sp.csr_matrix(wu2_sb_comp_denseT,dtype='float32')

    def decoder_u_sb_np_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = wu2_sb_comp_dense.dot(a1)  
        return y

    def decoder_u_sb_np_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = wu2_sb_comp_dense.dot(a1) 

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(wu2_sb_comp_denseT)
        return y,dydxT

    def decoder_u_sb_sp_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)
        return y

    def decoder_u_sb_sp_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,wu2_sb_comp_spT)
        return y,dydxT

    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('./wave_data/ex23_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1).astype('float32')

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_hat0=encoder_u_np_forward(u0.astype('float32')-u_ref)

        # gappyAE
        t_start_gappyAE=time.time()

        # solution
        u_reduced=np.zeros((nt+1,latent_dim))
        u_gappyAE=np.zeros((nt+1,ny*nx))

        # IC
        u_reduced[0]=np.copy(u_hat0)
        u_gappyAE[0]=np.copy(u0)

        for k in range(nt):
#             print("")
#             print(k,"th time step:")

            u_hatw=np.copy(u_reduced[k])

            umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

            umw += u_ref[msmt_idx]

            J_r=-Jg_umT.T
            J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

            r_um_hat = um[k+1]-umw

            res = np.linalg.norm(J_pinv.dot(r_um_hat))
#             res = np.linalg.norm(r_um_hat)
            res_hist=[res]
            for itr in range(maxitr):
                du_hatw = J_pinv.dot(r_um_hat)

                u_hatw -= du_hatw

                umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

                umw += u_ref[msmt_idx]

                J_r=-Jg_umT.T
                J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

                r_um_hat = um[k+1]-umw

                res = np.linalg.norm(J_pinv.dot(r_um_hat))
#                 res = np.linalg.norm(r_um_hat)
                res_hist.append(res)
#                 print(itr,"th Newton iteration", "res:", "{:.8e}".format(res))

                if res<tol:
                    break

            u_reduced[k+1]=u_hatw.copy()
            u_gappyAE[k+1]=u_ref+decoder_u_sp_forward(u_reduced[k+1])

        # elapsed time    
        t_elapsed_gappyAE=time.time()-t_start_gappyAE
        print('Time elapsed: {} sec'.format(t_elapsed_gappyAE))

        # error
        u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                         /np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
                     /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
        print()

        # save result
        solution[ii,jj]=u_gappyAE
        reduced[ii,jj,:,:f]=u_reduced
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyAE
        elapsed_time[ii,jj]=t_elapsed_gappyAE
    
results={'solution':solution,'reduced':reduced,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_DEIM_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [   0    9   19   41   46   59  840 1680 1859 2100 3583 3599]
# Param is 75
# Time elapsed: 15.002772092819214 sec
# average relative error of u: 1.3629687090227074%
# maximum relative error of u: 2.126158656212608%
#
# Param is 76
# Time elapsed: 15.493497610092163 sec
# average relative error of u: 1.2963003066748702%
# maximum relative error of u: 2.0266932636730863%
#
# Param is 77
# Time elapsed: 15.862072229385376 sec
# average relative error of u: 1.2353189664061537%
# maximum relative error of u: 1.9329909267178689%
#
# Param is 78
# Time elapsed: 15.499730348587036 sec
# average relative error of u: 1.1804307340507092%
# maximum relative error of u: 1.8449666570391594%
#
# Param is 79
# Time elapsed: 14.707631587982178 sec
# average relative error of u: 1.1320428608701671%
# maximum relative error of u: 1.762646067169782%
#
# Param is 80
# Time elapsed: 14.345109224319458 sec
# average relative error of u: 1.090546434804572%
# maximum relative error of u: 1.6859761641365627%
#
# Param is 81
# Time elapsed: 14.386831521987915 sec
# average relative error of u: 1.0562842807724955%
# maximum relative error of u: 1.6149167500811004%
#
# Param is 82
# Time elapsed: 14.236284255981445 sec
# average relative error of u: 1.0295142746263815%
# maximum relative error of u: 1.5496033879795887%
#
# Param is 83
# Time elapsed: 13.641939401626587 sec
# average relative error of u: 1.0103791174177266%
# maximum relative error of u: 1.4898881655098524%
#
# Param is 84
# Time elapsed: 13.24018669128418 sec
# average relative error of u: 0.9988707628635298%
# maximum relative error of u: 1.4530604768623188%
#
# Param is 85
# Time elapsed: 14.366263628005981 sec
# average relative error of u: 0.9948369162446331%
# maximum relative error of u: 1.5228653408082449%
#
# Param is 86
# Time elapsed: 15.74615740776062 sec
# average relative error of u: 0.9979586907808152%
# maximum relative error of u: 1.6057273661235%
#
# Param is 87
# Time elapsed: 15.991379022598267 sec
# average relative error of u: 1.0078055132853574%
# maximum relative error of u: 1.699004601677159%
#
# Param is 88
# Time elapsed: 15.667932987213135 sec
# average relative error of u: 1.0238559936870455%
# maximum relative error of u: 1.8094602355140776%
#
# Param is 89
# Time elapsed: 14.868167400360107 sec
# average relative error of u: 1.0455518658639447%
# maximum relative error of u: 1.934831248373161%
#
# Param is 90
# Time elapsed: 13.788691759109497 sec
# average relative error of u: 1.0723417379382325%
# maximum relative error of u: 2.0703432236812644%
#
# Param is 91
# Time elapsed: 14.300461530685425 sec
# average relative error of u: 1.1036979925153734%
# maximum relative error of u: 2.215681707166836%
#
# Param is 92
# Time elapsed: 13.89586329460144 sec
# average relative error of u: 1.13913956664384%
# maximum relative error of u: 2.370564723094885%
#
# Param is 93
# Time elapsed: 15.293004274368286 sec
# average relative error of u: 1.178215275012926%
# maximum relative error of u: 2.534734201760568%
#
# Param is 94
# Time elapsed: 15.866343021392822 sec
# average relative error of u: 1.2205099945263507%
# maximum relative error of u: 2.707902158526029%
#
# Param is 95
# Time elapsed: 16.11256432533264 sec
# average relative error of u: 1.2656457995197925%
# maximum relative error of u: 2.889833176666641%
#
# Param is 96
# Time elapsed: 16.076798677444458 sec
# average relative error of u: 1.3132754526192043%
# maximum relative error of u: 3.0802646243022136%
#
# Param is 97
# Time elapsed: 15.586934566497803 sec
# average relative error of u: 1.3630831865939899%
# maximum relative error of u: 3.2789490873235296%
#
# Param is 98
# Time elapsed: 15.447209596633911 sec
# average relative error of u: 1.4147947303894701%
# maximum relative error of u: 3.4895814302170147%
#
# Param is 99
# Time elapsed: 13.799169778823853 sec
# average relative error of u: 1.4681581956908207%
# maximum relative error of u: 3.7081772630136447%
#
# Param is 100
# Time elapsed: 11.904564619064331 sec
# average relative error of u: 1.522956452080965%
# maximum relative error of u: 3.933895631102216%
#
# Param is 101
# Time elapsed: 11.06649374961853 sec
# average relative error of u: 1.5790102146111589%
# maximum relative error of u: 4.166412183820978%
#
# Param is 102
# Time elapsed: 11.685362100601196 sec
# average relative error of u: 1.6361688357519082%
# maximum relative error of u: 4.405362491521333%
#
# Param is 103
# Time elapsed: 14.241518259048462 sec
# average relative error of u: 1.694300025993871%
# maximum relative error of u: 4.650350210891388%
#
# Param is 104
# Time elapsed: 14.293593168258667 sec
# average relative error of u: 1.7533342837125523%
# maximum relative error of u: 4.900945719687758%
#
# Param is 105
# Time elapsed: 15.073033332824707 sec
# average relative error of u: 1.8132069920858167%
# maximum relative error of u: 5.156662331447746%
#
# Param is 106
# Time elapsed: 15.44613242149353 sec
# average relative error of u: 1.87385005257417%
# maximum relative error of u: 5.4169120551290115%
#
# Param is 107
# Time elapsed: 15.271281480789185 sec
# average relative error of u: 1.935584257280019%
# maximum relative error of u: 5.681028752170736%
#
# Param is 108
# Time elapsed: 14.761119604110718 sec
# average relative error of u: 1.999036915096315%
# maximum relative error of u: 5.948157134640245%
#
# Param is 109
# Time elapsed: 15.089454889297485 sec
# average relative error of u: 2.0634429537536283%
# maximum relative error of u: 6.220086003287655%
#
# Param is 110
# Time elapsed: 15.54435110092163 sec
# average relative error of u: 2.1280408857677857%
# maximum relative error of u: 6.5043395803454365%
#
# Param is 111
# Time elapsed: 15.602083921432495 sec
# average relative error of u: 2.1937363436771564%
# maximum relative error of u: 6.793492794089071%
#
# Param is 112
# Time elapsed: 15.626089096069336 sec
# average relative error of u: 2.266627304529709%
# maximum relative error of u: 7.087312216254238%
#
# Param is 113
# Time elapsed: 15.98772144317627 sec
# average relative error of u: 2.3380830330805%
# maximum relative error of u: 7.385560475983893%
#
# Param is 114
# Time elapsed: 15.282106399536133 sec
# average relative error of u: 2.4083058878675145%
# maximum relative error of u: 7.688015347555907%
#
# Param is 115
# Time elapsed: 15.337705850601196 sec
# average relative error of u: 2.487111039467693%
# maximum relative error of u: 7.994467534105368%
#
# Param is 116
# Time elapsed: 15.069474458694458 sec
# average relative error of u: 2.5724475658882606%
# maximum relative error of u: 8.304732836774681%
#
# Param is 117
# Time elapsed: 15.260701894760132 sec
# average relative error of u: 2.6490991501976433%
# maximum relative error of u: 8.618644674256506%
#
# Param is 118
# Time elapsed: 15.211373805999756 sec
# average relative error of u: 2.7423802943264683%
# maximum relative error of u: 8.93606834988447%
#
# Param is 119
# Time elapsed: 15.538617849349976 sec
# average relative error of u: 2.8325811863250148%
# maximum relative error of u: 9.256851085882253%
#
# Param is 120
# Time elapsed: 15.323195934295654 sec
# average relative error of u: 2.923514443139231%
# maximum relative error of u: 9.58085086683548%
#
# Param is 121
# Time elapsed: 15.448108673095703 sec
# average relative error of u: 3.02995665702908%
# maximum relative error of u: 9.907845761710025%
#
# Param is 122
# Time elapsed: 15.084669589996338 sec
# average relative error of u: 3.120584624241335%
# maximum relative error of u: 10.237549712374397%
#
# Param is 123
# Time elapsed: 15.570475339889526 sec
# average relative error of u: 3.2195245100684984%
# maximum relative error of u: 10.569531811283014%
#
# Param is 124
# Time elapsed: 16.240878105163574 sec
# average relative error of u: 3.3436519696081977%
# maximum relative error of u: 10.903275474070078%
#
# Param is 125
# Time elapsed: 16.515886068344116 sec
# average relative error of u: 3.4446348229429233%
# maximum relative error of u: 11.238183743213755%
#
# Dim. of latent space is 4
# # of measurments: 12
# [   0   14   24   42   53  420  899 1800 2940 3480 3580 3598]
# Param is 75
# Time elapsed: 18.10085105895996 sec
# average relative error of u: 0.8619672024330772%
# maximum relative error of u: 1.7588315204715599%
#
# Param is 76
# Time elapsed: 17.232977390289307 sec
# average relative error of u: 0.8295324549668198%
# maximum relative error of u: 1.6991571498138833%
#
# Param is 77
# Time elapsed: 17.434105396270752 sec
# average relative error of u: 0.799429966140507%
# maximum relative error of u: 1.6414032051598137%
#
# Param is 78
# Time elapsed: 16.878108263015747 sec
# average relative error of u: 0.7715039802232606%
# maximum relative error of u: 1.5855279086639948%
#
# Param is 79
# Time elapsed: 17.18823552131653 sec
# average relative error of u: 0.7455992082719505%
# maximum relative error of u: 1.5313928806346597%
#
# Param is 80
# Time elapsed: 17.240469932556152 sec
# average relative error of u: 0.7215637833671275%
# maximum relative error of u: 1.4789225832000874%
#
# Param is 81
# Time elapsed: 16.03306794166565 sec
# average relative error of u: 0.6992586327103935%
# maximum relative error of u: 1.428045429888684%
#
# Param is 82
# Time elapsed: 14.98661184310913 sec
# average relative error of u: 0.678543771644832%
# maximum relative error of u: 1.378691976051663%
#
# Param is 83
# Time elapsed: 16.746662139892578 sec
# average relative error of u: 0.6592935925556865%
# maximum relative error of u: 1.3308168070606632%
#
# Param is 84
# Time elapsed: 17.366771936416626 sec
# average relative error of u: 0.6413880149179868%
# maximum relative error of u: 1.284288602637704%
#
# Param is 85
# Time elapsed: 17.312406301498413 sec
# average relative error of u: 0.6247146034302176%
# maximum relative error of u: 1.239132980132016%
#
# Param is 86
# Time elapsed: 15.518141031265259 sec
# average relative error of u: 0.6091716129791077%
# maximum relative error of u: 1.195215955044605%
#
# Param is 87
# Time elapsed: 15.661177158355713 sec
# average relative error of u: 0.5946639262300534%
# maximum relative error of u: 1.1525814111946948%
#
# Param is 88
# Time elapsed: 15.50217342376709 sec
# average relative error of u: 0.5811023374956816%
# maximum relative error of u: 1.111215213108119%
#
# Param is 89
# Time elapsed: 15.540054321289062 sec
# average relative error of u: 0.5684107527311678%
# maximum relative error of u: 1.0710615699250694%
#
# Param is 90
# Time elapsed: 15.660577297210693 sec
# average relative error of u: 0.5565151774106082%
# maximum relative error of u: 1.0321205716539967%
#
# Param is 91
# Time elapsed: 16.20036029815674 sec
# average relative error of u: 0.5453481678961483%
# maximum relative error of u: 0.9944705493371819%
#
# Param is 92
# Time elapsed: 15.545907735824585 sec
# average relative error of u: 0.5348516886444719%
# maximum relative error of u: 0.9580420251399491%
#
# Param is 93
# Time elapsed: 15.799884557723999 sec
# average relative error of u: 0.5249724580193165%
# maximum relative error of u: 0.9228439073490161%
#
# Param is 94
# Time elapsed: 16.84210467338562 sec
# average relative error of u: 0.5156645403486526%
# maximum relative error of u: 0.8889795448780751%
#
# Param is 95
# Time elapsed: 16.729653120040894 sec
# average relative error of u: 0.5068861081983682%
# maximum relative error of u: 0.8564140639963423%
#
# Param is 96
# Time elapsed: 18.067003965377808 sec
# average relative error of u: 0.49860534923086314%
# maximum relative error of u: 0.8253169646814345%
#
# Param is 97
# Time elapsed: 18.093492031097412 sec
# average relative error of u: 0.4907920051251538%
# maximum relative error of u: 0.7955536268400712%
#
# Param is 98
# Time elapsed: 18.33696937561035 sec
# average relative error of u: 0.4834279621642251%
# maximum relative error of u: 0.7716558692603867%
#
# Param is 99
# Time elapsed: 17.969402074813843 sec
# average relative error of u: 0.47650079084242614%
# maximum relative error of u: 0.7487187969330285%
#
# Param is 100
# Time elapsed: 17.469581604003906 sec
# average relative error of u: 0.4700021036451251%
# maximum relative error of u: 0.7258767974185514%
#
# Param is 101
# Time elapsed: 17.65032935142517 sec
# average relative error of u: 0.4639326759670807%
# maximum relative error of u: 0.703265750868384%
#
# Param is 102
# Time elapsed: 17.293996810913086 sec
# average relative error of u: 0.4583065352641456%
# maximum relative error of u: 0.7046715710065545%
#
# Param is 103
# Time elapsed: 15.66421389579773 sec
# average relative error of u: 0.45313820152983475%
# maximum relative error of u: 0.708442708599103%
#
# Param is 104
# Time elapsed: 15.988269329071045 sec
# average relative error of u: 0.44846094656424407%
# maximum relative error of u: 0.7129772972200357%
#
# Param is 105
# Time elapsed: 17.641271829605103 sec
# average relative error of u: 0.4443142313453108%
# maximum relative error of u: 0.7184263397854083%
#
# Param is 106
# Time elapsed: 17.910815238952637 sec
# average relative error of u: 0.4407515721782977%
# maximum relative error of u: 0.7247610749989534%
#
# Param is 107
# Time elapsed: 18.046460151672363 sec
# average relative error of u: 0.43783998750769754%
# maximum relative error of u: 0.7322649368862092%
#
# Param is 108
# Time elapsed: 18.090765714645386 sec
# average relative error of u: 0.43566368447975345%
# maximum relative error of u: 0.7408865942956838%
#
# Param is 109
# Time elapsed: 17.101276636123657 sec
# average relative error of u: 0.4343177294218432%
# maximum relative error of u: 0.7509136476085797%
#
# Param is 110
# Time elapsed: 17.244937658309937 sec
# average relative error of u: 0.43393207220623187%
# maximum relative error of u: 0.7624241957650455%
#
# Param is 111
# Time elapsed: 18.13581943511963 sec
# average relative error of u: 0.4346398142500675%
# maximum relative error of u: 0.7755339414235244%
#
# Param is 112
# Time elapsed: 18.029603481292725 sec
# average relative error of u: 0.4366079224018932%
# maximum relative error of u: 0.7907010719022611%
#
# Param is 113
# Time elapsed: 15.711335182189941 sec
# average relative error of u: 0.4400202157668782%
# maximum relative error of u: 0.8078445375226493%
#
# Param is 114
# Time elapsed: 15.568747282028198 sec
# average relative error of u: 0.44508605886533087%
# maximum relative error of u: 0.8273915187075237%
#
# Param is 115
# Time elapsed: 18.560944080352783 sec
# average relative error of u: 0.4520357048906736%
# maximum relative error of u: 0.8495413525238823%
#
# Param is 116
# Time elapsed: 18.16404438018799 sec
# average relative error of u: 0.46111355854819325%
# maximum relative error of u: 0.8744806823230367%
#
# Param is 117
# Time elapsed: 17.808651447296143 sec
# average relative error of u: 0.472586305595745%
# maximum relative error of u: 0.9027552117858137%
#
# Param is 118
# Time elapsed: 17.298613786697388 sec
# average relative error of u: 0.4867186511227767%
# maximum relative error of u: 0.934072040153643%
#
# Param is 119
# Time elapsed: 17.363189935684204 sec
# average relative error of u: 0.503792417142341%
# maximum relative error of u: 0.969325295888117%
#
# Param is 120
# Time elapsed: 17.626347064971924 sec
# average relative error of u: 0.5240804595724643%
# maximum relative error of u: 1.0084788660646433%
#
# Param is 121
# Time elapsed: 17.37780451774597 sec
# average relative error of u: 0.5478492202247683%
# maximum relative error of u: 1.0520510765716722%
#
# Param is 122
# Time elapsed: 17.112094402313232 sec
# average relative error of u: 0.5753641979906975%
# maximum relative error of u: 1.1003087628659658%
#
# Param is 123
# Time elapsed: 17.71651530265808 sec
# average relative error of u: 0.6068672341825805%
# maximum relative error of u: 1.1534555053127922%
#
# Param is 124
# Time elapsed: 15.703380346298218 sec
# average relative error of u: 0.6426048527566204%
# maximum relative error of u: 1.2122063766733389%
#
# Param is 125
# Time elapsed: 15.217192649841309 sec
# average relative error of u: 0.6828063498026605%
# maximum relative error of u: 1.2760857223631907%
#
# Dim. of latent space is 5
# # of measurments: 12
# [   0    7   14   18   49   53 1440 2760 2999 3539 3551 3579]
# Param is 75
# Time elapsed: 18.49196171760559 sec
# average relative error of u: 0.8979615349199235%
# maximum relative error of u: 2.4168038930575864%
#
# Param is 76
# Time elapsed: 17.438628673553467 sec
# average relative error of u: 0.8615146252160003%
# maximum relative error of u: 2.3286243767054007%
#
# Param is 77
# Time elapsed: 17.764249086380005 sec
# average relative error of u: 0.8275571322407441%
# maximum relative error of u: 2.2412043557416084%
#
# Param is 78
# Time elapsed: 17.577512502670288 sec
# average relative error of u: 0.7958829578350346%
# maximum relative error of u: 2.1893759175413474%
#
# Param is 79
# Time elapsed: 18.86097526550293 sec
# average relative error of u: 0.7663038736976848%
# maximum relative error of u: 2.1416275355438352%
#
# Param is 80
# Time elapsed: 19.82265043258667 sec
# average relative error of u: 0.7386378411996073%
# maximum relative error of u: 2.0910042592843006%
#
# Param is 81
# Time elapsed: 19.6575825214386 sec
# average relative error of u: 0.7127361123060328%
# maximum relative error of u: 2.037344017113202%
#
# Param is 82
# Time elapsed: 17.56695556640625 sec
# average relative error of u: 0.688479268879939%
# maximum relative error of u: 1.9812325408023812%
#
# Param is 83
# Time elapsed: 17.67040181159973 sec
# average relative error of u: 0.6657278685723569%
# maximum relative error of u: 1.9224074593833296%
#
# Param is 84
# Time elapsed: 17.72469997406006 sec
# average relative error of u: 0.6444133186445955%
# maximum relative error of u: 1.8615957730716857%
#
# Param is 85
# Time elapsed: 17.89378523826599 sec
# average relative error of u: 0.6244532222293552%
# maximum relative error of u: 1.7985978981238597%
#
# Param is 86
# Time elapsed: 18.202365398406982 sec
# average relative error of u: 0.6057760198787228%
# maximum relative error of u: 1.7337148349737568%
#
# Param is 87
# Time elapsed: 18.784685373306274 sec
# average relative error of u: 0.5883255452909903%
# maximum relative error of u: 1.6676764923166567%
#
# Param is 88
# Time elapsed: 18.850208520889282 sec
# average relative error of u: 0.5720533473615993%
# maximum relative error of u: 1.6004174116858905%
#
# Param is 89
# Time elapsed: 19.043405055999756 sec
# average relative error of u: 0.5569152375153666%
# maximum relative error of u: 1.5418838537675748%
#
# Param is 90
# Time elapsed: 18.960299730300903 sec
# average relative error of u: 0.5428423127494333%
# maximum relative error of u: 1.5293902577378706%
#
# Param is 91
# Time elapsed: 18.588200569152832 sec
# average relative error of u: 0.5297782033386916%
# maximum relative error of u: 1.5148927474967673%
#
# Param is 92
# Time elapsed: 18.06381893157959 sec
# average relative error of u: 0.5176831995052426%
# maximum relative error of u: 1.4985752699016122%
#
# Param is 93
# Time elapsed: 19.456830978393555 sec
# average relative error of u: 0.5064782925784275%
# maximum relative error of u: 1.4805160495557226%
#
# Param is 94
# Time elapsed: 19.39674735069275 sec
# average relative error of u: 0.49608576397561516%
# maximum relative error of u: 1.4608345465663375%
#
# Param is 95
# Time elapsed: 16.621814250946045 sec
# average relative error of u: 0.4864391145458667%
# maximum relative error of u: 1.439483602999968%
#
# Param is 96
# Time elapsed: 18.33103656768799 sec
# average relative error of u: 0.47748294978999284%
# maximum relative error of u: 1.4163665762714004%
#
# Param is 97
# Time elapsed: 18.16039776802063 sec
# average relative error of u: 0.4691189013944682%
# maximum relative error of u: 1.3916855684840297%
#
# Param is 98
# Time elapsed: 16.459038257598877 sec
# average relative error of u: 0.46130038885285546%
# maximum relative error of u: 1.3655048493969972%
#
# Param is 99
# Time elapsed: 16.865665912628174 sec
# average relative error of u: 0.45396059177242554%
# maximum relative error of u: 1.338015358342592%
#
# Param is 100
# Time elapsed: 16.97767186164856 sec
# average relative error of u: 0.44704054740027305%
# maximum relative error of u: 1.30953754914209%
#
# Param is 101
# Time elapsed: 16.792609930038452 sec
# average relative error of u: 0.4405071615907246%
# maximum relative error of u: 1.2797628485529633%
#
# Param is 102
# Time elapsed: 17.46878719329834 sec
# average relative error of u: 0.4343434029164887%
# maximum relative error of u: 1.2491864466342641%
#
# Param is 103
# Time elapsed: 20.92855477333069 sec
# average relative error of u: 0.4285336927822961%
# maximum relative error of u: 1.217459781073369%
#
# Param is 104
# Time elapsed: 26.368736267089844 sec
# average relative error of u: 0.4230963637627484%
# maximum relative error of u: 1.1851752635445836%
#
# Param is 105
# Time elapsed: 28.991019248962402 sec
# average relative error of u: 0.418074617105126%
# maximum relative error of u: 1.1523956842364624%
#
# Param is 106
# Time elapsed: 29.66624617576599 sec
# average relative error of u: 0.41354512350214606%
# maximum relative error of u: 1.1194129174582979%
#
# Param is 107
# Time elapsed: 31.42047619819641 sec
# average relative error of u: 0.4095953698549552%
# maximum relative error of u: 1.0857693230018615%
#
# Param is 108
# Time elapsed: 29.213979721069336 sec
# average relative error of u: 0.4063740223262556%
# maximum relative error of u: 1.052703501304811%
#
# Param is 109
# Time elapsed: 32.03523302078247 sec
# average relative error of u: 0.4040366673444441%
# maximum relative error of u: 1.01948765752419%
#
# Param is 110
# Time elapsed: 42.53047227859497 sec
# average relative error of u: 0.40279913343729806%
# maximum relative error of u: 1.0220473455947086%
#
# Param is 111
# Time elapsed: 76.74372720718384 sec
# average relative error of u: 0.40291170085447237%
# maximum relative error of u: 1.0261319642273914%
#
# Param is 112
# Time elapsed: 50.76729464530945 sec
# average relative error of u: 0.40463308479220617%
# maximum relative error of u: 1.0299771867609018%
#
# Param is 113
# Time elapsed: 34.8191237449646 sec
# average relative error of u: 0.40823852290793594%
# maximum relative error of u: 1.0338886628260535%
#
# Param is 114
# Time elapsed: 34.26713490486145 sec
# average relative error of u: 0.41404879805222033%
# maximum relative error of u: 1.0620838796597132%
#
# Param is 115
# Time elapsed: 52.161376953125 sec
# average relative error of u: 0.42235803761238144%
# maximum relative error of u: 1.147547874784631%
#
# Param is 116
# Time elapsed: 67.96156811714172 sec
# average relative error of u: 0.43343250361982755%
# maximum relative error of u: 1.240707195331154%
#
# Param is 117
# Time elapsed: 58.146095275878906 sec
# average relative error of u: 0.44753584065573143%
# maximum relative error of u: 1.3416864707061609%
#
# Param is 118
# Time elapsed: 27.66542935371399 sec
# average relative error of u: 0.4648737235322706%
# maximum relative error of u: 1.4505925482136408%
#
# Param is 119
# Time elapsed: 27.948918104171753 sec
# average relative error of u: 0.48559833267429436%
# maximum relative error of u: 1.5666911993171935%
#
# Param is 120
# Time elapsed: 22.651767253875732 sec
# average relative error of u: 0.5098384155382972%
# maximum relative error of u: 1.6902418834230104%
#
# Param is 121
# Time elapsed: 27.111641883850098 sec
# average relative error of u: 0.5376465257749558%
# maximum relative error of u: 1.8207523661666452%
#
# Param is 122
# Time elapsed: 22.72476840019226 sec
# average relative error of u: 0.569055776276799%
# maximum relative error of u: 1.957924526871622%
#
# Param is 123
# Time elapsed: 23.52884531021118 sec
# average relative error of u: 0.6040592278054433%
# maximum relative error of u: 2.101818469410912%
#
# Param is 124
# Time elapsed: 26.578115940093994 sec
# average relative error of u: 0.6426400562070355%
# maximum relative error of u: 2.2518650738856976%
#
# Param is 125
# Time elapsed: 27.701661586761475 sec
# average relative error of u: 0.6847503502074429%
# maximum relative error of u: 2.4080569898369975%
#
# Dim. of latent space is 6
# # of measurments: 12
# [   1    6   21   29 1080 2040 2460 2880 2999 3240 3552 3599]
# Param is 75
# Time elapsed: 29.83522915840149 sec
# average relative error of u: 0.5829401926718446%
# maximum relative error of u: 1.3817339740144363%
#
# Param is 76
# Time elapsed: 26.452526092529297 sec
# average relative error of u: 0.5580655491535134%
# maximum relative error of u: 1.3264380828414613%
#
# Param is 77
# Time elapsed: 28.47105836868286 sec
# average relative error of u: 0.5356655542498401%
# maximum relative error of u: 1.2782538085137565%
#
# Param is 78
# Time elapsed: 26.55760431289673 sec
# average relative error of u: 0.5154845123639776%
# maximum relative error of u: 1.2322464123515322%
#
# Param is 79
# Time elapsed: 26.867331981658936 sec
# average relative error of u: 0.4972950864553063%
# maximum relative error of u: 1.1882681399545043%
#
# Param is 80
# Time elapsed: 26.194312810897827 sec
# average relative error of u: 0.480854138540498%
# maximum relative error of u: 1.146421206507911%
#
# Param is 81
# Time elapsed: 27.715571403503418 sec
# average relative error of u: 0.465964111819234%
# maximum relative error of u: 1.1062990832996622%
#
# Param is 82
# Time elapsed: 27.088686227798462 sec
# average relative error of u: 0.45242026566877247%
# maximum relative error of u: 1.0678185534935016%
#
# Param is 83
# Time elapsed: 27.267164707183838 sec
# average relative error of u: 0.44006073813809743%
# maximum relative error of u: 1.0312137349036457%
#
# Param is 84
# Time elapsed: 27.010205030441284 sec
# average relative error of u: 0.4287357985552449%
# maximum relative error of u: 0.9961636067635997%
#
# Param is 85
# Time elapsed: 30.219754457473755 sec
# average relative error of u: 0.41831727664351737%
# maximum relative error of u: 0.9625536088075626%
#
# Param is 86
# Time elapsed: 29.23309350013733 sec
# average relative error of u: 0.40870794262168203%
# maximum relative error of u: 0.9303471244946644%
#
# Param is 87
# Time elapsed: 27.572213888168335 sec
# average relative error of u: 0.39983640693116207%
# maximum relative error of u: 0.8994904182109041%
#
# Param is 88
# Time elapsed: 25.536015272140503 sec
# average relative error of u: 0.3916482884665311%
# maximum relative error of u: 0.8697570175815443%
#
# Param is 89
# Time elapsed: 26.8912570476532 sec
# average relative error of u: 0.3840977190005629%
# maximum relative error of u: 0.8409444785107714%
#
# Param is 90
# Time elapsed: 26.236713409423828 sec
# average relative error of u: 0.37717079172077567%
# maximum relative error of u: 0.8134946431003374%
#
# Param is 91
# Time elapsed: 27.85057830810547 sec
# average relative error of u: 0.37085755735621045%
# maximum relative error of u: 0.786783596519875%
#
# Param is 92
# Time elapsed: 25.667590141296387 sec
# average relative error of u: 0.36515238152067436%
# maximum relative error of u: 0.7610486836709938%
#
# Param is 93
# Time elapsed: 25.3204243183136 sec
# average relative error of u: 0.36006318477595584%
# maximum relative error of u: 0.735876258432191%
#
# Param is 94
# Time elapsed: 26.235340118408203 sec
# average relative error of u: 0.3555853741033836%
# maximum relative error of u: 0.7205263258147288%
#
# Param is 95
# Time elapsed: 28.074666500091553 sec
# average relative error of u: 0.351721187789795%
# maximum relative error of u: 0.7463517928119656%
#
# Param is 96
# Time elapsed: 30.296018362045288 sec
# average relative error of u: 0.34844921005741886%
# maximum relative error of u: 0.7746934486517546%
#
# Param is 97
# Time elapsed: 29.312466382980347 sec
# average relative error of u: 0.34575637720005736%
# maximum relative error of u: 0.8022336167231714%
#
# Param is 98
# Time elapsed: 28.898153066635132 sec
# average relative error of u: 0.3436008898194203%
# maximum relative error of u: 0.8274803383183031%
#
# Param is 99
# Time elapsed: 27.753883838653564 sec
# average relative error of u: 0.34192982600009364%
# maximum relative error of u: 0.8501078848335175%
#
# Param is 100
# Time elapsed: 25.165595293045044 sec
# average relative error of u: 0.34066246813506007%
# maximum relative error of u: 0.8685333144139168%
#
# Param is 101
# Time elapsed: 26.060638666152954 sec
# average relative error of u: 0.33970388054875367%
# maximum relative error of u: 0.881626597572651%
#
# Param is 102
# Time elapsed: 25.093425273895264 sec
# average relative error of u: 0.3389791301618718%
# maximum relative error of u: 0.8891415665067952%
#
# Param is 103
# Time elapsed: 28.49053978919983 sec
# average relative error of u: 0.3383282754438041%
# maximum relative error of u: 0.8895921041997259%
#
# Param is 104
# Time elapsed: 28.552691221237183 sec
# average relative error of u: 0.33767024009044583%
# maximum relative error of u: 0.8831133095200089%
#
# Param is 105
# Time elapsed: 28.701531648635864 sec
# average relative error of u: 0.3368795407679046%
# maximum relative error of u: 0.8696235201642274%
#
# Param is 106
# Time elapsed: 29.858951330184937 sec
# average relative error of u: 0.33590444760580507%
# maximum relative error of u: 0.8500300588764877%
#
# Param is 107
# Time elapsed: 28.15721821784973 sec
# average relative error of u: 0.3346970291973544%
# maximum relative error of u: 0.8268500312345819%
#
# Param is 108
# Time elapsed: 25.948318243026733 sec
# average relative error of u: 0.33336684957368445%
# maximum relative error of u: 0.8013215753442728%
#
# Param is 109
# Time elapsed: 29.34513831138611 sec
# average relative error of u: 0.3320792761535373%
# maximum relative error of u: 0.7773142480674354%
#
# Param is 110
# Time elapsed: 30.380227088928223 sec
# average relative error of u: 0.3311390123418354%
# maximum relative error of u: 0.8150714481772968%
#
# Param is 111
# Time elapsed: 30.11698007583618 sec
# average relative error of u: 0.3310365692374406%
# maximum relative error of u: 0.8989091633514917%
#
# Param is 112
# Time elapsed: 29.863965034484863 sec
# average relative error of u: 0.33231420556168734%
# maximum relative error of u: 0.9799326945684549%
#
# Param is 113
# Time elapsed: 28.395220279693604 sec
# average relative error of u: 0.33567407427693813%
# maximum relative error of u: 1.0588185098129284%
#
# Param is 114
# Time elapsed: 26.279600620269775 sec
# average relative error of u: 0.3417799201156942%
# maximum relative error of u: 1.1549682685884644%
#
# Param is 115
# Time elapsed: 27.81594181060791 sec
# average relative error of u: 0.3512863860590637%
# maximum relative error of u: 1.24503742743879%
#
# Param is 116
# Time elapsed: 25.79984188079834 sec
# average relative error of u: 0.3647529243251919%
# maximum relative error of u: 1.3226976083195943%
#
# Param is 117
# Time elapsed: 28.069708347320557 sec
# average relative error of u: 0.38256928997692313%
# maximum relative error of u: 1.3812258088888485%
#
# Param is 118
# Time elapsed: 27.671887397766113 sec
# average relative error of u: 0.40497644338131233%
# maximum relative error of u: 1.4100385701590596%
#
# Param is 119
# Time elapsed: 26.832542419433594 sec
# average relative error of u: 0.4320686881542141%
# maximum relative error of u: 1.3939190107745782%
#
# Param is 120
# Time elapsed: 24.59965753555298 sec
# average relative error of u: 0.4639077665294632%
# maximum relative error of u: 1.3378441352880295%
#
# Param is 121
# Time elapsed: 29.37882685661316 sec
# average relative error of u: 0.5004719178096007%
# maximum relative error of u: 1.5049652169944474%
#
# Param is 122
# Time elapsed: 29.33212924003601 sec
# average relative error of u: 0.5417493552305878%
# maximum relative error of u: 1.6870253070442183%
#
# Param is 123
# Time elapsed: 24.220126628875732 sec
# average relative error of u: 0.5877701208874211%
# maximum relative error of u: 1.8961629838345544%
#
# Param is 124
# Time elapsed: 24.032583475112915 sec
# average relative error of u: 0.638446752647055%
# maximum relative error of u: 2.12268439974767%
#
# Param is 125
# Time elapsed: 21.802595853805542 sec
# average relative error of u: 0.6933401633019816%
# maximum relative error of u: 2.367088644667649%

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

idx=[0,1,2,3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_AE_bndry_DEIM_avg_rel_err_seed_{}.png".format(seed))

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_AE_bndry_DEIM_max_rel_err_seed_{}.png".format(seed))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# idx=[0,1,2,3]
idx = [3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
plt.show()

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
plt.show()

# %%
print(f_list)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=3; j=-1        
f=f_list[i]
param=FOM_parameters[j]

u_gappyAE=results['solution'][i,j]

ex = np.load('./wave_data/ex23_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("Latent Dim: {}, Param: {}".format(f,param))
plt.show()

# error
u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                 /np.linalg.norm(u_full,ord=2,axis=1)*100
u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
             /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
print("average relative error of u: {}%".format(u_avg_rel_err))
print()
print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
    
# plot original data
vmin=-1; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy AE @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_AE_{}_param_{}_bndry_DEIM_SOL_seed_{}.png".format(f,param,seed))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_param_{}_ground_truth.png".format(param))
# Out:
# average relative error of u: 0.6933401633019816%
#
# maximum relative error of u: 2.367088644667649%

# %%
i=3; j=-1
f=f_list[i]; param=FOM_parameters[j]
print("f={}".format(f))
print("param={}".format(param))
plt.plot(results['reduced'][i,j][:,:f])
plt.legend(np.arange(f))
plt.show()
# Out:
# f=6
# param=125
