# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle

# %%
# Given parameters
nx = 60
ny = 60
tf = 1.0
dt = 2.0e-3
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims=(nx,ny)

# POD basis
num_basis=np.arange(3,7,1)
print('num_basis {}'.format(num_basis))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_SOPT_result = "../__result/ex16_diffusion/ex16_POD_bndry_SOPT_gappy_result.p"
file_name_SVD="../__model/ex16_diffusion/ex16_SVD.p"

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# num_basis [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %% [markdown]
# # gappyPOD

# %%
# S-OPT
file_path_SOPT="/home/test/pylibROM_docker/pylibROM/tests/model/ex16_POD_bndry_SOPT_oversampling.p"
with open(file=file_path_SOPT, mode='rb') as ff:  
        msmt_idx_list = pickle.load(ff)

# %%
for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    
    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig("../__result/ex16_diffusion/ex16_POD_{}_bndry_SOPT_{}_samples.png".format(POD_basis,num_msmt))
# Out:
# # of measurments: 12
# [  17   35   42  479  659 2159 2219 2279 2339 2520 3577 3578]
# # of measurments: 12
# [  17   23   24   25   42  419  479  659  839 1919 2339 3547]
# # of measurments: 12
# [  11   17   28   29   42   49   50  659 1499 1680 2339 2819]
# # of measurments: 12
# [  10   17   29   42   51  299  659 1559 1740 2339 2879 3565]

# %%
solution=np.zeros((len(num_basis),len(FOM_parameters),nt+1,nx*ny))
avg_rel_err=np.zeros((len(num_basis),len(FOM_parameters)))
rel_err=np.zeros((len(num_basis),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(num_basis),len(FOM_parameters)))

with open(file=file_name_SVD, mode='rb') as ff:  
    SVD = pickle.load(ff)

for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    print("# of POD basis is {}".format(POD_basis))
    
    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.show()
    
    # Basis matrix
    phi_u = SVD['U'][:,:POD_basis]

    phim_u=phi_u[msmt_idx]
    phim_u_pinv=np.linalg.pinv(phim_u)
    
    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('../__data/ex16_diffusion/ex16_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1)

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_ref = u0

        # Gappy POD
        t_start_gappyPOD=time.time()

        # solution
        u_gappyPOD=np.zeros((nt+1,ny*nx))
        u_hat=np.zeros((nt+1,POD_basis))

        # IC
        u_hat0=np.zeros(POD_basis)
        u_gappyPOD[0]=np.copy(u0)

        for n in range(nt):
            u_hat[n+1] = phim_u_pinv.dot(um[n+1]-u_ref[msmt_idx])
            u_gappyPOD[n+1] = u_ref + phi_u.dot(u_hat[n+1])

        # elapsed time
        t_elapsed_gappyPOD=time.time()-t_start_gappyPOD
        print('Time elapsed: {} sec'.format(t_elapsed_gappyPOD))

        # error
        u_rel_err_gappyPOD=np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)/np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyPOD)))
        print()

        # save result
        solution[ii,jj]=u_gappyPOD
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyPOD
        elapsed_time[ii,jj]=t_elapsed_gappyPOD
    
results={'solution':solution,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_SOPT_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# # of POD basis is 3
# # of measurments: 12
# [  17   35   42  479  659 2159 2219 2279 2339 2520 3577 3578]
# Param is 75
# Time elapsed: 1.953453540802002 sec
# average relative error of u: 9.15053193137212%
# maximum relative error of u: 10.627146398115464%
#
# Param is 76
# Time elapsed: 1.8744919300079346 sec
# average relative error of u: 9.18389531105864%
# maximum relative error of u: 10.664930418339495%
#
# Param is 77
# Time elapsed: 1.7322046756744385 sec
# average relative error of u: 9.200543887433632%
# maximum relative error of u: 10.678466943541263%
#
# Param is 78
# Time elapsed: 2.046482801437378 sec
# average relative error of u: 9.200576043119739%
# maximum relative error of u: 10.667094710486154%
#
# Param is 79
# Time elapsed: 1.996161937713623 sec
# average relative error of u: 9.18427149744849%
# maximum relative error of u: 10.630367309927426%
#
# Param is 80
# Time elapsed: 2.17706298828125 sec
# average relative error of u: 9.152230645972907%
# maximum relative error of u: 10.568100304165679%
#
# Param is 81
# Time elapsed: 2.112718105316162 sec
# average relative error of u: 9.105403989797829%
# maximum relative error of u: 10.480467472287025%
#
# Param is 82
# Time elapsed: 2.1263792514801025 sec
# average relative error of u: 9.045031275922728%
# maximum relative error of u: 10.367918509088438%
#
# Param is 83
# Time elapsed: 2.1296563148498535 sec
# average relative error of u: 8.972825598666798%
# maximum relative error of u: 10.231498123301588%
#
# Param is 84
# Time elapsed: 2.041813850402832 sec
# average relative error of u: 8.89104215886452%
# maximum relative error of u: 10.07276248149626%
#
# Param is 85
# Time elapsed: 1.8646674156188965 sec
# average relative error of u: 8.802371092638623%
# maximum relative error of u: 9.893766452388947%
#
# Param is 86
# Time elapsed: 1.8780548572540283 sec
# average relative error of u: 8.71028220176107%
# maximum relative error of u: 9.697694327426557%
#
# Param is 87
# Time elapsed: 1.9896960258483887 sec
# average relative error of u: 8.618767336116482%
# maximum relative error of u: 9.488375573310718%
#
# Param is 88
# Time elapsed: 1.9292702674865723 sec
# average relative error of u: 8.532819410304954%
# maximum relative error of u: 9.336221133265763%
#
# Param is 89
# Time elapsed: 1.6391072273254395 sec
# average relative error of u: 8.457921148659313%
# maximum relative error of u: 9.24829387281283%
#
# Param is 90
# Time elapsed: 1.5247957706451416 sec
# average relative error of u: 8.400569591131667%
# maximum relative error of u: 9.197765449032994%
#
# Param is 91
# Time elapsed: 1.691086769104004 sec
# average relative error of u: 8.367772800076382%
# maximum relative error of u: 9.187728664664474%
#
# Param is 92
# Time elapsed: 1.5423085689544678 sec
# average relative error of u: 8.36707075826402%
# maximum relative error of u: 9.22277997356323%
#
# Param is 93
# Time elapsed: 1.8181560039520264 sec
# average relative error of u: 8.406251482611724%
# maximum relative error of u: 9.307935324968646%
#
# Param is 94
# Time elapsed: 1.672863245010376 sec
# average relative error of u: 8.492900680791355%
# maximum relative error of u: 9.448181724928554%
#
# Param is 95
# Time elapsed: 1.4820823669433594 sec
# average relative error of u: 8.634111810707118%
# maximum relative error of u: 9.648388808358217%
#
# Param is 96
# Time elapsed: 1.305626630783081 sec
# average relative error of u: 8.83592470130114%
# maximum relative error of u: 9.912825292687689%
#
# Param is 97
# Time elapsed: 1.331298828125 sec
# average relative error of u: 9.10299054170438%
# maximum relative error of u: 10.245170554045515%
#
# Param is 98
# Time elapsed: 1.3865923881530762 sec
# average relative error of u: 9.438406333335278%
# maximum relative error of u: 10.648275356902023%
#
# Param is 99
# Time elapsed: 1.525752067565918 sec
# average relative error of u: 9.843574561232453%
# maximum relative error of u: 11.124025173705798%
#
# Param is 100
# Time elapsed: 1.2655160427093506 sec
# average relative error of u: 10.318335309436048%
# maximum relative error of u: 11.673405225731583%
#
# Param is 101
# Time elapsed: 1.9284734725952148 sec
# average relative error of u: 10.86112717795845%
# maximum relative error of u: 12.296280051364041%
#
# Param is 102
# Time elapsed: 2.0622382164001465 sec
# average relative error of u: 11.469291676785485%
# maximum relative error of u: 12.991716937981357%
#
# Param is 103
# Time elapsed: 2.0628294944763184 sec
# average relative error of u: 12.139398931318661%
# maximum relative error of u: 13.757926266783219%
#
# Param is 104
# Time elapsed: 1.9471461772918701 sec
# average relative error of u: 12.867451421468287%
# maximum relative error of u: 14.592345676468865%
#
# Param is 105
# Time elapsed: 2.0059494972229004 sec
# average relative error of u: 13.649069873717925%
# maximum relative error of u: 15.491789300144266%
#
# Param is 106
# Time elapsed: 1.8563508987426758 sec
# average relative error of u: 14.47972709956063%
# maximum relative error of u: 16.452667580031207%
#
# Param is 107
# Time elapsed: 1.7752537727355957 sec
# average relative error of u: 15.354795762383352%
# maximum relative error of u: 17.470771978131378%
#
# Param is 108
# Time elapsed: 1.6540277004241943 sec
# average relative error of u: 16.269584874199495%
# maximum relative error of u: 18.541665779803793%
#
# Param is 109
# Time elapsed: 2.091768980026245 sec
# average relative error of u: 17.219424880679455%
# maximum relative error of u: 19.660550654436694%
#
# Param is 110
# Time elapsed: 1.6445293426513672 sec
# average relative error of u: 18.199637044514485%
# maximum relative error of u: 20.822428709088722%
#
# Param is 111
# Time elapsed: 1.6054062843322754 sec
# average relative error of u: 19.205677797890853%
# maximum relative error of u: 22.02209163803462%
#
# Param is 112
# Time elapsed: 1.6634366512298584 sec
# average relative error of u: 20.232856294055754%
# maximum relative error of u: 23.254054819483443%
#
# Param is 113
# Time elapsed: 1.9820449352264404 sec
# average relative error of u: 21.27665633690063%
# maximum relative error of u: 24.512823259330574%
#
# Param is 114
# Time elapsed: 2.18285870552063 sec
# average relative error of u: 22.33252230290731%
# maximum relative error of u: 25.79275216685528%
#
# Param is 115
# Time elapsed: 1.912632942199707 sec
# average relative error of u: 23.39596096836184%
# maximum relative error of u: 27.08813625205539%
#
# Param is 116
# Time elapsed: 1.5166747570037842 sec
# average relative error of u: 24.462534328204583%
# maximum relative error of u: 28.393250305682166%
#
# Param is 117
# Time elapsed: 1.7538433074951172 sec
# average relative error of u: 25.527886006842643%
# maximum relative error of u: 29.702391633025982%
#
# Param is 118
# Time elapsed: 1.5246729850769043 sec
# average relative error of u: 26.587744455614427%
# maximum relative error of u: 31.009834312613783%
#
# Param is 119
# Time elapsed: 1.8093833923339844 sec
# average relative error of u: 27.637894565789033%
# maximum relative error of u: 32.310001589182015%
#
# Param is 120
# Time elapsed: 1.9764235019683838 sec
# average relative error of u: 28.674374572793315%
# maximum relative error of u: 33.59752507684882%
#
# Param is 121
# Time elapsed: 2.04339337348938 sec
# average relative error of u: 29.693337329008894%
# maximum relative error of u: 34.867148191634136%
#
# Param is 122
# Time elapsed: 1.9823343753814697 sec
# average relative error of u: 30.691107663239976%
# maximum relative error of u: 36.11384952172988%
#
# Param is 123
# Time elapsed: 2.11820387840271 sec
# average relative error of u: 31.664276081288683%
# maximum relative error of u: 37.332907517086724%
#
# Param is 124
# Time elapsed: 2.3523359298706055 sec
# average relative error of u: 32.60963321365046%
# maximum relative error of u: 38.519829764116245%
#
# Param is 125
# Time elapsed: 2.1464083194732666 sec
# average relative error of u: 33.52436207191238%
# maximum relative error of u: 39.67061490339521%
#
# # of POD basis is 4
# # of measurments: 12
# [  17   23   24   25   42  419  479  659  839 1919 2339 3547]
# Param is 75
# Time elapsed: 2.0828633308410645 sec
# average relative error of u: 10.352356301356807%
# maximum relative error of u: 11.380254992893263%
#
# Param is 76
# Time elapsed: 1.9275133609771729 sec
# average relative error of u: 10.516966275193738%
# maximum relative error of u: 11.550531504079478%
#
# Param is 77
# Time elapsed: 2.1259243488311768 sec
# average relative error of u: 10.670386049560705%
# maximum relative error of u: 11.707378471926363%
#
# Param is 78
# Time elapsed: 1.8929579257965088 sec
# average relative error of u: 10.811901137737678%
# maximum relative error of u: 11.849792119496282%
#
# Param is 79
# Time elapsed: 2.1127431392669678 sec
# average relative error of u: 10.940922372144994%
# maximum relative error of u: 11.976992055851007%
#
# Param is 80
# Time elapsed: 1.8114089965820312 sec
# average relative error of u: 11.056867508945993%
# maximum relative error of u: 12.088156987008993%
#
# Param is 81
# Time elapsed: 1.6900172233581543 sec
# average relative error of u: 11.159258153501451%
# maximum relative error of u: 12.182531951602295%
#
# Param is 82
# Time elapsed: 1.6798741817474365 sec
# average relative error of u: 11.247592233005097%
# maximum relative error of u: 12.259371101854889%
#
# Param is 83
# Time elapsed: 1.804582118988037 sec
# average relative error of u: 11.321498324919414%
# maximum relative error of u: 12.318070884334933%
#
# Param is 84
# Time elapsed: 1.9291248321533203 sec
# average relative error of u: 11.380664106921047%
# maximum relative error of u: 12.358047771999448%
#
# Param is 85
# Time elapsed: 1.9131972789764404 sec
# average relative error of u: 11.424796350543023%
# maximum relative error of u: 12.378769411804006%
#
# Param is 86
# Time elapsed: 1.995288372039795 sec
# average relative error of u: 11.453780515725677%
# maximum relative error of u: 12.379880222828612%
#
# Param is 87
# Time elapsed: 1.8204684257507324 sec
# average relative error of u: 11.467578391560512%
# maximum relative error of u: 12.361173770862823%
#
# Param is 88
# Time elapsed: 2.013115882873535 sec
# average relative error of u: 11.466293778381234%
# maximum relative error of u: 12.322670302647479%
#
# Param is 89
# Time elapsed: 2.1496875286102295 sec
# average relative error of u: 11.450133337697714%
# maximum relative error of u: 12.264527214688284%
#
# Param is 90
# Time elapsed: 2.596806764602661 sec
# average relative error of u: 11.419552419131781%
# maximum relative error of u: 12.187424454835186%
#
# Param is 91
# Time elapsed: 2.2595913410186768 sec
# average relative error of u: 11.375050378141578%
# maximum relative error of u: 12.092468307975581%
#
# Param is 92
# Time elapsed: 2.3526418209075928 sec
# average relative error of u: 11.317460365887538%
# maximum relative error of u: 11.981871088986189%
#
# Param is 93
# Time elapsed: 2.343559741973877 sec
# average relative error of u: 11.247859822630028%
# maximum relative error of u: 11.85994782810042%
#
# Param is 94
# Time elapsed: 2.2032113075256348 sec
# average relative error of u: 11.167551830362225%
# maximum relative error of u: 11.735432730630906%
#
# Param is 95
# Time elapsed: 1.7291288375854492 sec
# average relative error of u: 11.078155248511646%
# maximum relative error of u: 11.623374813684688%
#
# Param is 96
# Time elapsed: 1.894758939743042 sec
# average relative error of u: 10.981739332770111%
# maximum relative error of u: 11.53615154618996%
#
# Param is 97
# Time elapsed: 1.7543809413909912 sec
# average relative error of u: 10.880626170290524%
# maximum relative error of u: 11.474865286020558%
#
# Param is 98
# Time elapsed: 1.790893316268921 sec
# average relative error of u: 10.77772125090495%
# maximum relative error of u: 11.436848344331048%
#
# Param is 99
# Time elapsed: 1.9688353538513184 sec
# average relative error of u: 10.67632314426961%
# maximum relative error of u: 11.419729894400115%
#
# Param is 100
# Time elapsed: 1.9153180122375488 sec
# average relative error of u: 10.580292220794979%
# maximum relative error of u: 11.42190554247386%
#
# Param is 101
# Time elapsed: 1.6403262615203857 sec
# average relative error of u: 10.49398289114617%
# maximum relative error of u: 11.442436503752841%
#
# Param is 102
# Time elapsed: 1.9738409519195557 sec
# average relative error of u: 10.422320493157331%
# maximum relative error of u: 11.480901857394807%
#
# Param is 103
# Time elapsed: 2.1100544929504395 sec
# average relative error of u: 10.370658538182315%
# maximum relative error of u: 11.53725957777602%
#
# Param is 104
# Time elapsed: 2.2991740703582764 sec
# average relative error of u: 10.344657068307445%
# maximum relative error of u: 11.611671362227211%
#
# Param is 105
# Time elapsed: 2.232147693634033 sec
# average relative error of u: 10.350295701268857%
# maximum relative error of u: 11.704714960236101%
#
# Param is 106
# Time elapsed: 2.243623971939087 sec
# average relative error of u: 10.39367729439137%
# maximum relative error of u: 11.81720468423213%
#
# Param is 107
# Time elapsed: 2.2667577266693115 sec
# average relative error of u: 10.48061834736827%
# maximum relative error of u: 11.950457316928635%
#
# Param is 108
# Time elapsed: 2.526638984680176 sec
# average relative error of u: 10.616420525825133%
# maximum relative error of u: 12.10579563024892%
#
# Param is 109
# Time elapsed: 2.751999855041504 sec
# average relative error of u: 10.805824829572083%
# maximum relative error of u: 12.285367513843406%
#
# Param is 110
# Time elapsed: 2.2568092346191406 sec
# average relative error of u: 11.052466613934836%
# maximum relative error of u: 12.491679405068641%
#
# Param is 111
# Time elapsed: 2.019200325012207 sec
# average relative error of u: 11.359010046427326%
# maximum relative error of u: 12.728311853480578%
#
# Param is 112
# Time elapsed: 2.1151978969573975 sec
# average relative error of u: 11.726762614970369%
# maximum relative error of u: 12.999499343734918%
#
# Param is 113
# Time elapsed: 1.959186315536499 sec
# average relative error of u: 12.155976118762732%
# maximum relative error of u: 13.311330956693471%
#
# Param is 114
# Time elapsed: 2.1795501708984375 sec
# average relative error of u: 12.645659098947682%
# maximum relative error of u: 13.67186695325158%
#
# Param is 115
# Time elapsed: 2.301506996154785 sec
# average relative error of u: 13.19389372905729%
# maximum relative error of u: 14.092372129763916%
#
# Param is 116
# Time elapsed: 2.2074685096740723 sec
# average relative error of u: 13.797976401492711%
# maximum relative error of u: 14.589408152960043%
#
# Param is 117
# Time elapsed: 2.574751615524292 sec
# average relative error of u: 14.454672188708145%
# maximum relative error of u: 15.22079171491261%
#
# Param is 118
# Time elapsed: 2.2124269008636475 sec
# average relative error of u: 15.160210414146299%
# maximum relative error of u: 16.193461931252422%
#
# Param is 119
# Time elapsed: 2.023254632949829 sec
# average relative error of u: 15.91050859907738%
# maximum relative error of u: 17.223099902079387%
#
# Param is 120
# Time elapsed: 2.1820623874664307 sec
# average relative error of u: 16.701408758019785%
# maximum relative error of u: 18.30354062596077%
#
# Param is 121
# Time elapsed: 2.0306546688079834 sec
# average relative error of u: 17.528687625918092%
# maximum relative error of u: 19.429147575728752%
#
# Param is 122
# Time elapsed: 2.194105386734009 sec
# average relative error of u: 18.38808616380652%
# maximum relative error of u: 20.594164486755453%
#
# Param is 123
# Time elapsed: 2.048987627029419 sec
# average relative error of u: 19.27542476198181%
# maximum relative error of u: 21.79326761927081%
#
# Param is 124
# Time elapsed: 1.8635594844818115 sec
# average relative error of u: 20.18667522653202%
# maximum relative error of u: 23.021356607433404%
#
# Param is 125
# Time elapsed: 1.827031135559082 sec
# average relative error of u: 21.11790321995018%
# maximum relative error of u: 24.2734956557889%
#
# # of POD basis is 5
# # of measurments: 12
# [  11   17   28   29   42   49   50  659 1499 1680 2339 2819]
# Param is 75
# Time elapsed: 1.851752758026123 sec
# average relative error of u: 15.233512584310224%
# maximum relative error of u: 22.158252098080144%
#
# Param is 76
# Time elapsed: 1.8720240592956543 sec
# average relative error of u: 16.439746370707294%
# maximum relative error of u: 23.395136961238403%
#
# Param is 77
# Time elapsed: 2.300931692123413 sec
# average relative error of u: 17.683809534223688%
# maximum relative error of u: 24.6453803927343%
#
# Param is 78
# Time elapsed: 2.0280961990356445 sec
# average relative error of u: 18.959657344320465%
# maximum relative error of u: 25.905254748119866%
#
# Param is 79
# Time elapsed: 2.020702600479126 sec
# average relative error of u: 20.262087530802646%
# maximum relative error of u: 27.17135261610299%
#
# Param is 80
# Time elapsed: 2.1250672340393066 sec
# average relative error of u: 21.586000082239938%
# maximum relative error of u: 28.43983532925413%
#
# Param is 81
# Time elapsed: 1.9150888919830322 sec
# average relative error of u: 22.92618439729718%
# maximum relative error of u: 29.708000601222768%
#
# Param is 82
# Time elapsed: 1.9760708808898926 sec
# average relative error of u: 24.276969465902493%
# maximum relative error of u: 30.970590566129836%
#
# Param is 83
# Time elapsed: 2.3097119331359863 sec
# average relative error of u: 25.63286128261504%
# maximum relative error of u: 32.223677991518244%
#
# Param is 84
# Time elapsed: 2.534451484680176 sec
# average relative error of u: 26.98859550010006%
# maximum relative error of u: 33.46322442871972%
#
# Param is 85
# Time elapsed: 2.051706314086914 sec
# average relative error of u: 28.337453293678188%
# maximum relative error of u: 34.68427918268775%
#
# Param is 86
# Time elapsed: 1.4240055084228516 sec
# average relative error of u: 29.67351951450904%
# maximum relative error of u: 35.881569632474374%
#
# Param is 87
# Time elapsed: 1.5083796977996826 sec
# average relative error of u: 30.990888603822587%
# maximum relative error of u: 37.050067889603916%
#
# Param is 88
# Time elapsed: 1.5548033714294434 sec
# average relative error of u: 32.281967950107166%
# maximum relative error of u: 38.183711036135485%
#
# Param is 89
# Time elapsed: 1.599118709564209 sec
# average relative error of u: 33.54139635742797%
# maximum relative error of u: 39.278777563077774%
#
# Param is 90
# Time elapsed: 1.910593032836914 sec
# average relative error of u: 34.760422349273945%
# maximum relative error of u: 40.32667512111853%
#
# Param is 91
# Time elapsed: 1.8115489482879639 sec
# average relative error of u: 35.932577388048095%
# maximum relative error of u: 41.322650911006285%
#
# Param is 92
# Time elapsed: 2.112574577331543 sec
# average relative error of u: 37.04963718890934%
# maximum relative error of u: 42.25961740647695%
#
# Param is 93
# Time elapsed: 1.8097877502441406 sec
# average relative error of u: 38.104598379821894%
# maximum relative error of u: 43.131315593950426%
#
# Param is 94
# Time elapsed: 1.6741304397583008 sec
# average relative error of u: 39.08810170637289%
# maximum relative error of u: 43.92989591616619%
#
# Param is 95
# Time elapsed: 1.7381460666656494 sec
# average relative error of u: 39.992803671177505%
# maximum relative error of u: 44.64893989607663%
#
# Param is 96
# Time elapsed: 1.9049043655395508 sec
# average relative error of u: 40.809561534645574%
# maximum relative error of u: 45.27987319430172%
#
# Param is 97
# Time elapsed: 1.9138054847717285 sec
# average relative error of u: 41.52914480535832%
# maximum relative error of u: 45.81541549005184%
#
# Param is 98
# Time elapsed: 2.2209980487823486 sec
# average relative error of u: 42.14319688360803%
# maximum relative error of u: 46.247056620685086%
#
# Param is 99
# Time elapsed: 2.297646999359131 sec
# average relative error of u: 42.64185132507403%
# maximum relative error of u: 46.56667268929786%
#
# Param is 100
# Time elapsed: 2.3100616931915283 sec
# average relative error of u: 43.01615984079689%
# maximum relative error of u: 46.766299185428686%
#
# Param is 101
# Time elapsed: 2.282212018966675 sec
# average relative error of u: 43.25663639222534%
# maximum relative error of u: 46.83756562438223%
#
# Param is 102
# Time elapsed: 2.369257688522339 sec
# average relative error of u: 43.35372934917499%
# maximum relative error of u: 46.77146113962139%
#
# Param is 103
# Time elapsed: 2.466026782989502 sec
# average relative error of u: 43.297857464519986%
# maximum relative error of u: 46.56016440099312%
#
# Param is 104
# Time elapsed: 2.4130046367645264 sec
# average relative error of u: 43.07977041069067%
# maximum relative error of u: 46.19689710445405%
#
# Param is 105
# Time elapsed: 2.33933424949646 sec
# average relative error of u: 42.69009578572473%
# maximum relative error of u: 45.67448429949417%
#
# Param is 106
# Time elapsed: 2.632755756378174 sec
# average relative error of u: 42.120394305808%
# maximum relative error of u: 44.987309839333854%
#
# Param is 107
# Time elapsed: 2.5429024696350098 sec
# average relative error of u: 41.36195516398996%
# maximum relative error of u: 44.131685798149604%
#
# Param is 108
# Time elapsed: 2.737818717956543 sec
# average relative error of u: 40.40724569423639%
# maximum relative error of u: 43.10598233031971%
#
# Param is 109
# Time elapsed: 2.558143377304077 sec
# average relative error of u: 39.24870365685021%
# maximum relative error of u: 41.909467129864275%
#
# Param is 110
# Time elapsed: 2.5597245693206787 sec
# average relative error of u: 37.88077422296941%
# maximum relative error of u: 40.546665491243985%
#
# Param is 111
# Time elapsed: 2.156684637069702 sec
# average relative error of u: 36.29893089309302%
# maximum relative error of u: 39.023078285638434%
#
# Param is 112
# Time elapsed: 1.7340493202209473 sec
# average relative error of u: 34.49985105870206%
# maximum relative error of u: 37.347438066590954%
#
# Param is 113
# Time elapsed: 1.7098007202148438 sec
# average relative error of u: 32.48303228205345%
# maximum relative error of u: 35.53063150161928%
#
# Param is 114
# Time elapsed: 1.7924230098724365 sec
# average relative error of u: 30.252523352862948%
# maximum relative error of u: 33.58813319040445%
#
# Param is 115
# Time elapsed: 1.9685750007629395 sec
# average relative error of u: 27.815663272784814%
# maximum relative error of u: 31.53476062213819%
#
# Param is 116
# Time elapsed: 1.7471487522125244 sec
# average relative error of u: 25.189832058198498%
# maximum relative error of u: 29.389959081728005%
#
# Param is 117
# Time elapsed: 1.8179223537445068 sec
# average relative error of u: 22.40527673692209%
# maximum relative error of u: 27.172209567825593%
#
# Param is 118
# Time elapsed: 1.740257740020752 sec
# average relative error of u: 19.518596483296363%
# maximum relative error of u: 24.904117532180354%
#
# Param is 119
# Time elapsed: 1.7590115070343018 sec
# average relative error of u: 16.6352640763529%
# maximum relative error of u: 22.610411731299294%
#
# Param is 120
# Time elapsed: 1.669203758239746 sec
# average relative error of u: 13.963307091812949%
# maximum relative error of u: 20.31498066054488%
#
# Param is 121
# Time elapsed: 1.8617231845855713 sec
# average relative error of u: 11.906781409528888%
# maximum relative error of u: 18.049839837098318%
#
# Param is 122
# Time elapsed: 2.083261489868164 sec
# average relative error of u: 11.111679749686742%
# maximum relative error of u: 15.848841124634456%
#
# Param is 123
# Time elapsed: 2.198899745941162 sec
# average relative error of u: 12.109385216845027%
# maximum relative error of u: 13.755823950923526%
#
# Param is 124
# Time elapsed: 2.2277326583862305 sec
# average relative error of u: 14.765161719075968%
# maximum relative error of u: 18.34126642709066%
#
# Param is 125
# Time elapsed: 2.286292314529419 sec
# average relative error of u: 18.557279026315804%
# maximum relative error of u: 23.964078135611924%
#
# # of POD basis is 6
# # of measurments: 12
# [  10   17   29   42   51  299  659 1559 1740 2339 2879 3565]
# Param is 75
# Time elapsed: 1.959651231765747 sec
# average relative error of u: 7.567812024696124%
# maximum relative error of u: 12.100859621927237%
#
# Param is 76
# Time elapsed: 2.014011859893799 sec
# average relative error of u: 7.8173419800850255%
# maximum relative error of u: 12.652706547994159%
#
# Param is 77
# Time elapsed: 1.783097267150879 sec
# average relative error of u: 8.139720818784376%
# maximum relative error of u: 13.204167278738064%
#
# Param is 78
# Time elapsed: 2.3169403076171875 sec
# average relative error of u: 8.530930330688124%
# maximum relative error of u: 13.753240658095233%
#
# Param is 79
# Time elapsed: 2.2666592597961426 sec
# average relative error of u: 8.98474314298182%
# maximum relative error of u: 14.296107433542529%
#
# Param is 80
# Time elapsed: 2.281723737716675 sec
# average relative error of u: 9.493357903022098%
# maximum relative error of u: 14.83065214628577%
#
# Param is 81
# Time elapsed: 1.8882067203521729 sec
# average relative error of u: 10.047886594167%
# maximum relative error of u: 15.352985418267131%
#
# Param is 82
# Time elapsed: 1.5547337532043457 sec
# average relative error of u: 10.639074722259044%
# maximum relative error of u: 15.86060190164171%
#
# Param is 83
# Time elapsed: 2.0791964530944824 sec
# average relative error of u: 11.258025734961054%
# maximum relative error of u: 16.34952391844648%
#
# Param is 84
# Time elapsed: 2.151362180709839 sec
# average relative error of u: 11.894095395579026%
# maximum relative error of u: 16.816387507062817%
#
# Param is 85
# Time elapsed: 2.115109443664551 sec
# average relative error of u: 12.53792033466786%
# maximum relative error of u: 17.25620219703649%
#
# Param is 86
# Time elapsed: 1.996006965637207 sec
# average relative error of u: 13.180620385199884%
# maximum relative error of u: 17.666311948309392%
#
# Param is 87
# Time elapsed: 1.9880197048187256 sec
# average relative error of u: 13.812732545179296%
# maximum relative error of u: 18.042216817567887%
#
# Param is 88
# Time elapsed: 1.9684414863586426 sec
# average relative error of u: 14.42459546450006%
# maximum relative error of u: 18.380008730398785%
#
# Param is 89
# Time elapsed: 2.098390817642212 sec
# average relative error of u: 15.007550793141505%
# maximum relative error of u: 18.675637822075895%
#
# Param is 90
# Time elapsed: 2.0234413146972656 sec
# average relative error of u: 15.551647712954008%
# maximum relative error of u: 18.924827389693057%
#
# Param is 91
# Time elapsed: 2.0890016555786133 sec
# average relative error of u: 16.047612682060823%
# maximum relative error of u: 19.1237525066625%
#
# Param is 92
# Time elapsed: 2.0707755088806152 sec
# average relative error of u: 16.486280124691394%
# maximum relative error of u: 19.26958452405447%
#
# Param is 93
# Time elapsed: 2.1281988620758057 sec
# average relative error of u: 16.858104449996272%
# maximum relative error of u: 19.360259165759857%
#
# Param is 94
# Time elapsed: 2.088714361190796 sec
# average relative error of u: 17.152770977194457%
# maximum relative error of u: 19.394924273707197%
#
# Param is 95
# Time elapsed: 2.2183914184570312 sec
# average relative error of u: 17.360958473121137%
# maximum relative error of u: 19.37633665218836%
#
# Param is 96
# Time elapsed: 2.1427011489868164 sec
# average relative error of u: 17.472547347910968%
# maximum relative error of u: 19.31008365274932%
#
# Param is 97
# Time elapsed: 2.0911152362823486 sec
# average relative error of u: 17.477625695104628%
# maximum relative error of u: 19.208611982327504%
#
# Param is 98
# Time elapsed: 1.7714698314666748 sec
# average relative error of u: 17.365790852000227%
# maximum relative error of u: 19.08167154478074%
#
# Param is 99
# Time elapsed: 1.716827630996704 sec
# average relative error of u: 17.127488926029226%
# maximum relative error of u: 18.922692505342145%
#
# Param is 100
# Time elapsed: 1.7482593059539795 sec
# average relative error of u: 16.75278642155888%
# maximum relative error of u: 18.7044597843316%
#
# Param is 101
# Time elapsed: 1.5242221355438232 sec
# average relative error of u: 16.231900547925296%
# maximum relative error of u: 18.39017889662505%
#
# Param is 102
# Time elapsed: 1.6865224838256836 sec
# average relative error of u: 15.555785811199623%
# maximum relative error of u: 17.94576075650706%
#
# Param is 103
# Time elapsed: 1.9287104606628418 sec
# average relative error of u: 14.715799242136146%
# maximum relative error of u: 17.33962915129545%
#
# Param is 104
# Time elapsed: 2.1667613983154297 sec
# average relative error of u: 13.706072284356601%
# maximum relative error of u: 16.547162574879025%
#
# Param is 105
# Time elapsed: 2.17790150642395 sec
# average relative error of u: 12.520961383609158%
# maximum relative error of u: 15.54457940594103%
#
# Param is 106
# Time elapsed: 2.3336544036865234 sec
# average relative error of u: 11.161955638305505%
# maximum relative error of u: 14.313495412141922%
#
# Param is 107
# Time elapsed: 2.368549108505249 sec
# average relative error of u: 9.639454810387525%
# maximum relative error of u: 12.84096097485852%
#
# Param is 108
# Time elapsed: 2.2758195400238037 sec
# average relative error of u: 7.986065326144802%
# maximum relative error of u: 11.121324269833144%
#
# Param is 109
# Time elapsed: 2.218620777130127 sec
# average relative error of u: 6.295270793637392%
# maximum relative error of u: 9.166698297985976%
#
# Param is 110
# Time elapsed: 2.186938524246216 sec
# average relative error of u: 4.838951154573687%
# maximum relative error of u: 7.040736794176235%
#
# Param is 111
# Time elapsed: 2.229710578918457 sec
# average relative error of u: 4.306885797404598%
# maximum relative error of u: 4.981343338165049%
#
# Param is 112
# Time elapsed: 2.2340071201324463 sec
# average relative error of u: 5.38217632493446%
# maximum relative error of u: 7.306787590296001%
#
# Param is 113
# Time elapsed: 2.266874313354492 sec
# average relative error of u: 7.689298770098256%
# maximum relative error of u: 10.212105558007591%
#
# Param is 114
# Time elapsed: 2.1125032901763916 sec
# average relative error of u: 10.676950732844578%
# maximum relative error of u: 13.502856886739433%
#
# Param is 115
# Time elapsed: 1.8503177165985107 sec
# average relative error of u: 14.108642554259687%
# maximum relative error of u: 17.138793130338183%
#
# Param is 116
# Time elapsed: 1.8781275749206543 sec
# average relative error of u: 17.896138764585327%
# maximum relative error of u: 21.109295535733672%
#
# Param is 117
# Time elapsed: 2.0543100833892822 sec
# average relative error of u: 22.001417543664235%
# maximum relative error of u: 25.413922223987313%
#
# Param is 118
# Time elapsed: 2.0069854259490967 sec
# average relative error of u: 26.404872996941524%
# maximum relative error of u: 30.059067004444103%
#
# Param is 119
# Time elapsed: 1.8720111846923828 sec
# average relative error of u: 31.09502681836914%
# maximum relative error of u: 35.05277359516391%
#
# Param is 120
# Time elapsed: 1.855677843093872 sec
# average relative error of u: 36.06307952097204%
# maximum relative error of u: 40.40668023313953%
#
# Param is 121
# Time elapsed: 1.941258192062378 sec
# average relative error of u: 41.299850396901796%
# maximum relative error of u: 46.1310684524251%
#
# Param is 122
# Time elapsed: 1.9066393375396729 sec
# average relative error of u: 46.797495630611735%
# maximum relative error of u: 52.241601049969866%
#
# Param is 123
# Time elapsed: 1.8318116664886475 sec
# average relative error of u: 52.54801270549353%
# maximum relative error of u: 58.758748139928464%
#
# Param is 124
# Time elapsed: 1.8783223628997803 sec
# average relative error of u: 58.54078223300863%
# maximum relative error of u: 66.23527413219067%
#
# Param is 125
# Time elapsed: 2.164337635040283 sec
# average relative error of u: 64.76588845737916%
# maximum relative error of u: 74.08739064980281%

# %%
print(num_basis)
idx=[0,1,2,3]
num_basis[idx]
# Out:
# [3 4 5 6]
# array([3, 4, 5, 6])

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_POD_SOPT_avg_rel_err.png")

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_POD_SOPT_max_rel_err.png")
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
print(num_basis)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
idx=[1]
num_basis[idx]
# Out:
# array([4])

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_POD_{}_SOPT_avg_rel_err.png".format(int(num_basis[idx])))

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_POD_{}_SOPT_max_rel_err.png".format(int(num_basis[idx])))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
# figure rel.err vs at given param and POD basis
i=1;j=-1
POD_basis=num_basis[i]                 
param=FOM_parameters[j]

u_gappyPOD=results['solution'][i,j]

ex = np.load('../__data/ex16_diffusion/ex16_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("POD basis: {} Param: {}".format(POD_basis,param))
plt.show()

# plot original data
vmin=0; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyPOD[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy POD @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex16_diffusion/ex16_POD_{}_SOPT_SOL.png".format(POD_basis))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex16_diffusion/ex16_ground_truth.png")
