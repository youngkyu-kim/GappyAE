# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle

# %%
# Given parameters
nx = 60
ny = 60
tf = 1.0
dt = 2.0e-3
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims=(nx,ny)

# POD basis
num_basis=np.array([3,4,5,6])
print('num_basis {}'.format(num_basis))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_DEIM_result = "./diffusion_result/ex16_POD_inner_DEIM_gappy_result.p"
file_name_SVD="./diffusion_model/ex16_SVD.p"

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# num_basis [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %%
def DEIM(phi_f, nfeval, unseen=np.array([])):
    
    ninf=np.NINF
    n,m=np.shape(phi_f)
    
    l=0
    u=np.reshape(phi_f[:,l],(n,1))
    r=np.abs(u)
    if len(unseen) >0 :
        r[unseen]=ninf
    p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
    p=p_temp
    U=u
    
    ns=int(np.ceil((nfeval-1)/(m-1)))
    for l in range(1,m):
        u=np.reshape(phi_f[:,l],(n,1))
        for k in range(ns):
            if len(p)==nfeval:
                return p
            c=np.linalg.lstsq(U[p,:],u[p,:],rcond=None)[0]
            r=np.abs(u-U@c)
            r[p]=ninf
            if len(unseen) > 0:
                r[unseen]=ninf
            p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
            p=np.sort(np.append(p,p_temp))
        U=np.concatenate((U,u),axis=1)
         
    return p

# %%
with open(file=file_name_SVD, mode='rb') as ff:  
    SVD = pickle.load(ff)

for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    
    # DEIM
    num_msmt=12

    phi_DEIM=SVD['U'][:,:POD_basis]

    msmt_idx=DEIM(phi_DEIM,num_msmt,bc_raveled_indicies)
    msmt_idx.sort()

    print("# of measurments: {}".format(len(msmt_idx)))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(y[msmt_idx],x[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.savefig("./diffusion_result/ex16_POD_{}_inner_DEIM_{}_samples.png".format(POD_basis,num_msmt))
# Out:
# # of measurments: 12
# [  93   95  197  838 1918 2038 2098 3477 3478 3493 3537 3538]
# # of measurments: 12
# [  61   62   95  103  197  838 2038 2158 2218 3478 3493 3538]
# # of measurments: 12
# [  61   62   95  105  197  838 1978 2038 2136 2196 3478 3538]
# # of measurments: 12
# [  61   62   95  105  197  838 1978 2038 2136 2196 3478 3538]

# %% [markdown]
# # gappyPOD

# %%
solution=np.zeros((len(num_basis),len(FOM_parameters),nt+1,nx*ny))
avg_rel_err=np.zeros((len(num_basis),len(FOM_parameters)))
rel_err=np.zeros((len(num_basis),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(num_basis),len(FOM_parameters)))

with open(file=file_name_SVD, mode='rb') as ff:  
    SVD = pickle.load(ff)

for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    print("# of POD basis is {}".format(POD_basis))
    
    # DEIM
    num_msmt=12
    
    phi_DEIM=SVD['U'][:,:POD_basis]

    msmt_idx=DEIM(phi_DEIM,num_msmt,bc_raveled_indicies)
    msmt_idx.sort()

    print("# of measurments: {}".format(len(msmt_idx)))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.show()
    
    # Basis matrix
    phi_u = SVD['U'][:,:POD_basis]

    phim_u=phi_u[msmt_idx]
    phim_u_pinv=np.linalg.pinv(phim_u)
    
    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('./diffusion_data/ex16_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1)

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_ref = u0

        # Gappy POD
        t_start_gappyPOD=time.time()

        # solution
        u_gappyPOD=np.zeros((nt+1,ny*nx))
        u_hat=np.zeros((nt+1,POD_basis))

        # IC
        u_hat0=np.zeros(POD_basis)
        u_gappyPOD[0]=np.copy(u0)

        for n in range(nt):
            u_hat[n+1] = phim_u_pinv.dot(um[n+1]-u_ref[msmt_idx])
            u_gappyPOD[n+1] = u_ref + phi_u.dot(u_hat[n+1])

        # elapsed time
        t_elapsed_gappyPOD=time.time()-t_start_gappyPOD
        print('Time elapsed: {} sec'.format(t_elapsed_gappyPOD))

        # error
        u_rel_err_gappyPOD=np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)/np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyPOD)))
        print()

        # save result
        solution[ii,jj]=u_gappyPOD
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyPOD
        elapsed_time[ii,jj]=t_elapsed_gappyPOD
    
results={'solution':solution,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_DEIM_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# # of POD basis is 3
# # of measurments: 12
# [  93   95  197  838 1918 2038 2098 3477 3478 3493 3537 3538]
# Param is 75
# Time elapsed: 1.7147681713104248 sec
# average relative error of u: 7.940019315822636%
# maximum relative error of u: 8.876024359431751%
#
# Param is 76
# Time elapsed: 1.778827428817749 sec
# average relative error of u: 8.001851168766908%
# maximum relative error of u: 8.83036915826539%
#
# Param is 77
# Time elapsed: 2.0544509887695312 sec
# average relative error of u: 8.071641402799635%
# maximum relative error of u: 8.840411780384022%
#
# Param is 78
# Time elapsed: 1.9108200073242188 sec
# average relative error of u: 8.152450346221746%
# maximum relative error of u: 8.942139700914538%
#
# Param is 79
# Time elapsed: 2.0993502140045166 sec
# average relative error of u: 8.247299970602237%
# maximum relative error of u: 9.074542657771717%
#
# Param is 80
# Time elapsed: 2.1506338119506836 sec
# average relative error of u: 8.35931636346455%
# maximum relative error of u: 9.236586766419512%
#
# Param is 81
# Time elapsed: 1.6902165412902832 sec
# average relative error of u: 8.49139057136387%
# maximum relative error of u: 9.428124986861572%
#
# Param is 82
# Time elapsed: 1.962648868560791 sec
# average relative error of u: 8.646191013701422%
# maximum relative error of u: 9.649140684541308%
#
# Param is 83
# Time elapsed: 2.1484978199005127 sec
# average relative error of u: 8.825940208485354%
# maximum relative error of u: 9.899617796878653%
#
# Param is 84
# Time elapsed: 2.4049787521362305 sec
# average relative error of u: 9.032567189720352%
# maximum relative error of u: 10.179565818573781%
#
# Param is 85
# Time elapsed: 2.212205648422241 sec
# average relative error of u: 9.267282279995138%
# maximum relative error of u: 10.488631503956007%
#
# Param is 86
# Time elapsed: 2.0045788288116455 sec
# average relative error of u: 9.530935764257793%
# maximum relative error of u: 10.826453535768325%
#
# Param is 87
# Time elapsed: 2.062486171722412 sec
# average relative error of u: 9.82367131920523%
# maximum relative error of u: 11.192323205262106%
#
# Param is 88
# Time elapsed: 2.040775775909424 sec
# average relative error of u: 10.145081520803902%
# maximum relative error of u: 11.585352735271703%
#
# Param is 89
# Time elapsed: 2.0999391078948975 sec
# average relative error of u: 10.494181471365692%
# maximum relative error of u: 12.00440802413026%
#
# Param is 90
# Time elapsed: 2.239715814590454 sec
# average relative error of u: 10.869519838450922%
# maximum relative error of u: 12.44808183816011%
#
# Param is 91
# Time elapsed: 2.8205528259277344 sec
# average relative error of u: 11.26924975523997%
# maximum relative error of u: 12.914744943729628%
#
# Param is 92
# Time elapsed: 1.6180031299591064 sec
# average relative error of u: 11.691058195976225%
# maximum relative error of u: 13.402539097931731%
#
# Param is 93
# Time elapsed: 1.9465417861938477 sec
# average relative error of u: 12.132454723167555%
# maximum relative error of u: 13.909412342258246%
#
# Param is 94
# Time elapsed: 2.2319343090057373 sec
# average relative error of u: 12.590561881401143%
# maximum relative error of u: 14.433094431209218%
#
# Param is 95
# Time elapsed: 1.9077980518341064 sec
# average relative error of u: 13.062459949301664%
# maximum relative error of u: 14.971127575968795%
#
# Param is 96
# Time elapsed: 1.6511516571044922 sec
# average relative error of u: 13.545048043619055%
# maximum relative error of u: 15.52088384713764%
#
# Param is 97
# Time elapsed: 1.715132713317871 sec
# average relative error of u: 14.035210829141349%
# maximum relative error of u: 16.079742190533366%
#
# Param is 98
# Time elapsed: 1.654022455215454 sec
# average relative error of u: 14.52973306376126%
# maximum relative error of u: 16.644787588301618%
#
# Param is 99
# Time elapsed: 1.7252004146575928 sec
# average relative error of u: 15.025498064159844%
# maximum relative error of u: 17.21317241709523%
#
# Param is 100
# Time elapsed: 1.7150561809539795 sec
# average relative error of u: 15.519455046491512%
# maximum relative error of u: 17.78210790644752%
#
# Param is 101
# Time elapsed: 1.8396167755126953 sec
# average relative error of u: 16.00864165832975%
# maximum relative error of u: 18.348690056097805%
#
# Param is 102
# Time elapsed: 1.806337833404541 sec
# average relative error of u: 16.49028413850455%
# maximum relative error of u: 18.910195077609636%
#
# Param is 103
# Time elapsed: 1.8123469352722168 sec
# average relative error of u: 16.961899162300583%
# maximum relative error of u: 19.46409613280119%
#
# Param is 104
# Time elapsed: 1.7780001163482666 sec
# average relative error of u: 17.421132141718733%
# maximum relative error of u: 20.007968358092306%
#
# Param is 105
# Time elapsed: 2.0262210369110107 sec
# average relative error of u: 17.866071569461326%
# maximum relative error of u: 20.539766398188938%
#
# Param is 106
# Time elapsed: 1.9592487812042236 sec
# average relative error of u: 18.29520739288802%
# maximum relative error of u: 21.057832873342374%
#
# Param is 107
# Time elapsed: 1.7843244075775146 sec
# average relative error of u: 18.70741932629257%
# maximum relative error of u: 21.560930281867265%
#
# Param is 108
# Time elapsed: 1.7826423645019531 sec
# average relative error of u: 19.102181507185247%
# maximum relative error of u: 22.048351646835176%
#
# Param is 109
# Time elapsed: 1.733795166015625 sec
# average relative error of u: 19.479593158699842%
# maximum relative error of u: 22.520177601209657%
#
# Param is 110
# Time elapsed: 1.6765358448028564 sec
# average relative error of u: 19.840399408465682%
# maximum relative error of u: 22.97704652044406%
#
# Param is 111
# Time elapsed: 1.8026385307312012 sec
# average relative error of u: 20.1860872392924%
# maximum relative error of u: 23.420533413315063%
#
# Param is 112
# Time elapsed: 1.9566700458526611 sec
# average relative error of u: 20.51900950200875%
# maximum relative error of u: 23.853139378443664%
#
# Param is 113
# Time elapsed: 1.881364107131958 sec
# average relative error of u: 20.84235803225465%
# maximum relative error of u: 24.278315324592857%
#
# Param is 114
# Time elapsed: 1.7907967567443848 sec
# average relative error of u: 21.160175816188108%
# maximum relative error of u: 24.700539566128555%
#
# Param is 115
# Time elapsed: 1.838691234588623 sec
# average relative error of u: 21.477506580034074%
# maximum relative error of u: 25.12542976820574%
#
# Param is 116
# Time elapsed: 1.7146410942077637 sec
# average relative error of u: 21.800228716491652%
# maximum relative error of u: 25.559642727778204%
#
# Param is 117
# Time elapsed: 1.7516465187072754 sec
# average relative error of u: 22.134967063764535%
# maximum relative error of u: 26.010721963553962%
#
# Param is 118
# Time elapsed: 1.9009678363800049 sec
# average relative error of u: 22.48911351447606%
# maximum relative error of u: 26.48723641115116%
#
# Param is 119
# Time elapsed: 1.9299201965332031 sec
# average relative error of u: 22.87055521129475%
# maximum relative error of u: 26.998414804009524%
#
# Param is 120
# Time elapsed: 1.8103716373443604 sec
# average relative error of u: 23.287471209891574%
# maximum relative error of u: 27.55390217867592%
#
# Param is 121
# Time elapsed: 1.8373465538024902 sec
# average relative error of u: 23.748136498687973%
# maximum relative error of u: 28.163624276525667%
#
# Param is 122
# Time elapsed: 1.808689832687378 sec
# average relative error of u: 24.26047925050126%
# maximum relative error of u: 28.837271913476197%
#
# Param is 123
# Time elapsed: 1.7505621910095215 sec
# average relative error of u: 24.831971626143%
# maximum relative error of u: 29.5842215541602%
#
# Param is 124
# Time elapsed: 1.8933985233306885 sec
# average relative error of u: 25.469222589222067%
# maximum relative error of u: 30.41281296488409%
#
# Param is 125
# Time elapsed: 1.7496280670166016 sec
# average relative error of u: 26.17763116575279%
# maximum relative error of u: 31.330332615065647%
#
# # of POD basis is 4
# # of measurments: 12
# [  61   62   95  103  197  838 2038 2158 2218 3478 3493 3538]
# Param is 75
# Time elapsed: 1.7420663833618164 sec
# average relative error of u: 8.065116390989116%
# maximum relative error of u: 9.012178823177068%
#
# Param is 76
# Time elapsed: 1.6996650695800781 sec
# average relative error of u: 8.096536082861984%
# maximum relative error of u: 9.038499691419698%
#
# Param is 77
# Time elapsed: 1.750936508178711 sec
# average relative error of u: 8.121083487858401%
# maximum relative error of u: 9.057725672710031%
#
# Param is 78
# Time elapsed: 1.7195725440979004 sec
# average relative error of u: 8.138774798596293%
# maximum relative error of u: 9.069849281072695%
#
# Param is 79
# Time elapsed: 1.6961960792541504 sec
# average relative error of u: 8.14955156584493%
# maximum relative error of u: 9.07478774089744%
#
# Param is 80
# Time elapsed: 1.8187568187713623 sec
# average relative error of u: 8.153331728646771%
# maximum relative error of u: 9.072383700061556%
#
# Param is 81
# Time elapsed: 1.6690337657928467 sec
# average relative error of u: 8.150108553401285%
# maximum relative error of u: 9.062546580334887%
#
# Param is 82
# Time elapsed: 1.7488603591918945 sec
# average relative error of u: 8.139757839262861%
# maximum relative error of u: 9.044986040226986%
#
# Param is 83
# Time elapsed: 2.0549020767211914 sec
# average relative error of u: 8.122085527955475%
# maximum relative error of u: 9.019370584992751%
#
# Param is 84
# Time elapsed: 1.7230031490325928 sec
# average relative error of u: 8.096950171271674%
# maximum relative error of u: 8.98541132109123%
#
# Param is 85
# Time elapsed: 1.7751116752624512 sec
# average relative error of u: 8.06404251893512%
# maximum relative error of u: 8.94254611100131%
#
# Param is 86
# Time elapsed: 1.6951956748962402 sec
# average relative error of u: 8.023178918868703%
# maximum relative error of u: 8.890372118552545%
#
# Param is 87
# Time elapsed: 1.6856844425201416 sec
# average relative error of u: 7.974002468991381%
# maximum relative error of u: 8.828297019783445%
#
# Param is 88
# Time elapsed: 1.7037100791931152 sec
# average relative error of u: 7.916169617870278%
# maximum relative error of u: 8.755777276135486%
#
# Param is 89
# Time elapsed: 1.7383928298950195 sec
# average relative error of u: 7.8492669659984164%
# maximum relative error of u: 8.672058694925072%
#
# Param is 90
# Time elapsed: 1.8083748817443848 sec
# average relative error of u: 7.772882886742198%
# maximum relative error of u: 8.576578864866475%
#
# Param is 91
# Time elapsed: 1.8233184814453125 sec
# average relative error of u: 7.686664900266586%
# maximum relative error of u: 8.468682623999367%
#
# Param is 92
# Time elapsed: 1.552800178527832 sec
# average relative error of u: 7.59019410767605%
# maximum relative error of u: 8.347816842974035%
#
# Param is 93
# Time elapsed: 1.8992812633514404 sec
# average relative error of u: 7.4832424528877%
# maximum relative error of u: 8.2135054839275%
#
# Param is 94
# Time elapsed: 1.808013916015625 sec
# average relative error of u: 7.365591416358896%
# maximum relative error of u: 8.065491192343739%
#
# Param is 95
# Time elapsed: 1.940922498703003 sec
# average relative error of u: 7.237262051490967%
# maximum relative error of u: 7.903830520211382%
#
# Param is 96
# Time elapsed: 1.9704577922821045 sec
# average relative error of u: 7.098569660865942%
# maximum relative error of u: 7.729046977442127%
#
# Param is 97
# Time elapsed: 1.7847330570220947 sec
# average relative error of u: 6.950232039165563%
# maximum relative error of u: 7.5425025951598%
#
# Param is 98
# Time elapsed: 1.6481571197509766 sec
# average relative error of u: 6.793440657294737%
# maximum relative error of u: 7.346676704295775%
#
# Param is 99
# Time elapsed: 1.4957125186920166 sec
# average relative error of u: 6.630150632618806%
# maximum relative error of u: 7.146181743039902%
#
# Param is 100
# Time elapsed: 1.5980327129364014 sec
# average relative error of u: 6.463228463436516%
# maximum relative error of u: 6.948862413312809%
#
# Param is 101
# Time elapsed: 1.5530681610107422 sec
# average relative error of u: 6.296749965489773%
# maximum relative error of u: 6.765788120255081%
#
# Param is 102
# Time elapsed: 1.4911634922027588 sec
# average relative error of u: 6.136287551840334%
# maximum relative error of u: 6.6068810684180495%
#
# Param is 103
# Time elapsed: 1.3900682926177979 sec
# average relative error of u: 5.989287706396629%
# maximum relative error of u: 6.477137111949122%
#
# Param is 104
# Time elapsed: 1.9509704113006592 sec
# average relative error of u: 5.865163191037989%
# maximum relative error of u: 6.379381144555907%
#
# Param is 105
# Time elapsed: 1.8976919651031494 sec
# average relative error of u: 5.775510660397353%
# maximum relative error of u: 6.316689638642256%
#
# Param is 106
# Time elapsed: 1.9356937408447266 sec
# average relative error of u: 5.733836188011183%
# maximum relative error of u: 6.293288946646491%
#
# Param is 107
# Time elapsed: 1.533571481704712 sec
# average relative error of u: 5.754704353502066%
# maximum relative error of u: 6.31492388789327%
#
# Param is 108
# Time elapsed: 1.8523390293121338 sec
# average relative error of u: 5.852596051466437%
# maximum relative error of u: 6.389523928086947%
#
# Param is 109
# Time elapsed: 1.8546814918518066 sec
# average relative error of u: 6.040183621830477%
# maximum relative error of u: 6.52783708686694%
#
# Param is 110
# Time elapsed: 1.9457509517669678 sec
# average relative error of u: 6.326799641045177%
# maximum relative error of u: 6.7452588743162565%
#
# Param is 111
# Time elapsed: 1.691798210144043 sec
# average relative error of u: 6.717624649132222%
# maximum relative error of u: 7.218613156104346%
#
# Param is 112
# Time elapsed: 1.529792070388794 sec
# average relative error of u: 7.213635012121965%
# maximum relative error of u: 7.902834323233327%
#
# Param is 113
# Time elapsed: 1.5940055847167969 sec
# average relative error of u: 7.812459565306002%
# maximum relative error of u: 8.70715310402912%
#
# Param is 114
# Time elapsed: 1.450988531112671 sec
# average relative error of u: 8.509481930847407%
# maximum relative error of u: 9.6240562287501%
#
# Param is 115
# Time elapsed: 1.8008522987365723 sec
# average relative error of u: 9.298802970931611%
# maximum relative error of u: 10.645802830834377%
#
# Param is 116
# Time elapsed: 1.7847421169281006 sec
# average relative error of u: 10.174161295561635%
# maximum relative error of u: 11.76501330024515%
#
# Param is 117
# Time elapsed: 2.167355537414551 sec
# average relative error of u: 11.129174273941688%
# maximum relative error of u: 12.974701789829588%
#
# Param is 118
# Time elapsed: 1.9812331199645996 sec
# average relative error of u: 12.157731193194401%
# maximum relative error of u: 14.268553063509733%
#
# Param is 119
# Time elapsed: 2.0266382694244385 sec
# average relative error of u: 13.254054025507145%
# maximum relative error of u: 15.640548584554598%
#
# Param is 120
# Time elapsed: 1.8137898445129395 sec
# average relative error of u: 14.41252372269171%
# maximum relative error of u: 17.08490278200711%
#
# Param is 121
# Time elapsed: 1.6443369388580322 sec
# average relative error of u: 15.6277882338181%
# maximum relative error of u: 18.59607197704037%
#
# Param is 122
# Time elapsed: 1.8095793724060059 sec
# average relative error of u: 16.894592810553384%
# maximum relative error of u: 20.16840502148057%
#
# Param is 123
# Time elapsed: 1.917952299118042 sec
# average relative error of u: 18.20779098804669%
# maximum relative error of u: 21.796294689850694%
#
# Param is 124
# Time elapsed: 1.8711190223693848 sec
# average relative error of u: 19.562329287857914%
# maximum relative error of u: 23.474216401278436%
#
# Param is 125
# Time elapsed: 1.8877344131469727 sec
# average relative error of u: 20.953081237121054%
# maximum relative error of u: 25.196254794804275%
#
# # of POD basis is 5
# # of measurments: 12
# [  61   62   95  105  197  838 1978 2038 2136 2196 3478 3538]
# Param is 75
# Time elapsed: 2.1357343196868896 sec
# average relative error of u: 3.9027206340897425%
# maximum relative error of u: 4.81631729794875%
#
# Param is 76
# Time elapsed: 1.6602065563201904 sec
# average relative error of u: 3.7519513420364734%
# maximum relative error of u: 4.614633045778958%
#
# Param is 77
# Time elapsed: 1.9109554290771484 sec
# average relative error of u: 3.600211065195081%
# maximum relative error of u: 4.40351833285957%
#
# Param is 78
# Time elapsed: 2.160635232925415 sec
# average relative error of u: 3.450757360685855%
# maximum relative error of u: 4.185629850490511%
#
# Param is 79
# Time elapsed: 1.9240641593933105 sec
# average relative error of u: 3.3075298732035434%
# maximum relative error of u: 3.964394465193582%
#
# Param is 80
# Time elapsed: 1.983053207397461 sec
# average relative error of u: 3.1750413357683414%
# maximum relative error of u: 3.744079380732865%
#
# Param is 81
# Time elapsed: 2.7630960941314697 sec
# average relative error of u: 3.058484447132988%
# maximum relative error of u: 3.5300764169045658%
#
# Param is 82
# Time elapsed: 1.8535370826721191 sec
# average relative error of u: 2.9633608427826332%
# maximum relative error of u: 3.328947931310141%
#
# Param is 83
# Time elapsed: 1.8180105686187744 sec
# average relative error of u: 2.895187453752563%
# maximum relative error of u: 3.1485150208574%
#
# Param is 84
# Time elapsed: 1.6665654182434082 sec
# average relative error of u: 2.858952797047915%
# maximum relative error of u: 3.1713060476543244%
#
# Param is 85
# Time elapsed: 1.8908729553222656 sec
# average relative error of u: 2.858394989195054%
# maximum relative error of u: 3.239290606040547%
#
# Param is 86
# Time elapsed: 1.8109171390533447 sec
# average relative error of u: 2.895467521064147%
# maximum relative error of u: 3.329288428115993%
#
# Param is 87
# Time elapsed: 2.0613210201263428 sec
# average relative error of u: 2.9699391908758215%
# maximum relative error of u: 3.4401389810236256%
#
# Param is 88
# Time elapsed: 1.83402419090271 sec
# average relative error of u: 3.079529542195226%
# maximum relative error of u: 3.5704598491633774%
#
# Param is 89
# Time elapsed: 1.8854174613952637 sec
# average relative error of u: 3.2203253269069574%
# maximum relative error of u: 3.718668088701434%
#
# Param is 90
# Time elapsed: 1.8176088333129883 sec
# average relative error of u: 3.3873774305396473%
# maximum relative error of u: 3.882850155089214%
#
# Param is 91
# Time elapsed: 1.9179425239562988 sec
# average relative error of u: 3.5752314288786473%
# maximum relative error of u: 4.060795646615407%
#
# Param is 92
# Time elapsed: 1.899364709854126 sec
# average relative error of u: 3.7784425576973146%
# maximum relative error of u: 4.250014329969224%
#
# Param is 93
# Time elapsed: 1.7093656063079834 sec
# average relative error of u: 3.991724636077665%
# maximum relative error of u: 4.447697364976038%
#
# Param is 94
# Time elapsed: 1.85447359085083 sec
# average relative error of u: 4.210157182290562%
# maximum relative error of u: 4.650897880208301%
#
# Param is 95
# Time elapsed: 1.787747859954834 sec
# average relative error of u: 4.429235198687332%
# maximum relative error of u: 4.856450442897276%
#
# Param is 96
# Time elapsed: 1.546576976776123 sec
# average relative error of u: 4.644810488977153%
# maximum relative error of u: 5.061155976970915%
#
# Param is 97
# Time elapsed: 1.7585632801055908 sec
# average relative error of u: 4.853160887174965%
# maximum relative error of u: 5.2618685493525215%
#
# Param is 98
# Time elapsed: 1.8828492164611816 sec
# average relative error of u: 5.050891965755584%
# maximum relative error of u: 5.455587235903046%
#
# Param is 99
# Time elapsed: 1.7486438751220703 sec
# average relative error of u: 5.234974018297016%
# maximum relative error of u: 5.639580158625043%
#
# Param is 100
# Time elapsed: 1.9986379146575928 sec
# average relative error of u: 5.402709267969032%
# maximum relative error of u: 5.8115077064200635%
#
# Param is 101
# Time elapsed: 1.8112843036651611 sec
# average relative error of u: 5.551859570927253%
# maximum relative error of u: 5.969667393935504%
#
# Param is 102
# Time elapsed: 1.8110053539276123 sec
# average relative error of u: 5.680540922384402%
# maximum relative error of u: 6.112879264130475%
#
# Param is 103
# Time elapsed: 1.8181452751159668 sec
# average relative error of u: 5.787467584915696%
# maximum relative error of u: 6.240705417479291%
#
# Param is 104
# Time elapsed: 1.8005163669586182 sec
# average relative error of u: 5.871904472833052%
# maximum relative error of u: 6.353404100643176%
#
# Param is 105
# Time elapsed: 1.6963756084442139 sec
# average relative error of u: 5.933874953528406%
# maximum relative error of u: 6.451841478613539%
#
# Param is 106
# Time elapsed: 1.5980613231658936 sec
# average relative error of u: 5.974383384115248%
# maximum relative error of u: 6.537582411657709%
#
# Param is 107
# Time elapsed: 1.578110694885254 sec
# average relative error of u: 5.99551420652401%
# maximum relative error of u: 6.612791431593708%
#
# Param is 108
# Time elapsed: 1.5863497257232666 sec
# average relative error of u: 6.000736640741898%
# maximum relative error of u: 6.680375434619376%
#
# Param is 109
# Time elapsed: 1.8617613315582275 sec
# average relative error of u: 5.995262002655964%
# maximum relative error of u: 6.743816244756866%
#
# Param is 110
# Time elapsed: 2.574183702468872 sec
# average relative error of u: 5.98620327143522%
# maximum relative error of u: 6.807341574500941%
#
# Param is 111
# Time elapsed: 1.625957727432251 sec
# average relative error of u: 5.98289001004927%
# maximum relative error of u: 6.876016224467439%
#
# Param is 112
# Time elapsed: 1.638298749923706 sec
# average relative error of u: 5.996958850857586%
# maximum relative error of u: 6.955680370059837%
#
# Param is 113
# Time elapsed: 1.6063485145568848 sec
# average relative error of u: 6.042226119694801%
# maximum relative error of u: 7.053093228960142%
#
# Param is 114
# Time elapsed: 1.55019211769104 sec
# average relative error of u: 6.134002920535455%
# maximum relative error of u: 7.176032574408571%
#
# Param is 115
# Time elapsed: 2.0484750270843506 sec
# average relative error of u: 6.2881167719349556%
# maximum relative error of u: 7.333426316372423%
#
# Param is 116
# Time elapsed: 1.778674602508545 sec
# average relative error of u: 6.519435120620984%
# maximum relative error of u: 7.535557552869662%
#
# Param is 117
# Time elapsed: 1.9536287784576416 sec
# average relative error of u: 6.840165398754003%
# maximum relative error of u: 7.794283546004369%
#
# Param is 118
# Time elapsed: 1.9176530838012695 sec
# average relative error of u: 7.2588511770909925%
# maximum relative error of u: 8.1237232472284%
#
# Param is 119
# Time elapsed: 2.0419423580169678 sec
# average relative error of u: 7.779749439416288%
# maximum relative error of u: 8.541085276375524%
#
# Param is 120
# Time elapsed: 2.053907871246338 sec
# average relative error of u: 8.40307308700743%
# maximum relative error of u: 9.06822185626103%
#
# Param is 121
# Time elapsed: 2.061880111694336 sec
# average relative error of u: 9.125924293479303%
# maximum relative error of u: 9.739587774627438%
#
# Param is 122
# Time elapsed: 2.1585545539855957 sec
# average relative error of u: 9.943117399359231%
# maximum relative error of u: 10.852558140726206%
#
# Param is 123
# Time elapsed: 1.9590973854064941 sec
# average relative error of u: 10.848173436069406%
# maximum relative error of u: 12.07080123761062%
#
# Param is 124
# Time elapsed: 1.7908000946044922 sec
# average relative error of u: 11.833993548852657%
# maximum relative error of u: 13.384025885993376%
#
# Param is 125
# Time elapsed: 1.9178507328033447 sec
# average relative error of u: 12.893155423511482%
# maximum relative error of u: 14.782424799656512%
#
# # of POD basis is 6
# # of measurments: 12
# [  61   62   95  105  197  838 1978 2038 2136 2196 3478 3538]
# Param is 75
# Time elapsed: 1.8236424922943115 sec
# average relative error of u: 5.042205413185338%
# maximum relative error of u: 6.466602646222029%
#
# Param is 76
# Time elapsed: 2.0556256771087646 sec
# average relative error of u: 4.801403485935589%
# maximum relative error of u: 6.173905970102191%
#
# Param is 77
# Time elapsed: 1.7990436553955078 sec
# average relative error of u: 4.547046768378786%
# maximum relative error of u: 5.858299367993005%
#
# Param is 78
# Time elapsed: 1.4301536083221436 sec
# average relative error of u: 4.2813546015297055%
# maximum relative error of u: 5.521425576083132%
#
# Param is 79
# Time elapsed: 1.435708999633789 sec
# average relative error of u: 4.0070345472053415%
# maximum relative error of u: 5.165132054814115%
#
# Param is 80
# Time elapsed: 1.4913928508758545 sec
# average relative error of u: 3.7276090895143463%
# maximum relative error of u: 4.7921549594645345%
#
# Param is 81
# Time elapsed: 1.5251731872558594 sec
# average relative error of u: 3.4475650445113857%
# maximum relative error of u: 4.405795960674771%
#
# Param is 82
# Time elapsed: 1.4993939399719238 sec
# average relative error of u: 3.1725951703871345%
# maximum relative error of u: 4.010463231061339%
#
# Param is 83
# Time elapsed: 1.444018840789795 sec
# average relative error of u: 2.9100445383858116%
# maximum relative error of u: 3.6119258392976348%
#
# Param is 84
# Time elapsed: 1.581712245941162 sec
# average relative error of u: 2.669423235155078%
# maximum relative error of u: 3.218395090894716%
#
# Param is 85
# Time elapsed: 1.674729824066162 sec
# average relative error of u: 2.462321899982311%
# maximum relative error of u: 2.8412067799063565%
#
# Param is 86
# Time elapsed: 1.4554622173309326 sec
# average relative error of u: 2.302339357870156%
# maximum relative error of u: 2.539648646453389%
#
# Param is 87
# Time elapsed: 1.5497798919677734 sec
# average relative error of u: 2.2028094326504344%
# maximum relative error of u: 2.5125669361342884%
#
# Param is 88
# Time elapsed: 1.4615058898925781 sec
# average relative error of u: 2.1735160172924837%
# maximum relative error of u: 2.5170549392740456%
#
# Param is 89
# Time elapsed: 1.7963390350341797 sec
# average relative error of u: 2.216799185883904%
# maximum relative error of u: 2.553077966176434%
#
# Param is 90
# Time elapsed: 1.6862683296203613 sec
# average relative error of u: 2.3263756070993935%
# maximum relative error of u: 2.622785520031508%
#
# Param is 91
# Time elapsed: 1.83748459815979 sec
# average relative error of u: 2.4896227128195756%
# maximum relative error of u: 2.734748753650914%
#
# Param is 92
# Time elapsed: 1.7440388202667236 sec
# average relative error of u: 2.6915304226423613%
# maximum relative error of u: 2.9136933205709625%
#
# Param is 93
# Time elapsed: 1.86029052734375 sec
# average relative error of u: 2.9176611086999023%
# maximum relative error of u: 3.1594040015136002%
#
# Param is 94
# Time elapsed: 1.7225441932678223 sec
# average relative error of u: 3.155471429574951%
# maximum relative error of u: 3.4393322032734743%
#
# Param is 95
# Time elapsed: 1.7918119430541992 sec
# average relative error of u: 3.394578460878895%
# maximum relative error of u: 3.732299288852644%
#
# Param is 96
# Time elapsed: 1.5829761028289795 sec
# average relative error of u: 3.626279863104924%
# maximum relative error of u: 4.02403479932103%
#
# Param is 97
# Time elapsed: 1.6675469875335693 sec
# average relative error of u: 3.8432404021303657%
# maximum relative error of u: 4.303669654620957%
#
# Param is 98
# Time elapsed: 1.7391984462738037 sec
# average relative error of u: 4.03908594909117%
# maximum relative error of u: 4.562133425360125%
#
# Param is 99
# Time elapsed: 1.8062567710876465 sec
# average relative error of u: 4.208210028393195%
# maximum relative error of u: 4.791642583969493%
#
# Param is 100
# Time elapsed: 1.8291189670562744 sec
# average relative error of u: 4.345496315198635%
# maximum relative error of u: 4.984961336377059%
#
# Param is 101
# Time elapsed: 1.747713565826416 sec
# average relative error of u: 4.4464038540595086%
# maximum relative error of u: 5.135743224662009%
#
# Param is 102
# Time elapsed: 1.6903142929077148 sec
# average relative error of u: 4.506666733318509%
# maximum relative error of u: 5.237745463600028%
#
# Param is 103
# Time elapsed: 1.485421895980835 sec
# average relative error of u: 4.522598530399958%
# maximum relative error of u: 5.285579845261087%
#
# Param is 104
# Time elapsed: 1.5673348903656006 sec
# average relative error of u: 4.490881454278848%
# maximum relative error of u: 5.274193507966738%
#
# Param is 105
# Time elapsed: 1.5339062213897705 sec
# average relative error of u: 4.408941568421739%
# maximum relative error of u: 5.199264423673683%
#
# Param is 106
# Time elapsed: 1.442016839981079 sec
# average relative error of u: 4.275066334728399%
# maximum relative error of u: 5.057285138432091%
#
# Param is 107
# Time elapsed: 1.3948967456817627 sec
# average relative error of u: 4.088889969065525%
# maximum relative error of u: 4.846207678691629%
#
# Param is 108
# Time elapsed: 1.3464884757995605 sec
# average relative error of u: 3.8519611297353906%
# maximum relative error of u: 4.565749489589274%
#
# Param is 109
# Time elapsed: 1.4787111282348633 sec
# average relative error of u: 3.569414065861043%
# maximum relative error of u: 4.219089792525353%
#
# Param is 110
# Time elapsed: 1.7749595642089844 sec
# average relative error of u: 3.2521881401080615%
# maximum relative error of u: 3.815129677607185%
#
# Param is 111
# Time elapsed: 1.5808565616607666 sec
# average relative error of u: 2.9217355180958333%
# maximum relative error of u: 3.373791423673907%
#
# Param is 112
# Time elapsed: 1.6446483135223389 sec
# average relative error of u: 2.61857302748632%
# maximum relative error of u: 2.9371141373868106%
#
# Param is 113
# Time elapsed: 1.5818774700164795 sec
# average relative error of u: 2.412633247837931%
# maximum relative error of u: 2.5912291076665266%
#
# Param is 114
# Time elapsed: 1.744499921798706 sec
# average relative error of u: 2.399227322783454%
# maximum relative error of u: 2.561645889427765%
#
# Param is 115
# Time elapsed: 1.9417674541473389 sec
# average relative error of u: 2.6525627779292917%
# maximum relative error of u: 2.7522156599556475%
#
# Param is 116
# Time elapsed: 1.436873197555542 sec
# average relative error of u: 3.173894256009196%
# maximum relative error of u: 3.392658216065226%
#
# Param is 117
# Time elapsed: 1.403268814086914 sec
# average relative error of u: 3.913863034343%
# maximum relative error of u: 4.3229252268598515%
#
# Param is 118
# Time elapsed: 1.4319732189178467 sec
# average relative error of u: 4.82182224878691%
# maximum relative error of u: 5.463943394948907%
#
# Param is 119
# Time elapsed: 1.663266897201538 sec
# average relative error of u: 5.862543441209278%
# maximum relative error of u: 6.76736227742943%
#
# Param is 120
# Time elapsed: 1.6736514568328857 sec
# average relative error of u: 7.013642289762057%
# maximum relative error of u: 8.205305128288357%
#
# Param is 121
# Time elapsed: 1.5844874382019043 sec
# average relative error of u: 8.260358410982994%
# maximum relative error of u: 9.76050024746614%
#
# Param is 122
# Time elapsed: 1.6068222522735596 sec
# average relative error of u: 9.59183459324967%
# maximum relative error of u: 11.420551602047912%
#
# Param is 123
# Time elapsed: 1.5027196407318115 sec
# average relative error of u: 10.999488489073304%
# maximum relative error of u: 13.175585961702255%
#
# Param is 124
# Time elapsed: 1.4328410625457764 sec
# average relative error of u: 12.475903906133517%
# maximum relative error of u: 15.017137181728483%
#
# Param is 125
# Time elapsed: 1.4902064800262451 sec
# average relative error of u: 14.01401475821059%
# maximum relative error of u: 16.936795722153946%

# %%
print(num_basis)
idx=[0,1,2,3]
num_basis[idx]
# Out:
# [3 4 5 6]
# array([3, 4, 5, 6])

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./diffusion_result/ex16_POD_inner_DEIM_avg_rel_err.png")

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./diffusion_result/ex16_POD_inner_DEIM_max_rel_err.png")
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
idx=[3]
POD_basis=num_basis[idx]
print(POD_basis)
# Out:
# [6]

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./diffusion_result/ex16_POD_{}_inner_DEIM_avg_rel_err.png".format(POD_basis)

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./diffusion_result/ex16_POD_{}_inner_DEIM_max_rel_err.png".format(POD_basis)
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
print(num_basis)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=3;j=-1
POD_basis=num_basis[i]                 
param=FOM_parameters[j]

u_gappyPOD=results['solution'][i,j]

ex = np.load('./diffusion_data/ex16_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("POD basis: {} Param: {}".format(POD_basis,param))
plt.show()

# plot original data
vmin=0; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyPOD[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy POD @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./diffusion_result/ex16_POD_{}_inner_DEIM_SOL.png".format(POD_basis))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./diffusion_result/ex16_ground_truth.png")
