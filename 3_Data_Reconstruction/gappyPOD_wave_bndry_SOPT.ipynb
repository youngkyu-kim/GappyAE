# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle

# %%
# Given parameters
nx = 60
ny = 60
tf = 5.0
dt = 1.0e-2
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims=(nx,ny)

# POD basis
num_basis=np.arange(3,7,1)
print('num_basis {}'.format(num_basis))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_SOPT_result = "../__result/ex23_wave/ex23_POD_bndry_SOPT_gappy_result.p"
file_name_SVD="../__model/ex23_wave/ex23_SVD.p"

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# num_basis [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %% [markdown]
# # gappyPOD

# %%
# S-OPT
file_path_SOPT="../__model/SOPT_sample_points/ex23_POD_bndry_SOPT_oversampling.p"
with open(file=file_path_SOPT, mode='rb') as ff:  
        msmt_idx_list = pickle.load(ff)

# %%
for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    
    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig("../__result/ex23_wave/ex23_POD_{}_bndry_SOPT_{}_samples.png".format(POD_basis,num_msmt))
# Out:
# # of measurments: 12
# [  20   22   28   29   58 1740 1799 1859 1919 2099 2459 3060]
# # of measurments: 12
# [   9   26   27   28   58 1679 1739 1919 3060 3567 3568 3599]
# # of measurments: 12
# [   9   29   30   58 1679 1739 1740 1800 1919 2879 3060 3567]
# # of measurments: 12
# [   9   22   23   24   38   58 1380 1919 2039 2159 2879 3060]

# %%
solution=np.zeros((len(num_basis),len(FOM_parameters),nt+1,nx*ny))
avg_rel_err=np.zeros((len(num_basis),len(FOM_parameters)))
rel_err=np.zeros((len(num_basis),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(num_basis),len(FOM_parameters)))

with open(file=file_name_SVD, mode='rb') as ff:  
    SVD = pickle.load(ff)

for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    print("# of POD basis is {}".format(POD_basis))
    
    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.show()
    
    # Basis matrix
    phi_u = SVD['U'][:,:POD_basis]

    phim_u=phi_u[msmt_idx]
    phim_u_pinv=np.linalg.pinv(phim_u)
    
    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('../__data/ex23_wave/ex23_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1)

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_ref = u0

        # Gappy POD
        t_start_gappyPOD=time.time()

        # solution
        u_gappyPOD=np.zeros((nt+1,ny*nx))
        u_hat=np.zeros((nt+1,POD_basis))

        # IC
        u_hat0=np.zeros(POD_basis)
        u_gappyPOD[0]=np.copy(u0)

        for n in range(nt):
            u_hat[n+1] = phim_u_pinv.dot(um[n+1]-u_ref[msmt_idx])
            u_gappyPOD[n+1] = u_ref + phi_u.dot(u_hat[n+1])

        # elapsed time
        t_elapsed_gappyPOD=time.time()-t_start_gappyPOD
        print('Time elapsed: {} sec'.format(t_elapsed_gappyPOD))

        # error
        u_rel_err_gappyPOD=np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)/np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyPOD)))
        print()

        # save result
        solution[ii,jj]=u_gappyPOD
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyPOD
        elapsed_time[ii,jj]=t_elapsed_gappyPOD
    
results={'solution':solution,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_SOPT_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# # of POD basis is 3
# # of measurments: 12
# [  20   22   28   29   58 1740 1799 1859 1919 2099 2459 3060]
# Param is 75
# Time elapsed: 1.598931074142456 sec
# average relative error of u: 4.723596306778911%
# maximum relative error of u: 6.580230783701249%
#
# Param is 76
# Time elapsed: 1.3713610172271729 sec
# average relative error of u: 4.524791388207824%
# maximum relative error of u: 6.325995307861543%
#
# Param is 77
# Time elapsed: 7.491789817810059 sec
# average relative error of u: 4.3424173305133325%
# maximum relative error of u: 6.08146637780002%
#
# Param is 78
# Time elapsed: 1.064610481262207 sec
# average relative error of u: 4.180049698977037%
# maximum relative error of u: 5.849546704360418%
#
# Param is 79
# Time elapsed: 3.593592882156372 sec
# average relative error of u: 4.0415071447651005%
# maximum relative error of u: 5.636913489558597%
#
# Param is 80
# Time elapsed: 0.966235876083374 sec
# average relative error of u: 3.930735882233168%
# maximum relative error of u: 5.457725152068317%
#
# Param is 81
# Time elapsed: 10.18944501876831 sec
# average relative error of u: 3.8515236724409587%
# maximum relative error of u: 5.3053440768831015%
#
# Param is 82
# Time elapsed: 2.057462215423584 sec
# average relative error of u: 3.807196780562119%
# maximum relative error of u: 5.185561636823002%
#
# Param is 83
# Time elapsed: 1.1848163604736328 sec
# average relative error of u: 3.8003146006665864%
# maximum relative error of u: 5.116841721555359%
#
# Param is 84
# Time elapsed: 1.322868824005127 sec
# average relative error of u: 3.832328531408445%
# maximum relative error of u: 5.106880912146413%
#
# Param is 85
# Time elapsed: 1.1889288425445557 sec
# average relative error of u: 3.9035139277220825%
# maximum relative error of u: 5.21926449839275%
#
# Param is 86
# Time elapsed: 1.2671468257904053 sec
# average relative error of u: 4.0128719629875995%
# maximum relative error of u: 5.5777420321542%
#
# Param is 87
# Time elapsed: 2.540086507797241 sec
# average relative error of u: 4.158473343891202%
# maximum relative error of u: 6.073501703171674%
#
# Param is 88
# Time elapsed: 1.1976866722106934 sec
# average relative error of u: 4.337588076557932%
# maximum relative error of u: 6.59502625338191%
#
# Param is 89
# Time elapsed: 1.3011014461517334 sec
# average relative error of u: 4.547153271437729%
# maximum relative error of u: 7.193829773702314%
#
# Param is 90
# Time elapsed: 5.798015594482422 sec
# average relative error of u: 4.783977276275572%
# maximum relative error of u: 7.855995666146945%
#
# Param is 91
# Time elapsed: 2.6192703247070312 sec
# average relative error of u: 5.044916925973621%
# maximum relative error of u: 8.542390778244604%
#
# Param is 92
# Time elapsed: 1.3434162139892578 sec
# average relative error of u: 5.327112017939663%
# maximum relative error of u: 9.249732420954135%
#
# Param is 93
# Time elapsed: 1.271080732345581 sec
# average relative error of u: 5.62794157589678%
# maximum relative error of u: 9.975612513857907%
#
# Param is 94
# Time elapsed: 1.110006332397461 sec
# average relative error of u: 5.945101478161971%
# maximum relative error of u: 10.718037430321226%
#
# Param is 95
# Time elapsed: 1.5940511226654053 sec
# average relative error of u: 6.2766105427227545%
# maximum relative error of u: 11.47545770672533%
#
# Param is 96
# Time elapsed: 1.2118415832519531 sec
# average relative error of u: 6.620718236759543%
# maximum relative error of u: 12.246582635857102%
#
# Param is 97
# Time elapsed: 1.080077886581421 sec
# average relative error of u: 6.9759569153699434%
# maximum relative error of u: 13.030342822817456%
#
# Param is 98
# Time elapsed: 2.920666217803955 sec
# average relative error of u: 7.341061912035109%
# maximum relative error of u: 13.825851501293233%
#
# Param is 99
# Time elapsed: 1.2335519790649414 sec
# average relative error of u: 7.714910889143684%
# maximum relative error of u: 14.632355667658903%
#
# Param is 100
# Time elapsed: 1.0052075386047363 sec
# average relative error of u: 8.096569461077097%
# maximum relative error of u: 15.449098283252452%
#
# Param is 101
# Time elapsed: 1.140092372894287 sec
# average relative error of u: 8.485258185081749%
# maximum relative error of u: 16.275613762461415%
#
# Param is 102
# Time elapsed: 1.0263104438781738 sec
# average relative error of u: 8.880259463639973%
# maximum relative error of u: 17.111269633999886%
#
# Param is 103
# Time elapsed: 1.1580352783203125 sec
# average relative error of u: 9.280943272885386%
# maximum relative error of u: 17.9556865768939%
#
# Param is 104
# Time elapsed: 1.2538866996765137 sec
# average relative error of u: 9.686769549056958%
# maximum relative error of u: 18.80833163564317%
#
# Param is 105
# Time elapsed: 2.0014448165893555 sec
# average relative error of u: 10.097297147398459%
# maximum relative error of u: 19.668791782197108%
#
# Param is 106
# Time elapsed: 1.056241512298584 sec
# average relative error of u: 10.512087557063822%
# maximum relative error of u: 20.536751742855238%
#
# Param is 107
# Time elapsed: 1.2319447994232178 sec
# average relative error of u: 10.930779590265093%
# maximum relative error of u: 21.411870427379412%
#
# Param is 108
# Time elapsed: 1.2976179122924805 sec
# average relative error of u: 11.353015612079481%
# maximum relative error of u: 22.293701824993608%
#
# Param is 109
# Time elapsed: 10.010935068130493 sec
# average relative error of u: 11.778519692864478%
# maximum relative error of u: 23.18199462012795%
#
# Param is 110
# Time elapsed: 1.1013689041137695 sec
# average relative error of u: 12.207045212928067%
# maximum relative error of u: 24.076457526679178%
#
# Param is 111
# Time elapsed: 0.938847541809082 sec
# average relative error of u: 12.638312183935241%
# maximum relative error of u: 24.976745897006765%
#
# Param is 112
# Time elapsed: 1.3388731479644775 sec
# average relative error of u: 13.072086285793505%
# maximum relative error of u: 25.882586069144597%
#
# Param is 113
# Time elapsed: 2.7361433506011963 sec
# average relative error of u: 13.508216164736472%
# maximum relative error of u: 26.793685928742406%
#
# Param is 114
# Time elapsed: 1.2531580924987793 sec
# average relative error of u: 13.946486397466042%
# maximum relative error of u: 27.709867298850256%
#
# Param is 115
# Time elapsed: 3.2455790042877197 sec
# average relative error of u: 14.386720140579945%
# maximum relative error of u: 28.6307325975239%
#
# Param is 116
# Time elapsed: 1.0405519008636475 sec
# average relative error of u: 14.828764323772969%
# maximum relative error of u: 29.556082543563605%
#
# Param is 117
# Time elapsed: 1.1199016571044922 sec
# average relative error of u: 15.272487887018087%
# maximum relative error of u: 30.485757309130978%
#
# Param is 118
# Time elapsed: 6.070730686187744 sec
# average relative error of u: 15.717740154928828%
# maximum relative error of u: 31.419428400336308%
#
# Param is 119
# Time elapsed: 2.9540886878967285 sec
# average relative error of u: 16.16438634955828%
# maximum relative error of u: 32.3567754161852%
#
# Param is 120
# Time elapsed: 0.9029233455657959 sec
# average relative error of u: 16.6123087752392%
# maximum relative error of u: 33.29770134923936%
#
# Param is 121
# Time elapsed: 4.588072061538696 sec
# average relative error of u: 17.061404831844182%
# maximum relative error of u: 34.241927462039115%
#
# Param is 122
# Time elapsed: 0.8785269260406494 sec
# average relative error of u: 17.511575615676186%
# maximum relative error of u: 35.18922053509391%
#
# Param is 123
# Time elapsed: 3.4860541820526123 sec
# average relative error of u: 17.96268056496392%
# maximum relative error of u: 36.139329283689555%
#
# Param is 124
# Time elapsed: 1.2292687892913818 sec
# average relative error of u: 18.41468586745653%
# maximum relative error of u: 37.09218419862607%
#
# Param is 125
# Time elapsed: 1.1510298252105713 sec
# average relative error of u: 18.867460809766527%
# maximum relative error of u: 38.047354693582065%
#
# # of POD basis is 4
# # of measurments: 12
# [   9   26   27   28   58 1679 1739 1919 3060 3567 3568 3599]
# Param is 75
# Time elapsed: 5.050267219543457 sec
# average relative error of u: 5.712766991137908%
# maximum relative error of u: 7.973231809939583%
#
# Param is 76
# Time elapsed: 2.632380962371826 sec
# average relative error of u: 5.512431962128513%
# maximum relative error of u: 7.650510865831965%
#
# Param is 77
# Time elapsed: 3.541991949081421 sec
# average relative error of u: 5.3158313615766914%
# maximum relative error of u: 7.332829937238813%
#
# Param is 78
# Time elapsed: 1.3074378967285156 sec
# average relative error of u: 5.1242895001312565%
# maximum relative error of u: 7.054981290200328%
#
# Param is 79
# Time elapsed: 3.2200276851654053 sec
# average relative error of u: 4.939409796291459%
# maximum relative error of u: 6.863406202765993%
#
# Param is 80
# Time elapsed: 1.0998871326446533 sec
# average relative error of u: 4.76295384553476%
# maximum relative error of u: 6.673881135411042%
#
# Param is 81
# Time elapsed: 3.597621202468872 sec
# average relative error of u: 4.59684712628092%
# maximum relative error of u: 6.486898978323861%
#
# Param is 82
# Time elapsed: 2.242449998855591 sec
# average relative error of u: 4.443306030602748%
# maximum relative error of u: 6.328408834262462%
#
# Param is 83
# Time elapsed: 1.1414330005645752 sec
# average relative error of u: 4.304604384160677%
# maximum relative error of u: 6.184112891121445%
#
# Param is 84
# Time elapsed: 1.8113512992858887 sec
# average relative error of u: 4.1832652973577025%
# maximum relative error of u: 6.042824195542326%
#
# Param is 85
# Time elapsed: 7.692461729049683 sec
# average relative error of u: 4.08178893710037%
# maximum relative error of u: 5.904771151113987%
#
# Param is 86
# Time elapsed: 1.3052730560302734 sec
# average relative error of u: 4.00267354360702%
# maximum relative error of u: 5.770145508977835%
#
# Param is 87
# Time elapsed: 1.2972774505615234 sec
# average relative error of u: 3.9481853978901165%
# maximum relative error of u: 5.639267580128663%
#
# Param is 88
# Time elapsed: 4.976451396942139 sec
# average relative error of u: 3.9202722181330114%
# maximum relative error of u: 5.512197352629873%
#
# Param is 89
# Time elapsed: 4.711687088012695 sec
# average relative error of u: 3.9203538130682856%
# maximum relative error of u: 5.389126860450496%
#
# Param is 90
# Time elapsed: 1.0767455101013184 sec
# average relative error of u: 3.949282662069531%
# maximum relative error of u: 5.670009646852936%
#
# Param is 91
# Time elapsed: 1.0772349834442139 sec
# average relative error of u: 4.007210533398116%
# maximum relative error of u: 6.092245037734221%
#
# Param is 92
# Time elapsed: 1.33457612991333 sec
# average relative error of u: 4.093634217010142%
# maximum relative error of u: 6.583973238343184%
#
# Param is 93
# Time elapsed: 1.352748155593872 sec
# average relative error of u: 4.2074588830874395%
# maximum relative error of u: 7.119496142051084%
#
# Param is 94
# Time elapsed: 1.3633027076721191 sec
# average relative error of u: 4.34716871905766%
# maximum relative error of u: 7.681785614507778%
#
# Param is 95
# Time elapsed: 1.3714921474456787 sec
# average relative error of u: 4.5109184436696%
# maximum relative error of u: 8.267293857679906%
#
# Param is 96
# Time elapsed: 1.132573127746582 sec
# average relative error of u: 4.696708964127354%
# maximum relative error of u: 8.873142140955974%
#
# Param is 97
# Time elapsed: 1.0075247287750244 sec
# average relative error of u: 4.90249387215976%
# maximum relative error of u: 9.497014031601884%
#
# Param is 98
# Time elapsed: 3.3670644760131836 sec
# average relative error of u: 5.126283671905836%
# maximum relative error of u: 10.136925982796846%
#
# Param is 99
# Time elapsed: 1.3278915882110596 sec
# average relative error of u: 5.3662023967245895%
# maximum relative error of u: 10.79134021559094%
#
# Param is 100
# Time elapsed: 1.2383158206939697 sec
# average relative error of u: 5.620519576052101%
# maximum relative error of u: 11.459019297021191%
#
# Param is 101
# Time elapsed: 1.5318398475646973 sec
# average relative error of u: 5.887652573302331%
# maximum relative error of u: 12.13863305506563%
#
# Param is 102
# Time elapsed: 1.2695176601409912 sec
# average relative error of u: 6.166225405033035%
# maximum relative error of u: 12.829430525861701%
#
# Param is 103
# Time elapsed: 1.2420947551727295 sec
# average relative error of u: 6.454939971981076%
# maximum relative error of u: 13.530390814558727%
#
# Param is 104
# Time elapsed: 1.1694209575653076 sec
# average relative error of u: 6.752748805242582%
# maximum relative error of u: 14.240904823872787%
#
# Param is 105
# Time elapsed: 2.612915515899658 sec
# average relative error of u: 7.0586516830670405%
# maximum relative error of u: 14.960331475251623%
#
# Param is 106
# Time elapsed: 1.1109042167663574 sec
# average relative error of u: 7.371793847647775%
# maximum relative error of u: 15.687912184876055%
#
# Param is 107
# Time elapsed: 1.398876428604126 sec
# average relative error of u: 7.691426030636543%
# maximum relative error of u: 16.42320567964895%
#
# Param is 108
# Time elapsed: 7.0838539600372314 sec
# average relative error of u: 8.016904239939807%
# maximum relative error of u: 17.16574094976356%
#
# Param is 109
# Time elapsed: 9.749891757965088 sec
# average relative error of u: 8.347622666774908%
# maximum relative error of u: 17.915137519499478%
#
# Param is 110
# Time elapsed: 1.1106727123260498 sec
# average relative error of u: 8.68306136410368%
# maximum relative error of u: 18.670733414883102%
#
# Param is 111
# Time elapsed: 1.3000242710113525 sec
# average relative error of u: 9.02277115668369%
# maximum relative error of u: 19.43238952179844%
#
# Param is 112
# Time elapsed: 1.0775127410888672 sec
# average relative error of u: 9.366327572996163%
# maximum relative error of u: 20.199544137099338%
#
# Param is 113
# Time elapsed: 4.239516496658325 sec
# average relative error of u: 9.713407257719282%
# maximum relative error of u: 20.972007973693827%
#
# Param is 114
# Time elapsed: 1.419607400894165 sec
# average relative error of u: 10.06364103579319%
# maximum relative error of u: 21.74923769953271%
#
# Param is 115
# Time elapsed: 1.4626309871673584 sec
# average relative error of u: 10.41672120771555%
# maximum relative error of u: 22.531113068856136%
#
# Param is 116
# Time elapsed: 1.9389455318450928 sec
# average relative error of u: 10.772416087239929%
# maximum relative error of u: 23.317290807346502%
#
# Param is 117
# Time elapsed: 0.9488325119018555 sec
# average relative error of u: 11.130492945138116%
# maximum relative error of u: 24.107419972615425%
#
# Param is 118
# Time elapsed: 3.0955348014831543 sec
# average relative error of u: 11.49069618695596%
# maximum relative error of u: 24.90118268227392%
#
# Param is 119
# Time elapsed: 2.1478636264801025 sec
# average relative error of u: 11.852832822787917%
# maximum relative error of u: 25.698338315492386%
#
# Param is 120
# Time elapsed: 5.475775241851807 sec
# average relative error of u: 12.216752134860478%
# maximum relative error of u: 26.498707869235044%
#
# Param is 121
# Time elapsed: 9.737778186798096 sec
# average relative error of u: 12.58221822645072%
# maximum relative error of u: 27.301828429305612%
#
# Param is 122
# Time elapsed: 1.3876266479492188 sec
# average relative error of u: 12.949170694675926%
# maximum relative error of u: 28.10768382240087%
#
# Param is 123
# Time elapsed: 2.95371675491333 sec
# average relative error of u: 13.317369732034084%
# maximum relative error of u: 28.915822911909228%
#
# Param is 124
# Time elapsed: 1.1056716442108154 sec
# average relative error of u: 13.686737549542158%
# maximum relative error of u: 29.726117742012708%
#
# Param is 125
# Time elapsed: 1.0018246173858643 sec
# average relative error of u: 14.057156796167082%
# maximum relative error of u: 30.538350034566818%
#
# # of POD basis is 5
# # of measurments: 12
# [   9   29   30   58 1679 1739 1740 1800 1919 2879 3060 3567]
# Param is 75
# Time elapsed: 1.341736078262329 sec
# average relative error of u: 4.865537942506757%
# maximum relative error of u: 6.845797617031282%
#
# Param is 76
# Time elapsed: 5.784237861633301 sec
# average relative error of u: 4.784686994185876%
# maximum relative error of u: 6.737370302717921%
#
# Param is 77
# Time elapsed: 2.5872035026550293 sec
# average relative error of u: 4.704712247591808%
# maximum relative error of u: 6.630557729383811%
#
# Param is 78
# Time elapsed: 3.3717658519744873 sec
# average relative error of u: 4.625625214546439%
# maximum relative error of u: 6.525825510428794%
#
# Param is 79
# Time elapsed: 1.0697104930877686 sec
# average relative error of u: 4.547619245544303%
# maximum relative error of u: 6.423509956996637%
#
# Param is 80
# Time elapsed: 1.2934744358062744 sec
# average relative error of u: 4.470777447895799%
# maximum relative error of u: 6.323352071845869%
#
# Param is 81
# Time elapsed: 1.258070468902588 sec
# average relative error of u: 4.3951293429616705%
# maximum relative error of u: 6.225312093964974%
#
# Param is 82
# Time elapsed: 1.09958815574646 sec
# average relative error of u: 4.320824047721833%
# maximum relative error of u: 6.129754240065403%
#
# Param is 83
# Time elapsed: 1.1595869064331055 sec
# average relative error of u: 4.247891882280344%
# maximum relative error of u: 6.036663904852991%
#
# Param is 84
# Time elapsed: 1.0219736099243164 sec
# average relative error of u: 4.176511601967332%
# maximum relative error of u: 5.946354741203611%
#
# Param is 85
# Time elapsed: 1.0503313541412354 sec
# average relative error of u: 4.106741066822997%
# maximum relative error of u: 5.858897419313663%
#
# Param is 86
# Time elapsed: 1.3284437656402588 sec
# average relative error of u: 4.038679744918762%
# maximum relative error of u: 5.774502360602279%
#
# Param is 87
# Time elapsed: 4.801663398742676 sec
# average relative error of u: 3.9723577356895774%
# maximum relative error of u: 5.693213581242429%
#
# Param is 88
# Time elapsed: 1.318735122680664 sec
# average relative error of u: 3.9079107152374224%
# maximum relative error of u: 5.615314075956943%
#
# Param is 89
# Time elapsed: 1.1906168460845947 sec
# average relative error of u: 3.8454182489252196%
# maximum relative error of u: 5.540866148585842%
#
# Param is 90
# Time elapsed: 1.239879846572876 sec
# average relative error of u: 3.7849837439658827%
# maximum relative error of u: 5.470070920403749%
#
# Param is 91
# Time elapsed: 6.650858402252197 sec
# average relative error of u: 3.726666328758421%
# maximum relative error of u: 5.403112717250575%
#
# Param is 92
# Time elapsed: 1.1584343910217285 sec
# average relative error of u: 3.6706505200852786%
# maximum relative error of u: 5.340246998699958%
#
# Param is 93
# Time elapsed: 1.2094430923461914 sec
# average relative error of u: 3.616905386574932%
# maximum relative error of u: 5.28241501552777%
#
# Param is 94
# Time elapsed: 1.1867871284484863 sec
# average relative error of u: 3.5656436430358327%
# maximum relative error of u: 5.229843065865429%
#
# Param is 95
# Time elapsed: 1.0236873626708984 sec
# average relative error of u: 3.5169380724890447%
# maximum relative error of u: 5.181905404390165%
#
# Param is 96
# Time elapsed: 8.134975671768188 sec
# average relative error of u: 3.4708269504814133%
# maximum relative error of u: 5.138698214152232%
#
# Param is 97
# Time elapsed: 1.3932678699493408 sec
# average relative error of u: 3.4274722961137787%
# maximum relative error of u: 5.100383328560958%
#
# Param is 98
# Time elapsed: 1.3124818801879883 sec
# average relative error of u: 3.3870493972859217%
# maximum relative error of u: 5.06738146079612%
#
# Param is 99
# Time elapsed: 9.540564060211182 sec
# average relative error of u: 3.349575277979654%
# maximum relative error of u: 5.039632624227652%
#
# Param is 100
# Time elapsed: 6.378522872924805 sec
# average relative error of u: 3.315229130693526%
# maximum relative error of u: 5.017480744885065%
#
# Param is 101
# Time elapsed: 7.743333578109741 sec
# average relative error of u: 3.2841657849836254%
# maximum relative error of u: 5.002047802544284%
#
# Param is 102
# Time elapsed: 2.935805082321167 sec
# average relative error of u: 3.2564105604257785%
# maximum relative error of u: 4.994341603601046%
#
# Param is 103
# Time elapsed: 1.4050233364105225 sec
# average relative error of u: 3.2321381623041767%
# maximum relative error of u: 4.992885545234959%
#
# Param is 104
# Time elapsed: 1.4151725769042969 sec
# average relative error of u: 3.2114987997060953%
# maximum relative error of u: 4.998055040905838%
#
# Param is 105
# Time elapsed: 1.4501690864562988 sec
# average relative error of u: 3.1946233925348526%
# maximum relative error of u: 5.009793201570457%
#
# Param is 106
# Time elapsed: 1.4253191947937012 sec
# average relative error of u: 3.1815402136377915%
# maximum relative error of u: 5.028271048515134%
#
# Param is 107
# Time elapsed: 1.4990999698638916 sec
# average relative error of u: 3.1725189465525805%
# maximum relative error of u: 5.056888789270116%
#
# Param is 108
# Time elapsed: 1.1854374408721924 sec
# average relative error of u: 3.167563928439011%
# maximum relative error of u: 5.092739764203401%
#
# Param is 109
# Time elapsed: 1.9194457530975342 sec
# average relative error of u: 3.1668143859947686%
# maximum relative error of u: 5.136151797083485%
#
# Param is 110
# Time elapsed: 7.465885162353516 sec
# average relative error of u: 3.1703576142506256%
# maximum relative error of u: 5.187099098685514%
#
# Param is 111
# Time elapsed: 3.5912656784057617 sec
# average relative error of u: 3.178343656240818%
# maximum relative error of u: 5.245673161205904%
#
# Param is 112
# Time elapsed: 1.0174579620361328 sec
# average relative error of u: 3.190845586917405%
# maximum relative error of u: 5.312103843266281%
#
# Param is 113
# Time elapsed: 1.1417596340179443 sec
# average relative error of u: 3.207863100375023%
# maximum relative error of u: 5.386336416356065%
#
# Param is 114
# Time elapsed: 1.081803321838379 sec
# average relative error of u: 3.2295805780095055%
# maximum relative error of u: 5.468611957420604%
#
# Param is 115
# Time elapsed: 1.181535243988037 sec
# average relative error of u: 3.2559281330422407%
# maximum relative error of u: 5.559948036313288%
#
# Param is 116
# Time elapsed: 1.178015947341919 sec
# average relative error of u: 3.287011237524045%
# maximum relative error of u: 5.661717918212726%
#
# Param is 117
# Time elapsed: 1.5377280712127686 sec
# average relative error of u: 3.322840494093083%
# maximum relative error of u: 5.77180113785505%
#
# Param is 118
# Time elapsed: 2.518125534057617 sec
# average relative error of u: 3.363464715645058%
# maximum relative error of u: 5.889931314486876%
#
# Param is 119
# Time elapsed: 1.3855102062225342 sec
# average relative error of u: 3.4088435546789233%
# maximum relative error of u: 6.016385346096979%
#
# Param is 120
# Time elapsed: 1.358293056488037 sec
# average relative error of u: 3.459024187660869%
# maximum relative error of u: 6.150849980264328%
#
# Param is 121
# Time elapsed: 8.595076322555542 sec
# average relative error of u: 3.513889327802136%
# maximum relative error of u: 6.2958761453742795%
#
# Param is 122
# Time elapsed: 1.0926754474639893 sec
# average relative error of u: 3.573489717590405%
# maximum relative error of u: 6.449899443856418%
#
# Param is 123
# Time elapsed: 2.996962785720825 sec
# average relative error of u: 3.6377858519617314%
# maximum relative error of u: 6.612168751297245%
#
# Param is 124
# Time elapsed: 1.3488729000091553 sec
# average relative error of u: 3.706789393960525%
# maximum relative error of u: 6.782532334542443%
#
# Param is 125
# Time elapsed: 4.444836378097534 sec
# average relative error of u: 3.780269067187889%
# maximum relative error of u: 6.960777759418065%
#
# # of POD basis is 6
# # of measurments: 12
# [   9   22   23   24   38   58 1380 1919 2039 2159 2879 3060]
# Param is 75
# Time elapsed: 1.3185887336730957 sec
# average relative error of u: 3.510380440715488%
# maximum relative error of u: 6.085021999339035%
#
# Param is 76
# Time elapsed: 1.3449077606201172 sec
# average relative error of u: 3.455690734072874%
# maximum relative error of u: 6.000217431144687%
#
# Param is 77
# Time elapsed: 4.667205095291138 sec
# average relative error of u: 3.401492838031311%
# maximum relative error of u: 5.915717725656455%
#
# Param is 78
# Time elapsed: 0.960092306137085 sec
# average relative error of u: 3.3478069818638634%
# maximum relative error of u: 5.831693548034648%
#
# Param is 79
# Time elapsed: 1.1298778057098389 sec
# average relative error of u: 3.2947310566150136%
# maximum relative error of u: 5.748282389160742%
#
# Param is 80
# Time elapsed: 1.3226537704467773 sec
# average relative error of u: 3.242356049676868%
# maximum relative error of u: 5.665732376158344%
#
# Param is 81
# Time elapsed: 1.3256683349609375 sec
# average relative error of u: 3.1906863289107164%
# maximum relative error of u: 5.584044103023661%
#
# Param is 82
# Time elapsed: 4.3969457149505615 sec
# average relative error of u: 3.1398439099319733%
# maximum relative error of u: 5.503472342228453%
#
# Param is 83
# Time elapsed: 3.3211538791656494 sec
# average relative error of u: 3.0898132596344716%
# maximum relative error of u: 5.423991506463633%
#
# Param is 84
# Time elapsed: 1.3529865741729736 sec
# average relative error of u: 3.0407360574977575%
# maximum relative error of u: 5.345841436089842%
#
# Param is 85
# Time elapsed: 1.6367435455322266 sec
# average relative error of u: 2.9925910145453405%
# maximum relative error of u: 5.269039387317072%
#
# Param is 86
# Time elapsed: 5.341527700424194 sec
# average relative error of u: 2.9455445431341847%
# maximum relative error of u: 5.19388319039994%
#
# Param is 87
# Time elapsed: 1.1564981937408447 sec
# average relative error of u: 2.899556165926374%
# maximum relative error of u: 5.120257727781592%
#
# Param is 88
# Time elapsed: 0.9519264698028564 sec
# average relative error of u: 2.854796664959585%
# maximum relative error of u: 5.04849977798334%
#
# Param is 89
# Time elapsed: 1.2486379146575928 sec
# average relative error of u: 2.8112626935166687%
# maximum relative error of u: 4.978517901802189%
#
# Param is 90
# Time elapsed: 1.191950798034668 sec
# average relative error of u: 2.7691301756007514%
# maximum relative error of u: 4.910709850421504%
#
# Param is 91
# Time elapsed: 1.1939420700073242 sec
# average relative error of u: 2.7284205266743378%
# maximum relative error of u: 4.846246059629245%
#
# Param is 92
# Time elapsed: 1.1887617111206055 sec
# average relative error of u: 2.6892381745278895%
# maximum relative error of u: 4.7853438108229325%
#
# Param is 93
# Time elapsed: 1.2608177661895752 sec
# average relative error of u: 2.6517169910660323%
# maximum relative error of u: 4.727036591394539%
#
# Param is 94
# Time elapsed: 1.1409461498260498 sec
# average relative error of u: 2.615959048563507%
# maximum relative error of u: 4.671200378331681%
#
# Param is 95
# Time elapsed: 1.10288405418396 sec
# average relative error of u: 2.582090122454965%
# maximum relative error of u: 4.61820295070127%
#
# Param is 96
# Time elapsed: 1.3466899394989014 sec
# average relative error of u: 2.550138552448843%
# maximum relative error of u: 4.56777903574692%
#
# Param is 97
# Time elapsed: 5.728509902954102 sec
# average relative error of u: 2.5203630131338968%
# maximum relative error of u: 4.5203781108352885%
#
# Param is 98
# Time elapsed: 3.58005690574646 sec
# average relative error of u: 2.492900622740507%
# maximum relative error of u: 4.476033905405785%
#
# Param is 99
# Time elapsed: 1.488257884979248 sec
# average relative error of u: 2.467823533683841%
# maximum relative error of u: 4.434890295678095%
#
# Param is 100
# Time elapsed: 4.920322418212891 sec
# average relative error of u: 2.4454187921658086%
# maximum relative error of u: 4.3971651716070355%
#
# Param is 101
# Time elapsed: 3.1067583560943604 sec
# average relative error of u: 2.4257458939383962%
# maximum relative error of u: 4.362887071070103%
#
# Param is 102
# Time elapsed: 7.927323579788208 sec
# average relative error of u: 2.4089813019366018%
# maximum relative error of u: 4.332128754000238%
#
# Param is 103
# Time elapsed: 1.1150128841400146 sec
# average relative error of u: 2.3953400451923517%
# maximum relative error of u: 4.305254866462099%
#
# Param is 104
# Time elapsed: 1.304520606994629 sec
# average relative error of u: 2.3850207029553636%
# maximum relative error of u: 4.282115086063161%
#
# Param is 105
# Time elapsed: 1.2233519554138184 sec
# average relative error of u: 2.3781375853999496%
# maximum relative error of u: 4.262973581436221%
#
# Param is 106
# Time elapsed: 1.132451057434082 sec
# average relative error of u: 2.374856188106859%
# maximum relative error of u: 4.247901670466434%
#
# Param is 107
# Time elapsed: 1.2826697826385498 sec
# average relative error of u: 2.375429204994718%
# maximum relative error of u: 4.237212240193848%
#
# Param is 108
# Time elapsed: 1.3628675937652588 sec
# average relative error of u: 2.380012921358859%
# maximum relative error of u: 4.230816393906828%
#
# Param is 109
# Time elapsed: 1.408811092376709 sec
# average relative error of u: 2.388670739292133%
# maximum relative error of u: 4.231404967990901%
#
# Param is 110
# Time elapsed: 1.4168951511383057 sec
# average relative error of u: 2.4016759171635274%
# maximum relative error of u: 4.24120391091774%
#
# Param is 111
# Time elapsed: 1.2528748512268066 sec
# average relative error of u: 2.419010907200421%
# maximum relative error of u: 4.255770278555842%
#
# Param is 112
# Time elapsed: 1.2480545043945312 sec
# average relative error of u: 2.4408754493726783%
# maximum relative error of u: 4.27557443331065%
#
# Param is 113
# Time elapsed: 1.2215979099273682 sec
# average relative error of u: 2.4674004214606264%
# maximum relative error of u: 4.300673473009839%
#
# Param is 114
# Time elapsed: 1.4562101364135742 sec
# average relative error of u: 2.498589718554476%
# maximum relative error of u: 4.33775535788856%
#
# Param is 115
# Time elapsed: 1.462386131286621 sec
# average relative error of u: 2.5345627959410253%
# maximum relative error of u: 4.38453994093107%
#
# Param is 116
# Time elapsed: 1.5694987773895264 sec
# average relative error of u: 2.5752440290402587%
# maximum relative error of u: 4.46309245008113%
#
# Param is 117
# Time elapsed: 3.7638092041015625 sec
# average relative error of u: 2.620724359152449%
# maximum relative error of u: 4.549214806387561%
#
# Param is 118
# Time elapsed: 1.3023629188537598 sec
# average relative error of u: 2.6711280608031682%
# maximum relative error of u: 4.6423517548734266%
#
# Param is 119
# Time elapsed: 1.1993930339813232 sec
# average relative error of u: 2.7261794669336736%
# maximum relative error of u: 4.742262931616188%
#
# Param is 120
# Time elapsed: 1.32399320602417 sec
# average relative error of u: 2.7860501536781315%
# maximum relative error of u: 4.868176387827981%
#
# Param is 121
# Time elapsed: 7.589706659317017 sec
# average relative error of u: 2.850699154345273%
# maximum relative error of u: 5.013366914409133%
#
# Param is 122
# Time elapsed: 1.011744499206543 sec
# average relative error of u: 2.9199178949587057%
# maximum relative error of u: 5.16614483675353%
#
# Param is 123
# Time elapsed: 0.8161511421203613 sec
# average relative error of u: 2.993788539732711%
# maximum relative error of u: 5.326610109623151%
#
# Param is 124
# Time elapsed: 0.8248677253723145 sec
# average relative error of u: 3.0721942867814755%
# maximum relative error of u: 5.494696268621254%
#
# Param is 125
# Time elapsed: 1.8199493885040283 sec
# average relative error of u: 3.1550464856347196%
# maximum relative error of u: 5.691646460431248%

# %%
print(num_basis)
idx=[0,1,2,3]
num_basis[idx]
# Out:
# [3 4 5 6]
# array([3, 4, 5, 6])

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex23_wave/ex23_POD_bndry_SOPT_avg_rel_err.png")

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex23_wave/ex23_POD_bndry_SOPT_max_rel_err.png")
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
print(num_basis)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
idx=[3]
num_basis[idx]
# Out:
# array([6])

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex23_wave/ex23_POD_{}_bndry_SOPT_avg_rel_err.png".format(int(num_basis[idx])))

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex23_wave/ex23_POD_{}_bndry_SOPT_max_rel_err.png".format(int(num_basis[idx])))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
# figure rel.err vs at given param and POD basis
i=3;j=-1
POD_basis=num_basis[i]                 
param=FOM_parameters[j]

u_gappyPOD=results['solution'][i,j]

ex = np.load('../__data/ex23_wave/ex23_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("POD basis: {} Param: {}".format(POD_basis,param))
plt.show()

# plot original data
vmin=-1; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyPOD[int(nt/4)*i].reshape(ny,nx))#,vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy POD @ t={}'.format(int(nt/4)*i*dt),fontsize=20)
    fig.colorbar(pcm, ax=ax,shrink=0.8)

# fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex23_wave/ex23_POD_{}_param_{}_bndry_SOPT_SOL.png".format(POD_basis,param))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx))#,vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)
    fig.colorbar(pcm, ax=ax,shrink=0.8)

# fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex23_wave/ex23_param_{}_ground_truth.png".format(param))
