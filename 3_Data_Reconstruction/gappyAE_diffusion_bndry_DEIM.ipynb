# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle
import torch
import torch.nn as nn

# %%
# Given parameters
nx = 60
ny = 60
tf = 1.0
dt = 2.0e-3
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims = (ny,nx)

# latent space dim.
f_list=np.array([3,4,5,6])
print('Latent Sapce Dim. {}'.format(f_list))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_DEIM_result = "../__result/ex16_diffusion/ex16_AE_swish_gappy_bndry_DEIM_result_seed_{}.p".format(seed)

# Gauss-Newton params
maxitr=4
tol=1e-8

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# Latent Sapce Dim. [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %%
def DEIM(phi_f, nfeval, unseen=np.array([])):
    
    ninf=np.NINF
    n,m=np.shape(phi_f)
    
    l=0
    u=np.reshape(phi_f[:,l],(n,1))
    r=np.abs(u)
    if len(unseen) >0 :
        r[unseen]=ninf
    p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
    p=p_temp
    U=u
    
    ns=int(np.ceil((nfeval-1)/(m-1)))
    for l in range(1,m):
        u=np.reshape(phi_f[:,l],(n,1))
        for k in range(ns):
            if len(p)==nfeval:
                return p
            c=np.linalg.lstsq(U[p,:],u[p,:],rcond=None)[0]
            r=np.abs(u-U@c)
            r[p]=ninf
            if len(unseen) > 0:
                r[unseen]=ninf
            p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
            p=np.sort(np.append(p,p_temp))
        U=np.concatenate((U,u),axis=1)
         
    return p

# %%
for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))
    
    # file path
    file_path_residual_SVD="../__model/ex16_diffusion/ex16_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)
    
    # DEIM
    with open(file=file_path_residual_SVD, mode='rb') as fff:
        SVD=pickle.load(fff)
    U=SVD['U']; S=SVD['S']
    num_msmt=12
    phi_r=U[:,:num_msmt]
    msmt_idx=DEIM(phi_r,num_msmt,inner_raveled_indicies)
    msmt_idx.sort()

    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig("../__result/ex16_diffusion/ex16_AE_{}_swish_bndry_DEIM_{}_samples_seed_{}.png".format(f,num_msmt,seed))
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [   0    4   41  179  359 2579 2880 3179 3539 3568 3588 3596]
# Dim. of latent space is 4
# # of measurments: 12
# [   0  120  480 1500 2279 2820 3419 3546 3570 3596 3598 3599]
# Dim. of latent space is 5
# # of measurments: 12
# [   0  120  240 1140 1740 2639 3119 3300 3360 3571 3581 3599]
# Dim. of latent space is 6
# # of measurments: 12
# [   0    2   11   18  360 2040 3545 3548 3562 3574 3595 3599]

# %% [markdown]
# # gappyAE

# %%
solution=np.zeros((len(f_list),len(FOM_parameters),nt+1,nx*ny))
reduced=np.zeros((len(f_list),len(FOM_parameters),nt+1,f_list[-1]))
avg_rel_err=np.zeros((len(f_list),len(FOM_parameters)))
rel_err=np.zeros((len(f_list),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(f_list),len(FOM_parameters)))

for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))
    
    # file path
    file_name_AE="../__model/ex16_diffusion/ex16_AE_{}_swish_seed_{}.p".format(f,seed)
    file_path_residual_SVD="../__model/ex16_diffusion/ex16_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)
    
    # DEIM
    with open(file=file_path_residual_SVD, mode='rb') as fff:
        SVD=pickle.load(fff)
    U=SVD['U']; S=SVD['S']
    num_msmt=12
    phi_r=U[:,:num_msmt]
    msmt_idx=DEIM(phi_r,num_msmt,inner_raveled_indicies)
    msmt_idx.sort()
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
    
    # precompute
    ZTphi_r=phi_r[msmt_idx]
    ZTphi_r_pinv=np.linalg.pinv(ZTphi_r)
    phi_rZTphi_r_pinv=phi_r.dot(ZTphi_r_pinv)
        
    with open(file=file_name_AE, mode='rb') as ff:    
        AE = pickle.load(ff)

    en_wu1=AE['en_wu1']
    en_bu1=AE['en_bu1']
    en_wu2=AE['en_wu2']
    de_wu1=AE['de_wu1']
    de_bu1=AE['de_bu1']
    de_wu2=AE['de_wu2']
    de_wu1T=AE['de_wu1T']
    de_wu2T=AE['de_wu2T']
    de_wu2_sp=AE['de_wu2_sp']
    de_wu2T_sp=AE['de_wu2T_sp']
    u_ref=AE['u_ref']

    latent_dim=de_wu1.shape[1]
    
    # numpy version of AE
    def sigmoid_np(input):
        return (1.0/(1.0+np.exp(-input))).astype('float32')

    def encoder_u_np_forward(x):
        z1 = en_wu1.dot(x) + en_bu1
        a1 = z1 * sigmoid_np(z1)
        y = en_wu2.dot(a1)   
        return y

    def decoder_u_np_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = de_wu2.dot(a1)  
        return y

    def decoder_u_sp_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(de_wu2_sp,a1)
        return y

    def decoder_u_np_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = de_wu2.dot(a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(de_wu2T)   
        return y,dydxT

    def decoder_u_sp_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(de_wu2_sp,a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,de_wu2T_sp)
        return y,dydxT
    
    m,M2=de_wu2.shape

    class Decoder_U_FC(nn.Module):

        def __init__(self,):
            super(Decoder_U_FC, self).__init__()
            self.fc1 = nn.Linear(latent_dim,M2)
            self.fc1.weight = nn.Parameter(torch.ones(de_wu1.shape))
            self.fc1.bias = nn.Parameter(torch.ones(de_bu1.shape))
    #         self.fc1.weight = nn.Parameter(torch.tensor(de_wu1))
    #         self.fc1.bias = nn.Parameter(torch.tensor(de_bu1))

            self.fc2 = nn.Linear(M2,m,bias=False)
            self.fc2.weight = nn.Parameter(torch.ones(de_wu2.shape))
    #         self.fc2.weight = nn.Parameter(torch.tensor(de_wu2))

        def forward(self, x):
            x = self.fc1(x)
            x = self.fc2(x)
            return x

    model = Decoder_U_FC()

    x_in=torch.ones(latent_dim)
    y_out=model(x_in)

    p_hr=msmt_idx

    upstream=torch.zeros_like(y_out)
    upstream[p_hr]=1.0

    y_out.backward(upstream)

    # masks for subnet
    wu1_mask=model.fc1.weight.grad
    wu2_mask=model.fc2.weight.grad

    bu1_mask=model.fc1.bias.grad

    # subnet sparse weight
    idx1=wu1_mask.to_sparse()._indices()
    i1=idx1.numpy()[0]
    j1=idx1.numpy()[1]
    v1=de_wu1[i1,j1]
    wu1_sb_sp=sp.csr_matrix(sp.csr_matrix((v1,(i1,j1)),shape=wu1_mask.shape).toarray())

    idx2=wu2_mask.to_sparse()._indices()
    i2=idx2.numpy()[0]
    j2=idx2.numpy()[1]
    v2=de_wu2[i2,j2]
    wu2_sb_sp=sp.csr_matrix(sp.csr_matrix((v2,(i2,j2)),shape=wu2_mask.shape).toarray())

    # subnet compressed weight
    i1,j1,v1=sp.find(wu1_sb_sp)
    i1_unique,i1_inverse=np.unique(i1,return_inverse=True)
    i1_comp=np.arange(i1_unique.size)
    i1_comp=i1_comp[i1_inverse]
    j1_unique,j1_inverse=np.unique(j1,return_inverse=True)
    j1_comp=np.arange(j1_unique.size)
    j1_comp=j1_comp[j1_inverse]
    wu1_sb_comp_sp=sp.csr_matrix((v1,(i1_comp,j1_comp)),shape=(i1_unique.size,j1_unique.size))

    i2,j2,v2=sp.find(wu2_sb_sp)
    i2_unique,i2_inverse=np.unique(i2,return_inverse=True)
    i2_comp=np.arange(i2_unique.size)
    i2_comp=i2_comp[i2_inverse]
    j2_unique,j2_inverse=np.unique(j2,return_inverse=True)
    j2_comp=np.arange(j2_unique.size)
    j2_comp=j2_comp[j2_inverse]
    wu2_sb_comp_sp=sp.csr_matrix((v2,(i2_comp,j2_comp)),shape=(i2_unique.size,j2_unique.size))

    wu1_sb_comp_dense=wu1_sb_comp_sp.toarray()
    wu1_sb_comp_dense=wu1_sb_comp_dense[j2_unique]
    wu2_sb_comp_dense=wu2_sb_comp_sp.toarray()

    wu1_sb_comp_denseT=wu1_sb_comp_dense.T
    wu2_sb_comp_denseT=wu2_sb_comp_dense.T

    # subnet compressed bias
    bu1_sb_comp_dense=de_bu1[i1_unique]
    bu1_sb_comp_dense=bu1_sb_comp_dense[j2_unique]

    # Using sparse matrix
    wu2_sb_comp_sp=sp.csr_matrix(wu2_sb_comp_dense,dtype='float32')
    wu2_sb_comp_spT=sp.csr_matrix(wu2_sb_comp_denseT,dtype='float32')

    def decoder_u_sb_np_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = wu2_sb_comp_dense.dot(a1)  
        return y

    def decoder_u_sb_np_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = wu2_sb_comp_dense.dot(a1) 

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(wu2_sb_comp_denseT)
        return y,dydxT

    def decoder_u_sb_sp_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)
        return y

    def decoder_u_sb_sp_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,wu2_sb_comp_spT)
        return y,dydxT

    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('../__data/ex16_diffusion/ex16_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1).astype('float32')

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_hat0=encoder_u_np_forward(u0.astype('float32')-u_ref)

        # gappyAE
        t_start_gappyAE=time.time()

        # solution
        u_reduced=np.zeros((nt+1,latent_dim))
        u_gappyAE=np.zeros((nt+1,ny*nx))

        # IC
        u_reduced[0]=np.copy(u_hat0)
        u_gappyAE[0]=np.copy(u0)

        for k in range(nt):
#             print("")
#             print(k,"th time step:")

            u_hatw=np.copy(u_reduced[k])

            umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

            umw += u_ref[msmt_idx]

            J_r=-Jg_umT.T
            J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

            r_um_hat = um[k+1]-umw

            res = np.linalg.norm(J_pinv.dot(r_um_hat))
#             res = np.linalg.norm(r_um_hat)
            res_hist=[res]
            for itr in range(maxitr):
                du_hatw = J_pinv.dot(r_um_hat)

                u_hatw -= du_hatw

                umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

                umw += u_ref[msmt_idx]

                J_r=-Jg_umT.T
                J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

                r_um_hat = um[k+1]-umw

                res = np.linalg.norm(J_pinv.dot(r_um_hat))
#                 res = np.linalg.norm(r_um_hat)
                res_hist.append(res)
#                 print(itr,"th Newton iteration", "res:", "{:.8e}".format(res))

                if res<tol:
                    break

            u_reduced[k+1]=u_hatw.copy()
            u_gappyAE[k+1]=u_ref+decoder_u_sp_forward(u_reduced[k+1])

        # elapsed time    
        t_elapsed_gappyAE=time.time()-t_start_gappyAE
        print('Time elapsed: {} sec'.format(t_elapsed_gappyAE))

        # error
        u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                         /np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
                     /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
        print()

        # save result
        solution[ii,jj]=u_gappyAE
        reduced[ii,jj,:,:f]=u_reduced
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyAE
        elapsed_time[ii,jj]=t_elapsed_gappyAE
    
results={'solution':solution,'reduced':reduced,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_DEIM_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [   0    4   41  179  359 2579 2880 3179 3539 3568 3588 3596]
# Param is 75
# Time elapsed: 37.125975370407104 sec
# average relative error of u: 0.2640015553380388%
# maximum relative error of u: 0.5726910581353082%
#
# Param is 76
# Time elapsed: 37.187602519989014 sec
# average relative error of u: 0.21527928712610245%
# maximum relative error of u: 0.5786696120168227%
#
# Param is 77
# Time elapsed: 50.87337064743042 sec
# average relative error of u: 0.16852996679621818%
# maximum relative error of u: 0.5840454836197398%
#
# Param is 78
# Time elapsed: 58.60437822341919 sec
# average relative error of u: 0.12836025895017258%
# maximum relative error of u: 0.5845368829954357%
#
# Param is 79
# Time elapsed: 19.31993794441223 sec
# average relative error of u: 0.10044049344879426%
# maximum relative error of u: 0.5783729678405901%
#
# Param is 80
# Time elapsed: 21.060447454452515 sec
# average relative error of u: 0.08619113212802867%
# maximum relative error of u: 0.5651762430139216%
#
# Param is 81
# Time elapsed: 29.886058568954468 sec
# average relative error of u: 0.08177097978687897%
# maximum relative error of u: 0.5455537401946611%
#
# Param is 82
# Time elapsed: 28.426687955856323 sec
# average relative error of u: 0.08161704924486093%
# maximum relative error of u: 0.5205561057475809%
#
# Param is 83
# Time elapsed: 26.200867176055908 sec
# average relative error of u: 0.08204430718798969%
# maximum relative error of u: 0.4915265918959378%
#
# Param is 84
# Time elapsed: 29.53374981880188 sec
# average relative error of u: 0.08154110516802603%
# maximum relative error of u: 0.46029681894974694%
#
# Param is 85
# Time elapsed: 28.8202805519104 sec
# average relative error of u: 0.07980197342468773%
# maximum relative error of u: 0.4284586252798558%
#
# Param is 86
# Time elapsed: 29.040628671646118 sec
# average relative error of u: 0.07701648189831775%
# maximum relative error of u: 0.3977994014392293%
#
# Param is 87
# Time elapsed: 25.421628713607788 sec
# average relative error of u: 0.07355798184096846%
# maximum relative error of u: 0.3698790575256839%
#
# Param is 88
# Time elapsed: 28.696046829223633 sec
# average relative error of u: 0.06982091764141554%
# maximum relative error of u: 0.3460122636248504%
#
# Param is 89
# Time elapsed: 29.150604963302612 sec
# average relative error of u: 0.06618507460774281%
# maximum relative error of u: 0.3271736778983401%
#
# Param is 90
# Time elapsed: 29.60849142074585 sec
# average relative error of u: 0.06295067848391338%
# maximum relative error of u: 0.3138714538986563%
#
# Param is 91
# Time elapsed: 27.51620054244995 sec
# average relative error of u: 0.06031784495631761%
# maximum relative error of u: 0.3061012307747713%
#
# Param is 92
# Time elapsed: 28.73020601272583 sec
# average relative error of u: 0.058382297308588356%
# maximum relative error of u: 0.30337912943636636%
#
# Param is 93
# Time elapsed: 29.272313117980957 sec
# average relative error of u: 0.05714031940374247%
# maximum relative error of u: 0.3047744486095121%
#
# Param is 94
# Time elapsed: 27.38492250442505 sec
# average relative error of u: 0.056503325400279684%
# maximum relative error of u: 0.30909770271186476%
#
# Param is 95
# Time elapsed: 27.787963151931763 sec
# average relative error of u: 0.05636996515206839%
# maximum relative error of u: 0.31510023475506976%
#
# Param is 96
# Time elapsed: 26.03972029685974 sec
# average relative error of u: 0.05663343143880853%
# maximum relative error of u: 0.3216732378412325%
#
# Param is 97
# Time elapsed: 23.857407093048096 sec
# average relative error of u: 0.05721532253830649%
# maximum relative error of u: 0.32786972145844473%
#
# Param is 98
# Time elapsed: 23.681971788406372 sec
# average relative error of u: 0.05805359635406653%
# maximum relative error of u: 0.3331198697785335%
#
# Param is 99
# Time elapsed: 22.416022777557373 sec
# average relative error of u: 0.059102677674957006%
# maximum relative error of u: 0.33716758680565023%
#
# Param is 100
# Time elapsed: 22.625675678253174 sec
# average relative error of u: 0.06033474824215557%
# maximum relative error of u: 0.34019009826863555%
#
# Param is 101
# Time elapsed: 22.258061408996582 sec
# average relative error of u: 0.061736871365162385%
# maximum relative error of u: 0.34267900791834116%
#
# Param is 102
# Time elapsed: 23.10054612159729 sec
# average relative error of u: 0.06330763610449579%
# maximum relative error of u: 0.34539037590281585%
#
# Param is 103
# Time elapsed: 21.796046018600464 sec
# average relative error of u: 0.06504389240003959%
# maximum relative error of u: 0.34915984461808025%
#
# Param is 104
# Time elapsed: 21.395654678344727 sec
# average relative error of u: 0.06693180815390791%
# maximum relative error of u: 0.3546956580998232%
#
# Param is 105
# Time elapsed: 23.924237966537476 sec
# average relative error of u: 0.06892409978985622%
# maximum relative error of u: 0.3625199526974991%
#
# Param is 106
# Time elapsed: 22.832159280776978 sec
# average relative error of u: 0.07094148640825222%
# maximum relative error of u: 0.37272144182303113%
#
# Param is 107
# Time elapsed: 21.39965510368347 sec
# average relative error of u: 0.07289656103417219%
# maximum relative error of u: 0.3851146740325978%
#
# Param is 108
# Time elapsed: 21.66865849494934 sec
# average relative error of u: 0.07471255386640453%
# maximum relative error of u: 0.3994451109886121%
#
# Param is 109
# Time elapsed: 21.28657102584839 sec
# average relative error of u: 0.07637464747935499%
# maximum relative error of u: 0.4153741079660468%
#
# Param is 110
# Time elapsed: 21.72354769706726 sec
# average relative error of u: 0.07793567657344971%
# maximum relative error of u: 0.43271569557048406%
#
# Param is 111
# Time elapsed: 23.216261625289917 sec
# average relative error of u: 0.07951715163806072%
# maximum relative error of u: 0.45130017990049404%
#
# Param is 112
# Time elapsed: 23.52299928665161 sec
# average relative error of u: 0.08125666034814338%
# maximum relative error of u: 0.4709408103923706%
#
# Param is 113
# Time elapsed: 23.5788893699646 sec
# average relative error of u: 0.08323878374653308%
# maximum relative error of u: 0.49132769227824685%
#
# Param is 114
# Time elapsed: 23.745946884155273 sec
# average relative error of u: 0.08540235954526583%
# maximum relative error of u: 0.5118967044160485%
#
# Param is 115
# Time elapsed: 23.32973623275757 sec
# average relative error of u: 0.08753487611954626%
# maximum relative error of u: 0.5320642351040579%
#
# Param is 116
# Time elapsed: 23.773748874664307 sec
# average relative error of u: 0.08932455420433036%
# maximum relative error of u: 0.5514956841332788%
#
# Param is 117
# Time elapsed: 23.382861137390137 sec
# average relative error of u: 0.09061910909999178%
# maximum relative error of u: 0.5706542290268027%
#
# Param is 118
# Time elapsed: 23.673327922821045 sec
# average relative error of u: 0.09189105692544179%
# maximum relative error of u: 0.5915562325871792%
#
# Param is 119
# Time elapsed: 24.403862237930298 sec
# average relative error of u: 0.09502909958692549%
# maximum relative error of u: 0.6184962901701528%
#
# Param is 120
# Time elapsed: 23.332186460494995 sec
# average relative error of u: 0.10409922958157576%
# maximum relative error of u: 0.6586342414039857%
#
# Param is 121
# Time elapsed: 22.31909465789795 sec
# average relative error of u: 0.12481832838103436%
# maximum relative error of u: 0.7215814610606222%
#
# Param is 122
# Time elapsed: 24.63463258743286 sec
# average relative error of u: 0.1620959981871212%
# maximum relative error of u: 0.8178347263595542%
#
# Param is 123
# Time elapsed: 21.837764501571655 sec
# average relative error of u: 0.21865500945946925%
# maximum relative error of u: 0.9565515270220658%
#
# Param is 124
# Time elapsed: 19.482216119766235 sec
# average relative error of u: 0.29603921549316226%
# maximum relative error of u: 1.1442364248158694%
#
# Param is 125
# Time elapsed: 22.5738263130188 sec
# average relative error of u: 0.3957272166499971%
# maximum relative error of u: 1.3850636662337181%
#
# Dim. of latent space is 4
# # of measurments: 12
# [   0  120  480 1500 2279 2820 3419 3546 3570 3596 3598 3599]
# Param is 75
# Time elapsed: 25.579967737197876 sec
# average relative error of u: 0.2235090997672026%
# maximum relative error of u: 0.8577986325986652%
#
# Param is 76
# Time elapsed: 26.87585163116455 sec
# average relative error of u: 0.17422949341700442%
# maximum relative error of u: 0.7384233381563396%
#
# Param is 77
# Time elapsed: 24.62849760055542 sec
# average relative error of u: 0.1353827166666112%
# maximum relative error of u: 0.6416989997357135%
#
# Param is 78
# Time elapsed: 26.283755779266357 sec
# average relative error of u: 0.10688058156297561%
# maximum relative error of u: 0.5658358198330451%
#
# Param is 79
# Time elapsed: 27.87418007850647 sec
# average relative error of u: 0.08814163652441126%
# maximum relative error of u: 0.5081287141583%
#
# Param is 80
# Time elapsed: 25.123491287231445 sec
# average relative error of u: 0.07756345316803885%
# maximum relative error of u: 0.4650080619145518%
#
# Param is 81
# Time elapsed: 24.275251626968384 sec
# average relative error of u: 0.07250705551099047%
# maximum relative error of u: 0.43290806647206126%
#
# Param is 82
# Time elapsed: 27.390491247177124 sec
# average relative error of u: 0.07021283199613475%
# maximum relative error of u: 0.4086762007400344%
#
# Param is 83
# Time elapsed: 26.755234718322754 sec
# average relative error of u: 0.06872520085197227%
# maximum relative error of u: 0.3900505786745819%
#
# Param is 84
# Time elapsed: 27.12299370765686 sec
# average relative error of u: 0.06706699833500333%
# maximum relative error of u: 0.37583153630448013%
#
# Param is 85
# Time elapsed: 28.44606351852417 sec
# average relative error of u: 0.06494407482112187%
# maximum relative error of u: 0.3653500533448651%
#
# Param is 86
# Time elapsed: 27.656047582626343 sec
# average relative error of u: 0.062462410251964647%
# maximum relative error of u: 0.35870753540023514%
#
# Param is 87
# Time elapsed: 28.257645845413208 sec
# average relative error of u: 0.05991368710253972%
# maximum relative error of u: 0.35600437760819537%
#
# Param is 88
# Time elapsed: 27.273284912109375 sec
# average relative error of u: 0.05762045282237875%
# maximum relative error of u: 0.3571978540871847%
#
# Param is 89
# Time elapsed: 25.70169949531555 sec
# average relative error of u: 0.05584917028665917%
# maximum relative error of u: 0.36216421294330403%
#
# Param is 90
# Time elapsed: 25.88204550743103 sec
# average relative error of u: 0.05475097625874598%
# maximum relative error of u: 0.37033892891003933%
#
# Param is 91
# Time elapsed: 28.500229120254517 sec
# average relative error of u: 0.05434781115502372%
# maximum relative error of u: 0.38102015093721864%
#
# Param is 92
# Time elapsed: 25.70392870903015 sec
# average relative error of u: 0.054570431212845855%
# maximum relative error of u: 0.3932625419697323%
#
# Param is 93
# Time elapsed: 25.99962568283081 sec
# average relative error of u: 0.05530013360307381%
# maximum relative error of u: 0.4063414425150948%
#
# Param is 94
# Time elapsed: 25.195432662963867 sec
# average relative error of u: 0.05641740185758618%
# maximum relative error of u: 0.4195307434305029%
#
# Param is 95
# Time elapsed: 27.595579862594604 sec
# average relative error of u: 0.05781600463354591%
# maximum relative error of u: 0.4323035571224679%
#
# Param is 96
# Time elapsed: 26.671860456466675 sec
# average relative error of u: 0.05941000933488193%
# maximum relative error of u: 0.4442677889094878%
#
# Param is 97
# Time elapsed: 27.58731508255005 sec
# average relative error of u: 0.06112660976640616%
# maximum relative error of u: 0.4551102492874112%
#
# Param is 98
# Time elapsed: 26.66772437095642 sec
# average relative error of u: 0.06290224682404356%
# maximum relative error of u: 0.46461813331250174%
#
# Param is 99
# Time elapsed: 27.637624979019165 sec
# average relative error of u: 0.06468613010268635%
# maximum relative error of u: 0.4725428612049919%
#
# Param is 100
# Time elapsed: 26.624747037887573 sec
# average relative error of u: 0.06645369332483968%
# maximum relative error of u: 0.4787858577598756%
#
# Param is 101
# Time elapsed: 26.64695119857788 sec
# average relative error of u: 0.06819401990293879%
# maximum relative error of u: 0.4831177166514393%
#
# Param is 102
# Time elapsed: 27.23484492301941 sec
# average relative error of u: 0.06992708806588788%
# maximum relative error of u: 0.48543649899573477%
#
# Param is 103
# Time elapsed: 24.811772108078003 sec
# average relative error of u: 0.07167818456936748%
# maximum relative error of u: 0.48563290324636366%
#
# Param is 104
# Time elapsed: 25.01650071144104 sec
# average relative error of u: 0.07346559685119451%
# maximum relative error of u: 0.4837322138958892%
#
# Param is 105
# Time elapsed: 27.519091606140137 sec
# average relative error of u: 0.07527907117759879%
# maximum relative error of u: 0.4800903641669557%
#
# Param is 106
# Time elapsed: 27.838895082473755 sec
# average relative error of u: 0.07707262213944321%
# maximum relative error of u: 0.47497010897938274%
#
# Param is 107
# Time elapsed: 24.889936685562134 sec
# average relative error of u: 0.07874858850124698%
# maximum relative error of u: 0.4692642284030128%
#
# Param is 108
# Time elapsed: 24.472257137298584 sec
# average relative error of u: 0.08019103921614154%
# maximum relative error of u: 0.4636905581966592%
#
# Param is 109
# Time elapsed: 25.81175136566162 sec
# average relative error of u: 0.08128187928139838%
# maximum relative error of u: 0.45927427262735354%
#
# Param is 110
# Time elapsed: 24.318614721298218 sec
# average relative error of u: 0.08194867663038492%
# maximum relative error of u: 0.45689857583801985%
#
# Param is 111
# Time elapsed: 25.648804426193237 sec
# average relative error of u: 0.0822025256401142%
# maximum relative error of u: 0.45754085813210543%
#
# Param is 112
# Time elapsed: 28.181137323379517 sec
# average relative error of u: 0.08214044574514294%
# maximum relative error of u: 0.46180718088130507%
#
# Param is 113
# Time elapsed: 24.943422079086304 sec
# average relative error of u: 0.08191503745067603%
# maximum relative error of u: 0.4702215729598791%
#
# Param is 114
# Time elapsed: 25.451008081436157 sec
# average relative error of u: 0.08165428976512032%
# maximum relative error of u: 0.48297896220435677%
#
# Param is 115
# Time elapsed: 30.426453351974487 sec
# average relative error of u: 0.08134673698001829%
# maximum relative error of u: 0.49994330039588913%
#
# Param is 116
# Time elapsed: 24.9358229637146 sec
# average relative error of u: 0.08079498164338048%
# maximum relative error of u: 0.5209227446434949%
#
# Param is 117
# Time elapsed: 25.066595554351807 sec
# average relative error of u: 0.0797528603345045%
# maximum relative error of u: 0.5459011180180379%
#
# Param is 118
# Time elapsed: 26.474114179611206 sec
# average relative error of u: 0.07845897131028759%
# maximum relative error of u: 0.5757010260563111%
#
# Param is 119
# Time elapsed: 28.212131023406982 sec
# average relative error of u: 0.0788159184680059%
# maximum relative error of u: 0.6128473676292147%
#
# Param is 120
# Time elapsed: 26.969751119613647 sec
# average relative error of u: 0.08592131149879458%
# maximum relative error of u: 0.6626790569487886%
#
# Param is 121
# Time elapsed: 27.349281549453735 sec
# average relative error of u: 0.10727897994521286%
# maximum relative error of u: 0.7336770729257361%
#
# Param is 122
# Time elapsed: 26.04434847831726 sec
# average relative error of u: 0.148282253704546%
# maximum relative error of u: 0.8368929226304445%
#
# Param is 123
# Time elapsed: 22.765363931655884 sec
# average relative error of u: 0.2108361182731759%
# maximum relative error of u: 0.9838898203600674%
#
# Param is 124
# Time elapsed: 21.35194706916809 sec
# average relative error of u: 0.2958494382940632%
# maximum relative error of u: 1.1844539498741389%
#
# Param is 125
# Time elapsed: 29.009533643722534 sec
# average relative error of u: 0.40447484487859925%
# maximum relative error of u: 1.4454398803375506%
#
# Dim. of latent space is 5
# # of measurments: 12
# [   0  120  240 1140 1740 2639 3119 3300 3360 3571 3581 3599]
# Param is 75
# Time elapsed: 31.145100355148315 sec
# average relative error of u: 0.36807362963961426%
# maximum relative error of u: 0.6842871708553393%
#
# Param is 76
# Time elapsed: 32.304959535598755 sec
# average relative error of u: 0.27515817223237565%
# maximum relative error of u: 0.5767499922606157%
#
# Param is 77
# Time elapsed: 31.2853524684906 sec
# average relative error of u: 0.2027088926718089%
# maximum relative error of u: 0.4999681599600292%
#
# Param is 78
# Time elapsed: 30.89190125465393 sec
# average relative error of u: 0.14947168255032126%
# maximum relative error of u: 0.448023350311457%
#
# Param is 79
# Time elapsed: 30.363593101501465 sec
# average relative error of u: 0.11339796266931682%
# maximum relative error of u: 0.4141350249112424%
#
# Param is 80
# Time elapsed: 31.307934999465942 sec
# average relative error of u: 0.09117924573141467%
# maximum relative error of u: 0.39190056642343546%
#
# Param is 81
# Time elapsed: 30.4986789226532 sec
# average relative error of u: 0.07841140741783025%
# maximum relative error of u: 0.37638827795714225%
#
# Param is 82
# Time elapsed: 30.399453163146973 sec
# average relative error of u: 0.07097680849523291%
# maximum relative error of u: 0.36440428851204015%
#
# Param is 83
# Time elapsed: 28.40881896018982 sec
# average relative error of u: 0.06636388475544176%
# maximum relative error of u: 0.35416282865193505%
#
# Param is 84
# Time elapsed: 30.499510049819946 sec
# average relative error of u: 0.06360445408740564%
# maximum relative error of u: 0.34478173244640226%
#
# Param is 85
# Time elapsed: 28.732771158218384 sec
# average relative error of u: 0.06242818470944383%
# maximum relative error of u: 0.33584290751730417%
#
# Param is 86
# Time elapsed: 28.92306923866272 sec
# average relative error of u: 0.06257428146033765%
# maximum relative error of u: 0.3271334898666498%
#
# Param is 87
# Time elapsed: 29.76314091682434 sec
# average relative error of u: 0.06356161852599233%
# maximum relative error of u: 0.31841829187526155%
#
# Param is 88
# Time elapsed: 24.272031784057617 sec
# average relative error of u: 0.06485934137993085%
# maximum relative error of u: 0.30969861638282403%
#
# Param is 89
# Time elapsed: 20.471556425094604 sec
# average relative error of u: 0.06605147797479458%
# maximum relative error of u: 0.30114446888879076%
#
# Param is 90
# Time elapsed: 21.664178371429443 sec
# average relative error of u: 0.06695355378004898%
# maximum relative error of u: 0.2931068066444576%
#
# Param is 91
# Time elapsed: 19.136605739593506 sec
# average relative error of u: 0.06758633153777638%
# maximum relative error of u: 0.28622106180883217%
#
# Param is 92
# Time elapsed: 18.305139541625977 sec
# average relative error of u: 0.06810631545968018%
# maximum relative error of u: 0.2812343294586275%
#
# Param is 93
# Time elapsed: 17.98259687423706 sec
# average relative error of u: 0.06867533404297439%
# maximum relative error of u: 0.27865632831739084%
#
# Param is 94
# Time elapsed: 18.238271474838257 sec
# average relative error of u: 0.06937077143394516%
# maximum relative error of u: 0.2785298304847396%
#
# Param is 95
# Time elapsed: 17.92658567428589 sec
# average relative error of u: 0.07013707143234688%
# maximum relative error of u: 0.28038141087163887%
#
# Param is 96
# Time elapsed: 17.909701824188232 sec
# average relative error of u: 0.07084606199459817%
# maximum relative error of u: 0.2834683659292822%
#
# Param is 97
# Time elapsed: 17.33063817024231 sec
# average relative error of u: 0.07143839227865383%
# maximum relative error of u: 0.28697741860335435%
#
# Param is 98
# Time elapsed: 17.777194023132324 sec
# average relative error of u: 0.0720528749563795%
# maximum relative error of u: 0.2903427507788986%
#
# Param is 99
# Time elapsed: 17.398515462875366 sec
# average relative error of u: 0.07305379721444459%
# maximum relative error of u: 0.29348571926523015%
#
# Param is 100
# Time elapsed: 17.698899030685425 sec
# average relative error of u: 0.07486333131470191%
# maximum relative error of u: 0.29672460463102013%
#
# Param is 101
# Time elapsed: 17.367584466934204 sec
# average relative error of u: 0.07769013039388192%
# maximum relative error of u: 0.30070632223340266%
#
# Param is 102
# Time elapsed: 18.37779450416565 sec
# average relative error of u: 0.08139499963720633%
# maximum relative error of u: 0.3061842880129033%
#
# Param is 103
# Time elapsed: 18.524341344833374 sec
# average relative error of u: 0.08555824692878689%
# maximum relative error of u: 0.3137372197138758%
#
# Param is 104
# Time elapsed: 24.565352201461792 sec
# average relative error of u: 0.08966945068179796%
# maximum relative error of u: 0.32368662674959425%
#
# Param is 105
# Time elapsed: 34.45024633407593 sec
# average relative error of u: 0.0932680465653191%
# maximum relative error of u: 0.33598574676228066%
#
# Param is 106
# Time elapsed: 25.20413851737976 sec
# average relative error of u: 0.09599178009214693%
# maximum relative error of u: 0.3502464950979101%
#
# Param is 107
# Time elapsed: 22.742302894592285 sec
# average relative error of u: 0.0975759992705936%
# maximum relative error of u: 0.3658440772021641%
#
# Param is 108
# Time elapsed: 47.33272123336792 sec
# average relative error of u: 0.0978743349622511%
# maximum relative error of u: 0.38209767429809394%
#
# Param is 109
# Time elapsed: 21.388532876968384 sec
# average relative error of u: 0.09688087144388925%
# maximum relative error of u: 0.39833133727866676%
#
# Param is 110
# Time elapsed: 42.205237865448 sec
# average relative error of u: 0.09475283294869202%
# maximum relative error of u: 0.4139383748926171%
#
# Param is 111
# Time elapsed: 40.09111785888672 sec
# average relative error of u: 0.09180503783234438%
# maximum relative error of u: 0.4284144327108992%
#
# Param is 112
# Time elapsed: 25.29873776435852 sec
# average relative error of u: 0.08850574369516309%
# maximum relative error of u: 0.44123162943274724%
#
# Param is 113
# Time elapsed: 25.450299501419067 sec
# average relative error of u: 0.08536531933870502%
# maximum relative error of u: 0.4517726970610393%
#
# Param is 114
# Time elapsed: 42.90427613258362 sec
# average relative error of u: 0.08281500656035608%
# maximum relative error of u: 0.4595310969758102%
#
# Param is 115
# Time elapsed: 19.499850749969482 sec
# average relative error of u: 0.08107700556470611%
# maximum relative error of u: 0.4638537077575497%
#
# Param is 116
# Time elapsed: 34.03444242477417 sec
# average relative error of u: 0.08028242245857506%
# maximum relative error of u: 0.46458100027801824%
#
# Param is 117
# Time elapsed: 53.639222621917725 sec
# average relative error of u: 0.08104819176277336%
# maximum relative error of u: 0.4626967243492466%
#
# Param is 118
# Time elapsed: 36.30903744697571 sec
# average relative error of u: 0.08562386235064465%
# maximum relative error of u: 0.4622151792188721%
#
# Param is 119
# Time elapsed: 25.401094436645508 sec
# average relative error of u: 0.0988857643749629%
# maximum relative error of u: 0.47234142314113603%
#
# Param is 120
# Time elapsed: 30.477240800857544 sec
# average relative error of u: 0.12713445063663964%
# maximum relative error of u: 0.5092829410497643%
#
# Param is 121
# Time elapsed: 29.991145372390747 sec
# average relative error of u: 0.17529174691854424%
# maximum relative error of u: 0.5932275622862447%
#
# Param is 122
# Time elapsed: 30.55124521255493 sec
# average relative error of u: 0.24638088333001637%
# maximum relative error of u: 0.7402136330157625%
#
# Param is 123
# Time elapsed: 33.13462495803833 sec
# average relative error of u: 0.3428255043543738%
# maximum relative error of u: 0.9581100296900432%
#
# Param is 124
# Time elapsed: 29.394099235534668 sec
# average relative error of u: 0.46716364737796545%
# maximum relative error of u: 1.2498064032511955%
#
# Param is 125
# Time elapsed: 27.044190645217896 sec
# average relative error of u: 0.6220672003832503%
# maximum relative error of u: 1.6168033810422435%
#
# Dim. of latent space is 6
# # of measurments: 12
# [   0    2   11   18  360 2040 3545 3548 3562 3574 3595 3599]
# Param is 75
# Time elapsed: 31.302762508392334 sec
# average relative error of u: 0.2526693500209515%
# maximum relative error of u: 0.8810865761902585%
#
# Param is 76
# Time elapsed: 31.49615740776062 sec
# average relative error of u: 0.19179955935042103%
# maximum relative error of u: 0.7414122313882882%
#
# Param is 77
# Time elapsed: 32.08026194572449 sec
# average relative error of u: 0.14306487011613564%
# maximum relative error of u: 0.6393853593486257%
#
# Param is 78
# Time elapsed: 31.9434916973114 sec
# average relative error of u: 0.10656427949599197%
# maximum relative error of u: 0.5709520252813858%
#
# Param is 79
# Time elapsed: 30.804094552993774 sec
# average relative error of u: 0.08222056842799469%
# maximum relative error of u: 0.5280764374936657%
#
# Param is 80
# Time elapsed: 32.342780351638794 sec
# average relative error of u: 0.06903136697693886%
# maximum relative error of u: 0.5008150964379597%
#
# Param is 81
# Time elapsed: 31.022810459136963 sec
# average relative error of u: 0.06413448428269612%
# maximum relative error of u: 0.48043363040925613%
#
# Param is 82
# Time elapsed: 26.504093647003174 sec
# average relative error of u: 0.06360047842070644%
# maximum relative error of u: 0.4610099689763725%
#
# Param is 83
# Time elapsed: 32.13088917732239 sec
# average relative error of u: 0.06440540956712797%
# maximum relative error of u: 0.43942913477726375%
#
# Param is 84
# Time elapsed: 32.03163719177246 sec
# average relative error of u: 0.06504580396355088%
# maximum relative error of u: 0.41469047994343045%
#
# Param is 85
# Time elapsed: 28.790446758270264 sec
# average relative error of u: 0.0650511705488323%
# maximum relative error of u: 0.3871435835650665%
#
# Param is 86
# Time elapsed: 30.346665859222412 sec
# average relative error of u: 0.06442632787102366%
# maximum relative error of u: 0.35795085049052927%
#
# Param is 87
# Time elapsed: 30.013376474380493 sec
# average relative error of u: 0.06335425834841121%
# maximum relative error of u: 0.3287098259707435%
#
# Param is 88
# Time elapsed: 30.536837339401245 sec
# average relative error of u: 0.062025440159775236%
# maximum relative error of u: 0.30118083774216375%
#
# Param is 89
# Time elapsed: 28.645496368408203 sec
# average relative error of u: 0.06058138694506517%
# maximum relative error of u: 0.27675016945573694%
#
# Param is 90
# Time elapsed: 30.92332363128662 sec
# average relative error of u: 0.059106719307542945%
# maximum relative error of u: 0.25651063609557967%
#
# Param is 91
# Time elapsed: 30.110851764678955 sec
# average relative error of u: 0.057647222128930684%
# maximum relative error of u: 0.24088255102460315%
#
# Param is 92
# Time elapsed: 30.61126732826233 sec
# average relative error of u: 0.05624215134436525%
# maximum relative error of u: 0.22979073531618743%
#
# Param is 93
# Time elapsed: 31.705715894699097 sec
# average relative error of u: 0.05494652243728036%
# maximum relative error of u: 0.22270373993271458%
#
# Param is 94
# Time elapsed: 30.562268018722534 sec
# average relative error of u: 0.05381963413492504%
# maximum relative error of u: 0.2189255071800238%
#
# Param is 95
# Time elapsed: 31.619122982025146 sec
# average relative error of u: 0.05292991435050096%
# maximum relative error of u: 0.21767837276937224%
#
# Param is 96
# Time elapsed: 30.236701250076294 sec
# average relative error of u: 0.052334447049206166%
# maximum relative error of u: 0.21838988869677073%
#
# Param is 97
# Time elapsed: 32.28660726547241 sec
# average relative error of u: 0.052066342695445585%
# maximum relative error of u: 0.22067418966112032%
#
# Param is 98
# Time elapsed: 33.422333002090454 sec
# average relative error of u: 0.05213096089384093%
# maximum relative error of u: 0.2244921733317598%
#
# Param is 99
# Time elapsed: 33.85295844078064 sec
# average relative error of u: 0.052519272367071865%
# maximum relative error of u: 0.22998466776331752%
#
# Param is 100
# Time elapsed: 30.25567388534546 sec
# average relative error of u: 0.05320347651287527%
# maximum relative error of u: 0.23741263195402978%
#
# Param is 101
# Time elapsed: 30.86913275718689 sec
# average relative error of u: 0.05414005055292653%
# maximum relative error of u: 0.24692422578479656%
#
# Param is 102
# Time elapsed: 32.071526527404785 sec
# average relative error of u: 0.05526285066470396%
# maximum relative error of u: 0.2582957422361235%
#
# Param is 103
# Time elapsed: 29.70265531539917 sec
# average relative error of u: 0.05648352074215506%
# maximum relative error of u: 0.27115536760821923%
#
# Param is 104
# Time elapsed: 30.333789348602295 sec
# average relative error of u: 0.05768272795814161%
# maximum relative error of u: 0.2844278905907699%
#
# Param is 105
# Time elapsed: 30.718228578567505 sec
# average relative error of u: 0.058715735997201035%
# maximum relative error of u: 0.2970720086488768%
#
# Param is 106
# Time elapsed: 31.438446521759033 sec
# average relative error of u: 0.05943816951812919%
# maximum relative error of u: 0.30796321448226993%
#
# Param is 107
# Time elapsed: 30.132853984832764 sec
# average relative error of u: 0.059715429145774476%
# maximum relative error of u: 0.31588897181219705%
#
# Param is 108
# Time elapsed: 32.570937395095825 sec
# average relative error of u: 0.05948536039287153%
# maximum relative error of u: 0.3200833757682866%
#
# Param is 109
# Time elapsed: 33.47244930267334 sec
# average relative error of u: 0.05878185358621837%
# maximum relative error of u: 0.32029666920692196%
#
# Param is 110
# Time elapsed: 32.92917513847351 sec
# average relative error of u: 0.05783810170140407%
# maximum relative error of u: 0.31732465061827847%
#
# Param is 111
# Time elapsed: 34.79149103164673 sec
# average relative error of u: 0.05715055683548159%
# maximum relative error of u: 0.31340723150153504%
#
# Param is 112
# Time elapsed: 33.67216920852661 sec
# average relative error of u: 0.05746867431473116%
# maximum relative error of u: 0.31284886142777635%
#
# Param is 113
# Time elapsed: 32.27783942222595 sec
# average relative error of u: 0.05953396825313747%
# maximum relative error of u: 0.32138512455429535%
#
# Param is 114
# Time elapsed: 31.691030025482178 sec
# average relative error of u: 0.06358648878369348%
# maximum relative error of u: 0.3446762457392275%
#
# Param is 115
# Time elapsed: 31.04809331893921 sec
# average relative error of u: 0.0690996720541046%
# maximum relative error of u: 0.38565450690168435%
#
# Param is 116
# Time elapsed: 28.838762521743774 sec
# average relative error of u: 0.07508282990850867%
# maximum relative error of u: 0.4435629854055602%
#
# Param is 117
# Time elapsed: 29.841248750686646 sec
# average relative error of u: 0.08070357711968482%
# maximum relative error of u: 0.515835959322279%
#
# Param is 118
# Time elapsed: 31.6539306640625 sec
# average relative error of u: 0.08591946677264484%
# maximum relative error of u: 0.5993239650146208%
#
# Param is 119
# Time elapsed: 30.303465604782104 sec
# average relative error of u: 0.09224654266273699%
# maximum relative error of u: 0.6921162020164435%
#
# Param is 120
# Time elapsed: 32.39198565483093 sec
# average relative error of u: 0.1035812218218869%
# maximum relative error of u: 0.7935479271417347%
#
# Param is 121
# Time elapsed: 29.98052740097046 sec
# average relative error of u: 0.12590805064734026%
# maximum relative error of u: 0.9040803846581723%
#
# Param is 122
# Time elapsed: 32.82587265968323 sec
# average relative error of u: 0.1650002679407999%
# maximum relative error of u: 1.0261385051078318%
#
# Param is 123
# Time elapsed: 33.36799621582031 sec
# average relative error of u: 0.22447591822360854%
# maximum relative error of u: 1.1651119873634541%
#
# Param is 124
# Time elapsed: 33.065972328186035 sec
# average relative error of u: 0.30633106309424457%
# maximum relative error of u: 1.3305490924224022%
#
# Param is 125
# Time elapsed: 32.59649348258972 sec
# average relative error of u: 0.41209205356744727%
# maximum relative error of u: 1.5362690306682671%

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

idx=[0,1,2,3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_AE_{}_DEIM_avg_rel_err_seed_{}.png".format(f,seed))

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_AE_{}_DEIM_max_rel_err_seed_{}.png".format(f,seed))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# idx=[0,1,2,3]
idx = [3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
plt.show()

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
plt.show()

# %%
print(f_list)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=3; j=-1        
f=f_list[i]
param=FOM_parameters[j]

u_gappyAE=results['solution'][i,j]

ex = np.load('../__data/ex16_diffusion/ex16_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("Latent Dim: {}, Param: {}".format(f,param))
plt.show()

# error
u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                 /np.linalg.norm(u_full,ord=2,axis=1)*100
u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
             /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
print("average relative error of u: {}%".format(u_avg_rel_err))
print()
print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
    
# plot original data
vmin=0; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy AE @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex16_diffusion/ex16_AE_{}_DEIM_SOL_seed_{}.png".format(f,seed))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex16_diffusion/ex16_ground_truth.png")
# Out:
# average relative error of u: 0.41209205356744727%
#
# maximum relative error of u: 1.5362690306682671%

# %%
i=3; j=-1
f=f_list[i]; param=FOM_parameters[j]
print("f={}".format(f))
print("param={}".format(param))
plt.plot(results['reduced'][i,j][:,:f])
plt.legend(np.arange(f))
plt.show()
# Out:
# f=6
# param=125
