# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle
import torch
import torch.nn as nn

# %%
# Given parameters
nx = 60
ny = 60
tf = 1.0
dt = 2.0e-3
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims = (ny,nx)

# latent space dim.
f_list=np.array([3,4,5,6])
print('Latent Sapce Dim. {}'.format(f_list))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_SOPT_result = "../__result/ex16_diffusion/ex16_AE_swish_gappy_bndry_SOPT_result_seed_{}.p".format(seed)

# Gauss-Newton params
maxitr=4
tol=1e-8

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# Latent Sapce Dim. [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %%
# S-OPT
file_path_SOPT="/home/test/pylibROM_docker/pylibROM/tests/model/ex16_AE_bndry_SOPT_no_oversampling.p"
with open(file=file_path_SOPT, mode='rb') as ff:  
        msmt_idx_list = pickle.load(ff)

# %%
for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))

    # file path
    file_path_residual_SVD="../__model/ex16_diffusion/ex16_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)

    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig("../__result/ex16_diffusion/ex16_AE_{}_swish_bndry_SOPT_{}_samples_seed_{}.png".format(f,num_msmt,seed))
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [   0    8   18  240  419 2760 3179 3420 3564 3580 3594 3599]
# Dim. of latent space is 4
# # of measurments: 12
# [   0   28  359  600  779  960 2160 2339 3059 3569 3592 3596]
# Dim. of latent space is 5
# # of measurments: 12
# [   0   16   59  360 1740 1860 2339 2760 3359 3543 3547 3595]
# Dim. of latent space is 6
# # of measurments: 12
# [   0   10   19   29   45   58  180 1680 3545 3562 3574 3595]

# %% [markdown]
# # gappyAE

# %%
solution=np.zeros((len(f_list),len(FOM_parameters),nt+1,nx*ny))
reduced=np.zeros((len(f_list),len(FOM_parameters),nt+1,f_list[-1]))
avg_rel_err=np.zeros((len(f_list),len(FOM_parameters)))
rel_err=np.zeros((len(f_list),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(f_list),len(FOM_parameters)))

for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))
    
    # file path
    file_name_AE="../__model/ex16_diffusion/ex16_AE_{}_swish_seed_{}.p".format(f,seed)
    file_path_residual_SVD="../__model/ex16_diffusion/ex16_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)
    
    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
    
    # precompute
    with open(file=file_path_residual_SVD, mode='rb') as fff:
        SVD=pickle.load(fff)
    U=SVD['U']
    phi_r=U[:,:num_msmt]
    ZTphi_r=phi_r[msmt_idx]
    ZTphi_r_pinv=np.linalg.pinv(ZTphi_r)
    phi_rZTphi_r_pinv=phi_r.dot(ZTphi_r_pinv)
        
    with open(file=file_name_AE, mode='rb') as ff:    
        AE = pickle.load(ff)

    en_wu1=AE['en_wu1']
    en_bu1=AE['en_bu1']
    en_wu2=AE['en_wu2']
    de_wu1=AE['de_wu1']
    de_bu1=AE['de_bu1']
    de_wu2=AE['de_wu2']
    de_wu1T=AE['de_wu1T']
    de_wu2T=AE['de_wu2T']
    de_wu2_sp=AE['de_wu2_sp']
    de_wu2T_sp=AE['de_wu2T_sp']
    u_ref=AE['u_ref']

    latent_dim=de_wu1.shape[1]
    
    # numpy version of AE
    def sigmoid_np(input):
        return (1.0/(1.0+np.exp(-input))).astype('float32')

    def encoder_u_np_forward(x):
        z1 = en_wu1.dot(x) + en_bu1
        a1 = z1 * sigmoid_np(z1)
        y = en_wu2.dot(a1)   
        return y

    def decoder_u_np_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = de_wu2.dot(a1)  
        return y

    def decoder_u_sp_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(de_wu2_sp,a1)
        return y

    def decoder_u_np_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = de_wu2.dot(a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(de_wu2T)   
        return y,dydxT

    def decoder_u_sp_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(de_wu2_sp,a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,de_wu2T_sp)
        return y,dydxT
    
    m,M2=de_wu2.shape

    class Decoder_U_FC(nn.Module):

        def __init__(self,):
            super(Decoder_U_FC, self).__init__()
            self.fc1 = nn.Linear(latent_dim,M2)
            self.fc1.weight = nn.Parameter(torch.ones(de_wu1.shape))
            self.fc1.bias = nn.Parameter(torch.ones(de_bu1.shape))
    #         self.fc1.weight = nn.Parameter(torch.tensor(de_wu1))
    #         self.fc1.bias = nn.Parameter(torch.tensor(de_bu1))

            self.fc2 = nn.Linear(M2,m,bias=False)
            self.fc2.weight = nn.Parameter(torch.ones(de_wu2.shape))
    #         self.fc2.weight = nn.Parameter(torch.tensor(de_wu2))

        def forward(self, x):
            x = self.fc1(x)
            x = self.fc2(x)
            return x

    model = Decoder_U_FC()

    x_in=torch.ones(latent_dim)
    y_out=model(x_in)

    p_hr=msmt_idx

    upstream=torch.zeros_like(y_out)
    upstream[p_hr]=1.0

    y_out.backward(upstream)

    # masks for subnet
    wu1_mask=model.fc1.weight.grad
    wu2_mask=model.fc2.weight.grad

    bu1_mask=model.fc1.bias.grad

    # subnet sparse weight
    idx1=wu1_mask.to_sparse()._indices()
    i1=idx1.numpy()[0]
    j1=idx1.numpy()[1]
    v1=de_wu1[i1,j1]
    wu1_sb_sp=sp.csr_matrix(sp.csr_matrix((v1,(i1,j1)),shape=wu1_mask.shape).toarray())

    idx2=wu2_mask.to_sparse()._indices()
    i2=idx2.numpy()[0]
    j2=idx2.numpy()[1]
    v2=de_wu2[i2,j2]
    wu2_sb_sp=sp.csr_matrix(sp.csr_matrix((v2,(i2,j2)),shape=wu2_mask.shape).toarray())

    # subnet compressed weight
    i1,j1,v1=sp.find(wu1_sb_sp)
    i1_unique,i1_inverse=np.unique(i1,return_inverse=True)
    i1_comp=np.arange(i1_unique.size)
    i1_comp=i1_comp[i1_inverse]
    j1_unique,j1_inverse=np.unique(j1,return_inverse=True)
    j1_comp=np.arange(j1_unique.size)
    j1_comp=j1_comp[j1_inverse]
    wu1_sb_comp_sp=sp.csr_matrix((v1,(i1_comp,j1_comp)),shape=(i1_unique.size,j1_unique.size))

    i2,j2,v2=sp.find(wu2_sb_sp)
    i2_unique,i2_inverse=np.unique(i2,return_inverse=True)
    i2_comp=np.arange(i2_unique.size)
    i2_comp=i2_comp[i2_inverse]
    j2_unique,j2_inverse=np.unique(j2,return_inverse=True)
    j2_comp=np.arange(j2_unique.size)
    j2_comp=j2_comp[j2_inverse]
    wu2_sb_comp_sp=sp.csr_matrix((v2,(i2_comp,j2_comp)),shape=(i2_unique.size,j2_unique.size))

    wu1_sb_comp_dense=wu1_sb_comp_sp.toarray()
    wu1_sb_comp_dense=wu1_sb_comp_dense[j2_unique]
    wu2_sb_comp_dense=wu2_sb_comp_sp.toarray()

    wu1_sb_comp_denseT=wu1_sb_comp_dense.T
    wu2_sb_comp_denseT=wu2_sb_comp_dense.T

    # subnet compressed bias
    bu1_sb_comp_dense=de_bu1[i1_unique]
    bu1_sb_comp_dense=bu1_sb_comp_dense[j2_unique]

    # Using sparse matrix
    wu2_sb_comp_sp=sp.csr_matrix(wu2_sb_comp_dense,dtype='float32')
    wu2_sb_comp_spT=sp.csr_matrix(wu2_sb_comp_denseT,dtype='float32')

    def decoder_u_sb_np_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = wu2_sb_comp_dense.dot(a1)  
        return y

    def decoder_u_sb_np_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = wu2_sb_comp_dense.dot(a1) 

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(wu2_sb_comp_denseT)
        return y,dydxT

    def decoder_u_sb_sp_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)
        return y

    def decoder_u_sb_sp_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,wu2_sb_comp_spT)
        return y,dydxT

    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('../__data/ex16_diffusion/ex16_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1).astype('float32')

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_hat0=encoder_u_np_forward(u0.astype('float32')-u_ref)

        # gappyAE
        t_start_gappyAE=time.time()

        # solution
        u_reduced=np.zeros((nt+1,latent_dim))
        u_gappyAE=np.zeros((nt+1,ny*nx))

        # IC
        u_reduced[0]=np.copy(u_hat0)
        u_gappyAE[0]=np.copy(u0)

        for k in range(nt):
#             print("")
#             print(k,"th time step:")

            u_hatw=np.copy(u_reduced[k])

            umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

            umw += u_ref[msmt_idx]

            J_r=-Jg_umT.T
            J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

            r_um_hat = um[k+1]-umw

            res = np.linalg.norm(J_pinv.dot(r_um_hat))
#             res = np.linalg.norm(r_um_hat)
            res_hist=[res]
            for itr in range(maxitr):
                du_hatw = J_pinv.dot(r_um_hat)

                u_hatw -= du_hatw

                umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

                umw += u_ref[msmt_idx]

                J_r=-Jg_umT.T
                J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

                r_um_hat = um[k+1]-umw

                res = np.linalg.norm(J_pinv.dot(r_um_hat))
#                 res = np.linalg.norm(r_um_hat)
                res_hist.append(res)
#                 print(itr,"th Newton iteration", "res:", "{:.8e}".format(res))

                if res<tol:
                    break

            u_reduced[k+1]=u_hatw.copy()
            u_gappyAE[k+1]=u_ref+decoder_u_sp_forward(u_reduced[k+1])

        # elapsed time    
        t_elapsed_gappyAE=time.time()-t_start_gappyAE
        print('Time elapsed: {} sec'.format(t_elapsed_gappyAE))

        # error
        u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                         /np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
                     /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
        print()

        # save result
        solution[ii,jj]=u_gappyAE
        reduced[ii,jj,:,:f]=u_reduced
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyAE
        elapsed_time[ii,jj]=t_elapsed_gappyAE
    
results={'solution':solution,'reduced':reduced,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_SOPT_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [   0    8   18  240  419 2760 3179 3420 3564 3580 3594 3599]
# Param is 75
# Time elapsed: 26.70952796936035 sec
# average relative error of u: 0.23984286712505223%
# maximum relative error of u: 0.4732139678932111%
#
# Param is 76
# Time elapsed: 16.228004455566406 sec
# average relative error of u: 0.1869584812078162%
# maximum relative error of u: 0.44609649092581793%
#
# Param is 77
# Time elapsed: 32.605611085891724 sec
# average relative error of u: 0.14457916495310622%
# maximum relative error of u: 0.42169030837667165%
#
# Param is 78
# Time elapsed: 35.315415143966675 sec
# average relative error of u: 0.1122406222048654%
# maximum relative error of u: 0.4003552909016255%
#
# Param is 79
# Time elapsed: 22.739052772521973 sec
# average relative error of u: 0.0889657479308168%
# maximum relative error of u: 0.38249526114752047%
#
# Param is 80
# Time elapsed: 45.31801414489746 sec
# average relative error of u: 0.0732561714657806%
# maximum relative error of u: 0.36813213547648954%
#
# Param is 81
# Time elapsed: 45.36244583129883 sec
# average relative error of u: 0.06330710139123638%
# maximum relative error of u: 0.3568195759681344%
#
# Param is 82
# Time elapsed: 32.856003522872925 sec
# average relative error of u: 0.05740197168263464%
# maximum relative error of u: 0.34785583864967634%
#
# Param is 83
# Time elapsed: 27.85713529586792 sec
# average relative error of u: 0.05425320564608476%
# maximum relative error of u: 0.3404724954328092%
#
# Param is 84
# Time elapsed: 29.25457763671875 sec
# average relative error of u: 0.05301195531077531%
# maximum relative error of u: 0.33409586737353414%
#
# Param is 85
# Time elapsed: 26.4463894367218 sec
# average relative error of u: 0.05305624515985308%
# maximum relative error of u: 0.32839428824134037%
#
# Param is 86
# Time elapsed: 27.307637214660645 sec
# average relative error of u: 0.053841741784585645%
# maximum relative error of u: 0.32327338210528556%
#
# Param is 87
# Time elapsed: 26.270980834960938 sec
# average relative error of u: 0.054874800569828804%
# maximum relative error of u: 0.3188493537838555%
#
# Param is 88
# Time elapsed: 29.40972328186035 sec
# average relative error of u: 0.05578034911133632%
# maximum relative error of u: 0.31529489023772495%
#
# Param is 89
# Time elapsed: 30.13075351715088 sec
# average relative error of u: 0.05634924356496991%
# maximum relative error of u: 0.3127917357840532%
#
# Param is 90
# Time elapsed: 27.89338254928589 sec
# average relative error of u: 0.056536867564581185%
# maximum relative error of u: 0.31141715123922575%
#
# Param is 91
# Time elapsed: 25.23529577255249 sec
# average relative error of u: 0.05643906907347651%
# maximum relative error of u: 0.31114308729329704%
#
# Param is 92
# Time elapsed: 28.883224487304688 sec
# average relative error of u: 0.056214913227228165%
# maximum relative error of u: 0.3117828219131704%
#
# Param is 93
# Time elapsed: 26.38349461555481 sec
# average relative error of u: 0.05603697438388439%
# maximum relative error of u: 0.3131205889631285%
#
# Param is 94
# Time elapsed: 26.52753496170044 sec
# average relative error of u: 0.056021754493410784%
# maximum relative error of u: 0.314908531115065%
#
# Param is 95
# Time elapsed: 29.12470054626465 sec
# average relative error of u: 0.056225357459434626%
# maximum relative error of u: 0.31684009569302046%
#
# Param is 96
# Time elapsed: 26.230096101760864 sec
# average relative error of u: 0.05664945492690619%
# maximum relative error of u: 0.3188016607468933%
#
# Param is 97
# Time elapsed: 27.507524728775024 sec
# average relative error of u: 0.05727326167428435%
# maximum relative error of u: 0.3206757394539292%
#
# Param is 98
# Time elapsed: 28.091267347335815 sec
# average relative error of u: 0.058085847528972355%
# maximum relative error of u: 0.32256299267367156%
#
# Param is 99
# Time elapsed: 21.968014001846313 sec
# average relative error of u: 0.059101448337586585%
# maximum relative error of u: 0.3246746747433199%
#
# Param is 100
# Time elapsed: 22.492161512374878 sec
# average relative error of u: 0.060346741197732444%
# maximum relative error of u: 0.3273196078682103%
#
# Param is 101
# Time elapsed: 23.571667671203613 sec
# average relative error of u: 0.061842691747591376%
# maximum relative error of u: 0.33087420995553685%
#
# Param is 102
# Time elapsed: 25.454617023468018 sec
# average relative error of u: 0.06358727726737327%
# maximum relative error of u: 0.33570863684602525%
#
# Param is 103
# Time elapsed: 23.711315870285034 sec
# average relative error of u: 0.06552503573687354%
# maximum relative error of u: 0.3421215022757653%
#
# Param is 104
# Time elapsed: 23.719792366027832 sec
# average relative error of u: 0.0675528270188872%
# maximum relative error of u: 0.3502336031155883%
#
# Param is 105
# Time elapsed: 21.69761848449707 sec
# average relative error of u: 0.06953570803915532%
# maximum relative error of u: 0.36004076885257785%
#
# Param is 106
# Time elapsed: 22.956385850906372 sec
# average relative error of u: 0.07133969648227613%
# maximum relative error of u: 0.3714273937245927%
#
# Param is 107
# Time elapsed: 23.801048517227173 sec
# average relative error of u: 0.07286461224731608%
# maximum relative error of u: 0.3842698248044786%
#
# Param is 108
# Time elapsed: 23.39527440071106 sec
# average relative error of u: 0.07409187204954147%
# maximum relative error of u: 0.3985235421741877%
#
# Param is 109
# Time elapsed: 22.280394554138184 sec
# average relative error of u: 0.07510173845438763%
# maximum relative error of u: 0.4142441223563698%
#
# Param is 110
# Time elapsed: 23.481565475463867 sec
# average relative error of u: 0.07608132577482879%
# maximum relative error of u: 0.43157524852765455%
#
# Param is 111
# Time elapsed: 23.631948947906494 sec
# average relative error of u: 0.07727320953064494%
# maximum relative error of u: 0.45057305458979174%
#
# Param is 112
# Time elapsed: 22.885597467422485 sec
# average relative error of u: 0.0788710790949899%
# maximum relative error of u: 0.47089841422499423%
#
# Param is 113
# Time elapsed: 21.54824471473694 sec
# average relative error of u: 0.08090028691013944%
# maximum relative error of u: 0.4917512894908189%
#
# Param is 114
# Time elapsed: 20.178026914596558 sec
# average relative error of u: 0.08312878121718283%
# maximum relative error of u: 0.5118301415136134%
#
# Param is 115
# Time elapsed: 22.96152663230896 sec
# average relative error of u: 0.08508313884120988%
# maximum relative error of u: 0.529577642718928%
#
# Param is 116
# Time elapsed: 24.032291412353516 sec
# average relative error of u: 0.08622614259541747%
# maximum relative error of u: 0.5438641508955152%
#
# Param is 117
# Time elapsed: 23.986238718032837 sec
# average relative error of u: 0.08631893303252791%
# maximum relative error of u: 0.5548024044376372%
#
# Param is 118
# Time elapsed: 23.857829332351685 sec
# average relative error of u: 0.0861001025826736%
# maximum relative error of u: 0.5651221275673569%
#
# Param is 119
# Time elapsed: 24.209515810012817 sec
# average relative error of u: 0.0883335346598848%
# maximum relative error of u: 0.5815970547094015%
#
# Param is 120
# Time elapsed: 24.238930225372314 sec
# average relative error of u: 0.09848791730362912%
# maximum relative error of u: 0.6157222983258881%
#
# Param is 121
# Time elapsed: 24.13393545150757 sec
# average relative error of u: 0.12282636694120011%
# maximum relative error of u: 0.6821128289031038%
#
# Param is 122
# Time elapsed: 23.13408851623535 sec
# average relative error of u: 0.1649242678034982%
# maximum relative error of u: 0.7939213600813488%
#
# Param is 123
# Time elapsed: 24.256080150604248 sec
# average relative error of u: 0.2256919187286118%
# maximum relative error of u: 0.9587034185547176%
#
# Param is 124
# Time elapsed: 22.062117338180542 sec
# average relative error of u: 0.3054511904863427%
# maximum relative error of u: 1.1783487067172647%
#
# Param is 125
# Time elapsed: 23.67799711227417 sec
# average relative error of u: 0.40483249130852306%
# maximum relative error of u: 1.4518295357504116%
#
# Dim. of latent space is 4
# # of measurments: 12
# [   0   28  359  600  779  960 2160 2339 3059 3569 3592 3596]
# Param is 75
# Time elapsed: 26.777905464172363 sec
# average relative error of u: 0.24688828185103756%
# maximum relative error of u: 1.1898796761261587%
#
# Param is 76
# Time elapsed: 25.742472410202026 sec
# average relative error of u: 0.18836748499933662%
# maximum relative error of u: 0.9847924099269035%
#
# Param is 77
# Time elapsed: 26.72458243370056 sec
# average relative error of u: 0.1412750016527681%
# maximum relative error of u: 0.8171575163421673%
#
# Param is 78
# Time elapsed: 27.309966325759888 sec
# average relative error of u: 0.10562084590964983%
# maximum relative error of u: 0.6856475372429616%
#
# Param is 79
# Time elapsed: 27.889651775360107 sec
# average relative error of u: 0.0814279592342055%
# maximum relative error of u: 0.5875412421424091%
#
# Param is 80
# Time elapsed: 28.089128732681274 sec
# average relative error of u: 0.06802937086764273%
# maximum relative error of u: 0.5186369556499201%
#
# Param is 81
# Time elapsed: 25.046108961105347 sec
# average relative error of u: 0.06293559902753024%
# maximum relative error of u: 0.4728401737995499%
#
# Param is 82
# Time elapsed: 24.914592504501343 sec
# average relative error of u: 0.06229194075108321%
# maximum relative error of u: 0.442993887119938%
#
# Param is 83
# Time elapsed: 24.732006549835205 sec
# average relative error of u: 0.06293791937904335%
# maximum relative error of u: 0.4218410513054373%
#
# Param is 84
# Time elapsed: 27.237846612930298 sec
# average relative error of u: 0.06327002948510112%
# maximum relative error of u: 0.4035624980782084%
#
# Param is 85
# Time elapsed: 25.636008977890015 sec
# average relative error of u: 0.06283916084515802%
# maximum relative error of u: 0.38442364726528294%
#
# Param is 86
# Time elapsed: 26.719401836395264 sec
# average relative error of u: 0.06181452443699852%
# maximum relative error of u: 0.36308098999784266%
#
# Param is 87
# Time elapsed: 27.449504375457764 sec
# average relative error of u: 0.0606159093766303%
# maximum relative error of u: 0.34013202060408665%
#
# Param is 88
# Time elapsed: 27.873366594314575 sec
# average relative error of u: 0.059690149060659295%
# maximum relative error of u: 0.3177845519882283%
#
# Param is 89
# Time elapsed: 30.432695388793945 sec
# average relative error of u: 0.05936161650893993%
# maximum relative error of u: 0.29892977538555887%
#
# Param is 90
# Time elapsed: 28.611958503723145 sec
# average relative error of u: 0.05974568945283228%
# maximum relative error of u: 0.28604059303713886%
#
# Param is 91
# Time elapsed: 27.179893016815186 sec
# average relative error of u: 0.06075154545502113%
# maximum relative error of u: 0.28009484500801196%
#
# Param is 92
# Time elapsed: 28.801902294158936 sec
# average relative error of u: 0.06214803022633184%
# maximum relative error of u: 0.2801673762522813%
#
# Param is 93
# Time elapsed: 27.281054973602295 sec
# average relative error of u: 0.06365981597839032%
# maximum relative error of u: 0.2839472852015863%
#
# Param is 94
# Time elapsed: 27.30559492111206 sec
# average relative error of u: 0.0650233007855022%
# maximum relative error of u: 0.2887336846329091%
#
# Param is 95
# Time elapsed: 28.01011085510254 sec
# average relative error of u: 0.06606397875646522%
# maximum relative error of u: 0.29242599810293674%
#
# Param is 96
# Time elapsed: 26.203096389770508 sec
# average relative error of u: 0.06669252241097%
# maximum relative error of u: 0.2937859290270811%
#
# Param is 97
# Time elapsed: 25.034119606018066 sec
# average relative error of u: 0.06693286327709691%
# maximum relative error of u: 0.29257534077395286%
#
# Param is 98
# Time elapsed: 25.99651551246643 sec
# average relative error of u: 0.06689323529665434%
# maximum relative error of u: 0.28947186840301975%
#
# Param is 99
# Time elapsed: 27.893820762634277 sec
# average relative error of u: 0.06671873152145998%
# maximum relative error of u: 0.28568095763739043%
#
# Param is 100
# Time elapsed: 25.742337226867676 sec
# average relative error of u: 0.06655487282020672%
# maximum relative error of u: 0.282764019947594%
#
# Param is 101
# Time elapsed: 26.728837966918945 sec
# average relative error of u: 0.0664728023892431%
# maximum relative error of u: 0.2822467189814771%
#
# Param is 102
# Time elapsed: 27.004982233047485 sec
# average relative error of u: 0.06647079631185267%
# maximum relative error of u: 0.2851231980419325%
#
# Param is 103
# Time elapsed: 27.60913872718811 sec
# average relative error of u: 0.06648484903649306%
# maximum relative error of u: 0.29189992754438576%
#
# Param is 104
# Time elapsed: 27.615372896194458 sec
# average relative error of u: 0.06646007307824182%
# maximum relative error of u: 0.3022787894395103%
#
# Param is 105
# Time elapsed: 26.661404848098755 sec
# average relative error of u: 0.06644606854087164%
# maximum relative error of u: 0.3156203725758203%
#
# Param is 106
# Time elapsed: 24.941872119903564 sec
# average relative error of u: 0.06664923208284945%
# maximum relative error of u: 0.3309508794362124%
#
# Param is 107
# Time elapsed: 27.80258870124817 sec
# average relative error of u: 0.06744636203642126%
# maximum relative error of u: 0.3474006977492651%
#
# Param is 108
# Time elapsed: 26.823285341262817 sec
# average relative error of u: 0.06928943841679536%
# maximum relative error of u: 0.3640152955667746%
#
# Param is 109
# Time elapsed: 27.02888822555542 sec
# average relative error of u: 0.0725115418399456%
# maximum relative error of u: 0.3800720148859788%
#
# Param is 110
# Time elapsed: 27.796452522277832 sec
# average relative error of u: 0.07714751337894195%
# maximum relative error of u: 0.3948842786831808%
#
# Param is 111
# Time elapsed: 27.58887243270874 sec
# average relative error of u: 0.08284451026323005%
# maximum relative error of u: 0.40796053051215764%
#
# Param is 112
# Time elapsed: 27.595083713531494 sec
# average relative error of u: 0.08892220252154445%
# maximum relative error of u: 0.419093409382325%
#
# Param is 113
# Time elapsed: 26.828466176986694 sec
# average relative error of u: 0.09452729305654956%
# maximum relative error of u: 0.42842358971522576%
#
# Param is 114
# Time elapsed: 25.834381818771362 sec
# average relative error of u: 0.09875584825011058%
# maximum relative error of u: 0.4365575190115893%
#
# Param is 115
# Time elapsed: 25.30130434036255 sec
# average relative error of u: 0.10080366503683466%
# maximum relative error of u: 0.44491428903376373%
#
# Param is 116
# Time elapsed: 26.92956852912903 sec
# average relative error of u: 0.10021384407674357%
# maximum relative error of u: 0.45588476553286444%
#
# Param is 117
# Time elapsed: 28.45108461380005 sec
# average relative error of u: 0.09741049556299668%
# maximum relative error of u: 0.4734099223904721%
#
# Param is 118
# Time elapsed: 25.786936283111572 sec
# average relative error of u: 0.09497041243403409%
# maximum relative error of u: 0.5036088016032112%
#
# Param is 119
# Time elapsed: 26.51528239250183 sec
# average relative error of u: 0.09951966648723766%
# maximum relative error of u: 0.5549475540810677%
#
# Param is 120
# Time elapsed: 26.98895525932312 sec
# average relative error of u: 0.12094120584935787%
# maximum relative error of u: 0.6375063205479796%
#
# Param is 121
# Time elapsed: 27.6873517036438 sec
# average relative error of u: 0.1658098447133408%
# maximum relative error of u: 0.7612336147583088%
#
# Param is 122
# Time elapsed: 28.002232551574707 sec
# average relative error of u: 0.235367217615545%
# maximum relative error of u: 0.9344109254042622%
#
# Param is 123
# Time elapsed: 26.26931381225586 sec
# average relative error of u: 0.3296908598907751%
# maximum relative error of u: 1.1632017866765587%
#
# Param is 124
# Time elapsed: 19.051934003829956 sec
# average relative error of u: 0.44962702524928594%
# maximum relative error of u: 1.4522236039911696%
#
# Param is 125
# Time elapsed: 23.794673681259155 sec
# average relative error of u: 0.5966025550929956%
# maximum relative error of u: 1.8048955755849079%
#
# Dim. of latent space is 5
# # of measurments: 12
# [   0   16   59  360 1740 1860 2339 2760 3359 3543 3547 3595]
# Param is 75
# Time elapsed: 27.782299280166626 sec
# average relative error of u: 0.26705873372216027%
# maximum relative error of u: 0.6659024172817688%
#
# Param is 76
# Time elapsed: 28.998276472091675 sec
# average relative error of u: 0.20476206469169708%
# maximum relative error of u: 0.5727208463975589%
#
# Param is 77
# Time elapsed: 29.293935775756836 sec
# average relative error of u: 0.15342726208677712%
# maximum relative error of u: 0.5098797920957923%
#
# Param is 78
# Time elapsed: 31.363794803619385 sec
# average relative error of u: 0.11367786039665716%
# maximum relative error of u: 0.4687252776315926%
#
# Param is 79
# Time elapsed: 31.202309131622314 sec
# average relative error of u: 0.08575827629214809%
# maximum relative error of u: 0.4400049135570066%
#
# Param is 80
# Time elapsed: 31.363574266433716 sec
# average relative error of u: 0.06903420933855452%
# maximum relative error of u: 0.41718939243594966%
#
# Param is 81
# Time elapsed: 28.67733097076416 sec
# average relative error of u: 0.061126663175450076%
# maximum relative error of u: 0.39689373070835465%
#
# Param is 82
# Time elapsed: 29.290676832199097 sec
# average relative error of u: 0.05830648656729991%
# maximum relative error of u: 0.37830853279692817%
#
# Param is 83
# Time elapsed: 29.865097999572754 sec
# average relative error of u: 0.05738297842242126%
# maximum relative error of u: 0.3615419675455253%
#
# Param is 84
# Time elapsed: 26.8105731010437 sec
# average relative error of u: 0.05670024658353845%
# maximum relative error of u: 0.3470078341630128%
#
# Param is 85
# Time elapsed: 28.596060276031494 sec
# average relative error of u: 0.05573409457079292%
# maximum relative error of u: 0.33464422550926654%
#
# Param is 86
# Time elapsed: 29.611894130706787 sec
# average relative error of u: 0.05450890009925765%
# maximum relative error of u: 0.323816777017822%
#
# Param is 87
# Time elapsed: 27.824058532714844 sec
# average relative error of u: 0.05322629072445146%
# maximum relative error of u: 0.31384237607330184%
#
# Param is 88
# Time elapsed: 28.537632942199707 sec
# average relative error of u: 0.052113502887348145%
# maximum relative error of u: 0.30406791949736867%
#
# Param is 89
# Time elapsed: 24.576151847839355 sec
# average relative error of u: 0.051364627487670775%
# maximum relative error of u: 0.29434161756172766%
#
# Param is 90
# Time elapsed: 23.628894090652466 sec
# average relative error of u: 0.051117732682195834%
# maximum relative error of u: 0.284839340359613%
#
# Param is 91
# Time elapsed: 18.760783672332764 sec
# average relative error of u: 0.05144193870388539%
# maximum relative error of u: 0.27610239285953925%
#
# Param is 92
# Time elapsed: 17.317463636398315 sec
# average relative error of u: 0.05230975259688833%
# maximum relative error of u: 0.2687352155818708%
#
# Param is 93
# Time elapsed: 16.481733322143555 sec
# average relative error of u: 0.053597066471704605%
# maximum relative error of u: 0.26319818924000393%
#
# Param is 94
# Time elapsed: 16.57105541229248 sec
# average relative error of u: 0.05511034323902593%
# maximum relative error of u: 0.25970707615745%
#
# Param is 95
# Time elapsed: 16.535717964172363 sec
# average relative error of u: 0.05662997605677304%
# maximum relative error of u: 0.25814661949700707%
#
# Param is 96
# Time elapsed: 16.406644582748413 sec
# average relative error of u: 0.057983728504661276%
# maximum relative error of u: 0.258323622247353%
#
# Param is 97
# Time elapsed: 16.83255410194397 sec
# average relative error of u: 0.05906190440823498%
# maximum relative error of u: 0.26005645315851633%
#
# Param is 98
# Time elapsed: 17.143171072006226 sec
# average relative error of u: 0.05984822503076273%
# maximum relative error of u: 0.2632775809823841%
#
# Param is 99
# Time elapsed: 16.98679518699646 sec
# average relative error of u: 0.06040190079462447%
# maximum relative error of u: 0.26803294020499197%
#
# Param is 100
# Time elapsed: 16.959295749664307 sec
# average relative error of u: 0.060821451956021164%
# maximum relative error of u: 0.2743831098516014%
#
# Param is 101
# Time elapsed: 17.21151351928711 sec
# average relative error of u: 0.061205854617272744%
# maximum relative error of u: 0.2823028631861665%
#
# Param is 102
# Time elapsed: 17.286950826644897 sec
# average relative error of u: 0.061616148189215625%
# maximum relative error of u: 0.2916453568480891%
#
# Param is 103
# Time elapsed: 17.229989528656006 sec
# average relative error of u: 0.06205544542677772%
# maximum relative error of u: 0.3022424562537551%
#
# Param is 104
# Time elapsed: 17.66381287574768 sec
# average relative error of u: 0.06247940923164424%
# maximum relative error of u: 0.31364911885385305%
#
# Param is 105
# Time elapsed: 18.482694387435913 sec
# average relative error of u: 0.06283480376427157%
# maximum relative error of u: 0.32558678106199646%
#
# Param is 106
# Time elapsed: 21.568496704101562 sec
# average relative error of u: 0.06310589449475343%
# maximum relative error of u: 0.3377323345866073%
#
# Param is 107
# Time elapsed: 60.71778130531311 sec
# average relative error of u: 0.06333979291375096%
# maximum relative error of u: 0.34969753659814806%
#
# Param is 108
# Time elapsed: 26.96959614753723 sec
# average relative error of u: 0.06366176970462281%
# maximum relative error of u: 0.3610786388279571%
#
# Param is 109
# Time elapsed: 28.916852235794067 sec
# average relative error of u: 0.06423864836474548%
# maximum relative error of u: 0.3714481103762474%
#
# Param is 110
# Time elapsed: 40.470174074172974 sec
# average relative error of u: 0.0652224971472846%
# maximum relative error of u: 0.3803515279825679%
#
# Param is 111
# Time elapsed: 22.315210580825806 sec
# average relative error of u: 0.06666272077830528%
# maximum relative error of u: 0.38754735099708343%
#
# Param is 112
# Time elapsed: 35.42163062095642 sec
# average relative error of u: 0.06849047066270718%
# maximum relative error of u: 0.3932604326338956%
#
# Param is 113
# Time elapsed: 17.226524114608765 sec
# average relative error of u: 0.07053182948809762%
# maximum relative error of u: 0.39842066948907434%
#
# Param is 114
# Time elapsed: 24.985170602798462 sec
# average relative error of u: 0.07256178432917891%
# maximum relative error of u: 0.404775949219307%
#
# Param is 115
# Time elapsed: 44.914040088653564 sec
# average relative error of u: 0.07438065994817533%
# maximum relative error of u: 0.41455751917847455%
#
# Param is 116
# Time elapsed: 33.01874327659607 sec
# average relative error of u: 0.07591569147389504%
# maximum relative error of u: 0.42972166709556614%
#
# Param is 117
# Time elapsed: 39.29731869697571 sec
# average relative error of u: 0.07744469030450328%
# maximum relative error of u: 0.45100123877798526%
#
# Param is 118
# Time elapsed: 46.49618458747864 sec
# average relative error of u: 0.0801227025664454%
# maximum relative error of u: 0.4779033051915241%
#
# Param is 119
# Time elapsed: 39.138646841049194 sec
# average relative error of u: 0.08681286858367405%
# maximum relative error of u: 0.5099108278360318%
#
# Param is 120
# Time elapsed: 21.71082901954651 sec
# average relative error of u: 0.10241940557759505%
# maximum relative error of u: 0.5489461868637986%
#
# Param is 121
# Time elapsed: 31.84837317466736 sec
# average relative error of u: 0.13239345349685994%
# maximum relative error of u: 0.6022736214766006%
#
# Param is 122
# Time elapsed: 31.65176486968994 sec
# average relative error of u: 0.18077744263367027%
# maximum relative error of u: 0.6835681663222657%
#
# Param is 123
# Time elapsed: 33.23479461669922 sec
# average relative error of u: 0.25037588692235485%
# maximum relative error of u: 0.8109908733137118%
#
# Param is 124
# Time elapsed: 33.12424564361572 sec
# average relative error of u: 0.3439610443189783%
# maximum relative error of u: 1.0019068594733622%
#
# Param is 125
# Time elapsed: 31.96287202835083 sec
# average relative error of u: 0.4649079695109969%
# maximum relative error of u: 1.2691551741251579%
#
# Dim. of latent space is 6
# # of measurments: 12
# [   0   10   19   29   45   58  180 1680 3545 3562 3574 3595]
# Param is 75
# Time elapsed: 28.960154056549072 sec
# average relative error of u: 0.3089947660585355%
# maximum relative error of u: 1.3611274314002366%
#
# Param is 76
# Time elapsed: 31.237131595611572 sec
# average relative error of u: 0.241514425872771%
# maximum relative error of u: 1.178410572308848%
#
# Param is 77
# Time elapsed: 32.58069849014282 sec
# average relative error of u: 0.18273327357174582%
# maximum relative error of u: 0.9928922299804934%
#
# Param is 78
# Time elapsed: 32.10250473022461 sec
# average relative error of u: 0.13527232301979664%
# maximum relative error of u: 0.8355345513926622%
#
# Param is 79
# Time elapsed: 32.19996643066406 sec
# average relative error of u: 0.10193684103131351%
# maximum relative error of u: 0.717778504353036%
#
# Param is 80
# Time elapsed: 32.545554637908936 sec
# average relative error of u: 0.0843269857891678%
# maximum relative error of u: 0.6371919785345308%
#
# Param is 81
# Time elapsed: 33.762166023254395 sec
# average relative error of u: 0.07965466950470358%
# maximum relative error of u: 0.5842994317261819%
#
# Param is 82
# Time elapsed: 30.24704360961914 sec
# average relative error of u: 0.08105773612936278%
# maximum relative error of u: 0.54749416085882%
#
# Param is 83
# Time elapsed: 29.180000066757202 sec
# average relative error of u: 0.08287570573084128%
# maximum relative error of u: 0.5165164698040717%
#
# Param is 84
# Time elapsed: 29.7698917388916 sec
# average relative error of u: 0.08272880099657487%
# maximum relative error of u: 0.49860788839183257%
#
# Param is 85
# Time elapsed: 35.25661754608154 sec
# average relative error of u: 0.08047843186447715%
# maximum relative error of u: 0.4747471835979371%
#
# Param is 86
# Time elapsed: 35.25525736808777 sec
# average relative error of u: 0.0769587444597763%
# maximum relative error of u: 0.4403465415084703%
#
# Param is 87
# Time elapsed: 33.52955102920532 sec
# average relative error of u: 0.07306755658270983%
# maximum relative error of u: 0.3971804997546186%
#
# Param is 88
# Time elapsed: 28.9348783493042 sec
# average relative error of u: 0.06933493215638531%
# maximum relative error of u: 0.3490422909080077%
#
# Param is 89
# Time elapsed: 31.943798065185547 sec
# average relative error of u: 0.0659915030703338%
# maximum relative error of u: 0.30299701124770456%
#
# Param is 90
# Time elapsed: 32.300644874572754 sec
# average relative error of u: 0.06316762979265245%
# maximum relative error of u: 0.2639790878143276%
#
# Param is 91
# Time elapsed: 32.77072882652283 sec
# average relative error of u: 0.06097143621670042%
# maximum relative error of u: 0.25602666151466236%
#
# Param is 92
# Time elapsed: 33.28886604309082 sec
# average relative error of u: 0.059408560643368254%
# maximum relative error of u: 0.25908704541840755%
#
# Param is 93
# Time elapsed: 31.519603490829468 sec
# average relative error of u: 0.0582895372533986%
# maximum relative error of u: 0.26776826667604503%
#
# Param is 94
# Time elapsed: 30.136824369430542 sec
# average relative error of u: 0.057329543032875935%
# maximum relative error of u: 0.27727423000843554%
#
# Param is 95
# Time elapsed: 34.71321964263916 sec
# average relative error of u: 0.05626840170180409%
# maximum relative error of u: 0.2845405829882752%
#
# Param is 96
# Time elapsed: 30.687785387039185 sec
# average relative error of u: 0.05501362700851061%
# maximum relative error of u: 0.28852585014195575%
#
# Param is 97
# Time elapsed: 31.785903692245483 sec
# average relative error of u: 0.053670432478305864%
# maximum relative error of u: 0.28908182576505675%
#
# Param is 98
# Time elapsed: 30.157698392868042 sec
# average relative error of u: 0.05248464771198308%
# maximum relative error of u: 0.28676669576048874%
#
# Param is 99
# Time elapsed: 32.33625364303589 sec
# average relative error of u: 0.05174905736533836%
# maximum relative error of u: 0.28255892724762494%
#
# Param is 100
# Time elapsed: 32.27377223968506 sec
# average relative error of u: 0.05164855901065167%
# maximum relative error of u: 0.2774247928924925%
#
# Param is 101
# Time elapsed: 33.264209270477295 sec
# average relative error of u: 0.052188912450980895%
# maximum relative error of u: 0.27235611145872973%
#
# Param is 102
# Time elapsed: 31.695390462875366 sec
# average relative error of u: 0.05319782120395905%
# maximum relative error of u: 0.26830057982533895%
#
# Param is 103
# Time elapsed: 31.09976816177368 sec
# average relative error of u: 0.054427582799742365%
# maximum relative error of u: 0.2659771854874135%
#
# Param is 104
# Time elapsed: 28.536638021469116 sec
# average relative error of u: 0.05565531792960729%
# maximum relative error of u: 0.2656954512108915%
#
# Param is 105
# Time elapsed: 25.847930192947388 sec
# average relative error of u: 0.0567680257759819%
# maximum relative error of u: 0.26722557976680994%
#
# Param is 106
# Time elapsed: 30.436999797821045 sec
# average relative error of u: 0.0577588287998804%
# maximum relative error of u: 0.2699055682786683%
#
# Param is 107
# Time elapsed: 33.29392051696777 sec
# average relative error of u: 0.058690214904830215%
# maximum relative error of u: 0.2729150760409444%
#
# Param is 108
# Time elapsed: 33.0283637046814 sec
# average relative error of u: 0.0596239915486151%
# maximum relative error of u: 0.2758697702938298%
#
# Param is 109
# Time elapsed: 32.384674072265625 sec
# average relative error of u: 0.060589858875114234%
# maximum relative error of u: 0.27905002319388517%
#
# Param is 110
# Time elapsed: 33.385669469833374 sec
# average relative error of u: 0.06157786064049792%
# maximum relative error of u: 0.28364211432128605%
#
# Param is 111
# Time elapsed: 30.63774609565735 sec
# average relative error of u: 0.06257524470065423%
# maximum relative error of u: 0.29128760891506345%
#
# Param is 112
# Time elapsed: 30.81712770462036 sec
# average relative error of u: 0.06362773672159361%
# maximum relative error of u: 0.30333292371656645%
#
# Param is 113
# Time elapsed: 31.31957483291626 sec
# average relative error of u: 0.06484760741149463%
# maximum relative error of u: 0.3200464983276003%
#
# Param is 114
# Time elapsed: 31.597885608673096 sec
# average relative error of u: 0.06635300830245666%
# maximum relative error of u: 0.3404138771146109%
#
# Param is 115
# Time elapsed: 33.41137766838074 sec
# average relative error of u: 0.06814649270180713%
# maximum relative error of u: 0.3621624853833166%
#
# Param is 116
# Time elapsed: 32.384413719177246 sec
# average relative error of u: 0.06998093777685277%
# maximum relative error of u: 0.3826912236916626%
#
# Param is 117
# Time elapsed: 30.644139289855957 sec
# average relative error of u: 0.07143714675320098%
# maximum relative error of u: 0.40032962311764514%
#
# Param is 118
# Time elapsed: 33.122716665267944 sec
# average relative error of u: 0.07236659701239523%
# maximum relative error of u: 0.41614805801298205%
#
# Param is 119
# Time elapsed: 31.40007758140564 sec
# average relative error of u: 0.07410756560354383%
# maximum relative error of u: 0.4370117867722521%
#
# Param is 120
# Time elapsed: 34.005207777023315 sec
# average relative error of u: 0.08145063384268976%
# maximum relative error of u: 0.4782963765205564%
#
# Param is 121
# Time elapsed: 33.136401414871216 sec
# average relative error of u: 0.10284117644861769%
# maximum relative error of u: 0.5627020705474629%
#
# Param is 122
# Time elapsed: 35.450698137283325 sec
# average relative error of u: 0.1455787236669342%
# maximum relative error of u: 0.7113542814741743%
#
# Param is 123
# Time elapsed: 30.91730237007141 sec
# average relative error of u: 0.2130521068398625%
# maximum relative error of u: 0.9368159386034426%
#
# Param is 124
# Time elapsed: 33.08562469482422 sec
# average relative error of u: 0.3072072861122467%
# maximum relative error of u: 1.2445862706227182%
#
# Param is 125
# Time elapsed: 30.307342529296875 sec
# average relative error of u: 0.4301913731369354%
# maximum relative error of u: 1.6380580293924962%

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

idx=[0,1,2,3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_AE_{}_SOPT_avg_rel_err_seed_{}.png".format(f,seed))

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_AE_{}_SOPT_max_rel_err_seed_{}.png".format(f,seed))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# idx=[0,1,2,3]
idx = [2]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
plt.show()

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
plt.show()

# %%
print(f_list)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=2; j=-1        
f=f_list[i]
param=FOM_parameters[j]

u_gappyAE=results['solution'][i,j]

ex = np.load('../__data/ex16_diffusion/ex16_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("Latent Dim: {}, Param: {}".format(f,param))
plt.show()

# error
u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                 /np.linalg.norm(u_full,ord=2,axis=1)*100
u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
             /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
print("average relative error of u: {}%".format(u_avg_rel_err))
print()
print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
    
# plot original data
vmin=0; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy AE @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex16_diffusion/ex16_AE_{}_SOPT_SOL_seed_{}.png".format(f,seed))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex16_diffusion/ex16_ground_truth.png")
# Out:
# average relative error of u: 0.4649079695109969%
#
# maximum relative error of u: 1.2691551741251579%

# %%
i=3; j=-1
f=f_list[i]; param=FOM_parameters[j]
print("f={}".format(f))
print("param={}".format(param))
plt.plot(results['reduced'][i,j][:,:f])
plt.legend(np.arange(f))
plt.show()
# Out:
# f=6
# param=125
