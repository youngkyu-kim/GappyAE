# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle
from scipy.stats import qmc

# %%
LHS_seed=0

# Given parameters
nx = 60
ny = 60
tf = 1.0
dt = 2.0e-3
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims=(nx,ny)

# POD basis
num_basis=np.array([3,4,5,6])
print('num_basis {}'.format(num_basis))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_LHS_result = "../__result/ex16_diffusion/ex16_POD_inner_LHS_seed_{}_gappy_result.p".format(LHS_seed)
file_name_SVD="../__model/ex16_diffusion/ex16_SVD.p"

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# num_basis [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %%
# LHS
num_msmt = 12
sampler = qmc.LatinHypercube(d=2,seed=LHS_seed)
sample=sampler.integers(l_bounds=[1, 1], u_bounds=[ny-1,nx-1], n=num_msmt, endpoint=False)
msmt_idx=np.sort(np.ravel_multi_index((sample[:,0],sample[:,1]),dims))

num_msmt=len(msmt_idx)
print("# of measurments: {}".format(num_msmt))
print(msmt_idx)

# plot measuremnt positions
plt.figure()
plt.scatter(y[msmt_idx],x[msmt_idx], color = 'blue')
plt.axis('square')
plt.axis([xmin,xmax,ymin,ymax])
plt.xlabel('x')
plt.ylabel('y')
plt.savefig("../__result/ex16_diffusion/ex16_POD_LHS_seed_{}_{}_samples.png".format(LHS_seed,num_msmt))
# Out:
# # of measurments: 12
# [ 353  422  718  968 1271 1707 1839 2176 2499 2749 3214 3323]

# %% [markdown]
# # gappyPOD

# %%
solution=np.zeros((len(num_basis),len(FOM_parameters),nt+1,nx*ny))
avg_rel_err=np.zeros((len(num_basis),len(FOM_parameters)))
rel_err=np.zeros((len(num_basis),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(num_basis),len(FOM_parameters)))

with open(file=file_name_SVD, mode='rb') as ff:  
    SVD = pickle.load(ff)

for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    print("# of POD basis is {}".format(POD_basis))
    
    # LHS
    num_msmt = 12
    sampler = qmc.LatinHypercube(d=2,seed=LHS_seed)
    sample=sampler.integers(l_bounds=[1, 1], u_bounds=[ny-1,nx-1], n=num_msmt, endpoint=False)
    msmt_idx=np.sort(np.ravel_multi_index((sample[:,0],sample[:,1]),dims))

    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(y[msmt_idx],x[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
    
    # Basis matrix
    phi_u = SVD['U'][:,:POD_basis]

    phim_u=phi_u[msmt_idx]
    phim_u_pinv=np.linalg.pinv(phim_u)
    
    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('../__data/ex16_diffusion/ex16_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1)

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_ref = u0

        # Gappy POD
        t_start_gappyPOD=time.time()

        # solution
        u_gappyPOD=np.zeros((nt+1,ny*nx))
        u_hat=np.zeros((nt+1,POD_basis))

        # IC
        u_hat0=np.zeros(POD_basis)
        u_gappyPOD[0]=np.copy(u0)

        for n in range(nt):
            u_hat[n+1] = phim_u_pinv.dot(um[n+1]-u_ref[msmt_idx])
            u_gappyPOD[n+1] = u_ref + phi_u.dot(u_hat[n+1])

        # elapsed time
        t_elapsed_gappyPOD=time.time()-t_start_gappyPOD
        print('Time elapsed: {} sec'.format(t_elapsed_gappyPOD))

        # error
        u_rel_err_gappyPOD=np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)/np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyPOD)))
        print()

        # save result
        solution[ii,jj]=u_gappyPOD
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyPOD
        elapsed_time[ii,jj]=t_elapsed_gappyPOD
    
results={'solution':solution,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_LHS_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# # of POD basis is 3
# # of measurments: 12
# [ 353  422  718  968 1271 1707 1839 2176 2499 2749 3214 3323]
# Param is 75
# Time elapsed: 1.3199217319488525 sec
# average relative error of u: 4.882954504854513%
# maximum relative error of u: 5.635276751750638%
#
# Param is 76
# Time elapsed: 1.1557598114013672 sec
# average relative error of u: 4.904595821329039%
# maximum relative error of u: 5.60813644773956%
#
# Param is 77
# Time elapsed: 1.4384410381317139 sec
# average relative error of u: 4.925790589875651%
# maximum relative error of u: 5.570287933427274%
#
# Param is 78
# Time elapsed: 1.2956855297088623 sec
# average relative error of u: 4.948140909736187%
# maximum relative error of u: 5.522927939380239%
#
# Param is 79
# Time elapsed: 1.6185123920440674 sec
# average relative error of u: 4.973472122146445%
# maximum relative error of u: 5.54260748446086%
#
# Param is 80
# Time elapsed: 2.0373103618621826 sec
# average relative error of u: 5.003835291421072%
# maximum relative error of u: 5.585450828644389%
#
# Param is 81
# Time elapsed: 2.282485008239746 sec
# average relative error of u: 5.041438213049821%
# maximum relative error of u: 5.645616198151988%
#
# Param is 82
# Time elapsed: 2.168541669845581 sec
# average relative error of u: 5.088658056139098%
# maximum relative error of u: 5.723893902233999%
#
# Param is 83
# Time elapsed: 2.244982957839966 sec
# average relative error of u: 5.147937041879628%
# maximum relative error of u: 5.821299440631522%
#
# Param is 84
# Time elapsed: 2.256157875061035 sec
# average relative error of u: 5.221769927468845%
# maximum relative error of u: 5.938923738927714%
#
# Param is 85
# Time elapsed: 1.713378667831421 sec
# average relative error of u: 5.31253980002636%
# maximum relative error of u: 6.077810205714657%
#
# Param is 86
# Time elapsed: 1.7794592380523682 sec
# average relative error of u: 5.422500929019989%
# maximum relative error of u: 6.238957145779159%
#
# Param is 87
# Time elapsed: 1.6563961505889893 sec
# average relative error of u: 5.553681390364378%
# maximum relative error of u: 6.423303189968312%
#
# Param is 88
# Time elapsed: 1.8814787864685059 sec
# average relative error of u: 5.7077720762826205%
# maximum relative error of u: 6.6316032269769485%
#
# Param is 89
# Time elapsed: 1.501493215560913 sec
# average relative error of u: 5.886096839753592%
# maximum relative error of u: 6.864518520267773%
#
# Param is 90
# Time elapsed: 1.4955368041992188 sec
# average relative error of u: 6.089559917706487%
# maximum relative error of u: 7.122510871400428%
#
# Param is 91
# Time elapsed: 1.8251395225524902 sec
# average relative error of u: 6.3186542578148%
# maximum relative error of u: 7.405877059014612%
#
# Param is 92
# Time elapsed: 1.594541311264038 sec
# average relative error of u: 6.5734156720712065%
# maximum relative error of u: 7.714696980171038%
#
# Param is 93
# Time elapsed: 1.5893917083740234 sec
# average relative error of u: 6.853560740935391%
# maximum relative error of u: 8.048888961896235%
#
# Param is 94
# Time elapsed: 1.4203588962554932 sec
# average relative error of u: 7.158388962415992%
# maximum relative error of u: 8.408166728135432%
#
# Param is 95
# Time elapsed: 1.4127607345581055 sec
# average relative error of u: 7.486930187447377%
# maximum relative error of u: 8.792020633696696%
#
# Param is 96
# Time elapsed: 1.806006669998169 sec
# average relative error of u: 7.837982530514416%
# maximum relative error of u: 9.199772389787979%
#
# Param is 97
# Time elapsed: 1.6730482578277588 sec
# average relative error of u: 8.210106786831036%
# maximum relative error of u: 9.63052248411894%
#
# Param is 98
# Time elapsed: 2.136484384536743 sec
# average relative error of u: 8.601698776367869%
# maximum relative error of u: 10.083205870664605%
#
# Param is 99
# Time elapsed: 1.6488349437713623 sec
# average relative error of u: 9.011066621875468%
# maximum relative error of u: 10.556608341628053%
#
# Param is 100
# Time elapsed: 1.9266068935394287 sec
# average relative error of u: 9.436414980639658%
# maximum relative error of u: 11.049354436793303%
#
# Param is 101
# Time elapsed: 1.7130541801452637 sec
# average relative error of u: 9.87581940953559%
# maximum relative error of u: 11.559845309144402%
#
# Param is 102
# Time elapsed: 1.8143336772918701 sec
# average relative error of u: 10.327361003461224%
# maximum relative error of u: 12.08642515473934%
#
# Param is 103
# Time elapsed: 1.6850554943084717 sec
# average relative error of u: 10.789051821587044%
# maximum relative error of u: 12.62727056761494%
#
# Param is 104
# Time elapsed: 1.62446928024292 sec
# average relative error of u: 11.258895769459162%
# maximum relative error of u: 13.180451364943993%
#
# Param is 105
# Time elapsed: 1.515671968460083 sec
# average relative error of u: 11.734876533784657%
# maximum relative error of u: 13.743921446884313%
#
# Param is 106
# Time elapsed: 1.7232818603515625 sec
# average relative error of u: 12.214971389484475%
# maximum relative error of u: 14.315575200608263%
#
# Param is 107
# Time elapsed: 1.677398681640625 sec
# average relative error of u: 12.697191340604938%
# maximum relative error of u: 14.893258167082642%
#
# Param is 108
# Time elapsed: 1.5453860759735107 sec
# average relative error of u: 13.179545805675374%
# maximum relative error of u: 15.474734580452704%
#
# Param is 109
# Time elapsed: 1.5827484130859375 sec
# average relative error of u: 13.660109655726785%
# maximum relative error of u: 16.057765906065057%
#
# Param is 110
# Time elapsed: 1.6682534217834473 sec
# average relative error of u: 14.137059530632609%
# maximum relative error of u: 16.640158572649252%
#
# Param is 111
# Time elapsed: 1.436189889907837 sec
# average relative error of u: 14.608540883406885%
# maximum relative error of u: 17.21967122696568%
#
# Param is 112
# Time elapsed: 1.4772276878356934 sec
# average relative error of u: 15.07292171588859%
# maximum relative error of u: 17.794231883603054%
#
# Param is 113
# Time elapsed: 1.6479969024658203 sec
# average relative error of u: 15.528611376517606%
# maximum relative error of u: 18.361788851895902%
#
# Param is 114
# Time elapsed: 1.7434377670288086 sec
# average relative error of u: 15.974203522264697%
# maximum relative error of u: 18.92048758390471%
#
# Param is 115
# Time elapsed: 1.8092410564422607 sec
# average relative error of u: 16.40845899861775%
# maximum relative error of u: 19.468578419832944%
#
# Param is 116
# Time elapsed: 1.6320054531097412 sec
# average relative error of u: 16.830325956836408%
# maximum relative error of u: 20.004574761858002%
#
# Param is 117
# Time elapsed: 1.6744089126586914 sec
# average relative error of u: 17.238976393901126%
# maximum relative error of u: 20.527205158889515%
#
# Param is 118
# Time elapsed: 1.6322126388549805 sec
# average relative error of u: 17.63381187365173%
# maximum relative error of u: 21.035427070575523%
#
# Param is 119
# Time elapsed: 1.6436264514923096 sec
# average relative error of u: 18.014499068261266%
# maximum relative error of u: 21.528604154671747%
#
# Param is 120
# Time elapsed: 1.893674373626709 sec
# average relative error of u: 18.380943701881332%
# maximum relative error of u: 22.00625263967323%
#
# Param is 121
# Time elapsed: 1.8156507015228271 sec
# average relative error of u: 18.733436489398468%
# maximum relative error of u: 22.46847314437308%
#
# Param is 122
# Time elapsed: 1.7113373279571533 sec
# average relative error of u: 19.07241313840659%
# maximum relative error of u: 22.915524502214776%
#
# Param is 123
# Time elapsed: 1.715869426727295 sec
# average relative error of u: 19.398709152289822%
# maximum relative error of u: 23.348158418845305%
#
# Param is 124
# Time elapsed: 1.6173365116119385 sec
# average relative error of u: 19.713395865483395%
# maximum relative error of u: 23.767439054779327%
#
# Param is 125
# Time elapsed: 1.6689791679382324 sec
# average relative error of u: 20.017857279732976%
# maximum relative error of u: 24.17486275441943%
#
# # of POD basis is 4
# # of measurments: 12
# [ 353  422  718  968 1271 1707 1839 2176 2499 2749 3214 3323]
# Param is 75
# Time elapsed: 1.901947259902954 sec
# average relative error of u: 6.425537270304325%
# maximum relative error of u: 7.442545774876155%
#
# Param is 76
# Time elapsed: 2.08976674079895 sec
# average relative error of u: 6.382044422980846%
# maximum relative error of u: 7.381366581848677%
#
# Param is 77
# Time elapsed: 2.0426619052886963 sec
# average relative error of u: 6.327138864373727%
# maximum relative error of u: 7.30544782085648%
#
# Param is 78
# Time elapsed: 1.8581786155700684 sec
# average relative error of u: 6.260965798745522%
# maximum relative error of u: 7.214895075886177%
#
# Param is 79
# Time elapsed: 1.964468002319336 sec
# average relative error of u: 6.183761822838151%
# maximum relative error of u: 7.110121430498408%
#
# Param is 80
# Time elapsed: 2.0636065006256104 sec
# average relative error of u: 6.095904156822569%
# maximum relative error of u: 6.991578307523196%
#
# Param is 81
# Time elapsed: 1.819422721862793 sec
# average relative error of u: 5.997811485876399%
# maximum relative error of u: 6.859886947235465%
#
# Param is 82
# Time elapsed: 1.9600374698638916 sec
# average relative error of u: 5.890014825993322%
# maximum relative error of u: 6.715848109888302%
#
# Param is 83
# Time elapsed: 1.8974430561065674 sec
# average relative error of u: 5.773205374493829%
# maximum relative error of u: 6.560439487701009%
#
# Param is 84
# Time elapsed: 1.7714731693267822 sec
# average relative error of u: 5.648153231323631%
# maximum relative error of u: 6.394799620771245%
#
# Param is 85
# Time elapsed: 1.8450627326965332 sec
# average relative error of u: 5.515803629828028%
# maximum relative error of u: 6.220289718026225%
#
# Param is 86
# Time elapsed: 1.8500494956970215 sec
# average relative error of u: 5.377253738656134%
# maximum relative error of u: 6.03841414215578%
#
# Param is 87
# Time elapsed: 1.932790994644165 sec
# average relative error of u: 5.233690209916383%
# maximum relative error of u: 5.850831616832773%
#
# Param is 88
# Time elapsed: 1.8391361236572266 sec
# average relative error of u: 5.086616523186821%
# maximum relative error of u: 5.6595192632027205%
#
# Param is 89
# Time elapsed: 1.8814787864685059 sec
# average relative error of u: 4.937559631779577%
# maximum relative error of u: 5.466465262986125%
#
# Param is 90
# Time elapsed: 1.97483491897583 sec
# average relative error of u: 4.788406340140743%
# maximum relative error of u: 5.274076835740052%
#
# Param is 91
# Time elapsed: 1.8598017692565918 sec
# average relative error of u: 4.64119140305018%
# maximum relative error of u: 5.0848889664859644%
#
# Param is 92
# Time elapsed: 1.9271576404571533 sec
# average relative error of u: 4.498189210979687%
# maximum relative error of u: 4.901835505943567%
#
# Param is 93
# Time elapsed: 1.963914394378662 sec
# average relative error of u: 4.361856145182235%
# maximum relative error of u: 4.72815647279482%
#
# Param is 94
# Time elapsed: 1.8915958404541016 sec
# average relative error of u: 4.234866909823749%
# maximum relative error of u: 4.567729439671153%
#
# Param is 95
# Time elapsed: 1.7843937873840332 sec
# average relative error of u: 4.12006225292305%
# maximum relative error of u: 4.425383048581943%
#
# Param is 96
# Time elapsed: 1.8979017734527588 sec
# average relative error of u: 4.020351947984784%
# maximum relative error of u: 4.307478244219918%
#
# Param is 97
# Time elapsed: 1.7834358215332031 sec
# average relative error of u: 3.938568636422932%
# maximum relative error of u: 4.22083501200544%
#
# Param is 98
# Time elapsed: 1.7072687149047852 sec
# average relative error of u: 3.877436907990555%
# maximum relative error of u: 4.167788142532613%
#
# Param is 99
# Time elapsed: 1.4159653186798096 sec
# average relative error of u: 3.839327683297924%
# maximum relative error of u: 4.145809655642727%
#
# Param is 100
# Time elapsed: 1.4332852363586426 sec
# average relative error of u: 3.8261127944436244%
# maximum relative error of u: 4.1514231501060435%
#
# Param is 101
# Time elapsed: 1.5276305675506592 sec
# average relative error of u: 3.8391060290281667%
# maximum relative error of u: 4.181785007019246%
#
# Param is 102
# Time elapsed: 1.3729517459869385 sec
# average relative error of u: 3.878880188736385%
# maximum relative error of u: 4.234565875333113%
#
# Param is 103
# Time elapsed: 1.640496015548706 sec
# average relative error of u: 3.9453746669564014%
# maximum relative error of u: 4.307976308288967%
#
# Param is 104
# Time elapsed: 1.6819713115692139 sec
# average relative error of u: 4.037937999479037%
# maximum relative error of u: 4.400527775326153%
#
# Param is 105
# Time elapsed: 1.7342870235443115 sec
# average relative error of u: 4.155447709533888%
# maximum relative error of u: 4.511087440517888%
#
# Param is 106
# Time elapsed: 1.7368271350860596 sec
# average relative error of u: 4.296530944980538%
# maximum relative error of u: 4.638928192197788%
#
# Param is 107
# Time elapsed: 1.794499158859253 sec
# average relative error of u: 4.459735486482117%
# maximum relative error of u: 4.78363331820615%
#
# Param is 108
# Time elapsed: 1.689823865890503 sec
# average relative error of u: 4.643672017050958%
# maximum relative error of u: 4.945365297465206%
#
# Param is 109
# Time elapsed: 1.7438976764678955 sec
# average relative error of u: 4.847156174074388%
# maximum relative error of u: 5.139999687685468%
#
# Param is 110
# Time elapsed: 1.5779244899749756 sec
# average relative error of u: 5.069328121051114%
# maximum relative error of u: 5.429667925903037%
#
# Param is 111
# Time elapsed: 1.5168263912200928 sec
# average relative error of u: 5.309646010091009%
# maximum relative error of u: 5.740590435074258%
#
# Param is 112
# Time elapsed: 1.2369451522827148 sec
# average relative error of u: 5.567982483588756%
# maximum relative error of u: 6.073138255517003%
#
# Param is 113
# Time elapsed: 1.6221404075622559 sec
# average relative error of u: 5.844587395214659%
# maximum relative error of u: 6.428225092528845%
#
# Param is 114
# Time elapsed: 1.7309210300445557 sec
# average relative error of u: 6.140008294655778%
# maximum relative error of u: 6.807308078623587%
#
# Param is 115
# Time elapsed: 1.778630018234253 sec
# average relative error of u: 6.455154746947349%
# maximum relative error of u: 7.212312768782725%
#
# Param is 116
# Time elapsed: 1.6931169033050537 sec
# average relative error of u: 6.791211270734918%
# maximum relative error of u: 7.6454414905065065%
#
# Param is 117
# Time elapsed: 1.6944291591644287 sec
# average relative error of u: 7.14947100960073%
# maximum relative error of u: 8.109060013969088%
#
# Param is 118
# Time elapsed: 1.8281409740447998 sec
# average relative error of u: 7.531408030960816%
# maximum relative error of u: 8.605629766724077%
#
# Param is 119
# Time elapsed: 1.931187391281128 sec
# average relative error of u: 7.9385187965406505%
# maximum relative error of u: 9.137516891786731%
#
# Param is 120
# Time elapsed: 1.7214686870574951 sec
# average relative error of u: 8.372202834574754%
# maximum relative error of u: 9.706848386037638%
#
# Param is 121
# Time elapsed: 1.6138989925384521 sec
# average relative error of u: 8.833817335364678%
# maximum relative error of u: 10.315538820842415%
#
# Param is 122
# Time elapsed: 1.7826688289642334 sec
# average relative error of u: 9.32448868144664%
# maximum relative error of u: 10.965069070023429%
#
# Param is 123
# Time elapsed: 1.6004436016082764 sec
# average relative error of u: 9.845141156236151%
# maximum relative error of u: 11.656534209544422%
#
# Param is 124
# Time elapsed: 1.3914244174957275 sec
# average relative error of u: 10.396410164282678%
# maximum relative error of u: 12.390539835068106%
#
# Param is 125
# Time elapsed: 1.3746776580810547 sec
# average relative error of u: 10.97861642868099%
# maximum relative error of u: 13.167175775886722%
#
# # of POD basis is 5
# # of measurments: 12
# [ 353  422  718  968 1271 1707 1839 2176 2499 2749 3214 3323]
# Param is 75
# Time elapsed: 1.4695019721984863 sec
# average relative error of u: 3.569743059680613%
# maximum relative error of u: 4.206534395869771%
#
# Param is 76
# Time elapsed: 1.418123722076416 sec
# average relative error of u: 3.4874644794473575%
# maximum relative error of u: 4.0954290385068415%
#
# Param is 77
# Time elapsed: 1.5329680442810059 sec
# average relative error of u: 3.400594741468619%
# maximum relative error of u: 3.975213816621623%
#
# Param is 78
# Time elapsed: 1.5948286056518555 sec
# average relative error of u: 3.3103105506592767%
# maximum relative error of u: 3.846904082215837%
#
# Param is 79
# Time elapsed: 1.7471325397491455 sec
# average relative error of u: 3.2180111383915584%
# maximum relative error of u: 3.7118194503923605%
#
# Param is 80
# Time elapsed: 1.5156493186950684 sec
# average relative error of u: 3.125382150028195%
# maximum relative error of u: 3.57166953350161%
#
# Param is 81
# Time elapsed: 1.5253238677978516 sec
# average relative error of u: 3.034285644061164%
# maximum relative error of u: 3.4284201175340914%
#
# Param is 82
# Time elapsed: 1.4471654891967773 sec
# average relative error of u: 2.9469003082010903%
# maximum relative error of u: 3.2846032524603554%
#
# Param is 83
# Time elapsed: 1.4911670684814453 sec
# average relative error of u: 2.8656171131153507%
# maximum relative error of u: 3.1431233528922493%
#
# Param is 84
# Time elapsed: 1.8224947452545166 sec
# average relative error of u: 2.793026626898359%
# maximum relative error of u: 3.031553336114344%
#
# Param is 85
# Time elapsed: 2.3239150047302246 sec
# average relative error of u: 2.7318154189125745%
# maximum relative error of u: 3.013912274443637%
#
# Param is 86
# Time elapsed: 1.9398703575134277 sec
# average relative error of u: 2.6846510968212094%
# maximum relative error of u: 3.0068418721106047%
#
# Param is 87
# Time elapsed: 1.9655373096466064 sec
# average relative error of u: 2.653915224339748%
# maximum relative error of u: 3.010813121926043%
#
# Param is 88
# Time elapsed: 2.3505799770355225 sec
# average relative error of u: 2.641687790875293%
# maximum relative error of u: 3.0263361827552897%
#
# Param is 89
# Time elapsed: 1.385404348373413 sec
# average relative error of u: 2.6492727560195144%
# maximum relative error of u: 3.0537038078272096%
#
# Param is 90
# Time elapsed: 2.100754499435425 sec
# average relative error of u: 2.677331664263671%
# maximum relative error of u: 3.093209194892046%
#
# Param is 91
# Time elapsed: 1.9366772174835205 sec
# average relative error of u: 2.7255886105530394%
# maximum relative error of u: 3.1448833519183963%
#
# Param is 92
# Time elapsed: 2.235459804534912 sec
# average relative error of u: 2.7929605942690117%
# maximum relative error of u: 3.208610698915501%
#
# Param is 93
# Time elapsed: 1.9763669967651367 sec
# average relative error of u: 2.8776294856926605%
# maximum relative error of u: 3.283999079212889%
#
# Param is 94
# Time elapsed: 2.002187967300415 sec
# average relative error of u: 2.9772570900457915%
# maximum relative error of u: 3.370457101758157%
#
# Param is 95
# Time elapsed: 1.9028427600860596 sec
# average relative error of u: 3.089145756805736%
# maximum relative error of u: 3.4670651509415373%
#
# Param is 96
# Time elapsed: 1.7345221042633057 sec
# average relative error of u: 3.210397121991985%
# maximum relative error of u: 3.5726112975510578%
#
# Param is 97
# Time elapsed: 1.737429141998291 sec
# average relative error of u: 3.338081082715347%
# maximum relative error of u: 3.685642390861779%
#
# Param is 98
# Time elapsed: 1.4350173473358154 sec
# average relative error of u: 3.4693106062142367%
# maximum relative error of u: 3.8045121156027686%
#
# Param is 99
# Time elapsed: 1.4204940795898438 sec
# average relative error of u: 3.601322421422421%
# maximum relative error of u: 3.9273259055046457%
#
# Param is 100
# Time elapsed: 1.3895623683929443 sec
# average relative error of u: 3.731509780155469%
# maximum relative error of u: 4.052177442673443%
#
# Param is 101
# Time elapsed: 1.478787899017334 sec
# average relative error of u: 3.8575027105036193%
# maximum relative error of u: 4.177174118197947%
#
# Param is 102
# Time elapsed: 1.4771699905395508 sec
# average relative error of u: 3.9771291672256592%
# maximum relative error of u: 4.300530424091495%
#
# Param is 103
# Time elapsed: 1.2252607345581055 sec
# average relative error of u: 4.0884956982322365%
# maximum relative error of u: 4.420675761318137%
#
# Param is 104
# Time elapsed: 1.3717634677886963 sec
# average relative error of u: 4.190021100608498%
# maximum relative error of u: 4.5363419816342985%
#
# Param is 105
# Time elapsed: 1.3826849460601807 sec
# average relative error of u: 4.280421535313327%
# maximum relative error of u: 4.646513357891257%
#
# Param is 106
# Time elapsed: 1.4652659893035889 sec
# average relative error of u: 4.358848325203395%
# maximum relative error of u: 4.750514668568722%
#
# Param is 107
# Time elapsed: 1.6347615718841553 sec
# average relative error of u: 4.424937557317391%
# maximum relative error of u: 4.847957819836901%
#
# Param is 108
# Time elapsed: 1.6713523864746094 sec
# average relative error of u: 4.4788820049140154%
# maximum relative error of u: 4.9387330439368515%
#
# Param is 109
# Time elapsed: 1.6839075088500977 sec
# average relative error of u: 4.521553503220399%
# maximum relative error of u: 5.023014772496176%
#
# Param is 110
# Time elapsed: 1.856628179550171 sec
# average relative error of u: 4.554653015482267%
# maximum relative error of u: 5.101267912680611%
#
# Param is 111
# Time elapsed: 1.8472175598144531 sec
# average relative error of u: 4.580819338972237%
# maximum relative error of u: 5.174175963328241%
#
# Param is 112
# Time elapsed: 1.9460182189941406 sec
# average relative error of u: 4.603828338000978%
# maximum relative error of u: 5.242923313477785%
#
# Param is 113
# Time elapsed: 1.8652894496917725 sec
# average relative error of u: 4.628650576023459%
# maximum relative error of u: 5.308933967772472%
#
# Param is 114
# Time elapsed: 1.5777182579040527 sec
# average relative error of u: 4.661550406976722%
# maximum relative error of u: 5.374225992995213%
#
# Param is 115
# Time elapsed: 1.846827745437622 sec
# average relative error of u: 4.710062022963295%
# maximum relative error of u: 5.441399786835035%
#
# Param is 116
# Time elapsed: 1.7613253593444824 sec
# average relative error of u: 4.782821193031509%
# maximum relative error of u: 5.514031329332267%
#
# Param is 117
# Time elapsed: 1.7418384552001953 sec
# average relative error of u: 4.889031679288383%
# maximum relative error of u: 5.596851504127027%
#
# Param is 118
# Time elapsed: 1.6932275295257568 sec
# average relative error of u: 5.037994458720972%
# maximum relative error of u: 5.696674741867711%
#
# Param is 119
# Time elapsed: 1.7495996952056885 sec
# average relative error of u: 5.238269676655819%
# maximum relative error of u: 5.823351498531566%
#
# Param is 120
# Time elapsed: 1.497115135192871 sec
# average relative error of u: 5.496966693819668%
# maximum relative error of u: 5.992347907132413%
#
# Param is 121
# Time elapsed: 1.9774096012115479 sec
# average relative error of u: 5.819168155651566%
# maximum relative error of u: 6.229728949611861%
#
# Param is 122
# Time elapsed: 1.8106944561004639 sec
# average relative error of u: 6.2077700487505%
# maximum relative error of u: 6.669335031237885%
#
# Param is 123
# Time elapsed: 2.579362630844116 sec
# average relative error of u: 6.663484802380556%
# maximum relative error of u: 7.365213234878026%
#
# Param is 124
# Time elapsed: 1.7238707542419434 sec
# average relative error of u: 7.185236876074108%
# maximum relative error of u: 8.145908061334833%
#
# Param is 125
# Time elapsed: 1.7027413845062256 sec
# average relative error of u: 7.770558919391149%
# maximum relative error of u: 9.004943236144992%
#
# # of POD basis is 6
# # of measurments: 12
# [ 353  422  718  968 1271 1707 1839 2176 2499 2749 3214 3323]
# Param is 75
# Time elapsed: 1.3778538703918457 sec
# average relative error of u: 3.457410349929669%
# maximum relative error of u: 4.118106909030351%
#
# Param is 76
# Time elapsed: 1.7927541732788086 sec
# average relative error of u: 3.3538777355616487%
# maximum relative error of u: 3.9882825673053053%
#
# Param is 77
# Time elapsed: 1.557511806488037 sec
# average relative error of u: 3.2424705251487516%
# maximum relative error of u: 3.8464909143604684%
#
# Param is 78
# Time elapsed: 1.599485158920288 sec
# average relative error of u: 3.1238822271569067%
# maximum relative error of u: 3.6933049843710415%
#
# Param is 79
# Time elapsed: 1.637342929840088 sec
# average relative error of u: 2.9989778028702045%
# maximum relative error of u: 3.529488805075951%
#
# Param is 80
# Time elapsed: 1.6451516151428223 sec
# average relative error of u: 2.86887431518312%
# maximum relative error of u: 3.356134446658056%
#
# Param is 81
# Time elapsed: 1.591071367263794 sec
# average relative error of u: 2.734826240085736%
# maximum relative error of u: 3.1744890927497846%
#
# Param is 82
# Time elapsed: 1.514883041381836 sec
# average relative error of u: 2.598459316309324%
# maximum relative error of u: 2.9863050220369924%
#
# Param is 83
# Time elapsed: 1.5249593257904053 sec
# average relative error of u: 2.4616718968204365%
# maximum relative error of u: 2.793653300660519%
#
# Param is 84
# Time elapsed: 1.7108721733093262 sec
# average relative error of u: 2.3267951711134405%
# maximum relative error of u: 2.5992658372710786%
#
# Param is 85
# Time elapsed: 1.79091477394104 sec
# average relative error of u: 2.1965621503881994%
# maximum relative error of u: 2.4066242719976727%
#
# Param is 86
# Time elapsed: 1.930868148803711 sec
# average relative error of u: 2.0742234420905845%
# maximum relative error of u: 2.2543438349869964%
#
# Param is 87
# Time elapsed: 1.7695505619049072 sec
# average relative error of u: 1.9634304250391084%
# maximum relative error of u: 2.1670024567055286%
#
# Param is 88
# Time elapsed: 1.7269575595855713 sec
# average relative error of u: 1.8682905782649355%
# maximum relative error of u: 2.086400350104988%
#
# Param is 89
# Time elapsed: 1.888472557067871 sec
# average relative error of u: 1.7928736050101024%
# maximum relative error of u: 2.013612029082911%
#
# Param is 90
# Time elapsed: 1.8947772979736328 sec
# average relative error of u: 1.740973438777466%
# maximum relative error of u: 1.9499637446554308%
#
# Param is 91
# Time elapsed: 1.8863935470581055 sec
# average relative error of u: 1.7153367663924417%
# maximum relative error of u: 1.8970393821330165%
#
# Param is 92
# Time elapsed: 1.6439244747161865 sec
# average relative error of u: 1.7171160420876495%
# maximum relative error of u: 1.8571351938528171%
#
# Param is 93
# Time elapsed: 1.5794029235839844 sec
# average relative error of u: 1.745546830447349%
# maximum relative error of u: 1.83621978846773%
#
# Param is 94
# Time elapsed: 1.7145230770111084 sec
# average relative error of u: 1.798033450745477%
# maximum relative error of u: 1.8825434200594904%
#
# Param is 95
# Time elapsed: 1.5837345123291016 sec
# average relative error of u: 1.87061491970188%
# maximum relative error of u: 1.9897288802601352%
#
# Param is 96
# Time elapsed: 1.5103752613067627 sec
# average relative error of u: 1.9585648366627062%
# maximum relative error of u: 2.1207633723195762%
#
# Param is 97
# Time elapsed: 1.6615610122680664 sec
# average relative error of u: 2.0570172052905584%
# maximum relative error of u: 2.264926009584587%
#
# Param is 98
# Time elapsed: 1.712721347808838 sec
# average relative error of u: 2.1612338074879633%
# maximum relative error of u: 2.4146284222891263%
#
# Param is 99
# Time elapsed: 1.4912569522857666 sec
# average relative error of u: 2.2668625665299538%
# maximum relative error of u: 2.5636330360661406%
#
# Param is 100
# Time elapsed: 1.570453405380249 sec
# average relative error of u: 2.3700193008775403%
# maximum relative error of u: 2.706781623350089%
#
# Param is 101
# Time elapsed: 1.4599175453186035 sec
# average relative error of u: 2.4672367646575086%
# maximum relative error of u: 2.839488142496308%
#
# Param is 102
# Time elapsed: 1.5056519508361816 sec
# average relative error of u: 2.555501593417713%
# maximum relative error of u: 2.957798413973588%
#
# Param is 103
# Time elapsed: 1.2665677070617676 sec
# average relative error of u: 2.6321751992796347%
# maximum relative error of u: 3.0581321538600283%
#
# Param is 104
# Time elapsed: 1.2646713256835938 sec
# average relative error of u: 2.695106799444184%
# maximum relative error of u: 3.137549530225215%
#
# Param is 105
# Time elapsed: 1.3510785102844238 sec
# average relative error of u: 2.7424578477717083%
# maximum relative error of u: 3.193346971102152%
#
# Param is 106
# Time elapsed: 1.5265324115753174 sec
# average relative error of u: 2.772948622295987%
# maximum relative error of u: 3.22349086709057%
#
# Param is 107
# Time elapsed: 1.4241540431976318 sec
# average relative error of u: 2.785902317253873%
# maximum relative error of u: 3.226661113352823%
#
# Param is 108
# Time elapsed: 1.3258421421051025 sec
# average relative error of u: 2.781364013260963%
# maximum relative error of u: 3.202330375040896%
#
# Param is 109
# Time elapsed: 1.5190215110778809 sec
# average relative error of u: 2.7603605020310784%
# maximum relative error of u: 3.151278095679088%
#
# Param is 110
# Time elapsed: 1.2673652172088623 sec
# average relative error of u: 2.725250437026009%
# maximum relative error of u: 3.0760457064457203%
#
# Param is 111
# Time elapsed: 1.2628865242004395 sec
# average relative error of u: 2.6800079040664877%
# maximum relative error of u: 2.9815714719870665%
#
# Param is 112
# Time elapsed: 1.357414722442627 sec
# average relative error of u: 2.630966783007826%
# maximum relative error of u: 2.8765877178625106%
#
# Param is 113
# Time elapsed: 1.6896624565124512 sec
# average relative error of u: 2.5871569041817177%
# maximum relative error of u: 2.7748421816785696%
#
# Param is 114
# Time elapsed: 1.6341173648834229 sec
# average relative error of u: 2.560724036893376%
# maximum relative error of u: 2.7105989843570755%
#
# Param is 115
# Time elapsed: 1.563178539276123 sec
# average relative error of u: 2.566808848472423%
# maximum relative error of u: 2.7751308680899625%
#
# Param is 116
# Time elapsed: 1.4576497077941895 sec
# average relative error of u: 2.622213250338868%
# maximum relative error of u: 2.843299443763123%
#
# Param is 117
# Time elapsed: 1.4048740863800049 sec
# average relative error of u: 2.7426606064301757%
# maximum relative error of u: 2.917337063019528%
#
# Param is 118
# Time elapsed: 1.4883131980895996 sec
# average relative error of u: 2.940038776027001%
# maximum relative error of u: 3.1346271604107105%
#
# Param is 119
# Time elapsed: 1.5044021606445312 sec
# average relative error of u: 3.220320785567906%
# maximum relative error of u: 3.5313807881735264%
#
# Param is 120
# Time elapsed: 1.4165928363800049 sec
# average relative error of u: 3.583740014226285%
# maximum relative error of u: 4.045532282670741%
#
# Param is 121
# Time elapsed: 1.570953369140625 sec
# average relative error of u: 4.026598012421739%
# maximum relative error of u: 4.66581024823324%
#
# Param is 122
# Time elapsed: 1.6509222984313965 sec
# average relative error of u: 4.543249539890542%
# maximum relative error of u: 5.380641537976158%
#
# Param is 123
# Time elapsed: 1.6906681060791016 sec
# average relative error of u: 5.127532091010598%
# maximum relative error of u: 6.179879098488817%
#
# Param is 124
# Time elapsed: 1.5019333362579346 sec
# average relative error of u: 5.773549230119899%
# maximum relative error of u: 7.054990969221599%
#
# Param is 125
# Time elapsed: 1.5313527584075928 sec
# average relative error of u: 6.475903018324355%
# maximum relative error of u: 7.998869831444906%

# %%
print(num_basis)
idx=[0,1,2,3]
num_basis[idx]
# Out:
# [3 4 5 6]
# array([3, 4, 5, 6])

# %%
# with open(file=file_path_gappy_LHS_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_POD_inner_LHS_seed_{}_avg_rel_err.png".format(LHS_seed))

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_POD_inner_LHS_seed_{}_max_rel_err.png".format(LHS_seed))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
idx=[3]
POD_basis=num_basis[idx]
print(POD_basis)
# Out:
# [6]

# %%
# with open(file=file_path_gappy_LHS_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_POD_{}_LHS_seed_{}_avg_rel_err.png".format(POD_basis,LHS_seed)

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex16_diffusion/ex16_POD_{}_LHS_seed_{}_max_rel_err.png".format(POD_basis,LHS_seed)
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
print(num_basis)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=3;j=-1
POD_basis=num_basis[i]                 
param=FOM_parameters[j]

u_gappyPOD=results['solution'][i,j]

ex = np.load('../__data/ex16_diffusion/ex16_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("POD basis: {} Param: {}".format(POD_basis,param))
plt.show()

# plot original data
vmin=0; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyPOD[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy POD @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex16_diffusion/ex16_POD_{}_inner_LHS_seed_{}_SOL.png".format(POD_basis,LHS_seed))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex16_diffusion/ex16_ground_truth.png")
