# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle
import torch
import torch.nn as nn

# %%
# Given parameters
nx = 60
ny = 60
tf = 5.0
dt = 1.0e-2
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims = (ny,nx)

# latent space dim.
f_list=np.array([3,4,5,6])
print('Latent Sapce Dim. {}'.format(f_list))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_SOPT_result = "../__result/ex23_wave/ex23_AE_swish_inner_SOPT_gappy_result_seed_{}.p".format(seed)
print(file_path_gappy_SOPT_result)

# Gauss-Newton params
maxitr=4
tol=1e-8

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# Latent Sapce Dim. [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]
# ../__result/ex23_wave/ex23_AE_swish_inner_SOPT_gappy_result_seed_0.p

# %%
file_path_SOPT="../__model/SOPT_sample_points/ex23_AE_inner_SOPT_no_oversampling.p"
with open(file=file_path_SOPT, mode='rb') as ff:  
        msmt_idx_list = pickle.load(ff)

for ii in range(len(f_list)):
    f=f_list[ii]
    print("Latent Space Dimension: {}".format(f))
    
    # S-OPT
    msmt_idx=msmt_idx_list[ii]
    print("# of measurments: {}".format(len(msmt_idx)))
    print(msmt_idx)
    num_msmt=len(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig("../__result/ex23_wave/ex23_AE_{}_swish_inner_SOPT_{}_samples_seed_{}.png".format(f,num_msmt,seed))
# Out:
# Latent Space Dimension: 3
# # of measurments: 12
# [  61  103  118  202  549  817 1036 1683 1858 2563 3012 3173]
# Latent Space Dimension: 4
# # of measurments: 12
# [ 241  451  669  718  761  855 2163 2643 2894 3003 3175 3382]
# Latent Space Dimension: 5
# # of measurments: 12
# [ 122  166  471  598  856 1206 1392 1681 1858 2502 2528 3354]
# Latent Space Dimension: 6
# # of measurments: 12
# [  61   95  313  440  718 1565 1861 2592 2701 2745 3302 3358]

# %% [markdown]
# # gappyAE

# %%
solution=np.zeros((len(f_list),len(FOM_parameters),nt+1,nx*ny))
reduced=np.zeros((len(f_list),len(FOM_parameters),nt+1,f_list[-1]))
avg_rel_err=np.zeros((len(f_list),len(FOM_parameters)))
rel_err=np.zeros((len(f_list),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(f_list),len(FOM_parameters)))

for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))
    
    # file path
    file_name_AE="../__model/ex23_wave/ex23_AE_{}_swish_seed_{}.p".format(f,seed)
    file_path_residual_SVD="../__model/ex23_wave/ex23_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)
    
    with open(file=file_path_residual_SVD, mode='rb') as fff:
        SVD=pickle.load(fff)

    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
    
    # precompute
    phi_r=SVD['U'][:,:num_msmt]
    ZTphi_r=phi_r[msmt_idx]
    ZTphi_r_pinv=np.linalg.pinv(ZTphi_r)
    phi_rZTphi_r_pinv=phi_r.dot(ZTphi_r_pinv)
        
    with open(file=file_name_AE, mode='rb') as ff:    
        AE = pickle.load(ff)

    en_wu1=AE['en_wu1']
    en_bu1=AE['en_bu1']
    en_wu2=AE['en_wu2']
    de_wu1=AE['de_wu1']
    de_bu1=AE['de_bu1']
    de_wu2=AE['de_wu2']
    de_wu1T=AE['de_wu1T']
    de_wu2T=AE['de_wu2T']
    de_wu2_sp=AE['de_wu2_sp']
    de_wu2T_sp=AE['de_wu2T_sp']
    u_ref=AE['u_ref']

    latent_dim=de_wu1.shape[1]
    
    # numpy version of AE
    def sigmoid_np(input):
        return (1.0/(1.0+np.exp(-input))).astype('float32')

    def encoder_u_np_forward(x):
        z1 = en_wu1.dot(x) + en_bu1
        a1 = z1 * sigmoid_np(z1)
        y = en_wu2.dot(a1)   
        return y

    def decoder_u_np_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = de_wu2.dot(a1)  
        return y

    def decoder_u_sp_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(de_wu2_sp,a1)
        return y

    def decoder_u_np_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = de_wu2.dot(a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(de_wu2T)   
        return y,dydxT

    def decoder_u_sp_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(de_wu2_sp,a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,de_wu2T_sp)
        return y,dydxT
    
    m,M2=de_wu2.shape

    class Decoder_U_FC(nn.Module):

        def __init__(self,):
            super(Decoder_U_FC, self).__init__()
            self.fc1 = nn.Linear(latent_dim,M2)
            self.fc1.weight = nn.Parameter(torch.ones(de_wu1.shape))
            self.fc1.bias = nn.Parameter(torch.ones(de_bu1.shape))
    #         self.fc1.weight = nn.Parameter(torch.tensor(de_wu1))
    #         self.fc1.bias = nn.Parameter(torch.tensor(de_bu1))

            self.fc2 = nn.Linear(M2,m,bias=False)
            self.fc2.weight = nn.Parameter(torch.ones(de_wu2.shape))
    #         self.fc2.weight = nn.Parameter(torch.tensor(de_wu2))

        def forward(self, x):
            x = self.fc1(x)
            x = self.fc2(x)
            return x

    model = Decoder_U_FC()

    x_in=torch.ones(latent_dim)
    y_out=model(x_in)

    p_hr=msmt_idx

    upstream=torch.zeros_like(y_out)
    upstream[p_hr]=1.0

    y_out.backward(upstream)

    # masks for subnet
    wu1_mask=model.fc1.weight.grad
    wu2_mask=model.fc2.weight.grad

    bu1_mask=model.fc1.bias.grad

    # subnet sparse weight
    idx1=wu1_mask.to_sparse()._indices()
    i1=idx1.numpy()[0]
    j1=idx1.numpy()[1]
    v1=de_wu1[i1,j1]
    wu1_sb_sp=sp.csr_matrix(sp.csr_matrix((v1,(i1,j1)),shape=wu1_mask.shape).toarray())

    idx2=wu2_mask.to_sparse()._indices()
    i2=idx2.numpy()[0]
    j2=idx2.numpy()[1]
    v2=de_wu2[i2,j2]
    wu2_sb_sp=sp.csr_matrix(sp.csr_matrix((v2,(i2,j2)),shape=wu2_mask.shape).toarray())

    # subnet compressed weight
    i1,j1,v1=sp.find(wu1_sb_sp)
    i1_unique,i1_inverse=np.unique(i1,return_inverse=True)
    i1_comp=np.arange(i1_unique.size)
    i1_comp=i1_comp[i1_inverse]
    j1_unique,j1_inverse=np.unique(j1,return_inverse=True)
    j1_comp=np.arange(j1_unique.size)
    j1_comp=j1_comp[j1_inverse]
    wu1_sb_comp_sp=sp.csr_matrix((v1,(i1_comp,j1_comp)),shape=(i1_unique.size,j1_unique.size))

    i2,j2,v2=sp.find(wu2_sb_sp)
    i2_unique,i2_inverse=np.unique(i2,return_inverse=True)
    i2_comp=np.arange(i2_unique.size)
    i2_comp=i2_comp[i2_inverse]
    j2_unique,j2_inverse=np.unique(j2,return_inverse=True)
    j2_comp=np.arange(j2_unique.size)
    j2_comp=j2_comp[j2_inverse]
    wu2_sb_comp_sp=sp.csr_matrix((v2,(i2_comp,j2_comp)),shape=(i2_unique.size,j2_unique.size))

    wu1_sb_comp_dense=wu1_sb_comp_sp.toarray()
    wu1_sb_comp_dense=wu1_sb_comp_dense[j2_unique]
    wu2_sb_comp_dense=wu2_sb_comp_sp.toarray()

    wu1_sb_comp_denseT=wu1_sb_comp_dense.T
    wu2_sb_comp_denseT=wu2_sb_comp_dense.T

    # subnet compressed bias
    bu1_sb_comp_dense=de_bu1[i1_unique]
    bu1_sb_comp_dense=bu1_sb_comp_dense[j2_unique]

    # Using sparse matrix
    wu2_sb_comp_sp=sp.csr_matrix(wu2_sb_comp_dense,dtype='float32')
    wu2_sb_comp_spT=sp.csr_matrix(wu2_sb_comp_denseT,dtype='float32')

    def decoder_u_sb_np_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = wu2_sb_comp_dense.dot(a1)  
        return y

    def decoder_u_sb_np_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = wu2_sb_comp_dense.dot(a1) 

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(wu2_sb_comp_denseT)
        return y,dydxT

    def decoder_u_sb_sp_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)
        return y

    def decoder_u_sb_sp_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,wu2_sb_comp_spT)
        return y,dydxT

    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('../__data/ex23_wave/ex23_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1).astype('float32')

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_hat0=encoder_u_np_forward(u0.astype('float32')-u_ref)

        # gappyAE
        t_start_gappyAE=time.time()

        # solution
        u_reduced=np.zeros((nt+1,latent_dim))
        u_gappyAE=np.zeros((nt+1,ny*nx))

        # IC
        u_reduced[0]=np.copy(u_hat0)
        u_gappyAE[0]=np.copy(u0)

        for k in range(nt):
#             print("")
#             print(k,"th time step:")

            u_hatw=np.copy(u_reduced[k])

            umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

            umw += u_ref[msmt_idx]

            J_r=-Jg_umT.T
            J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

            r_um_hat = um[k+1]-umw

            res = np.linalg.norm(J_pinv.dot(r_um_hat))
#             res = np.linalg.norm(r_um_hat)
            res_hist=[res]
            for itr in range(maxitr):
                du_hatw = J_pinv.dot(r_um_hat)

                u_hatw -= du_hatw

                umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

                umw += u_ref[msmt_idx]

                J_r=-Jg_umT.T
                J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

                r_um_hat = um[k+1]-umw

                res = np.linalg.norm(J_pinv.dot(r_um_hat))
#                 res = np.linalg.norm(r_um_hat)
                res_hist.append(res)
#                 print(itr,"th Newton iteration", "res:", "{:.8e}".format(res))

                if res<tol:
                    break

            u_reduced[k+1]=u_hatw.copy()
            u_gappyAE[k+1]=u_ref+decoder_u_sp_forward(u_reduced[k+1])

        # elapsed time    
        t_elapsed_gappyAE=time.time()-t_start_gappyAE
        print('Time elapsed: {} sec'.format(t_elapsed_gappyAE))

        # error
        u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                         /np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
                     /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
        print()

        # save result
        solution[ii,jj]=u_gappyAE
        reduced[ii,jj,:,:f]=u_reduced
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyAE
        elapsed_time[ii,jj]=t_elapsed_gappyAE
    
results={'solution':solution,'reduced':reduced,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_SOPT_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [  61  103  118  202  549  817 1036 1683 1858 2563 3012 3173]
# Param is 75
# Time elapsed: 23.570838689804077 sec
# average relative error of u: 1.2496275490569875%
# maximum relative error of u: 1.960218527326942%
#
# Param is 76
# Time elapsed: 26.34062623977661 sec
# average relative error of u: 1.1858714687202245%
# maximum relative error of u: 1.865701870520968%
#
# Param is 77
# Time elapsed: 26.861974954605103 sec
# average relative error of u: 1.1276229151229433%
# maximum relative error of u: 1.7776340179876517%
#
# Param is 78
# Time elapsed: 24.689069271087646 sec
# average relative error of u: 1.075374380650814%
# maximum relative error of u: 1.696467798927017%
#
# Param is 79
# Time elapsed: 25.799973726272583 sec
# average relative error of u: 1.029626849221672%
# maximum relative error of u: 1.6225683124031356%
#
# Param is 80
# Time elapsed: 27.98044514656067 sec
# average relative error of u: 0.990863822926974%
# maximum relative error of u: 1.5562329834103783%
#
# Param is 81
# Time elapsed: 26.640472650527954 sec
# average relative error of u: 0.9595111574653197%
# maximum relative error of u: 1.4976527227744931%
#
# Param is 82
# Time elapsed: 26.036069631576538 sec
# average relative error of u: 0.9358953088926552%
# maximum relative error of u: 1.44684079489767%
#
# Param is 83
# Time elapsed: 25.75807523727417 sec
# average relative error of u: 0.9201971851089489%
# maximum relative error of u: 1.4036747873774993%
#
# Param is 84
# Time elapsed: 26.030951023101807 sec
# average relative error of u: 0.9124150918797838%
# maximum relative error of u: 1.4352489280121883%
#
# Param is 85
# Time elapsed: 26.86210560798645 sec
# average relative error of u: 0.9123541234309172%
# maximum relative error of u: 1.5101752483207436%
#
# Param is 86
# Time elapsed: 27.131346464157104 sec
# average relative error of u: 0.91963914967317%
# maximum relative error of u: 1.5951941881864595%
#
# Param is 87
# Time elapsed: 26.52811074256897 sec
# average relative error of u: 0.9337520059023312%
# maximum relative error of u: 1.6915748359815366%
#
# Param is 88
# Time elapsed: 24.117326259613037 sec
# average relative error of u: 0.9540885082055096%
# maximum relative error of u: 1.806825042861952%
#
# Param is 89
# Time elapsed: 25.930135488510132 sec
# average relative error of u: 0.9800115346339802%
# maximum relative error of u: 1.9324192632710988%
#
# Param is 90
# Time elapsed: 29.0013108253479 sec
# average relative error of u: 1.0108937690738493%
# maximum relative error of u: 2.0680835987358646%
#
# Param is 91
# Time elapsed: 28.89285111427307 sec
# average relative error of u: 1.0461442798056089%
# maximum relative error of u: 2.2135619623337552%
#
# Param is 92
# Time elapsed: 26.41373324394226 sec
# average relative error of u: 1.0852195007083987%
# maximum relative error of u: 2.3685878519695693%
#
# Param is 93
# Time elapsed: 27.556643962860107 sec
# average relative error of u: 1.1276286846454053%
# maximum relative error of u: 2.5329170330811195%
#
# Param is 94
# Time elapsed: 25.037731647491455 sec
# average relative error of u: 1.1729348361513379%
# maximum relative error of u: 2.7062615297897814%
#
# Param is 95
# Time elapsed: 27.101346492767334 sec
# average relative error of u: 1.220748675243553%
# maximum relative error of u: 2.888397034365879%
#
# Param is 96
# Time elapsed: 25.654426097869873 sec
# average relative error of u: 1.2707282811656693%
# maximum relative error of u: 3.0790515545099795%
#
# Param is 97
# Time elapsed: 24.898870944976807 sec
# average relative error of u: 1.3225730664510897%
# maximum relative error of u: 3.2779755745911583%
#
# Param is 98
# Time elapsed: 27.748267889022827 sec
# average relative error of u: 1.3760239644134076%
# maximum relative error of u: 3.489020092926394%
#
# Param is 99
# Time elapsed: 25.835777521133423 sec
# average relative error of u: 1.4308545003089734%
# maximum relative error of u: 3.7081015300403046%
#
# Param is 100
# Time elapsed: 26.858062028884888 sec
# average relative error of u: 1.4868729414146937%
# maximum relative error of u: 3.9343148374481807%
#
# Param is 101
# Time elapsed: 27.842103481292725 sec
# average relative error of u: 1.5439224177937851%
# maximum relative error of u: 4.167314102876977%
#
# Param is 102
# Time elapsed: 25.44487428665161 sec
# average relative error of u: 1.6018705644581497%
# maximum relative error of u: 4.406736323602568%
#
# Param is 103
# Time elapsed: 26.000245571136475 sec
# average relative error of u: 1.6606195812897913%
# maximum relative error of u: 4.652185679820513%
#
# Param is 104
# Time elapsed: 26.301835536956787 sec
# average relative error of u: 1.7202051822622955%
# maximum relative error of u: 4.903222686133915%
#
# Param is 105
# Time elapsed: 24.627363681793213 sec
# average relative error of u: 1.7806286835670089%
# maximum relative error of u: 5.159366106745544%
#
# Param is 106
# Time elapsed: 26.283349752426147 sec
# average relative error of u: 1.8417047044586667%
# maximum relative error of u: 5.420044990798673%
#
# Param is 107
# Time elapsed: 25.59236240386963 sec
# average relative error of u: 1.9038062150146708%
# maximum relative error of u: 5.684610949832959%
#
# Param is 108
# Time elapsed: 25.581218004226685 sec
# average relative error of u: 1.9677795817608499%
# maximum relative error of u: 5.952256848170943%
#
# Param is 109
# Time elapsed: 23.956519603729248 sec
# average relative error of u: 2.031885142369402%
# maximum relative error of u: 6.222007630619941%
#
# Param is 110
# Time elapsed: 27.885841608047485 sec
# average relative error of u: 2.0964070758810385%
# maximum relative error of u: 6.50556236932765%
#
# Param is 111
# Time elapsed: 27.61882972717285 sec
# average relative error of u: 2.1686542321835582%
# maximum relative error of u: 6.795037995717008%
#
# Param is 112
# Time elapsed: 28.248406410217285 sec
# average relative error of u: 2.23806500829984%
# maximum relative error of u: 7.089375373431503%
#
# Param is 113
# Time elapsed: 27.311140537261963 sec
# average relative error of u: 2.305839816794713%
# maximum relative error of u: 7.388414712976483%
#
# Param is 114
# Time elapsed: 27.65506935119629 sec
# average relative error of u: 2.3909580617844073%
# maximum relative error of u: 7.692027643451775%
#
# Param is 115
# Time elapsed: 26.608097076416016 sec
# average relative error of u: 2.4632755078416286%
# maximum relative error of u: 8.000079139280349%
#
# Param is 116
# Time elapsed: 27.695326328277588 sec
# average relative error of u: 2.550141651081058%
# maximum relative error of u: 8.312454852516415%
#
# Param is 117
# Time elapsed: 29.225339651107788 sec
# average relative error of u: 2.6367254204270236%
# maximum relative error of u: 8.629015617402496%
#
# Param is 118
# Time elapsed: 27.668822765350342 sec
# average relative error of u: 2.7171611969194567%
# maximum relative error of u: 8.949580330176973%
#
# Param is 119
# Time elapsed: 24.5597505569458 sec
# average relative error of u: 2.824403032782206%
# maximum relative error of u: 9.273906099477008%
#
# Param is 120
# Time elapsed: 27.322242975234985 sec
# average relative error of u: 2.906928193664167%
# maximum relative error of u: 9.601677522832034%
#
# Param is 121
# Time elapsed: 26.357128143310547 sec
# average relative error of u: 3.021764396580919%
# maximum relative error of u: 9.932471580586705%
#
# Param is 122
# Time elapsed: 24.61382746696472 sec
# average relative error of u: 3.113813612491281%
# maximum relative error of u: 10.265785725624427%
#
# Param is 123
# Time elapsed: 27.51908564567566 sec
# average relative error of u: 3.2024061269118955%
# maximum relative error of u: 10.60102037242714%
#
# Param is 124
# Time elapsed: 28.317302227020264 sec
# average relative error of u: 3.3352559181080537%
# maximum relative error of u: 11.103496122886524%
#
# Param is 125
# Time elapsed: 27.04322910308838 sec
# average relative error of u: 3.4308209896140633%
# maximum relative error of u: 11.307993522263294%
#
# Dim. of latent space is 4
# # of measurments: 12
# [ 241  451  669  718  761  855 2163 2643 2894 3003 3175 3382]
# Param is 75
# Time elapsed: 25.126057147979736 sec
# average relative error of u: 0.8619575962440775%
# maximum relative error of u: 1.5357228832816463%
#
# Param is 76
# Time elapsed: 28.155126571655273 sec
# average relative error of u: 0.8273538374996374%
# maximum relative error of u: 1.4827203333422507%
#
# Param is 77
# Time elapsed: 24.472570419311523 sec
# average relative error of u: 0.7953675341888252%
# maximum relative error of u: 1.4314042128038966%
#
# Param is 78
# Time elapsed: 23.072301149368286 sec
# average relative error of u: 0.7658543857646224%
# maximum relative error of u: 1.3818224605381282%
#
# Param is 79
# Time elapsed: 23.107500076293945 sec
# average relative error of u: 0.73866422968144%
# maximum relative error of u: 1.3338851093328292%
#
# Param is 80
# Time elapsed: 19.811466455459595 sec
# average relative error of u: 0.7136408130823356%
# maximum relative error of u: 1.2876813009542567%
#
# Param is 81
# Time elapsed: 20.81887459754944 sec
# average relative error of u: 0.6906275327470522%
# maximum relative error of u: 1.2431643199583695%
#
# Param is 82
# Time elapsed: 21.92953085899353 sec
# average relative error of u: 0.6694627129286917%
# maximum relative error of u: 1.2003295691812057%
#
# Param is 83
# Time elapsed: 20.095967292785645 sec
# average relative error of u: 0.6499893703598525%
# maximum relative error of u: 1.1591586509548581%
#
# Param is 84
# Time elapsed: 19.394333600997925 sec
# average relative error of u: 0.6320490449315417%
# maximum relative error of u: 1.11961504857632%
#
# Param is 85
# Time elapsed: 16.663615465164185 sec
# average relative error of u: 0.6154955786508275%
# maximum relative error of u: 1.0817315184246126%
#
# Param is 86
# Time elapsed: 17.12902045249939 sec
# average relative error of u: 0.6001846310509518%
# maximum relative error of u: 1.0466436030905284%
#
# Param is 87
# Time elapsed: 17.39431595802307 sec
# average relative error of u: 0.5859767559527942%
# maximum relative error of u: 1.0173575379959454%
#
# Param is 88
# Time elapsed: 18.27086114883423 sec
# average relative error of u: 0.5727523379453027%
# maximum relative error of u: 0.988884660856601%
#
# Param is 89
# Time elapsed: 19.697969436645508 sec
# average relative error of u: 0.5603930399354877%
# maximum relative error of u: 0.9612142883581037%
#
# Param is 90
# Time elapsed: 18.520389556884766 sec
# average relative error of u: 0.5487947659895669%
# maximum relative error of u: 0.9343264667267313%
#
# Param is 91
# Time elapsed: 18.979511260986328 sec
# average relative error of u: 0.5378677704584478%
# maximum relative error of u: 0.9082109137534317%
#
# Param is 92
# Time elapsed: 18.795122146606445 sec
# average relative error of u: 0.52752744745645%
# maximum relative error of u: 0.8828261037114397%
#
# Param is 93
# Time elapsed: 18.07221269607544 sec
# average relative error of u: 0.5177062891207482%
# maximum relative error of u: 0.8581376619829874%
#
# Param is 94
# Time elapsed: 17.534050703048706 sec
# average relative error of u: 0.5083443063410499%
# maximum relative error of u: 0.8342090684250341%
#
# Param is 95
# Time elapsed: 18.22226047515869 sec
# average relative error of u: 0.49939313965984267%
# maximum relative error of u: 0.8110024643617377%
#
# Param is 96
# Time elapsed: 16.932595252990723 sec
# average relative error of u: 0.4908169992463871%
# maximum relative error of u: 0.788515701623147%
#
# Param is 97
# Time elapsed: 17.619921684265137 sec
# average relative error of u: 0.48258427627195494%
# maximum relative error of u: 0.7790500447644544%
#
# Param is 98
# Time elapsed: 18.26825475692749 sec
# average relative error of u: 0.4746784736130827%
# maximum relative error of u: 0.7703916513384017%
#
# Param is 99
# Time elapsed: 18.37928557395935 sec
# average relative error of u: 0.46709025381237357%
# maximum relative error of u: 0.7617383215448007%
#
# Param is 100
# Time elapsed: 17.825464963912964 sec
# average relative error of u: 0.45982107474955225%
# maximum relative error of u: 0.7530759368873307%
#
# Param is 101
# Time elapsed: 17.687679052352905 sec
# average relative error of u: 0.4528795912995656%
# maximum relative error of u: 0.7444855248269102%
#
# Param is 102
# Time elapsed: 18.674741983413696 sec
# average relative error of u: 0.4462902190441841%
# maximum relative error of u: 0.7359171930090544%
#
# Param is 103
# Time elapsed: 18.603318691253662 sec
# average relative error of u: 0.44008470843948566%
# maximum relative error of u: 0.7275168113838338%
#
# Param is 104
# Time elapsed: 19.933340787887573 sec
# average relative error of u: 0.4343078953072413%
# maximum relative error of u: 0.719359489075901%
#
# Param is 105
# Time elapsed: 17.5252947807312 sec
# average relative error of u: 0.42901935128899826%
# maximum relative error of u: 0.7114459540672824%
#
# Param is 106
# Time elapsed: 16.33859944343567 sec
# average relative error of u: 0.42429637053324076%
# maximum relative error of u: 0.703868401945079%
#
# Param is 107
# Time elapsed: 18.022257566452026 sec
# average relative error of u: 0.4202291866392664%
# maximum relative error of u: 0.6967314605802862%
#
# Param is 108
# Time elapsed: 18.385822534561157 sec
# average relative error of u: 0.4169314262842982%
# maximum relative error of u: 0.690150439226202%
#
# Param is 109
# Time elapsed: 17.26828098297119 sec
# average relative error of u: 0.414534025566035%
# maximum relative error of u: 0.6842427344328128%
#
# Param is 110
# Time elapsed: 16.7106511592865 sec
# average relative error of u: 0.413189784835878%
# maximum relative error of u: 0.679169992134153%
#
# Param is 111
# Time elapsed: 16.9069983959198 sec
# average relative error of u: 0.41307818753095965%
# maximum relative error of u: 0.6784673118735054%
#
# Param is 112
# Time elapsed: 16.773922443389893 sec
# average relative error of u: 0.41439590439511104%
# maximum relative error of u: 0.6995271363897112%
#
# Param is 113
# Time elapsed: 16.952208042144775 sec
# average relative error of u: 0.41735781170168623%
# maximum relative error of u: 0.7206458572931279%
#
# Param is 114
# Time elapsed: 16.805317640304565 sec
# average relative error of u: 0.4221983930195945%
# maximum relative error of u: 0.7420738178859673%
#
# Param is 115
# Time elapsed: 18.29850673675537 sec
# average relative error of u: 0.4291580603293873%
# maximum relative error of u: 0.7638931169647213%
#
# Param is 116
# Time elapsed: 17.429919958114624 sec
# average relative error of u: 0.4384874245629563%
# maximum relative error of u: 0.7863829595708723%
#
# Param is 117
# Time elapsed: 17.375231742858887 sec
# average relative error of u: 0.450432114349105%
# maximum relative error of u: 0.8097942702021358%
#
# Param is 118
# Time elapsed: 16.108360528945923 sec
# average relative error of u: 0.4652273293910513%
# maximum relative error of u: 0.8344184761207512%
#
# Param is 119
# Time elapsed: 16.002254009246826 sec
# average relative error of u: 0.48310141395139894%
# maximum relative error of u: 0.8606779547198642%
#
# Param is 120
# Time elapsed: 15.613757610321045 sec
# average relative error of u: 0.504258475537002%
# maximum relative error of u: 0.888971319782458%
#
# Param is 121
# Time elapsed: 14.124085664749146 sec
# average relative error of u: 0.5288856996499853%
# maximum relative error of u: 0.9197883635796699%
#
# Param is 122
# Time elapsed: 14.129343748092651 sec
# average relative error of u: 0.5571552782171908%
# maximum relative error of u: 0.9536589550956289%
#
# Param is 123
# Time elapsed: 12.898843050003052 sec
# average relative error of u: 0.5892215773834035%
# maximum relative error of u: 0.9911194380936402%
#
# Param is 124
# Time elapsed: 12.858232021331787 sec
# average relative error of u: 0.6252221571277197%
# maximum relative error of u: 1.0327686175315023%
#
# Param is 125
# Time elapsed: 12.884774446487427 sec
# average relative error of u: 0.6652933274895027%
# maximum relative error of u: 1.0792614403421583%
#
# Dim. of latent space is 5
# # of measurments: 12
# [ 122  166  471  598  856 1206 1392 1681 1858 2502 2528 3354]
# Param is 75
# Time elapsed: 12.915256977081299 sec
# average relative error of u: 0.7070061995532688%
# maximum relative error of u: 1.4769937127959054%
#
# Param is 76
# Time elapsed: 12.92959475517273 sec
# average relative error of u: 0.672380519583862%
# maximum relative error of u: 1.440447290760414%
#
# Param is 77
# Time elapsed: 12.953066349029541 sec
# average relative error of u: 0.6400851145877631%
# maximum relative error of u: 1.402543310947683%
#
# Param is 78
# Time elapsed: 12.949921369552612 sec
# average relative error of u: 0.6099975818566129%
# maximum relative error of u: 1.363268957264385%
#
# Param is 79
# Time elapsed: 13.104143857955933 sec
# average relative error of u: 0.5820079755691597%
# maximum relative error of u: 1.3228439770242264%
#
# Param is 80
# Time elapsed: 14.32532262802124 sec
# average relative error of u: 0.5560004952551191%
# maximum relative error of u: 1.2812935550050106%
#
# Param is 81
# Time elapsed: 14.246576309204102 sec
# average relative error of u: 0.5318734023669248%
# maximum relative error of u: 1.2388578858100237%
#
# Param is 82
# Time elapsed: 14.254670858383179 sec
# average relative error of u: 0.5095233292719843%
# maximum relative error of u: 1.1955363886446042%
#
# Param is 83
# Time elapsed: 14.38512659072876 sec
# average relative error of u: 0.48885686689478713%
# maximum relative error of u: 1.1515879090137302%
#
# Param is 84
# Time elapsed: 14.282352209091187 sec
# average relative error of u: 0.4697773452588973%
# maximum relative error of u: 1.106921201369811%
#
# Param is 85
# Time elapsed: 14.326116800308228 sec
# average relative error of u: 0.452192999854999%
# maximum relative error of u: 1.0619207013443217%
#
# Param is 86
# Time elapsed: 14.293692350387573 sec
# average relative error of u: 0.4360164111292682%
# maximum relative error of u: 1.0163696467602%
#
# Param is 87
# Time elapsed: 14.427010536193848 sec
# average relative error of u: 0.4211639442915012%
# maximum relative error of u: 0.9707558502060029%
#
# Param is 88
# Time elapsed: 14.427565097808838 sec
# average relative error of u: 0.40754671640597623%
# maximum relative error of u: 0.9249297746600823%
#
# Param is 89
# Time elapsed: 14.356551885604858 sec
# average relative error of u: 0.3950799042626767%
# maximum relative error of u: 0.8791123414681311%
#
# Param is 90
# Time elapsed: 14.205544233322144 sec
# average relative error of u: 0.3836777466243787%
# maximum relative error of u: 0.8343284274688887%
#
# Param is 91
# Time elapsed: 13.72594404220581 sec
# average relative error of u: 0.3732542574752107%
# maximum relative error of u: 0.7921333684949158%
#
# Param is 92
# Time elapsed: 13.779288053512573 sec
# average relative error of u: 0.363722959446388%
# maximum relative error of u: 0.7502383085102527%
#
# Param is 93
# Time elapsed: 13.761037588119507 sec
# average relative error of u: 0.35499955672518313%
# maximum relative error of u: 0.7087458420032962%
#
# Param is 94
# Time elapsed: 13.715853691101074 sec
# average relative error of u: 0.3469938316280938%
# maximum relative error of u: 0.6678697948778245%
#
# Param is 95
# Time elapsed: 13.864912748336792 sec
# average relative error of u: 0.3396243973105127%
# maximum relative error of u: 0.6275183128941174%
#
# Param is 96
# Time elapsed: 13.755188703536987 sec
# average relative error of u: 0.33281148234960356%
# maximum relative error of u: 0.6041404640467584%
#
# Param is 97
# Time elapsed: 13.734153509140015 sec
# average relative error of u: 0.32647262589282405%
# maximum relative error of u: 0.5951591577483462%
#
# Param is 98
# Time elapsed: 13.697941303253174 sec
# average relative error of u: 0.3205389737658697%
# maximum relative error of u: 0.5863537961537985%
#
# Param is 99
# Time elapsed: 13.752263069152832 sec
# average relative error of u: 0.31494288152924366%
# maximum relative error of u: 0.5771263794211351%
#
# Param is 100
# Time elapsed: 13.644372940063477 sec
# average relative error of u: 0.30962585802145826%
# maximum relative error of u: 0.5676018716146667%
#
# Param is 101
# Time elapsed: 13.788761615753174 sec
# average relative error of u: 0.30454703809066047%
# maximum relative error of u: 0.5574871295542935%
#
# Param is 102
# Time elapsed: 13.512601852416992 sec
# average relative error of u: 0.299668112224589%
# maximum relative error of u: 0.5470081714362317%
#
# Param is 103
# Time elapsed: 13.633822917938232 sec
# average relative error of u: 0.2949730717600098%
# maximum relative error of u: 0.5361208483538851%
#
# Param is 104
# Time elapsed: 13.46953535079956 sec
# average relative error of u: 0.2904606426156746%
# maximum relative error of u: 0.5247717069935497%
#
# Param is 105
# Time elapsed: 13.340452432632446 sec
# average relative error of u: 0.2861505431178854%
# maximum relative error of u: 0.5129956627829837%
#
# Param is 106
# Time elapsed: 13.332859992980957 sec
# average relative error of u: 0.28208957113962946%
# maximum relative error of u: 0.5009268674663743%
#
# Param is 107
# Time elapsed: 13.962680578231812 sec
# average relative error of u: 0.2783445648638863%
# maximum relative error of u: 0.48860408105380726%
#
# Param is 108
# Time elapsed: 13.914984464645386 sec
# average relative error of u: 0.2750147937422225%
# maximum relative error of u: 0.4773587675900132%
#
# Param is 109
# Time elapsed: 14.04851770401001 sec
# average relative error of u: 0.2722319033005964%
# maximum relative error of u: 0.4685273123519511%
#
# Param is 110
# Time elapsed: 13.928932905197144 sec
# average relative error of u: 0.27015896039543547%
# maximum relative error of u: 0.4739773599177915%
#
# Param is 111
# Time elapsed: 13.318695068359375 sec
# average relative error of u: 0.2689939360529438%
# maximum relative error of u: 0.4794223782817814%
#
# Param is 112
# Time elapsed: 14.208997011184692 sec
# average relative error of u: 0.26896118953871023%
# maximum relative error of u: 0.48464700162145274%
#
# Param is 113
# Time elapsed: 14.401200532913208 sec
# average relative error of u: 0.2703101346369899%
# maximum relative error of u: 0.49752454585931294%
#
# Param is 114
# Time elapsed: 14.610360383987427 sec
# average relative error of u: 0.2733049806287789%
# maximum relative error of u: 0.5169568525679338%
#
# Param is 115
# Time elapsed: 14.481616020202637 sec
# average relative error of u: 0.278207118480558%
# maximum relative error of u: 0.5399227039564668%
#
# Param is 116
# Time elapsed: 14.564208745956421 sec
# average relative error of u: 0.28526979721467777%
# maximum relative error of u: 0.5663204602667631%
#
# Param is 117
# Time elapsed: 14.534148693084717 sec
# average relative error of u: 0.2947087774306664%
# maximum relative error of u: 0.596262924097367%
#
# Param is 118
# Time elapsed: 14.353568315505981 sec
# average relative error of u: 0.3067072546970196%
# maximum relative error of u: 0.6295404362484013%
#
# Param is 119
# Time elapsed: 14.491068601608276 sec
# average relative error of u: 0.3213999348196498%
# maximum relative error of u: 0.6661258676419176%
#
# Param is 120
# Time elapsed: 14.545123815536499 sec
# average relative error of u: 0.33887109232215795%
# maximum relative error of u: 0.7058827452202465%
#
# Param is 121
# Time elapsed: 13.297908782958984 sec
# average relative error of u: 0.3591670037776403%
# maximum relative error of u: 0.7486971745609823%
#
# Param is 122
# Time elapsed: 14.15799880027771 sec
# average relative error of u: 0.38229504645595186%
# maximum relative error of u: 0.7945742947769866%
#
# Param is 123
# Time elapsed: 14.372929573059082 sec
# average relative error of u: 0.4082347110244005%
# maximum relative error of u: 0.8433048400986959%
#
# Param is 124
# Time elapsed: 14.503769397735596 sec
# average relative error of u: 0.4369484033492504%
# maximum relative error of u: 0.8947390555905624%
#
# Param is 125
# Time elapsed: 14.485863447189331 sec
# average relative error of u: 0.468394368399955%
# maximum relative error of u: 0.9487647548529586%
#
# Dim. of latent space is 6
# # of measurments: 12
# [  61   95  313  440  718 1565 1861 2592 2701 2745 3302 3358]
# Param is 75
# Time elapsed: 15.111652135848999 sec
# average relative error of u: 0.5450523872770553%
# maximum relative error of u: 1.2282019751208806%
#
# Param is 76
# Time elapsed: 15.083468437194824 sec
# average relative error of u: 0.5192497964776659%
# maximum relative error of u: 1.169887362128574%
#
# Param is 77
# Time elapsed: 14.579413175582886 sec
# average relative error of u: 0.4957140277573395%
# maximum relative error of u: 1.1139798198412503%
#
# Param is 78
# Time elapsed: 14.714029312133789 sec
# average relative error of u: 0.4743261114384478%
# maximum relative error of u: 1.0612629364022252%
#
# Param is 79
# Time elapsed: 14.339108943939209 sec
# average relative error of u: 0.4549642610721167%
# maximum relative error of u: 1.011878597618958%
#
# Param is 80
# Time elapsed: 14.804835319519043 sec
# average relative error of u: 0.4374833266859614%
# maximum relative error of u: 0.9644030098933335%
#
# Param is 81
# Time elapsed: 14.839632749557495 sec
# average relative error of u: 0.42174275929012395%
# maximum relative error of u: 0.919109417036279%
#
# Param is 82
# Time elapsed: 14.85629677772522 sec
# average relative error of u: 0.4075958485247137%
# maximum relative error of u: 0.8754965539192858%
#
# Param is 83
# Time elapsed: 14.62708330154419 sec
# average relative error of u: 0.3948952391188856%
# maximum relative error of u: 0.8338506647258288%
#
# Param is 84
# Time elapsed: 14.509089946746826 sec
# average relative error of u: 0.3834966171601352%
# maximum relative error of u: 0.7940600053760972%
#
# Param is 85
# Time elapsed: 14.710638284683228 sec
# average relative error of u: 0.37325944982168363%
# maximum relative error of u: 0.7556686809397912%
#
# Param is 86
# Time elapsed: 14.467801570892334 sec
# average relative error of u: 0.36404411665170466%
# maximum relative error of u: 0.7410015576957781%
#
# Param is 87
# Time elapsed: 14.517089366912842 sec
# average relative error of u: 0.3557263757901985%
# maximum relative error of u: 0.7279026612730919%
#
# Param is 88
# Time elapsed: 14.102823734283447 sec
# average relative error of u: 0.34819231761023245%
# maximum relative error of u: 0.7132682245898028%
#
# Param is 89
# Time elapsed: 14.139846801757812 sec
# average relative error of u: 0.3413336794396483%
# maximum relative error of u: 0.6975219465791944%
#
# Param is 90
# Time elapsed: 14.234664678573608 sec
# average relative error of u: 0.33506162694290137%
# maximum relative error of u: 0.6805202584058734%
#
# Param is 91
# Time elapsed: 14.282614469528198 sec
# average relative error of u: 0.3292784377067028%
# maximum relative error of u: 0.6625442737232211%
#
# Param is 92
# Time elapsed: 14.180952072143555 sec
# average relative error of u: 0.3239286688716742%
# maximum relative error of u: 0.6457613891562273%
#
# Param is 93
# Time elapsed: 14.272931098937988 sec
# average relative error of u: 0.3189321014225257%
# maximum relative error of u: 0.6299496160509437%
#
# Param is 94
# Time elapsed: 14.195901155471802 sec
# average relative error of u: 0.3142437569131217%
# maximum relative error of u: 0.6278572745971762%
#
# Param is 95
# Time elapsed: 14.247357606887817 sec
# average relative error of u: 0.3098083649022286%
# maximum relative error of u: 0.6299631844972848%
#
# Param is 96
# Time elapsed: 14.158638954162598 sec
# average relative error of u: 0.3055870802237327%
# maximum relative error of u: 0.6319288438529328%
#
# Param is 97
# Time elapsed: 14.347628355026245 sec
# average relative error of u: 0.3015392487727988%
# maximum relative error of u: 0.6334232034114746%
#
# Param is 98
# Time elapsed: 14.254581689834595 sec
# average relative error of u: 0.2976322705176333%
# maximum relative error of u: 0.6345557365176419%
#
# Param is 99
# Time elapsed: 14.318755149841309 sec
# average relative error of u: 0.29383260532386635%
# maximum relative error of u: 0.6352803054931611%
#
# Param is 100
# Time elapsed: 13.846320390701294 sec
# average relative error of u: 0.29012373678193953%
# maximum relative error of u: 0.6353990213287691%
#
# Param is 101
# Time elapsed: 14.576226234436035 sec
# average relative error of u: 0.28647736899063103%
# maximum relative error of u: 0.634994385612218%
#
# Param is 102
# Time elapsed: 14.649224519729614 sec
# average relative error of u: 0.2828808275612751%
# maximum relative error of u: 0.6336368488557602%
#
# Param is 103
# Time elapsed: 14.635862350463867 sec
# average relative error of u: 0.27932426277616823%
# maximum relative error of u: 0.6316155776339505%
#
# Param is 104
# Time elapsed: 14.456075191497803 sec
# average relative error of u: 0.27580149957314615%
# maximum relative error of u: 0.6286161889048821%
#
# Param is 105
# Time elapsed: 14.48376989364624 sec
# average relative error of u: 0.2723211102660374%
# maximum relative error of u: 0.6246852192504082%
#
# Param is 106
# Time elapsed: 13.913000106811523 sec
# average relative error of u: 0.268904999943971%
# maximum relative error of u: 0.6194995761881226%
#
# Param is 107
# Time elapsed: 14.011972427368164 sec
# average relative error of u: 0.26558155952882967%
# maximum relative error of u: 0.6133019670423564%
#
# Param is 108
# Time elapsed: 13.879103899002075 sec
# average relative error of u: 0.26239394700137125%
# maximum relative error of u: 0.6055052109605141%
#
# Param is 109
# Time elapsed: 14.062743425369263 sec
# average relative error of u: 0.2594149317541587%
# maximum relative error of u: 0.5962296912498446%
#
# Param is 110
# Time elapsed: 13.853713512420654 sec
# average relative error of u: 0.25673802793314243%
# maximum relative error of u: 0.5854473528509178%
#
# Param is 111
# Time elapsed: 13.998555421829224 sec
# average relative error of u: 0.2544741525388269%
# maximum relative error of u: 0.5807385748187722%
#
# Param is 112
# Time elapsed: 13.906813383102417 sec
# average relative error of u: 0.25277701484920595%
# maximum relative error of u: 0.5936404047348374%
#
# Param is 113
# Time elapsed: 13.977049350738525 sec
# average relative error of u: 0.2518332142555757%
# maximum relative error of u: 0.6066869903040429%
#
# Param is 114
# Time elapsed: 13.912278175354004 sec
# average relative error of u: 0.25185744989603714%
# maximum relative error of u: 0.6190915820678645%
#
# Param is 115
# Time elapsed: 13.916666030883789 sec
# average relative error of u: 0.25310593435049716%
# maximum relative error of u: 0.6308844046786056%
#
# Param is 116
# Time elapsed: 13.884799480438232 sec
# average relative error of u: 0.25586007445911274%
# maximum relative error of u: 0.6425981433579528%
#
# Param is 117
# Time elapsed: 13.99111819267273 sec
# average relative error of u: 0.2604322632782099%
# maximum relative error of u: 0.6539311808593948%
#
# Param is 118
# Time elapsed: 13.924491882324219 sec
# average relative error of u: 0.26713452755106487%
# maximum relative error of u: 0.6650483748506579%
#
# Param is 119
# Time elapsed: 14.096966028213501 sec
# average relative error of u: 0.27626534415182946%
# maximum relative error of u: 0.6757693081526039%
#
# Param is 120
# Time elapsed: 13.28463888168335 sec
# average relative error of u: 0.28811441924096987%
# maximum relative error of u: 0.6866834216763071%
#
# Param is 121
# Time elapsed: 12.943193197250366 sec
# average relative error of u: 0.30292462027425%
# maximum relative error of u: 0.697228946276086%
#
# Param is 122
# Time elapsed: 11.579435586929321 sec
# average relative error of u: 0.3208933316882424%
# maximum relative error of u: 0.7254501458891441%
#
# Param is 123
# Time elapsed: 11.132827043533325 sec
# average relative error of u: 0.3421855022453913%
# maximum relative error of u: 0.7711933914638902%
#
# Param is 124
# Time elapsed: 10.987313270568848 sec
# average relative error of u: 0.3668924100353988%
# maximum relative error of u: 0.8206064291652866%
#
# Param is 125
# Time elapsed: 11.048701047897339 sec
# average relative error of u: 0.39510182347497125%
# maximum relative error of u: 0.9046495645116367%

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

idx=[0,1,2,3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex23_wave/ex23_AE_inner_SOPT_avg_rel_err_seed_{}.png".format(seed))

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("../__result/ex23_wave/ex23_AE_inner_SOPT_max_rel_err_seed_{}.png".format(seed))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

idx = [3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
plt.show()

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
plt.show()

# %%
print(f_list)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=3; j=-1        
f=f_list[i]
param=FOM_parameters[j]

u_gappyAE=results['solution'][i,j]

ex = np.load('../__data/ex23_wave/ex23_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("Latent Dim: {}, Param: {}".format(f,param))
plt.show()

# error
u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                 /np.linalg.norm(u_full,ord=2,axis=1)*100
u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
             /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
print("average relative error of u: {}%".format(u_avg_rel_err))
print()
print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
    
# plot original data
vmin=-1; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy AE @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex23_wave/ex23_AE_{}_param_{}_inner_SOPT_SOL_seed_{}.png".format(f,param,seed))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("../__result/ex23_wave/ex23_param_{}_ground_truth.png".format(param))
# Out:
# average relative error of u: 0.39510182347497125%
#
# maximum relative error of u: 0.9046495645116367%

# %%
i=3; j=-1
f=f_list[i]; param=FOM_parameters[j]
print("f={}".format(f))
print("param={}".format(param))
plt.plot(results['reduced'][i,j][:,:f])
plt.legend(np.arange(f))
plt.show()
# Out:
# f=6
# param=125
