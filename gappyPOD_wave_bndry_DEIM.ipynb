# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle

# %%
# Given parameters
nx = 60
ny = 60
tf = 5.0
dt = 1.0e-2
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims=(nx,ny)

# POD basis
num_basis=np.arange(3,7,1)
print('num_basis {}'.format(num_basis))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_DEIM_result = "./wave_result/ex23_POD_bndry_DEIM_gappy_result.p"
file_name_SVD="./wave_model/ex23_SVD.p"

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# num_basis [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %% [markdown]
# # gappyPOD

# %%
# Jessi 알고리즘
def DEIM(phi_f, nfeval, unseen=np.array([])):
    
    ninf=np.NINF
    n,m=np.shape(phi_f)
    
    l=0
    u=np.reshape(phi_f[:,l],(n,1))
    r=np.abs(u)
    if len(unseen) >0 :
        r[unseen]=ninf
    p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
    p=p_temp
    U=u
    
    ns=int(np.ceil((nfeval-1)/(m-1)))
    for l in range(1,m):
        u=np.reshape(phi_f[:,l],(n,1))
        for k in range(ns):
            if len(p)==nfeval:
                return p
            c=np.linalg.lstsq(U[p,:],u[p,:],rcond=None)[0]
            r=np.abs(u-U@c)
            r[p]=ninf
            if len(unseen) > 0:
                r[unseen]=ninf
            p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
            p=np.sort(np.append(p,p_temp))
        U=np.concatenate((U,u),axis=1)
         
    return p

# %%
with open(file=file_name_SVD, mode='rb') as ff:  
    SVD = pickle.load(ff)

for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    
    # DEIM
    num_msmt=12

    phi_DEIM=SVD['U'][:,:POD_basis]

    msmt_idx=DEIM(phi_DEIM,num_msmt,inner_raveled_indicies)
    msmt_idx.sort()

    print("# of measurments: {}".format(len(msmt_idx)))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.savefig("./wave_result/ex23_POD_{}_bndry_DEIM_{}_samples.png".format(POD_basis,num_msmt))
# Out:
# # of measurments: 12
# [   0    1   58   59   60  119 3480 3539 3540 3541 3598 3599]
# # of measurments: 12
# [   0   58   59   60 1799 1859 3480 3539 3540 3569 3598 3599]
# # of measurments: 12
# [   0   30   58   59   60 1739 1799 1800 3540 3569 3598 3599]
# # of measurments: 12
# [   0   30   58   59   60 1739 1799 1800 3540 3569 3598 3599]

# %%
solution=np.zeros((len(num_basis),len(FOM_parameters),nt+1,nx*ny))
avg_rel_err=np.zeros((len(num_basis),len(FOM_parameters)))
rel_err=np.zeros((len(num_basis),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(num_basis),len(FOM_parameters)))

with open(file=file_name_SVD, mode='rb') as ff:  
    SVD = pickle.load(ff)

for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    print("# of POD basis is {}".format(POD_basis))
    
    # DEIM
    num_msmt=12
    U = SVD['U'];S = SVD['S']

    phi_DEIM=U[:,:POD_basis]

    msmt_idx=DEIM(phi_DEIM,num_msmt,inner_raveled_indicies)
    msmt_idx.sort()

    print("# of measurments: {}".format(len(msmt_idx)))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.show()

    # Basis matrix
    phi_u = SVD['U'][:,:POD_basis]

    phim_u=phi_u[msmt_idx]
    phim_u_pinv=np.linalg.pinv(phim_u)
    
    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('./wave_data/ex23_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1)

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_ref = u0

        # Gappy POD
        t_start_gappyPOD=time.time()

        # solution
        u_gappyPOD=np.zeros((nt+1,ny*nx))
        u_hat=np.zeros((nt+1,POD_basis))

        # IC
        u_hat0=np.zeros(POD_basis)
        u_gappyPOD[0]=np.copy(u0)

        for n in range(nt):
            u_hat[n+1] = phim_u_pinv.dot(um[n+1]-u_ref[msmt_idx])
            u_gappyPOD[n+1] = u_ref + phi_u.dot(u_hat[n+1])

        # elapsed time
        t_elapsed_gappyPOD=time.time()-t_start_gappyPOD
        print('Time elapsed: {} sec'.format(t_elapsed_gappyPOD))

        # error
        u_rel_err_gappyPOD=np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)/np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyPOD)))
        print()

        # save result
        solution[ii,jj]=u_gappyPOD
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyPOD
        elapsed_time[ii,jj]=t_elapsed_gappyPOD
    
results={'solution':solution,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_DEIM_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# # of POD basis is 3
# # of measurments: 12
# [   0    1   58   59   60  119 3480 3539 3540 3541 3598 3599]
# Param is 75
# Time elapsed: 2.156973361968994 sec
# average relative error of u: 6.634969343244068%
# maximum relative error of u: 8.541134527941416%
#
# Param is 76
# Time elapsed: 2.018420696258545 sec
# average relative error of u: 6.2426838284358395%
# maximum relative error of u: 8.174632368093402%
#
# Param is 77
# Time elapsed: 1.4394760131835938 sec
# average relative error of u: 5.878778894720549%
# maximum relative error of u: 7.828846203567254%
#
# Param is 78
# Time elapsed: 1.1506602764129639 sec
# average relative error of u: 5.551848242424677%
# maximum relative error of u: 7.519649810437372%
#
# Param is 79
# Time elapsed: 1.1045515537261963 sec
# average relative error of u: 5.2718106739413075%
# maximum relative error of u: 7.240143954016756%
#
# Param is 80
# Time elapsed: 0.981792688369751 sec
# average relative error of u: 5.049658567570205%
# maximum relative error of u: 6.9945055425122495%
#
# Param is 81
# Time elapsed: 3.0527660846710205 sec
# average relative error of u: 4.896334030571657%
# maximum relative error of u: 6.78874981246971%
#
# Param is 82
# Time elapsed: 1.308323860168457 sec
# average relative error of u: 4.82151106115761%
# maximum relative error of u: 6.629118025581675%
#
# Param is 83
# Time elapsed: 2.411680221557617 sec
# average relative error of u: 4.831845036214213%
# maximum relative error of u: 6.521318941781907%
#
# Param is 84
# Time elapsed: 4.3626649379730225 sec
# average relative error of u: 4.929665119899322%
# maximum relative error of u: 6.948350837324526%
#
# Param is 85
# Time elapsed: 1.0818002223968506 sec
# average relative error of u: 5.112612287525193%
# maximum relative error of u: 7.758619136503161%
#
# Param is 86
# Time elapsed: 1.5915653705596924 sec
# average relative error of u: 5.374460886131362%
# maximum relative error of u: 8.715715943749824%
#
# Param is 87
# Time elapsed: 1.039325475692749 sec
# average relative error of u: 5.706616653372026%
# maximum relative error of u: 9.761373408406294%
#
# Param is 88
# Time elapsed: 0.9610776901245117 sec
# average relative error of u: 6.099616573507818%
# maximum relative error of u: 10.875012964423385%
#
# Param is 89
# Time elapsed: 6.978748559951782 sec
# average relative error of u: 6.544342800349928%
# maximum relative error of u: 12.044828712245607%
#
# Param is 90
# Time elapsed: 1.1491320133209229 sec
# average relative error of u: 7.032632974431385%
# maximum relative error of u: 13.258322613867552%
#
# Param is 91
# Time elapsed: 1.0904066562652588 sec
# average relative error of u: 7.557528758407985%
# maximum relative error of u: 14.503393088789519%
#
# Param is 92
# Time elapsed: 1.0323383808135986 sec
# average relative error of u: 8.113229126274954%
# maximum relative error of u: 15.776205628828082%
#
# Param is 93
# Time elapsed: 1.3039777278900146 sec
# average relative error of u: 8.695027710290324%
# maximum relative error of u: 17.074322162202563%
#
# Param is 94
# Time elapsed: 1.440143346786499 sec
# average relative error of u: 9.29910382514146%
# maximum relative error of u: 18.395519991341537%
#
# Param is 95
# Time elapsed: 1.3360767364501953 sec
# average relative error of u: 9.922304073809078%
# maximum relative error of u: 19.73810974726902%
#
# Param is 96
# Time elapsed: 1.5044746398925781 sec
# average relative error of u: 10.562154297224417%
# maximum relative error of u: 21.100643321360227%
#
# Param is 97
# Time elapsed: 0.8862326145172119 sec
# average relative error of u: 11.216504086833043%
# maximum relative error of u: 22.48201789622534%
#
# Param is 98
# Time elapsed: 1.2481465339660645 sec
# average relative error of u: 11.883725922774797%
# maximum relative error of u: 23.88128532961783%
#
# Param is 99
# Time elapsed: 1.0275921821594238 sec
# average relative error of u: 12.562377192344137%
# maximum relative error of u: 25.297531134082202%
#
# Param is 100
# Time elapsed: 1.021094560623169 sec
# average relative error of u: 13.251260320024432%
# maximum relative error of u: 26.730045639260176%
#
# Param is 101
# Time elapsed: 0.9659161567687988 sec
# average relative error of u: 13.949357214681731%
# maximum relative error of u: 28.178013545012924%
#
# Param is 102
# Time elapsed: 0.8699314594268799 sec
# average relative error of u: 14.655817294960965%
# maximum relative error of u: 29.640843771057668%
#
# Param is 103
# Time elapsed: 0.9325284957885742 sec
# average relative error of u: 15.369907138705827%
# maximum relative error of u: 31.11802146377114%
#
# Param is 104
# Time elapsed: 0.6727931499481201 sec
# average relative error of u: 16.09096324422975%
# maximum relative error of u: 32.608871966811115%
#
# Param is 105
# Time elapsed: 5.996173620223999 sec
# average relative error of u: 16.81842601755038%
# maximum relative error of u: 34.11294969605843%
#
# Param is 106
# Time elapsed: 1.1472208499908447 sec
# average relative error of u: 17.551819924471353%
# maximum relative error of u: 35.62975815926968%
#
# Param is 107
# Time elapsed: 1.0435206890106201 sec
# average relative error of u: 18.290681568497313%
# maximum relative error of u: 37.15886672509406%
#
# Param is 108
# Time elapsed: 0.8023343086242676 sec
# average relative error of u: 19.034581237488176%
# maximum relative error of u: 38.699622257259705%
#
# Param is 109
# Time elapsed: 9.825745105743408 sec
# average relative error of u: 19.783230259390685%
# maximum relative error of u: 40.25180463734659%
#
# Param is 110
# Time elapsed: 0.7754158973693848 sec
# average relative error of u: 20.536246766119348%
# maximum relative error of u: 41.814897657463554%
#
# Param is 111
# Time elapsed: 1.012397050857544 sec
# average relative error of u: 21.29334320546364%
# maximum relative error of u: 43.388401683276136%
#
# Param is 112
# Time elapsed: 0.9491689205169678 sec
# average relative error of u: 22.05425650566333%
# maximum relative error of u: 44.97204431920366%
#
# Param is 113
# Time elapsed: 3.5787930488586426 sec
# average relative error of u: 22.818720404475545%
# maximum relative error of u: 46.565309770237825%
#
# Param is 114
# Time elapsed: 1.6230010986328125 sec
# average relative error of u: 23.586462399527516%
# maximum relative error of u: 48.167823381683334%
#
# Param is 115
# Time elapsed: 1.2939791679382324 sec
# average relative error of u: 24.357351655127157%
# maximum relative error of u: 49.77919514770338%
#
# Param is 116
# Time elapsed: 1.1029179096221924 sec
# average relative error of u: 25.131156135157916%
# maximum relative error of u: 51.399186782255576%
#
# Param is 117
# Time elapsed: 2.344480514526367 sec
# average relative error of u: 25.907635174917797%
# maximum relative error of u: 53.027231657726624%
#
# Param is 118
# Time elapsed: 0.9375097751617432 sec
# average relative error of u: 26.686664394380223%
# maximum relative error of u: 54.66305191025652%
#
# Param is 119
# Time elapsed: 5.159360885620117 sec
# average relative error of u: 27.468043517473873%
# maximum relative error of u: 56.30624373926232%
#
# Param is 120
# Time elapsed: 2.180760383605957 sec
# average relative error of u: 28.25160122579764%
# maximum relative error of u: 57.9563656827887%
#
# Param is 121
# Time elapsed: 1.2816119194030762 sec
# average relative error of u: 29.037204003519417%
# maximum relative error of u: 59.61317202956013%
#
# Param is 122
# Time elapsed: 1.3961186408996582 sec
# average relative error of u: 29.82470870483429%
# maximum relative error of u: 61.27632991495923%
#
# Param is 123
# Time elapsed: 1.6885793209075928 sec
# average relative error of u: 30.61396284802021%
# maximum relative error of u: 62.945403396051304%
#
# Param is 124
# Time elapsed: 1.2888262271881104 sec
# average relative error of u: 31.404820140747447%
# maximum relative error of u: 64.62008982541902%
#
# Param is 125
# Time elapsed: 1.1806256771087646 sec
# average relative error of u: 32.197201934743035%
# maximum relative error of u: 66.30588935048975%
#
# # of POD basis is 4
# # of measurments: 12
# [   0   58   59   60 1799 1859 3480 3539 3540 3569 3598 3599]
# Param is 75
# Time elapsed: 1.6581790447235107 sec
# average relative error of u: 6.841425576222983%
# maximum relative error of u: 8.951290208689338%
#
# Param is 76
# Time elapsed: 3.511721134185791 sec
# average relative error of u: 6.50553261338753%
# maximum relative error of u: 8.442724025105818%
#
# Param is 77
# Time elapsed: 9.356579065322876 sec
# average relative error of u: 6.181823922832373%
# maximum relative error of u: 7.951297364985713%
#
# Param is 78
# Time elapsed: 4.354825735092163 sec
# average relative error of u: 5.875373689965356%
# maximum relative error of u: 7.503133269758769%
#
# Param is 79
# Time elapsed: 1.1493983268737793 sec
# average relative error of u: 5.592279340962502%
# maximum relative error of u: 7.277776839729171%
#
# Param is 80
# Time elapsed: 1.3727025985717773 sec
# average relative error of u: 5.339615144102074%
# maximum relative error of u: 7.087731075087887%
#
# Param is 81
# Time elapsed: 7.452665328979492 sec
# average relative error of u: 5.12531672237862%
# maximum relative error of u: 6.9015432546809645%
#
# Param is 82
# Time elapsed: 2.618891716003418 sec
# average relative error of u: 4.957898382596135%
# maximum relative error of u: 6.718564887930251%
#
# Param is 83
# Time elapsed: 1.2100887298583984 sec
# average relative error of u: 4.845798600052753%
# maximum relative error of u: 6.539124707744897%
#
# Param is 84
# Time elapsed: 3.4305830001831055 sec
# average relative error of u: 4.796458766554962%
# maximum relative error of u: 6.640625504364575%
#
# Param is 85
# Time elapsed: 1.0468688011169434 sec
# average relative error of u: 4.815296349047859%
# maximum relative error of u: 7.171534812890439%
#
# Param is 86
# Time elapsed: 1.2028818130493164 sec
# average relative error of u: 4.904902235600325%
# maximum relative error of u: 7.894589303125985%
#
# Param is 87
# Time elapsed: 11.489489555358887 sec
# average relative error of u: 5.0647310678578386%
# maximum relative error of u: 8.748259646285828%
#
# Param is 88
# Time elapsed: 1.281442403793335 sec
# average relative error of u: 5.291415452451432%
# maximum relative error of u: 9.702527086710951%
#
# Param is 89
# Time elapsed: 4.114732503890991 sec
# average relative error of u: 5.579615031053392%
# maximum relative error of u: 10.728263912477054%
#
# Param is 90
# Time elapsed: 0.9110236167907715 sec
# average relative error of u: 5.922925378183685%
# maximum relative error of u: 11.814250017070293%
#
# Param is 91
# Time elapsed: 2.105786085128784 sec
# average relative error of u: 6.314736146229468%
# maximum relative error of u: 12.94504243466496%
#
# Param is 92
# Time elapsed: 1.4722568988800049 sec
# average relative error of u: 6.748742896868838%
# maximum relative error of u: 14.115594511565035%
#
# Param is 93
# Time elapsed: 1.2197082042694092 sec
# average relative error of u: 7.219307437740649%
# maximum relative error of u: 15.321646900102307%
#
# Param is 94
# Time elapsed: 1.6725025177001953 sec
# average relative error of u: 7.721553118833101%
# maximum relative error of u: 16.56008468321152%
#
# Param is 95
# Time elapsed: 1.189333200454712 sec
# average relative error of u: 8.251279756423239%
# maximum relative error of u: 17.828294978080354%
#
# Param is 96
# Time elapsed: 1.0746691226959229 sec
# average relative error of u: 8.805058990082525%
# maximum relative error of u: 19.12451869835399%
#
# Param is 97
# Time elapsed: 1.0146520137786865 sec
# average relative error of u: 9.379913207083616%
# maximum relative error of u: 20.446848543709542%
#
# Param is 98
# Time elapsed: 1.1020839214324951 sec
# average relative error of u: 9.973474022093372%
# maximum relative error of u: 21.793834244017738%
#
# Param is 99
# Time elapsed: 1.047792911529541 sec
# average relative error of u: 10.583703934258217%
# maximum relative error of u: 23.164398043389046%
#
# Param is 100
# Time elapsed: 1.3426291942596436 sec
# average relative error of u: 11.208892862738185%
# maximum relative error of u: 24.5572226403418%
#
# Param is 101
# Time elapsed: 1.3817222118377686 sec
# average relative error of u: 11.847592257415329%
# maximum relative error of u: 25.971282221680898%
#
# Param is 102
# Time elapsed: 11.9850332736969 sec
# average relative error of u: 12.49857328979666%
# maximum relative error of u: 27.406194759802755%
#
# Param is 103
# Time elapsed: 2.1899876594543457 sec
# average relative error of u: 13.160807232271887%
# maximum relative error of u: 28.86064053750989%
#
# Param is 104
# Time elapsed: 1.3960940837860107 sec
# average relative error of u: 13.833369757052418%
# maximum relative error of u: 30.333911929467057%
#
# Param is 105
# Time elapsed: 1.2883093357086182 sec
# average relative error of u: 14.51545794116251%
# maximum relative error of u: 31.82584362964433%
#
# Param is 106
# Time elapsed: 1.4827134609222412 sec
# average relative error of u: 15.20639971685332%
# maximum relative error of u: 33.33552274062248%
#
# Param is 107
# Time elapsed: 1.9163775444030762 sec
# average relative error of u: 15.905560456477799%
# maximum relative error of u: 34.86187757686653%
#
# Param is 108
# Time elapsed: 1.08353853225708 sec
# average relative error of u: 16.612377126010703%
# maximum relative error of u: 36.40444956485984%
#
# Param is 109
# Time elapsed: 0.9893374443054199 sec
# average relative error of u: 17.326391174804527%
# maximum relative error of u: 37.9627718470715%
#
# Param is 110
# Time elapsed: 3.7336294651031494 sec
# average relative error of u: 18.04713616039306%
# maximum relative error of u: 39.53655759438024%
#
# Param is 111
# Time elapsed: 1.298868179321289 sec
# average relative error of u: 18.774203126455674%
# maximum relative error of u: 41.12517757979355%
#
# Param is 112
# Time elapsed: 6.241322994232178 sec
# average relative error of u: 19.507226483041737%
# maximum relative error of u: 42.72796091487941%
#
# Param is 113
# Time elapsed: 1.1441140174865723 sec
# average relative error of u: 20.245845440337018%
# maximum relative error of u: 44.34425897672744%
#
# Param is 114
# Time elapsed: 1.0583503246307373 sec
# average relative error of u: 20.9897307481624%
# maximum relative error of u: 45.97377043263723%
#
# Param is 115
# Time elapsed: 10.643622398376465 sec
# average relative error of u: 21.73864861612794%
# maximum relative error of u: 47.61610848303137%
#
# Param is 116
# Time elapsed: 1.0124585628509521 sec
# average relative error of u: 22.492303087514788%
# maximum relative error of u: 49.270667851494295%
#
# Param is 117
# Time elapsed: 1.0434238910675049 sec
# average relative error of u: 23.250402202118458%
# maximum relative error of u: 50.93677690154665%
#
# Param is 118
# Time elapsed: 5.770646095275879 sec
# average relative error of u: 24.012726534989298%
# maximum relative error of u: 52.61406137437275%
#
# Param is 119
# Time elapsed: 1.1646816730499268 sec
# average relative error of u: 24.779046676796938%
# maximum relative error of u: 54.302104390520036%
#
# Param is 120
# Time elapsed: 1.0546493530273438 sec
# average relative error of u: 25.54914199315827%
# maximum relative error of u: 56.000647382415856%
#
# Param is 121
# Time elapsed: 1.1931509971618652 sec
# average relative error of u: 26.322798902032073%
# maximum relative error of u: 57.70874571629816%
#
# Param is 122
# Time elapsed: 14.300283908843994 sec
# average relative error of u: 27.099843551085844%
# maximum relative error of u: 59.426592001839005%
#
# Param is 123
# Time elapsed: 1.1892378330230713 sec
# average relative error of u: 27.88006207466887%
# maximum relative error of u: 61.153102171192685%
#
# Param is 124
# Time elapsed: 1.192507266998291 sec
# average relative error of u: 28.663287465461913%
# maximum relative error of u: 62.888294384229795%
#
# Param is 125
# Time elapsed: 7.260117053985596 sec
# average relative error of u: 29.449372074489016%
# maximum relative error of u: 64.63151361128321%
#
# # of POD basis is 5
# # of measurments: 12
# [   0   30   58   59   60 1739 1799 1800 3540 3569 3598 3599]
# Param is 75
# Time elapsed: 1.5294339656829834 sec
# average relative error of u: 5.380974556450519%
# maximum relative error of u: 7.3690668490837234%
#
# Param is 76
# Time elapsed: 1.2889375686645508 sec
# average relative error of u: 5.299443510015486%
# maximum relative error of u: 7.2615547493372805%
#
# Param is 77
# Time elapsed: 1.4214909076690674 sec
# average relative error of u: 5.21829618948969%
# maximum relative error of u: 7.155001247861481%
#
# Param is 78
# Time elapsed: 1.0762255191802979 sec
# average relative error of u: 5.137629898803172%
# maximum relative error of u: 7.049411280811619%
#
# Param is 79
# Time elapsed: 1.179569959640503 sec
# average relative error of u: 5.057575408277264%
# maximum relative error of u: 6.945088195128586%
#
# Param is 80
# Time elapsed: 4.189479112625122 sec
# average relative error of u: 4.978222989362204%
# maximum relative error of u: 6.8428814535257%
#
# Param is 81
# Time elapsed: 3.653454303741455 sec
# average relative error of u: 4.899626826566415%
# maximum relative error of u: 6.742328326021789%
#
# Param is 82
# Time elapsed: 4.4652440547943115 sec
# average relative error of u: 4.821866485717282%
# maximum relative error of u: 6.643224519576431%
#
# Param is 83
# Time elapsed: 3.8820722103118896 sec
# average relative error of u: 4.745053754950675%
# maximum relative error of u: 6.546089845427812%
#
# Param is 84
# Time elapsed: 12.083109140396118 sec
# average relative error of u: 4.669274865735903%
# maximum relative error of u: 6.450888277588835%
#
# Param is 85
# Time elapsed: 1.3156921863555908 sec
# average relative error of u: 4.594604376332902%
# maximum relative error of u: 6.357706257856783%
#
# Param is 86
# Time elapsed: 2.3954920768737793 sec
# average relative error of u: 4.521124831402508%
# maximum relative error of u: 6.266776724709763%
#
# Param is 87
# Time elapsed: 1.056462049484253 sec
# average relative error of u: 4.448919505924531%
# maximum relative error of u: 6.178103221535552%
#
# Param is 88
# Time elapsed: 1.0251610279083252 sec
# average relative error of u: 4.378050254390368%
# maximum relative error of u: 6.092073656033027%
#
# Param is 89
# Time elapsed: 0.993828535079956 sec
# average relative error of u: 4.30863035054975%
# maximum relative error of u: 6.008659192546383%
#
# Param is 90
# Time elapsed: 1.84236741065979 sec
# average relative error of u: 4.240757666075683%
# maximum relative error of u: 5.928081117453994%
#
# Param is 91
# Time elapsed: 1.7860000133514404 sec
# average relative error of u: 4.174497951343176%
# maximum relative error of u: 5.85060349577379%
#
# Param is 92
# Time elapsed: 1.2110416889190674 sec
# average relative error of u: 4.1099780095957525%
# maximum relative error of u: 5.776221494113732%
#
# Param is 93
# Time elapsed: 1.3575799465179443 sec
# average relative error of u: 4.047253234769732%
# maximum relative error of u: 5.70519979895354%
#
# Param is 94
# Time elapsed: 1.4255661964416504 sec
# average relative error of u: 3.9864654610566235%
# maximum relative error of u: 5.637711437737749%
#
# Param is 95
# Time elapsed: 1.4662542343139648 sec
# average relative error of u: 3.927740471418748%
# maximum relative error of u: 5.575750358578816%
#
# Param is 96
# Time elapsed: 1.5507283210754395 sec
# average relative error of u: 3.871119923810199%
# maximum relative error of u: 5.517651328996991%
#
# Param is 97
# Time elapsed: 1.6518993377685547 sec
# average relative error of u: 3.816758646667158%
# maximum relative error of u: 5.463832700255623%
#
# Param is 98
# Time elapsed: 3.9371862411499023 sec
# average relative error of u: 3.764828214927532%
# maximum relative error of u: 5.4145368812681%
#
# Param is 99
# Time elapsed: 1.2326347827911377 sec
# average relative error of u: 3.7153703168049668%
# maximum relative error of u: 5.369993527728843%
#
# Param is 100
# Time elapsed: 1.152496099472046 sec
# average relative error of u: 3.6686133956729%
# maximum relative error of u: 5.330406946014192%
#
# Param is 101
# Time elapsed: 9.122138261795044 sec
# average relative error of u: 3.62469559273643%
# maximum relative error of u: 5.296216751468596%
#
# Param is 102
# Time elapsed: 1.987215280532837 sec
# average relative error of u: 3.5836561536389024%
# maximum relative error of u: 5.26759662322108%
#
# Param is 103
# Time elapsed: 1.099499225616455 sec
# average relative error of u: 3.5457839749346585%
# maximum relative error of u: 5.2469846379996525%
#
# Param is 104
# Time elapsed: 1.0423469543457031 sec
# average relative error of u: 3.511184576456112%
# maximum relative error of u: 5.232630526534536%
#
# Param is 105
# Time elapsed: 1.1875648498535156 sec
# average relative error of u: 3.4800260658701556%
# maximum relative error of u: 5.224561534718336%
#
# Param is 106
# Time elapsed: 1.2008557319641113 sec
# average relative error of u: 3.4524384525138507%
# maximum relative error of u: 5.223349404886053%
#
# Param is 107
# Time elapsed: 4.159437894821167 sec
# average relative error of u: 3.428672458886633%
# maximum relative error of u: 5.229209811692086%
#
# Param is 108
# Time elapsed: 1.1125640869140625 sec
# average relative error of u: 3.408829557302061%
# maximum relative error of u: 5.242177861164858%
#
# Param is 109
# Time elapsed: 1.2249565124511719 sec
# average relative error of u: 3.3931280240938846%
# maximum relative error of u: 5.265336020001643%
#
# Param is 110
# Time elapsed: 1.0551786422729492 sec
# average relative error of u: 3.3816839343142%
# maximum relative error of u: 5.29681538082643%
#
# Param is 111
# Time elapsed: 1.2728793621063232 sec
# average relative error of u: 3.3746606047646748%
# maximum relative error of u: 5.336336510518605%
#
# Param is 112
# Time elapsed: 1.27195405960083 sec
# average relative error of u: 3.3723085992194006%
# maximum relative error of u: 5.38437655964438%
#
# Param is 113
# Time elapsed: 1.223973035812378 sec
# average relative error of u: 3.374660808969069%
# maximum relative error of u: 5.440809307798611%
#
# Param is 114
# Time elapsed: 1.2434167861938477 sec
# average relative error of u: 3.3818649716575404%
# maximum relative error of u: 5.506052067311615%
#
# Param is 115
# Time elapsed: 1.3326163291931152 sec
# average relative error of u: 3.394051878740568%
# maximum relative error of u: 5.5799099427290235%
#
# Param is 116
# Time elapsed: 1.2582221031188965 sec
# average relative error of u: 3.411391312398329%
# maximum relative error of u: 5.664822485939928%
#
# Param is 117
# Time elapsed: 1.2404696941375732 sec
# average relative error of u: 3.433848035229544%
# maximum relative error of u: 5.760112991214859%
#
# Param is 118
# Time elapsed: 1.4575583934783936 sec
# average relative error of u: 3.461605384768609%
# maximum relative error of u: 5.8645489819696515%
#
# Param is 119
# Time elapsed: 5.764984130859375 sec
# average relative error of u: 3.4946548479915394%
# maximum relative error of u: 5.978309862610198%
#
# Param is 120
# Time elapsed: 1.4227888584136963 sec
# average relative error of u: 3.533141917759769%
# maximum relative error of u: 6.101293628448278%
#
# Param is 121
# Time elapsed: 1.3725311756134033 sec
# average relative error of u: 3.5768862709623317%
# maximum relative error of u: 6.233244301439033%
#
# Param is 122
# Time elapsed: 1.2379651069641113 sec
# average relative error of u: 3.626058202626128%
# maximum relative error of u: 6.374448282962383%
#
# Param is 123
# Time elapsed: 5.1675801277160645 sec
# average relative error of u: 3.6806191686767145%
# maximum relative error of u: 6.524877510983757%
#
# Param is 124
# Time elapsed: 1.2986259460449219 sec
# average relative error of u: 3.7405083649064323%
# maximum relative error of u: 6.687010024158516%
#
# Param is 125
# Time elapsed: 1.1892898082733154 sec
# average relative error of u: 3.805716322479352%
# maximum relative error of u: 6.85866458441472%
#
# # of POD basis is 6
# # of measurments: 12
# [   0   30   58   59   60 1739 1799 1800 3540 3569 3598 3599]
# Param is 75
# Time elapsed: 1.9105861186981201 sec
# average relative error of u: 4.604183208790234%
# maximum relative error of u: 8.15970343134229%
#
# Param is 76
# Time elapsed: 1.858567714691162 sec
# average relative error of u: 4.544730476999658%
# maximum relative error of u: 8.050138358867029%
#
# Param is 77
# Time elapsed: 1.327807903289795 sec
# average relative error of u: 4.485279123792241%
# maximum relative error of u: 7.941328119684544%
#
# Param is 78
# Time elapsed: 8.298875093460083 sec
# average relative error of u: 4.425794803738404%
# maximum relative error of u: 7.830991206734502%
#
# Param is 79
# Time elapsed: 1.179105520248413 sec
# average relative error of u: 4.366513978531299%
# maximum relative error of u: 7.721599215747786%
#
# Param is 80
# Time elapsed: 3.3786208629608154 sec
# average relative error of u: 4.307518619498203%
# maximum relative error of u: 7.614143561125858%
#
# Param is 81
# Time elapsed: 1.1969444751739502 sec
# average relative error of u: 4.2487288272661905%
# maximum relative error of u: 7.506713783593974%
#
# Param is 82
# Time elapsed: 6.191288471221924 sec
# average relative error of u: 4.190261972110114%
# maximum relative error of u: 7.398532321604876%
#
# Param is 83
# Time elapsed: 1.256845474243164 sec
# average relative error of u: 4.132218172949847%
# maximum relative error of u: 7.292824654556251%
#
# Param is 84
# Time elapsed: 1.2291641235351562 sec
# average relative error of u: 4.074723939224726%
# maximum relative error of u: 7.18734961480592%
#
# Param is 85
# Time elapsed: 1.456315279006958 sec
# average relative error of u: 4.017801250487117%
# maximum relative error of u: 7.086661553357179%
#
# Param is 86
# Time elapsed: 5.863605499267578 sec
# average relative error of u: 3.9615884570573314%
# maximum relative error of u: 6.985333954761053%
#
# Param is 87
# Time elapsed: 1.0348632335662842 sec
# average relative error of u: 3.905998039943363%
# maximum relative error of u: 6.8854697018597895%
#
# Param is 88
# Time elapsed: 1.0761964321136475 sec
# average relative error of u: 3.851261137740684%
# maximum relative error of u: 6.788326504700104%
#
# Param is 89
# Time elapsed: 0.8777203559875488 sec
# average relative error of u: 3.7973721525634727%
# maximum relative error of u: 6.693575931500644%
#
# Param is 90
# Time elapsed: 1.182499885559082 sec
# average relative error of u: 3.7444817662937178%
# maximum relative error of u: 6.602389579544729%
#
# Param is 91
# Time elapsed: 6.3802571296691895 sec
# average relative error of u: 3.692557241915501%
# maximum relative error of u: 6.5107333713560465%
#
# Param is 92
# Time elapsed: 1.6112143993377686 sec
# average relative error of u: 3.6418964377661323%
# maximum relative error of u: 6.425309488628011%
#
# Param is 93
# Time elapsed: 1.0809900760650635 sec
# average relative error of u: 3.592475208175909%
# maximum relative error of u: 6.343449541266427%
#
# Param is 94
# Time elapsed: 5.485294818878174 sec
# average relative error of u: 3.544330447577315%
# maximum relative error of u: 6.264136024120042%
#
# Param is 95
# Time elapsed: 1.2353999614715576 sec
# average relative error of u: 3.4977042765075748%
# maximum relative error of u: 6.191597742126218%
#
# Param is 96
# Time elapsed: 1.0738246440887451 sec
# average relative error of u: 3.452634479320286%
# maximum relative error of u: 6.119778229522477%
#
# Param is 97
# Time elapsed: 0.936699628829956 sec
# average relative error of u: 3.409257795697372%
# maximum relative error of u: 6.055398553320317%
#
# Param is 98
# Time elapsed: 1.2774569988250732 sec
# average relative error of u: 3.3676991765938107%
# maximum relative error of u: 5.9952422039679085%
#
# Param is 99
# Time elapsed: 1.0577702522277832 sec
# average relative error of u: 3.328060384895512%
# maximum relative error of u: 5.940081524157115%
#
# Param is 100
# Time elapsed: 1.2214679718017578 sec
# average relative error of u: 3.290619985287198%
# maximum relative error of u: 5.889702462560462%
#
# Param is 101
# Time elapsed: 1.2266101837158203 sec
# average relative error of u: 3.255439687485361%
# maximum relative error of u: 5.844819063940069%
#
# Param is 102
# Time elapsed: 1.2247159481048584 sec
# average relative error of u: 3.222613390546002%
# maximum relative error of u: 5.803214420574961%
#
# Param is 103
# Time elapsed: 1.1751165390014648 sec
# average relative error of u: 3.1924543875407356%
# maximum relative error of u: 5.767752550188796%
#
# Param is 104
# Time elapsed: 1.722175121307373 sec
# average relative error of u: 3.1651394813431404%
# maximum relative error of u: 5.73799737272593%
#
# Param is 105
# Time elapsed: 1.3283438682556152 sec
# average relative error of u: 3.140726059948864%
# maximum relative error of u: 5.710825493492811%
#
# Param is 106
# Time elapsed: 5.880427598953247 sec
# average relative error of u: 3.119535604135759%
# maximum relative error of u: 5.691599454150202%
#
# Param is 107
# Time elapsed: 1.2027506828308105 sec
# average relative error of u: 3.101620510646618%
# maximum relative error of u: 5.678728774352905%
#
# Param is 108
# Time elapsed: 4.353693723678589 sec
# average relative error of u: 3.087400931874392%
# maximum relative error of u: 5.673465912911458%
#
# Param is 109
# Time elapsed: 1.0026309490203857 sec
# average relative error of u: 3.076783075777447%
# maximum relative error of u: 5.672065253143356%
#
# Param is 110
# Time elapsed: 5.374573469161987 sec
# average relative error of u: 3.0701897705188648%
# maximum relative error of u: 5.680687487902297%
#
# Param is 111
# Time elapsed: 1.6984915733337402 sec
# average relative error of u: 3.0677073889789015%
# maximum relative error of u: 5.695665013302215%
#
# Param is 112
# Time elapsed: 3.5637683868408203 sec
# average relative error of u: 3.06961596155165%
# maximum relative error of u: 5.719235539827061%
#
# Param is 113
# Time elapsed: 1.2739052772521973 sec
# average relative error of u: 3.0760309449987995%
# maximum relative error of u: 5.751166554287696%
#
# Param is 114
# Time elapsed: 2.7409634590148926 sec
# average relative error of u: 3.08707960778057%
# maximum relative error of u: 5.790540127332028%
#
# Param is 115
# Time elapsed: 1.2756690979003906 sec
# average relative error of u: 3.1029058357472685%
# maximum relative error of u: 5.839068313996957%
#
# Param is 116
# Time elapsed: 4.414163112640381 sec
# average relative error of u: 3.1237203089209693%
# maximum relative error of u: 5.9004040264082045%
#
# Param is 117
# Time elapsed: 1.316512107849121 sec
# average relative error of u: 3.149643073258878%
# maximum relative error of u: 5.972934348903471%
#
# Param is 118
# Time elapsed: 1.3211472034454346 sec
# average relative error of u: 3.1807308977181723%
# maximum relative error of u: 6.052547300676233%
#
# Param is 119
# Time elapsed: 1.1570510864257812 sec
# average relative error of u: 3.2170868861603066%
# maximum relative error of u: 6.142782674983431%
#
# Param is 120
# Time elapsed: 1.0896224975585938 sec
# average relative error of u: 3.2588212086593975%
# maximum relative error of u: 6.243783931821614%
#
# Param is 121
# Time elapsed: 1.1202592849731445 sec
# average relative error of u: 3.305821252894513%
# maximum relative error of u: 6.3527709259619565%
#
# Param is 122
# Time elapsed: 1.1425881385803223 sec
# average relative error of u: 3.358221989146378%
# maximum relative error of u: 6.471381920531277%
#
# Param is 123
# Time elapsed: 1.2367734909057617 sec
# average relative error of u: 3.4161533243100726%
# maximum relative error of u: 6.599347881092703%
#
# Param is 124
# Time elapsed: 1.1408979892730713 sec
# average relative error of u: 3.4794429188463476%
# maximum relative error of u: 6.738363450336851%
#
# Param is 125
# Time elapsed: 1.1681394577026367 sec
# average relative error of u: 3.548109610560768%
# maximum relative error of u: 6.883975129240605%

# %%
print(num_basis)
idx=[0,1,2,3]
num_basis[idx]
# Out:
# [3 4 5 6]
# array([3, 4, 5, 6])

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_bndry_DEIM_avg_rel_err.png")

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_bndry_DEIM_max_rel_err.png")
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
print(num_basis)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
idx=[3]
num_basis[idx]
# Out:
# array([6])

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_{}_bndry_DEIM_avg_rel_err.png".format(int(num_basis[idx])))

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_{}_bndry_DEIM_max_rel_err.png".format(int(num_basis[idx])))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
# figure rel.err vs at given param and POD basis
i=3;j=-1
POD_basis=num_basis[i]                 
param=FOM_parameters[j]

u_gappyPOD=results['solution'][i,j]

ex = np.load('./wave_data/ex23_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("POD basis: {} Param: {}".format(POD_basis,param))
plt.show()

# plot original data
vmin=-1; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyPOD[int(nt/4)*i].reshape(ny,nx))#,vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy POD @ t={}'.format(int(nt/4)*i*dt),fontsize=20)
    fig.colorbar(pcm, ax=ax,shrink=0.8)

# fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_POD_{}_param_{}_bndry_DEIM_SOL.png".format(POD_basis,param))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx))#,vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)
    fig.colorbar(pcm, ax=ax,shrink=0.8)

# fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_param_{}_ground_truth.png".format(param))
