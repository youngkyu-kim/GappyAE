# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.utils.prune as prune
from torch.utils.data.dataloader import DataLoader
import torch.utils.data as data_utils
from torch.optim import lr_scheduler
import sparselinear as sl

import numpy as np
import matplotlib.pyplot as plt

from scipy import sparse as sp
from scipy.sparse.linalg import spsolve

import sys,time
import os
import copy
import pickle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 9
#       7 from torch.optim import lr_scheduler
#       8 import numpy as np
# ----> 9 from scipy import sparse as sp
#      10 from scipy.sparse.linalg import spsolve
#      11 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# # Set device
# device = torch.device("cpu")
# print("Using device:", device, '\n')

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device, '\n')
# Out:
# Using device: cuda

# %%
# Given parameters
nx = 60
ny = 60
m=nx*ny
tf = 5.0
dt = 1.0e-2
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims = (ny,nx)

# set batch_size, number of epochs, paitience for early stop
batch_size = 240
num_epochs = 10000
num_epochs_print = 100
early_stop_patience = 200
num_patience = 50
l_rate = 0.001

# Choose data normalize option (option 1: -1<=X<=1 option 2: 0<=X<=1, option 3: no scaling)
option = 3

# Choose activation function (sigmoid, swish)
activation = 'swish'

# parameters
training_params = np.arange(80,121,5)
print("nt={}".format(nt))
print("training parameters={}".format(training_params))

# train:test split
r_test=0.2

# set the number of nodes in each layer
a = 2
b = int(100)
db = int(10)

M1 = int(a*m) # encoder hidden layer
M2 = b + (m-1)*db # decoder hidden layer

# latent space dimension
f_list=np.array([3,4,5,6])

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
free_multi_index=(multi_index_j[1:-1,1:-1].flatten(),multi_index_i[1:-1,1:-1].flatten())
x0_multi_index=(multi_index_j[1:-1,0].flatten(),multi_index_i[1:-1,0].flatten())
x1_multi_index=(multi_index_j[1:-1,-1].flatten(),multi_index_i[1:-1,-1].flatten())
y0_multi_index=(multi_index_j[0,1:-1].flatten(),multi_index_i[0,1:-1].flatten())
y1_multi_index=(multi_index_j[-1,1:-1].flatten(),multi_index_i[-1,1:-1].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
free_raveled_indicies=np.ravel_multi_index(free_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
x01_raveled_indicies=np.concatenate((x0_raveled_indicies,x1_raveled_indicies))
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
y01_raveled_indicies=np.concatenate((y0_raveled_indicies,y1_raveled_indicies))
fixed_raveled_indicies=np.setdiff1d(full_raveled_indicies,free_raveled_indicies)

# measurements
msmt_idx=full_raveled_indicies

# Gauss-Newton iteration parameters
maxitr=4
tol=1e-8

# random number generator seed
seed=np.random.randint(10)
# Out:
# nt=500
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %%
# load snapshot
snapshot = np.array([])
for i in training_params:
    ex = np.load('./wave_data/ex23_interp_{}.npz'.format(i), allow_pickle = True)
    ex = ex.f.arr_0
    snapshot = np.append(snapshot, ex)
snapshot = snapshot.reshape(len(training_params)*(nt+1),-1).astype('float32')
print(snapshot.shape,snapshot.dtype)

# number of data points
ndata = snapshot.shape[0]

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)

orig_data_u=np.copy(snapshot)

# normalize data
if option==1: # option 1: -1<=X<=1
    print("option {}: -1<=X<=1".format(option))
    u_ref = (np.max(orig_data_u,axis=0)+np.min(orig_data_u,axis=0))/2.0
    u_scale = (np.max(orig_data_u,axis=0)-np.min(orig_data_u,axis=0))/2.0
    u_scale = np.where(u_scale > np.finfo('float32').resolution, u_scale, 1)
    u_scale_reciprocal = np.reciprocal(u_scale)  
    data_u = u_scale_reciprocal*(orig_data_u-u_ref)
    
elif option==2: # option 2: 0<=X<=1
    print("option {}: 0<=X<=1".format(option))
    u_ref = np.min(orig_data_u,axis=0)    
    u_scale = np.max(orig_data_u,axis=0)-np.min(orig_data_u,axis=0)    
    u_scale = np.where(u_scale > np.finfo('float32').resolution, u_scale, 1)    
    u_scale_reciprocal = np.reciprocal(u_scale)    
    data_u = u_scale_reciprocal*(orig_data_u-u_ref)
elif option==3: # option 3: no scale applied
    print("option {}: no scaling".format(option))
    u_ref = np.zeros(orig_data_u.shape[1],dtype='float32')
    u_scale = np.ones(orig_data_u.shape[1],dtype='float32')   
    u_scale_reciprocal = u_scale
    data_u = u_scale_reciprocal*(orig_data_u-u_ref)
else:
    raise NameError('{} is given for option, but it must be either 1, 2 or 3'.format(option))

# check shapes of snapshot
print('data shape \t {}'.format(data_u.shape))
print('data dtype \t {}'.format(data_u.dtype))

# restore data
rest_data_u = u_ref + u_scale*data_u

# check precision
print('max. abs difference \t {}'.format(np.max(np.abs(orig_data_u-rest_data_u))))

# define testset and trainset indices
nset = len(training_params)
test_ind = np.array([],dtype='int')
for foo in range(nset):
    np.random.seed(foo)
    rand_perm = np.sort(np.random.permutation(nt+1)[:int(r_test*(nt+1))])
    rand_ind = np.arange(foo*(nt+1),(foo+1)*(nt+1))[rand_perm]
    test_ind = np.append(test_ind,rand_ind)
test_ind.sort()
train_ind = np.setdiff1d(np.arange(ndata),test_ind)

# set trainset and testset
# np.random.seed(0)
np.random.shuffle(train_ind)
np.random.shuffle(test_ind)
trainset = data_u[train_ind]
testset = data_u[test_ind] 

# set dataset
dataset = {'train':data_utils.TensorDataset(torch.tensor(trainset,dtype=torch.float32)),
           'test':data_utils.TensorDataset(torch.tensor(testset,dtype=torch.float32))}

# compute dataset shapes
dataset_shapes = {'train':trainset.shape,'test':testset.shape}
print("train set size: {} \t test set size: {}".format(dataset_shapes['train'],dataset_shapes['test']))

# set data loaders
train_loader = DataLoader(dataset=dataset['train'],batch_size=batch_size, shuffle=False, num_workers=0)
test_loader = DataLoader(dataset=dataset['test'],batch_size=batch_size, shuffle=False, num_workers=0)
data_loaders = {'train':train_loader, 'test':test_loader}

# data size
data_size=np.prod(orig_data_u.shape)
print('Data size:{:.8e}({:.4}GB)'.format(data_size,data_size*4/2**30))
# Out:
# (4509, 3600) float32
# option 3: no scaling
# data shape 	 (4509, 3600)
# data dtype 	 float32
# max. abs difference 	 0.0
# train set size: (3609, 3600) 	 test set size: (900, 3600)
# Data size:1.62324000e+07(0.06047GB)

# %%
data_u[0].max(), data_u[0].min()
# Out:
# (1.0, 0.00822975)

# %%
data_u[-1].max(), data_u[-1].min()
# Out:
# (0.541264, -0.447263)

# %%
data_u.max(), data_u.min()
# Out:
# (1.0, -0.455838)

# %%
def create_mask_2d(m,b,db):
    
    # local
    Mb=sp.diags([np.ones(nx),np.ones(nx),np.ones(nx)],[0,-1,1],(nx,nx))
    M=sp.kron(sp.eye(ny),Mb,format="csr")

    Ib=sp.eye(nx)
    N=sp.kron(sp.diags([np.ones(ny),np.ones(ny),np.ones(ny)],[0,-1,1],(ny,ny)),Ib,format="csr")

    local=(M+N).astype('int8')
    I,J,V=sp.find(local)
    local[I,J]=1
    
    # basis
    M2 = int(b + db*(m-1))
    basis = np.zeros((m,M2),dtype='int8')

    block = np.ones(b,dtype='int8')
    ind = np.arange(b)
    for row in range(m):
        col = ind + row*db
        basis[row,col] = block
    
    # mask
    col_ind=np.array([],dtype='int8')
    row_ind=np.array([],dtype='int8')
    for i in range(m):
        col=basis[sp.find(local[i])[1]].sum(axis=0).nonzero()[0]
        row=i*np.ones(col.size).astype(int)

        col_ind=np.append(col_ind,col)
        row_ind=np.append(row_ind,row)

    connection=np.vstack((row_ind,col_ind))

    # data=np.ones(row_ind.size,dtype='int8')
    # mask=sp.csr_matrix((data,(row_ind,col_ind)),shape=(m,M2)).toarray()
    
    print("Sparsity in {} by {} mask: {:.2f}%".format(m, M2, (1.0-connection.shape[1]/(m*M2))*100))
    
#     plt.figure()
#     plt.spy(mask)
#     plt.show()

    return connection

# %% [markdown]
# # Train model

# %%
np.random.seed(seed)
torch.manual_seed(seed)

# sparsity and shape of mask
# mask_2d=create_mask_2d(m,b,db)
connection=torch.tensor(create_mask_2d(m,b,db))

for i in range(len(f_list)):
    f = f_list[i] # latent dimension

    # Set file names
    file_name_AE="./wave_model/ex23_AE_"+str(f)+"_swish_seed_"+str(seed)+".p"
    file_name_AE_temp="./wave_temp/ex23_AE_"+str(f)+"_swish_temp_seed_"+str(seed)+".pkl"
    PATH = './wave_temp/ex23_AE_'+str(f)+"_swish_checkpoint_seed_"+str(seed)+".tar"
    loss_hist_name="./wave_result/ex23_AE_"+str(f)+"_swish_loss_seed_"+str(seed)+".p"
    loss_fig_name="./wave_result/ex23_AE_"+str(f)+"_swish_loss_seed_"+str(seed)+".png"
    rel_recon_fig_name="./wave_result/ex23_AE_"+str(f)+"_swish_rel_recon_seed_"+str(seed)+".png"
    avg_rel_err_fig_name="./wave_result/ex23_AE_"+str(f)+"_swish_avg_rel_err_seed_"+str(seed)+".png"
    max_rel_err_fig_name="./wave_result/ex23_AE_"+str(f)+"_swish_max_rel_err_seed_"+str(seed)+".png"
    rel_err_fig_name="./wave_result/ex23_AE_"+str(f)+"_swish_rel_err_seed_"+str(seed)+".png"

    print(file_name_AE)
    print(file_name_AE_temp)
    print(PATH)
    print(loss_fig_name)
    print(rel_recon_fig_name)
    print(avg_rel_err_fig_name)
    print(max_rel_err_fig_name)
    print(rel_err_fig_name)
    
    if activation=='sigmoid':
        print('Activation fundtion: sigmoid')
        class Encoder(nn.Module):
            def __init__(self,m,M1,f):
                super(Encoder,self).__init__()
                self.full = nn.Sequential(
                    nn.Linear(m,M1),
                    nn.Sigmoid(),
                    nn.Linear(M1,f,bias=False)
                )

            def forward(self, y):     
                y = y.view(-1,m)
                T = self.full(y)
                T = T.squeeze()

                return T

        class Decoder(nn.Module):
            def __init__(self,f,M2,m):
                super(Decoder,self).__init__()
                self.full = nn.Sequential(
                    nn.Linear(f,M2),
                    nn.Sigmoid(),
                    # nn.Linear(M2,m,bias=False)
                    sl.SparseLinear(M2,m,bias=False,connectivity=connection)
                )

            def forward(self,T):
                T = T.view(-1,f)
                y = self.full(T)
                y = y.squeeze()

                return y

    elif activation=='swish':
        print('Activation fundtion: swish')
        def silu(input):
            return input * torch.sigmoid(input)

        class SiLU(nn.Module):
            def __init__(self):
                super().__init__()

            def forward(self, input):
                return silu(input)

        class Encoder(nn.Module):
            def __init__(self,m,M1,f):
                super(Encoder,self).__init__()
                self.full = nn.Sequential(
                    nn.Linear(m,M1),
                    SiLU(),
                    nn.Linear(M1,f,bias=False)
                )

            def forward(self, y):     
                y = y.view(-1,m)
                T = self.full(y)
                T = T.squeeze()

                return T

        class Decoder(nn.Module):
            def __init__(self,f,M2,m):
                super(Decoder,self).__init__()
                self.full = nn.Sequential(
                    nn.Linear(f,M2),
                    SiLU(),
                    # nn.Linear(M2,m,bias=False)
                    sl.SparseLinear(M2,m,bias=False,connectivity=connection)
                )

            def forward(self,T):
                T = T.view(-1,f)
                y = self.full(T)
                y = y.squeeze()

                return y
    else:
        raise NameError('{} is given for option, but it must be either sigmoid or swish'.format(activation))
        
        
    # number of parameters and memory
    en_para=m*M1+M1+M1*f
    # de_para=f*M2+M2+np.count_nonzero(mask_2d)
    de_para=f*M2+M2+connection.shape[1]
    # print('Encoder parameters:{:.8e}({:.4}GB)'.format(en_para,en_para*4/2**30),\
    #       'Decoder parameters:{:.8e}({:.4}GB)'.format(de_para,(f*M2+M2+M2*m)*4/2**30))
    print('Encoder parameters:{:.8e}({:.4}GB)'.format(en_para,en_para*4/2**30),\
          'Decoder parameters:{:.8e}({:.4}GB)'.format(de_para,de_para*4/2**30))
    
    # load model
    try:
        checkpoint = torch.load(PATH, map_location=device)

        encoder = Encoder(m,M1,f).to(device)
        decoder = Decoder(f,M2,m).to(device)

        # # Prune
        # prune.custom_from_mask(decoder.full[2], name='weight', mask=torch.tensor(mask_2d).to(device))    

        optimizer = torch.optim.Adam(list(encoder.parameters()) + list(decoder.parameters()), lr=l_rate)
        scheduler = lr_scheduler.ReduceLROnPlateau(optimizer,patience=num_patience) 

        loss_func = nn.MSELoss(reduction='mean')

        encoder.load_state_dict(checkpoint['encoder_state_dict'])
        decoder.load_state_dict(checkpoint['decoder_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

        last_epoch = checkpoint['epoch']
        loss_hist = checkpoint['loss_hist']
        best_loss = checkpoint['best_loss']
        early_stop_counter = checkpoint['early_stop_counter']
        best_encoder_wts = checkpoint['best_encoder_wts']
        best_decoder_wts = checkpoint['best_decoder_wts']

        print("\n--------checkpoint restored--------\n")

        # resume training
        print("")
        print('Re-start {}th training... m={}, f={},a={}, b={}, db={}'.format(last_epoch+1, m, f, a, b, db))
    except:
        encoder = Encoder(m,M1,f).to(device)
        decoder = Decoder(f,M2,m).to(device)

        # # Prune
        # prune.custom_from_mask(decoder.full[2], name='weight', mask=torch.tensor(mask_2d).to(device))

        optimizer = torch.optim.Adam(list(encoder.parameters()) + list(decoder.parameters()), lr=l_rate)
        scheduler = lr_scheduler.ReduceLROnPlateau(optimizer,patience=num_patience) 

        loss_func = nn.MSELoss(reduction='mean')

        last_epoch = 0
        loss_hist = {'train':[],'test':[]}
        best_loss = float("inf")
        early_stop_counter = 1
        best_encoder_wts = copy.deepcopy(encoder.state_dict())
        best_decoder_wts = copy.deepcopy(decoder.state_dict())

        print("\n--------checkpoint not restored--------\n")

        # start training
        print("")
        print('Start first training... m={}, f={}, a={}, b={}, db={}'.format(m, f, a, b, db))
    pass

    # train model
    since = time.time()

    for epoch in range(last_epoch+1,num_epochs+1):   

        if epoch%num_epochs_print == 0:
            print()
            print('Epoch {}/{}, Learning rate {}'.format(
                epoch, num_epochs, optimizer.state_dict()['param_groups'][0]['lr']))
            print('-' * 10)

        # Each epoch has a training and test phase
        for phase in ['train', 'test']:
            if phase == 'train':
                encoder.train()  # Set model to training mode
                decoder.train()  # Set model to training mode
            else:
                encoder.eval()   # Set model to evaluation mode
                decoder.eval()   # Set model to evaluation mode

            running_loss = 0.0

            # Iterate over data
            for data, in data_loaders[phase]:
                inputs = data.to(device)
                targets = data.to(device)

                if phase == 'train':
                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    outputs = decoder(encoder(inputs))
                    loss = loss_func(outputs, targets)

                    # backward
                    loss.backward()

                    # optimize
                    optimizer.step()  

                    # add running loss
                    running_loss += loss.item()*inputs.shape[0]
                else:
                    with torch.set_grad_enabled(False):
                        outputs = decoder(encoder(inputs))
                        running_loss += loss_func(outputs,targets).item()*inputs.shape[0]

            # compute epoch loss
            epoch_loss = running_loss / dataset_shapes[phase][0]
            loss_hist[phase].append(epoch_loss)

            # update learning rate
            if phase == 'train':
                scheduler.step(epoch_loss)

            if epoch%num_epochs_print == 0:
                print('{} MSELoss: {}'.format(
                    phase, epoch_loss))

        # deep copy the model
        if round(loss_hist['test'][-1],10) < round(best_loss,10):
            best_loss = loss_hist['test'][-1]
            early_stop_counter = 1
            best_encoder_wts = copy.deepcopy(encoder.state_dict())
            best_decoder_wts = copy.deepcopy(decoder.state_dict())
        else:
            early_stop_counter += 1
            if early_stop_counter >= early_stop_patience:  
                break

        # save checkpoint every num_epoch_print
        if epoch%num_epochs_print== 0:
            torch.save({
                        'epoch': epoch,
                        'encoder_state_dict': encoder.state_dict(),
                        'decoder_state_dict': decoder.state_dict(),
                        'optimizer_state_dict': optimizer.state_dict(),
                        'loss_hist': loss_hist,
                        'best_loss': best_loss,
                        'early_stop_counter': early_stop_counter,
                        'best_encoder_wts': best_encoder_wts,
                        'best_decoder_wts': best_decoder_wts,
                        }, PATH)        

    print()
    print('Epoch {}/{}, Learning rate {}'.format(epoch, num_epochs, optimizer.state_dict()['param_groups'][0]['lr']))
    print('-' * 10)
    print('train MSELoss: {}'.format(loss_hist['train'][-1]))
    print('test MSELoss: {}'.format(loss_hist['test'][-1]))

    time_elapsed = time.time() - since

    # load best model weights
    encoder.load_state_dict(best_encoder_wts)
    decoder.load_state_dict(best_decoder_wts)

    # compute best train MSELoss
    encoder.to('cpu').eval()
    decoder.to('cpu').eval()

    with torch.set_grad_enabled(False):
        train_inputs = torch.tensor(data_u[train_ind])
        train_targets = torch.tensor(data_u[train_ind])
        train_outputs = decoder(encoder(train_inputs))
        train_loss = loss_func(train_outputs,train_targets).item()

    # print out training time and best results
    print()
    if epoch < num_epochs:
        print('Early stopping: {}th training complete in {:.0f}h {:.0f}m {:.0f}s'\
              .format(epoch-last_epoch, time_elapsed // 3600, (time_elapsed % 3600) // 60, (time_elapsed % 3600) % 60))
    else:
        print('No early stopping: {}th training complete in {:.0f}h {:.0f}m {:.0f}s'\
              .format(epoch-last_epoch, time_elapsed // 3600, (time_elapsed % 3600) // 60, (time_elapsed % 3600) % 60))
    print('-' * 10)
    print('Best train MSELoss: {}'.format(train_loss))
    print('Best test MSELoss: {}'.format(best_loss))

    # save models
    print()
    print("Saving after {}th training to".format(epoch),file_name_AE_temp)
    torch.save((encoder,decoder),file_name_AE_temp)
    
    # delete checkpoint
    try:
        os.remove(PATH)
        print()
        print("checkpoint removed")
    except:
        print("no checkpoint exists") 

    # release gpu memory
    torch.cuda.empty_cache()

    # plot train and test loss
    plt.figure(figsize=(10,5))
    plt.semilogy(loss_hist['train'])
    plt.semilogy(loss_hist['test'])
    plt.legend(['train','test'])
    # plt.show()   
    plt.savefig(loss_fig_name)

    # load models
    try:
        encoder_u,decoder_u = torch.load(file_name_AE_temp,map_location='cpu')
        print("\n--------model restored--------\n")
    except:
        print("\n--------model not restored--------\n")
        pass

    # load weights and bias
    en_wu1_s=encoder_u.full[0].weight.detach().numpy().astype('float32')
    en_bu1=encoder_u.full[0].bias.detach().numpy().astype('float32')
    en_wu2=encoder_u.full[2].weight.detach().numpy().astype('float32')
    de_wu1=decoder_u.full[0].weight.detach().numpy().astype('float32')
    de_bu1=decoder_u.full[0].bias.detach().numpy().astype('float32')
    # de_wu2_s=decoder_u.full[2].weight.detach().numpy().astype('float32')
    # de_wu2_s_sp=sp.csr_matrix(de_wu2_s,dtype='float32')
    aaa=decoder.full[2].weight.detach()
    de_wu2_s_sp=sp.csr_matrix((aaa.values(),(aaa.indices()[0],aaa.indices()[1])),
                            shape=aaa.size(),dtype='float32')
    de_wu2_s=de_wu2_s_sp.toarray().astype('float32')

    # rescale weights
    en_wu1=en_wu1_s*u_scale_reciprocal
    de_wu1T=de_wu1.T
    de_wu2T=u_scale*de_wu2_s.T
    de_wu2=de_wu2T.T
    de_wu2_sp=sp.csr_matrix(de_wu2,dtype='float32')
    de_wu2T_sp=de_wu2_sp.T
    
    # save weights and references   
    AE={'en_wu1':en_wu1,'en_bu1':en_bu1,'en_wu2':en_wu2,
        'de_wu1':de_wu1,'de_bu1':de_bu1,'de_wu2':de_wu2,
        'de_wu1T':de_wu1T,'de_wu2T':de_wu2T,'de_wu2_sp':de_wu2_sp,'de_wu2T_sp':de_wu2T_sp,'u_ref':u_ref,}

    with open(file_name_AE,'wb') as ffff:
        pickle.dump(AE,ffff)
        
    # save loss history
    with open(loss_hist_name,'wb') as f5:
        pickle.dump(loss_hist,f5)
# Out:
# Sparsity in 3600 by 36090 mask: 99.12%
# ./wave_model/ex23_AE_3_swish_seed_0.p
# ./wave_temp/ex23_AE_3_swish_temp_seed_0.pkl
# ./wave_temp/ex23_AE_3_swish_checkpoint_seed_0.tar
# ./wave_result/ex23_AE_3_swish_loss_seed_0.png
# ./wave_result/ex23_AE_3_swish_rel_recon_seed_0.png
# ./wave_result/ex23_AE_3_swish_avg_rel_err_seed_0.png
# ./wave_result/ex23_AE_3_swish_max_rel_err_seed_0.png
# ./wave_result/ex23_AE_3_swish_rel_err_seed_0.png
# Activation fundtion: swish
# Encoder parameters:2.59488000e+07(0.09667GB) Decoder parameters:1.28316000e+06(0.4845GB)
#
# --------checkpoint not restored--------
#
#
# Start first training... m=3600, f=3, a=2, b=100, db=10
#
# Epoch 100/10000, Learning rate 0.001
# ----------
# train MSELoss: 9.183394153627969e-05
# test MSELoss: 0.00010012501685802514
#
# Epoch 200/10000, Learning rate 0.001
# ----------
# train MSELoss: 9.724901778287087e-05
# test MSELoss: 0.00011953800276387483
#
# Epoch 300/10000, Learning rate 0.0001
# ----------
# train MSELoss: 7.405682274930842e-05
# test MSELoss: 7.155258160006876e-05
#
# Epoch 400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.246100034435834e-05
# test MSELoss: 7.04989957739599e-05
#
# Epoch 500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.209649913015207e-05
# test MSELoss: 7.007204646167034e-05
#
# Epoch 600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.134611884354891e-05
# test MSELoss: 6.931368310082083e-05
#
# Epoch 700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.980806029633873e-05
# test MSELoss: 6.787990181085964e-05
#
# Epoch 800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.712720944810445e-05
# test MSELoss: 6.539944927984228e-05
#
# Epoch 900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.387987802100192e-05
# test MSELoss: 6.260299948432172e-05
#
# Epoch 1000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.0930792714288364e-05
# test MSELoss: 6.0270006846015654e-05
#
# Epoch 1100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 5.8564809454975227e-05
# test MSELoss: 5.8465550440208364e-05
#
# Epoch 1200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 5.664951306171315e-05
# test MSELoss: 5.699552202713676e-05
#
# Epoch 1300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 5.504532107524128e-05
# test MSELoss: 5.573353215974445e-05
#
# Epoch 1400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 5.367704453432572e-05
# test MSELoss: 5.46256429515779e-05
#
# Epoch 1500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 5.251117816522413e-05
# test MSELoss: 5.366224650060758e-05
#
# Epoch 1600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 5.152197486242157e-05
# test MSELoss: 5.282359658546435e-05
#
# Epoch 1700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 5.067930373779602e-05
# test MSELoss: 5.2092627690096076e-05
#
# Epoch 1800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.994955763756607e-05
# test MSELoss: 5.1444510609144346e-05
#
# Epoch 1900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.930351685272893e-05
# test MSELoss: 5.085689166056303e-05
#
# Epoch 2000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.871859536987187e-05
# test MSELoss: 5.0313908044093596e-05
#
# Epoch 2100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.8186436595934416e-05
# test MSELoss: 4.9830668770785755e-05
#
# Epoch 2200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.767179589051636e-05
# test MSELoss: 4.93176921736449e-05
#
# Epoch 2300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.7190507483797424e-05
# test MSELoss: 4.8847929671561964e-05
#
# Epoch 2400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.6723850391269934e-05
# test MSELoss: 4.837797096115537e-05
#
# Epoch 2500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.6273445051252174e-05
# test MSELoss: 4.79224712762516e-05
#
# Epoch 2600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.583247804580163e-05
# test MSELoss: 4.746728130461027e-05
#
# Epoch 2700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.5402143470395635e-05
# test MSELoss: 4.702108975228232e-05
#
# Epoch 2800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.497857851278625e-05
# test MSELoss: 4.6575359010603276e-05
#
# Epoch 2900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.456200866339761e-05
# test MSELoss: 4.613403386125962e-05
#
# Epoch 3000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.41513803334775e-05
# test MSELoss: 4.569594627052235e-05
#
# Epoch 3100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.374576809818046e-05
# test MSELoss: 4.526035384818291e-05
#
# Epoch 3200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.334515719617312e-05
# test MSELoss: 4.482803827462097e-05
#
# Epoch 3300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.294954279571761e-05
# test MSELoss: 4.439941452195247e-05
#
# Epoch 3400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.255904064381215e-05
# test MSELoss: 4.397510905012799e-05
#
# Epoch 3500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.217388752358443e-05
# test MSELoss: 4.3555920759293563e-05
#
# Epoch 3600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.1794393002687014e-05
# test MSELoss: 4.314307031260493e-05
#
# Epoch 3700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.142098245852052e-05
# test MSELoss: 4.273715288339493e-05
#
# Epoch 3800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.105413033735018e-05
# test MSELoss: 4.233918565053803e-05
#
# Epoch 3900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.0694261002750846e-05
# test MSELoss: 4.1949580433235195e-05
#
# Epoch 4000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 4.033955558023433e-05
# test MSELoss: 4.1560574997371685e-05
#
# Epoch 4100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.9990951836708466e-05
# test MSELoss: 4.116983376055335e-05
#
# Epoch 4200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.9648998636727305e-05
# test MSELoss: 4.0804068945969144e-05
#
# Epoch 4300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.931803460115603e-05
# test MSELoss: 4.045423823602808e-05
#
# Epoch 4400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.8998330227176145e-05
# test MSELoss: 4.0118066923848046e-05
#
# Epoch 4500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.8690202856616464e-05
# test MSELoss: 3.979658455743144e-05
#
# Epoch 4600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.8393842043898085e-05
# test MSELoss: 3.949055462726392e-05
#
# Epoch 4700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.8109156747694154e-05
# test MSELoss: 3.919976782829811e-05
#
# Epoch 4800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.783587334542739e-05
# test MSELoss: 3.8923524698475376e-05
#
# Epoch 4900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.757362058068012e-05
# test MSELoss: 3.866145101104242e-05
#
# Epoch 5000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.7321903684554465e-05
# test MSELoss: 3.84133056892703e-05
#
# Epoch 5100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.708012085166408e-05
# test MSELoss: 3.8178120060668634e-05
#
# Epoch 5200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.6847735896325134e-05
# test MSELoss: 3.7954777750807506e-05
#
# Epoch 5300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.662419224860534e-05
# test MSELoss: 3.77423470733144e-05
#
# Epoch 5400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.640873258746258e-05
# test MSELoss: 3.7539965220882246e-05
#
# Epoch 5500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.620059960130501e-05
# test MSELoss: 3.7346433843291985e-05
#
# Epoch 5600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.5999087158597375e-05
# test MSELoss: 3.7160911597311495e-05
#
# Epoch 5700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.580358524090621e-05
# test MSELoss: 3.698272497179763e-05
#
# Epoch 5800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.5613511251857106e-05
# test MSELoss: 3.6811106353222084e-05
#
# Epoch 5900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.5428260311699456e-05
# test MSELoss: 3.664533857469602e-05
#
# Epoch 6000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.524726090054007e-05
# test MSELoss: 3.648465232496771e-05
#
# Epoch 6100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.5070042157926985e-05
# test MSELoss: 3.632845412842774e-05
#
# Epoch 6200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.4896142976850614e-05
# test MSELoss: 3.617618713178672e-05
#
# Epoch 6300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.4725062755323816e-05
# test MSELoss: 3.602694365933227e-05
#
# Epoch 6400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.455640668759353e-05
# test MSELoss: 3.588016588764731e-05
#
# Epoch 6500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.438994994324299e-05
# test MSELoss: 3.5735742737112254e-05
#
# Epoch 6600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.422550791223623e-05
# test MSELoss: 3.5593675541652677e-05
#
# Epoch 6700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.4062837146353886e-05
# test MSELoss: 3.545359468262177e-05
#
# Epoch 6800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.390180798930139e-05
# test MSELoss: 3.531516704242676e-05
#
# Epoch 6900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.374227524701599e-05
# test MSELoss: 3.5178122683040174e-05
#
# Epoch 7000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.3584125822357296e-05
# test MSELoss: 3.5042266608797946e-05
#
# Epoch 7100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.342713080163264e-05
# test MSELoss: 3.4907559893326834e-05
#
# Epoch 7200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.327106338687749e-05
# test MSELoss: 3.477378049865365e-05
#
# Epoch 7300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.3115701705611894e-05
# test MSELoss: 3.464049623289611e-05
#
# Epoch 7400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.296097616561472e-05
# test MSELoss: 3.450801050348673e-05
#
# Epoch 7500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.2806529064056193e-05
# test MSELoss: 3.4375368462254606e-05
#
# Epoch 7600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.265065245456087e-05
# test MSELoss: 3.4236301750449154e-05
#
# Epoch 7700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.249492642578644e-05
# test MSELoss: 3.409155906410888e-05
#
# Epoch 7800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.234073722418957e-05
# test MSELoss: 3.395857953970942e-05
#
# Epoch 7900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.218621864111043e-05
# test MSELoss: 3.3826428504350287e-05
#
# Epoch 8000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.203196305320454e-05
# test MSELoss: 3.369421319803223e-05
#
# Epoch 8100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.187799339856333e-05
# test MSELoss: 3.356183442519978e-05
#
# Epoch 8200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.172430137455106e-05
# test MSELoss: 3.34292373736389e-05
#
# Epoch 8300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.1570863741801435e-05
# test MSELoss: 3.329647273252097e-05
#
# Epoch 8400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.141767926195011e-05
# test MSELoss: 3.3163676926051265e-05
#
# Epoch 8500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.12647922223993e-05
# test MSELoss: 3.303110643173568e-05
#
# Epoch 8600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.1112195809498976e-05
# test MSELoss: 3.2898674665678605e-05
#
# Epoch 8700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.095996532948604e-05
# test MSELoss: 3.276647124342465e-05
#
# Epoch 8800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.080802520168753e-05
# test MSELoss: 3.2633957501578456e-05
#
# Epoch 8900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.065662401300569e-05
# test MSELoss: 3.25017321301857e-05
#
# Epoch 9000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.0505770654639544e-05
# test MSELoss: 3.236933419733153e-05
#
# Epoch 9100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.035562957615916e-05
# test MSELoss: 3.2236945601956296e-05
#
# Epoch 9200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.0206240371202965e-05
# test MSELoss: 3.210438990208786e-05
#
# Epoch 9300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 3.005761552850161e-05
# test MSELoss: 3.197161483209735e-05
#
# Epoch 9400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.9909690061143153e-05
# test MSELoss: 3.183880277598898e-05
#
# Epoch 9500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.976261825095514e-05
# test MSELoss: 3.170671261614189e-05
#
# Epoch 9600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.9616384948764812e-05
# test MSELoss: 3.1574857590991696e-05
#
# Epoch 9700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.9471234449536394e-05
# test MSELoss: 3.144379370496608e-05
#
# Epoch 9800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.9327449269692265e-05
# test MSELoss: 3.1313070333756814e-05
#
# Epoch 9900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.918563134616664e-05
# test MSELoss: 3.118286161528279e-05
#
# Epoch 10000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.904928607604415e-05
# test MSELoss: 3.1060893525136636e-05
#
# Epoch 10000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.904928607604415e-05
# test MSELoss: 3.1060893525136636e-05
#
# No early stopping: 10000th training complete in 4h 51m 5s
# ----------
# Best train MSELoss: 2.9134087526472285e-05
# Best test MSELoss: 3.1060893525136636e-05
#
# Saving after 10000th training to ./wave_temp/ex23_AE_3_swish_temp_seed_0.pkl
#
# checkpoint removed
#
# --------model restored--------
#
# ./wave_model/ex23_AE_4_swish_seed_0.p
# ./wave_temp/ex23_AE_4_swish_temp_seed_0.pkl
# ./wave_temp/ex23_AE_4_swish_checkpoint_seed_0.tar
# ./wave_result/ex23_AE_4_swish_loss_seed_0.png
# ./wave_result/ex23_AE_4_swish_rel_recon_seed_0.png
# ./wave_result/ex23_AE_4_swish_avg_rel_err_seed_0.png
# ./wave_result/ex23_AE_4_swish_max_rel_err_seed_0.png
# ./wave_result/ex23_AE_4_swish_rel_err_seed_0.png
# Activation fundtion: swish
# Encoder parameters:2.59560000e+07(0.09669GB) Decoder parameters:1.31925000e+06(0.4847GB)
#
# --------checkpoint not restored--------
#
#
# Start first training... m=3600, f=4, a=2, b=100, db=10
#
# Epoch 100/10000, Learning rate 0.001
# ----------
# train MSELoss: 3.61271539550549e-05
# test MSELoss: 2.6779211475513874e-05
#
# Epoch 200/10000, Learning rate 0.001
# ----------
# train MSELoss: 2.1192860759815807e-05
# test MSELoss: 1.733235694700852e-05
#
# Epoch 300/10000, Learning rate 0.001
# ----------
# train MSELoss: 9.151678341179092e-06
# test MSELoss: 1.0697425568650943e-05
#
# Epoch 400/10000, Learning rate 0.0001
# ----------
# train MSELoss: 5.339876897990281e-06
# test MSELoss: 5.503517483399871e-06
#
# Epoch 500/10000, Learning rate 0.0001
# ----------
# train MSELoss: 5.168849370076513e-06
# test MSELoss: 5.471791397818985e-06
#
# Epoch 600/10000, Learning rate 0.0001
# ----------
# train MSELoss: 4.986043831530192e-06
# test MSELoss: 5.4147243645275015e-06
#
# Epoch 700/10000, Learning rate 0.0001
# ----------
# train MSELoss: 4.569555984845062e-06
# test MSELoss: 4.871546328407324e-06
#
# Epoch 800/10000, Learning rate 0.0001
# ----------
# train MSELoss: 5.182352825029229e-06
# test MSELoss: 5.484100862910661e-06
#
# Epoch 900/10000, Learning rate 0.0001
# ----------
# train MSELoss: 4.137160026089104e-06
# test MSELoss: 4.392585075644698e-06
#
# Epoch 1000/10000, Learning rate 0.0001
# ----------
# train MSELoss: 3.98976734628371e-06
# test MSELoss: 4.29157804925732e-06
#
# Epoch 1100/10000, Learning rate 0.0001
# ----------
# train MSELoss: 3.597692570872737e-06
# test MSELoss: 3.886884239060843e-06
#
# Epoch 1200/10000, Learning rate 0.0001
# ----------
# train MSELoss: 4.01229094080289e-06
# test MSELoss: 4.399535130990747e-06
#
# Epoch 1300/10000, Learning rate 0.0001
# ----------
# train MSELoss: 3.6082650922064374e-06
# test MSELoss: 3.630219180195127e-06
#
# Epoch 1400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.787539111751393e-06
# test MSELoss: 2.879142645421477e-06
#
# Epoch 1500/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.73553779486442e-06
# test MSELoss: 2.8363645621235872e-06
#
# Epoch 1600/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.7324888059224287e-06
# test MSELoss: 2.831844100607365e-06
#
# Epoch 1700/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.727877016376815e-06
# test MSELoss: 2.826780413064019e-06
#
# Epoch 1800/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.7225883320918103e-06
# test MSELoss: 2.821028859519477e-06
#
# Epoch 1900/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.717203215191149e-06
# test MSELoss: 2.815133363280135e-06
# Epoch 2000/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.7118979210039952e-06
# test MSELoss: 2.8093833861930763e-06
#
# Epoch 2100/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.7067158103328753e-06
# test MSELoss: 2.8037934498570394e-06
#
# Epoch 2200/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.7016454257559117e-06
# test MSELoss: 2.7983409684869304e-06
#
# Epoch 2300/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6966705171430186e-06
# test MSELoss: 2.793006782061032e-06
#
# Epoch 2400/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6917778700767346e-06
# test MSELoss: 2.78777315543266e-06
#
# Epoch 2500/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6869568971277246e-06
# test MSELoss: 2.7826297355204588e-06
#
# Epoch 2600/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6822008172494044e-06
# test MSELoss: 2.7775680640237018e-06
#
# Epoch 2700/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6775040615822784e-06
# test MSELoss: 2.772578303241365e-06
#
# Epoch 2800/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.672860501526917e-06
# test MSELoss: 2.7676564059220254e-06
#
# Epoch 2900/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6682668276906613e-06
# test MSELoss: 2.7627952780070093e-06
#
# Epoch 3000/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6637198018414397e-06
# test MSELoss: 2.757991812056086e-06
#
# Epoch 3100/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6592160689417517e-06
# test MSELoss: 2.7532429612620034e-06
#
# Epoch 3200/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.654753669098557e-06
# test MSELoss: 2.748544663215095e-06
#
# Epoch 3300/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.650330509358909e-06
# test MSELoss: 2.7438950989259564e-06
#
# Epoch 3400/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.645944131422135e-06
# test MSELoss: 2.73929035756737e-06
#
# Epoch 3500/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.641593399270382e-06
# test MSELoss: 2.734729923759005e-06
#
# Epoch 3600/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.637275915084753e-06
# test MSELoss: 2.7302113873399017e-06
#
# Epoch 3700/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.63299110362686e-06
# test MSELoss: 2.725732641314001e-06
#
# Epoch 3800/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6287375727763314e-06
# test MSELoss: 2.72129210922382e-06
#
# Epoch 3900/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.624514428158909e-06
# test MSELoss: 2.7168893817967426e-06
#
# Epoch 4000/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.620320561729563e-06
# test MSELoss: 2.712522154979524e-06
#
# Epoch 4100/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.61615482962671e-06
# test MSELoss: 2.7081896253851786e-06
#
# Epoch 4200/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6120160950764754e-06
# test MSELoss: 2.7038905348793683e-06
#
# Epoch 4300/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.607903967782401e-06
# test MSELoss: 2.6996241407080864e-06
#
# Epoch 4400/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.6038174512127296e-06
# test MSELoss: 2.6953888512556053e-06
#
# Epoch 4500/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.599756086934502e-06
# test MSELoss: 2.691185166744011e-06
#
# Epoch 4600/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.595718679582124e-06
# test MSELoss: 2.687010055524297e-06
#
# Epoch 4700/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5917053420864103e-06
# test MSELoss: 2.6828647454143114e-06
#
# Epoch 4800/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5877151005017674e-06
# test MSELoss: 2.678747281000445e-06
#
# Epoch 4900/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5837474824088255e-06
# test MSELoss: 2.6746570711111415e-06
#
# Epoch 5000/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5798018090886585e-06
# test MSELoss: 2.6705933578341503e-06
#
# Epoch 5100/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.575878083376349e-06
# test MSELoss: 2.6665563685431456e-06
#
# Epoch 5200/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5719750223967336e-06
# test MSELoss: 2.6625446783630955e-06
#
# Epoch 5300/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5680930480101976e-06
# test MSELoss: 2.658558226661019e-06
#
# Epoch 5400/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5642312121649077e-06
# test MSELoss: 2.6545961191004606e-06
#
# Epoch 5500/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5603894790443114e-06
# test MSELoss: 2.6506587346375455e-06
#
# Epoch 5600/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.556567341074007e-06
# test MSELoss: 2.646744572606015e-06
#
# Epoch 5700/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5527636909649867e-06
# test MSELoss: 2.642853921012526e-06
#
# Epoch 5800/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.54897937924222e-06
# test MSELoss: 2.6389853246655546e-06
#
# Epoch 5900/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5452127035327276e-06
# test MSELoss: 2.635138162077055e-06
#
# Epoch 6000/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.541464253533822e-06
# test MSELoss: 2.631313176001034e-06
#
# Epoch 6100/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.537733564008345e-06
# test MSELoss: 2.627509896531895e-06
#
# Epoch 6200/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5340202954078267e-06
# test MSELoss: 2.6237268987946058e-06
#
# Epoch 6300/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.530324266003433e-06
# test MSELoss: 2.6199650468091324e-06
#
# Epoch 6400/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.526645179434462e-06
# test MSELoss: 2.616223885828125e-06
#
# Epoch 6500/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5229825352142207e-06
# test MSELoss: 2.612501960660059e-06
#
# Epoch 6600/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.519336030461317e-06
# test MSELoss: 2.6087994077291416e-06
#
# Epoch 6700/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.515705850779199e-06
# test MSELoss: 2.6051160906111664e-06
#
# Epoch 6800/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.512091577426073e-06
# test MSELoss: 2.6014512817103724e-06
#
# Epoch 6900/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5084925884791814e-06
# test MSELoss: 2.597805208400435e-06
#
# Epoch 7000/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.5049092608155878e-06
# test MSELoss: 2.594177628149434e-06
#
# Epoch 7100/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.501341156225927e-06
# test MSELoss: 2.5905677678868718e-06
#
# Epoch 7200/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4977881588497973e-06
# test MSELoss: 2.5869761429930805e-06
#
# Epoch 7300/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.494249546686002e-06
# test MSELoss: 2.583401449858987e-06
#
# Epoch 7400/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.490726147578845e-06
# test MSELoss: 2.579844416080353e-06
#
# Epoch 7500/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.487217015839063e-06
# test MSELoss: 2.5763043898526424e-06
#
# Epoch 7600/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4837220304086008e-06
# test MSELoss: 2.5727807496878087e-06
#
# Epoch 7700/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4802413545882532e-06
# test MSELoss: 2.5692734652693615e-06
#
# Epoch 7800/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4767742494608264e-06
# test MSELoss: 2.565782187957666e-06
#
# Epoch 7900/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.473320439928744e-06
# test MSELoss: 2.5623069329109663e-06
#
# Epoch 8000/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.469880323470675e-06
# test MSELoss: 2.5588473211731373e-06
#
# Epoch 8100/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4664534356054835e-06
# test MSELoss: 2.555402807047358e-06
#
# Epoch 8200/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.463039559543804e-06
# test MSELoss: 2.5519736633820383e-06
#
# Epoch 8300/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4596387080435116e-06
# test MSELoss: 2.5485594960628076e-06
#
# Epoch 8400/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4562510600928607e-06
# test MSELoss: 2.5451604718303617e-06
#
# Epoch 8500/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.452875826499182e-06
# test MSELoss: 2.541775832772449e-06
#
# Epoch 8600/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.449513000174767e-06
# test MSELoss: 2.5384057001550295e-06
#
# Epoch 8700/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4461628267323273e-06
# test MSELoss: 2.535049528281282e-06
#
# Epoch 8800/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4428240973868736e-06
# test MSELoss: 2.5317076203161076e-06
#
# Epoch 8900/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4394980388789216e-06
# test MSELoss: 2.5283799156265256e-06
#
# Epoch 9000/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.436183448471661e-06
# test MSELoss: 2.52506561082555e-06
#
# Epoch 9100/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.43288060031764e-06
# test MSELoss: 2.5217645088559947e-06
#
# Epoch 9200/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.429589436203149e-06
# test MSELoss: 2.5184770341487212e-06
#
# Epoch 9300/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4263098428193632e-06
# test MSELoss: 2.5152025955321733e-06
#
# Epoch 9400/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.423041517568397e-06
# test MSELoss: 2.511941390063536e-06
#
# Epoch 9500/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.419784588218002e-06
# test MSELoss: 2.5086923566656574e-06
#
# Epoch 9600/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4165388316471272e-06
# test MSELoss: 2.505456162301319e-06
#
# Epoch 9700/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4133044179607675e-06
# test MSELoss: 2.502232488647375e-06
#
# Epoch 9800/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4100809602645635e-06
# test MSELoss: 2.499022078457832e-06
#
# Epoch 9900/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.406868126475766e-06
# test MSELoss: 2.4958230975850407e-06
#
# Epoch 10000/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4036655388667854e-06
# test MSELoss: 2.4926366525808893e-06
#
# Epoch 10000/10000, Learning rate 1.0000000000000002e-06
# ----------
# train MSELoss: 2.4036655388667854e-06
# test MSELoss: 2.4926366525808893e-06
#
# No early stopping: 10000th training complete in 4h 50m 14s
# ----------
# Best train MSELoss: 2.3995141873456305e-06
# Best test MSELoss: 2.4926366525808893e-06
#
# Saving after 10000th training to ./wave_temp/ex23_AE_4_swish_temp_seed_0.pkl
#
# checkpoint removed
#
# --------model restored--------
#
# ./wave_model/ex23_AE_5_swish_seed_0.p
# ./wave_temp/ex23_AE_5_swish_temp_seed_0.pkl
# ./wave_temp/ex23_AE_5_swish_checkpoint_seed_0.tar
# ./wave_result/ex23_AE_5_swish_loss_seed_0.png
# ./wave_result/ex23_AE_5_swish_rel_recon_seed_0.png
# ./wave_result/ex23_AE_5_swish_avg_rel_err_seed_0.png
# ./wave_result/ex23_AE_5_swish_max_rel_err_seed_0.png
# ./wave_result/ex23_AE_5_swish_rel_err_seed_0.png
# Activation fundtion: swish
# Encoder parameters:2.59632000e+07(0.09672GB) Decoder parameters:1.35534000e+06(0.4848GB)
#
# --------checkpoint not restored--------
#
#
# Start first training... m=3600, f=5, a=2, b=100, db=10
#
# Epoch 100/10000, Learning rate 0.001
# ----------
# train MSELoss: 7.00120958553923e-05
# test MSELoss: 5.6857498808919145e-05
#
# Epoch 200/10000, Learning rate 0.001
# ----------
# train MSELoss: 3.465331449759919e-05
# test MSELoss: 2.2951051384249392e-05
#
# Epoch 300/10000, Learning rate 0.0001
# ----------
# train MSELoss: 5.024621735235389e-06
# test MSELoss: 5.144647760365236e-06
#
# Epoch 400/10000, Learning rate 0.0001
# ----------
# train MSELoss: 4.607432134572526e-06
# test MSELoss: 4.787643986977249e-06
#
# Epoch 500/10000, Learning rate 0.0001
# ----------
# train MSELoss: 4.383913276253522e-06
# test MSELoss: 4.63225997009431e-06
#
# Epoch 600/10000, Learning rate 0.0001
# ----------
# train MSELoss: 4.284469386389328e-06
# test MSELoss: 4.438440282683587e-06
#
# Epoch 700/10000, Learning rate 0.0001
# ----------
# train MSELoss: 3.9464754007473846e-06
# test MSELoss: 4.736143425058496e-06
#
# Epoch 800/10000, Learning rate 0.0001
# ----------
# train MSELoss: 5.2198099292309735e-06
# test MSELoss: 5.359811742285577e-06
#
# Epoch 900/10000, Learning rate 0.0001
# ----------
# train MSELoss: 3.727734747296267e-06
# test MSELoss: 3.7204059026407775e-06
#
# Epoch 1000/10000, Learning rate 0.0001
# ----------
# train MSELoss: 4.2329158737344e-06
# test MSELoss: 4.170030812626161e-06
#
# Epoch 1100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.3293650198570486e-06
# test MSELoss: 2.4063349883363115e-06
#
# Epoch 1200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.301010952677547e-06
# test MSELoss: 2.3820969848505533e-06
#
# Epoch 1300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.260274001635575e-06
# test MSELoss: 2.336234638278256e-06
#
# Epoch 1400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.218353236356608e-06
# test MSELoss: 2.295463536938769e-06
#
# Epoch 1500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.1780350749268426e-06
# test MSELoss: 2.255261764124346e-06
#
# Epoch 1600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.1411734018993088e-06
# test MSELoss: 2.2182727813439367e-06
#
# Epoch 1700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.1072931230977585e-06
# test MSELoss: 2.1844082463455075e-06
#
# Epoch 1800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.0759705092499634e-06
# test MSELoss: 2.1532024978417513e-06
#
# Epoch 1900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.046832411142169e-06
# test MSELoss: 2.124267530234647e-06
#
# Epoch 2000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.019434704007856e-06
# test MSELoss: 2.0975902316422435e-06
#
# Epoch 2100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.993611018736609e-06
# test MSELoss: 2.0725737310082573e-06
#
# Epoch 2200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.9678600780155626e-06
# test MSELoss: 2.044126661833919e-06
#
# Epoch 2300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.9437597072554507e-06
# test MSELoss: 2.0174269366179942e-06
#
# Epoch 2400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.921084787333522e-06
# test MSELoss: 1.9941965244167173e-06
#
# Epoch 2500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.898945213627274e-06
# test MSELoss: 1.9706444012020557e-06
#
# Epoch 2600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.8781785028947864e-06
# test MSELoss: 1.948756062120083e-06
#
# Epoch 2700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.8582345477760066e-06
# test MSELoss: 1.9290851923869924e-06
#
# Epoch 2800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.8385389751972175e-06
# test MSELoss: 1.90883650551162e-06
#
# Epoch 2900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.8203313118523213e-06
# test MSELoss: 1.8909246970603514e-06
#
# Epoch 3000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.801835358438043e-06
# test MSELoss: 1.8709727328314329e-06
#
# Epoch 3100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.7838356036541157e-06
# test MSELoss: 1.8516457657824504e-06
#
# Epoch 3200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.7665051183697111e-06
# test MSELoss: 1.833688118798212e-06
#
# Epoch 3300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.7496099535008395e-06
# test MSELoss: 1.8162547197183206e-06
#
# Epoch 3400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.7331326058106247e-06
# test MSELoss: 1.7993082944182484e-06
#
# Epoch 3500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.7170270680408437e-06
# test MSELoss: 1.7827690726335276e-06
#
# Epoch 3600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.7012611982858454e-06
# test MSELoss: 1.766560861445517e-06
#
# Epoch 3700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.6857921222906382e-06
# test MSELoss: 1.7505949623834264e-06
#
# Epoch 3800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.670481757326264e-06
# test MSELoss: 1.7344978838688499e-06
#
# Epoch 3900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.6551261529387097e-06
# test MSELoss: 1.7191857371775161e-06
#
# Epoch 4000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.64012077493567e-06
# test MSELoss: 1.7049146132800767e-06
#
# Epoch 4100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.6270793516076987e-06
# test MSELoss: 1.6902065150740478e-06
#
# Epoch 4200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.6113745344251374e-06
# test MSELoss: 1.6760294784035067e-06
#
# Epoch 4300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.5964732118678022e-06
# test MSELoss: 1.6591508028795944e-06
#
# Epoch 4400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.5829002834366705e-06
# test MSELoss: 1.6455952618343872e-06
#
# Epoch 4500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.5709424839217128e-06
# test MSELoss: 1.6365424320004725e-06
#
# Epoch 4600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.5590780194577207e-06
# test MSELoss: 1.6244407333942946e-06
#
# Epoch 4700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.5435543230796687e-06
# test MSELoss: 1.6065671995117251e-06
#
# Epoch 4800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.5302566581719738e-06
# test MSELoss: 1.5920977527154416e-06
#
# Epoch 4900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.5177033254198096e-06
# test MSELoss: 1.580731380575647e-06
#
# Epoch 5000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.5049315730355833e-06
# test MSELoss: 1.5679547383721606e-06
#
# Epoch 5100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.492899719350976e-06
# test MSELoss: 1.5576941526281491e-06
#
# Epoch 5200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.4801351144478417e-06
# test MSELoss: 1.5438609959043485e-06
#
# Epoch 5300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.4689264986246006e-06
# test MSELoss: 1.5346441311218465e-06
#
# Epoch 5400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.4568632451173788e-06
# test MSELoss: 1.5244449286910822e-06
#
# Epoch 5500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.4438508747301201e-06
# test MSELoss: 1.508348532297532e-06
#
# Epoch 5600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.4334716352904654e-06
# test MSELoss: 1.4994425706997088e-06
#
# Epoch 5700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.4207561617182737e-06
# test MSELoss: 1.4869774304315798e-06
#
# Epoch 5800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.4096825046457742e-06
# test MSELoss: 1.4747890418220777e-06
#
# Epoch 5900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3980439617748436e-06
# test MSELoss: 1.4639430825506376e-06
#
# Epoch 6000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3878519903089227e-06
# test MSELoss: 1.454960336862617e-06
#
# Epoch 6100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3767407141389676e-06
# test MSELoss: 1.4426138401783343e-06
#
# Epoch 6200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3645391709417111e-06
# test MSELoss: 1.430831601586154e-06
#
# Epoch 6300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.355297273101916e-06
# test MSELoss: 1.4224655084641806e-06
#
# Epoch 6400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3432282501058083e-06
# test MSELoss: 1.4105626557163002e-06
#
# Epoch 6500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.33276214900799e-06
# test MSELoss: 1.4001186400491862e-06
#
# Epoch 6600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3244778685255464e-06
# test MSELoss: 1.3929952501712251e-06
#
# Epoch 6700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3125426521968567e-06
# test MSELoss: 1.3805127612916597e-06
#
# Epoch 6800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3034487323297834e-06
# test MSELoss: 1.3725687949772692e-06
#
# Epoch 6900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2920912319214532e-06
# test MSELoss: 1.3623077393276617e-06
#
# Epoch 7000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2814417293836684e-06
# test MSELoss: 1.3519404774342546e-06
#
# Epoch 7100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2718859888692945e-06
# test MSELoss: 1.3436605665143968e-06
#
# Epoch 7200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2628518048202496e-06
# test MSELoss: 1.3336753985034496e-06
#
# Epoch 7300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2529568832166387e-06
# test MSELoss: 1.3250491065264213e-06
#
# Epoch 7400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2428631855639297e-06
# test MSELoss: 1.3150412238852975e-06
#
# Epoch 7500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2343413663096067e-06
# test MSELoss: 1.3055044519205694e-06
#
# Epoch 7600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2244894256546194e-06
# test MSELoss: 1.2984727163711796e-06
#
# Epoch 7700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2170123352338962e-06
# test MSELoss: 1.2896045670155823e-06
#
# Epoch 7800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2068413790114596e-06
# test MSELoss: 1.2787732581879633e-06
#
# Epoch 7900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.1989615871308604e-06
# test MSELoss: 1.2709173915936844e-06
#
# Epoch 8000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.188759212846774e-06
# test MSELoss: 1.263137604231209e-06
#
# Epoch 8100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.1802668833722388e-06
# test MSELoss: 1.2566599859079966e-06
#
# Epoch 8200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.1713277600893245e-06
# test MSELoss: 1.2462362519727321e-06
#
# Epoch 8300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.1627158183586038e-06
# test MSELoss: 1.235484713409581e-06
#
# Epoch 8400/10000, Learning rate 1.0000000000000002e-07
# ----------
# train MSELoss: 1.1105122658413383e-06
# test MSELoss: 1.1829866025436785e-06
#
# Epoch 8500/10000, Learning rate 1.0000000000000004e-08
# ----------
# train MSELoss: 1.110221261935781e-06
# test MSELoss: 1.1829787202562633e-06
#
# Epoch 8579/10000, Learning rate 1.0000000000000004e-08
# ----------
# train MSELoss: 1.1102133492893492e-06
# test MSELoss: 1.1829723158977382e-06
#
# Early stopping: 8579th training complete in 2h 35m 18s
# ----------
# Best train MSELoss: 1.11013503101276e-06
# Best test MSELoss: 1.1828540740073853e-06
#
# Saving after 8579th training to ./wave_temp/ex23_AE_5_swish_temp_seed_0.pkl
#
# checkpoint removed
#
# --------model restored--------
#
# ./wave_model/ex23_AE_6_swish_seed_0.p
# ./wave_temp/ex23_AE_6_swish_temp_seed_0.pkl
# ./wave_temp/ex23_AE_6_swish_checkpoint_seed_0.tar
# ./wave_result/ex23_AE_6_swish_loss_seed_0.png
# ./wave_result/ex23_AE_6_swish_rel_recon_seed_0.png
# ./wave_result/ex23_AE_6_swish_avg_rel_err_seed_0.png
# ./wave_result/ex23_AE_6_swish_max_rel_err_seed_0.png
# ./wave_result/ex23_AE_6_swish_rel_err_seed_0.png
# Activation fundtion: swish
# Encoder parameters:2.59704000e+07(0.09675GB) Decoder parameters:1.39143000e+06(0.4849GB)
#
# --------checkpoint not restored--------
#
#
# Start first training... m=3600, f=6, a=2, b=100, db=10
#
# Epoch 100/10000, Learning rate 0.001
# ----------
# train MSELoss: 2.5740830517869786e-05
# test MSELoss: 2.2604260811931455e-05
#
# Epoch 200/10000, Learning rate 0.001
# ----------
# train MSELoss: 1.5163988728249536e-05
# test MSELoss: 8.442999084460704e-06
#
# Epoch 300/10000, Learning rate 0.0001
# ----------
# train MSELoss: 4.2841915820642955e-06
# test MSELoss: 4.375590803344191e-06
#
# Epoch 400/10000, Learning rate 0.0001
# ----------
# train MSELoss: 3.923896729066199e-06
# test MSELoss: 4.068799626111286e-06
#
# Epoch 500/10000, Learning rate 0.0001
# ----------
# train MSELoss: 3.497195145744896e-06
# test MSELoss: 3.6886199116755355e-06
# Epoch 600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.806322359790078e-06
# test MSELoss: 2.897087112311662e-06
#
# Epoch 700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.76142104920355e-06
# test MSELoss: 2.8695900558280603e-06
#
# Epoch 800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.6810429918424124e-06
# test MSELoss: 2.7996326783371234e-06
#
# Epoch 900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.575942039357527e-06
# test MSELoss: 2.6926786176773023e-06
#
# Epoch 1000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.474546448804028e-06
# test MSELoss: 2.591641229325129e-06
#
# Epoch 1100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.3800323975730214e-06
# test MSELoss: 2.497413909926157e-06
#
# Epoch 1200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.2938272156903608e-06
# test MSELoss: 2.4123759734114475e-06
#
# Epoch 1300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.2142712895631004e-06
# test MSELoss: 2.334258639772694e-06
#
# Epoch 1400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.1395570049921573e-06
# test MSELoss: 2.2610862743022152e-06
#
# Epoch 1500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 2.0683856773500677e-06
# test MSELoss: 2.191511399966354e-06
#
# Epoch 1600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.999689951759955e-06
# test MSELoss: 2.1238737948200043e-06
#
# Epoch 1700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.9339484892162855e-06
# test MSELoss: 2.060877962624848e-06
#
# Epoch 1800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.8698456967496822e-06
# test MSELoss: 1.9991227418358905e-06
#
# Epoch 1900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.8068013808132962e-06
# test MSELoss: 1.9343084735131317e-06
#
# Epoch 2000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.7468030926689654e-06
# test MSELoss: 1.869262897950345e-06
#
# Epoch 2100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.6901456026775763e-06
# test MSELoss: 1.8084996554534881e-06
#
# Epoch 2200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.6360344246908818e-06
# test MSELoss: 1.7503772217726995e-06
#
# Epoch 2300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.584105582359683e-06
# test MSELoss: 1.6950535609794316e-06
#
# Epoch 2400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.5348064918403802e-06
# test MSELoss: 1.6431916871321543e-06
#
# Epoch 2500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.4873476149137426e-06
# test MSELoss: 1.5903007579254336e-06
#
# Epoch 2600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.4423692946305436e-06
# test MSELoss: 1.5432276162149112e-06
#
# Epoch 2700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3989150186543742e-06
# test MSELoss: 1.496974982728716e-06
#
# Epoch 2800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3575084914986275e-06
# test MSELoss: 1.4527695460249864e-06
#
# Epoch 2900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.3180339425394046e-06
# test MSELoss: 1.4114557340387061e-06
#
# Epoch 3000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.280448163218149e-06
# test MSELoss: 1.3696752375835786e-06
#
# Epoch 3100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.2455899067672416e-06
# test MSELoss: 1.334039552602917e-06
#
# Epoch 3200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.213690305237467e-06
# test MSELoss: 1.2999902689140679e-06
#
# Epoch 3300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.1846164567309706e-06
# test MSELoss: 1.2710580828449261e-06
#
# Epoch 3400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.1569595385035027e-06
# test MSELoss: 1.240464568278791e-06
#
# Epoch 3500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.1322872583570048e-06
# test MSELoss: 1.2149050235166214e-06
#
# Epoch 3600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.109482571430508e-06
# test MSELoss: 1.1902314251225714e-06
#
# Epoch 3700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.0885897493442785e-06
# test MSELoss: 1.1689959364957758e-06
#
# Epoch 3800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.0698213510463155e-06
# test MSELoss: 1.1489499759894292e-06
#
# Epoch 3900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.0520851696508653e-06
# test MSELoss: 1.1325615635845073e-06
#
# Epoch 4000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.0363877875685906e-06
# test MSELoss: 1.1155399382308436e-06
#
# Epoch 4100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.020594674931771e-06
# test MSELoss: 1.100896846158624e-06
#
# Epoch 4200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 1.0069371686437755e-06
# test MSELoss: 1.0853628206556702e-06
#
# Epoch 4300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 9.946864935013086e-07
# test MSELoss: 1.0735676899760924e-06
#
# Epoch 4400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 9.813877950640206e-07
# test MSELoss: 1.0609706502388387e-06
#
# Epoch 4500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 9.687884404057035e-07
# test MSELoss: 1.0493280948746057e-06
#
# Epoch 4600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 9.586764933694624e-07
# test MSELoss: 1.0407407216916908e-06
#
# Epoch 4700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 9.467243613276456e-07
# test MSELoss: 1.0244960246078942e-06
#
# Epoch 4800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 9.358632076355138e-07
# test MSELoss: 1.0206725013025184e-06
#
# Epoch 4900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 9.244110189437388e-07
# test MSELoss: 1.0039617753439718e-06
#
# Epoch 5000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 9.141982572926905e-07
# test MSELoss: 9.917772824034424e-07
#
# Epoch 5100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 9.053745660538602e-07
# test MSELoss: 9.826047327502844e-07
#
# Epoch 5200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.95940573889135e-07
# test MSELoss: 9.72444634802135e-07
#
# Epoch 5300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.873948496146118e-07
# test MSELoss: 9.639488098400762e-07
#
# Epoch 5400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.78288611051e-07
# test MSELoss: 9.534216966737101e-07
#
# Epoch 5500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.701278528534111e-07
# test MSELoss: 9.45219096593064e-07
#
# Epoch 5600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.620892381688225e-07
# test MSELoss: 9.366733176345103e-07
#
# Epoch 5700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.537269092152108e-07
# test MSELoss: 9.280518952436978e-07
#
# Epoch 5800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.456127163147283e-07
# test MSELoss: 9.194963809022738e-07
#
# Epoch 5900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.383028296056736e-07
# test MSELoss: 9.112645064609144e-07
#
# Epoch 6000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.304343501324443e-07
# test MSELoss: 9.041505450113618e-07
#
# Epoch 6100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.23457136106547e-07
# test MSELoss: 8.96020355867222e-07
#
# Epoch 6200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.153703859140023e-07
# test MSELoss: 8.8894458182646e-07
#
# Epoch 6300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 8.078843822987224e-07
# test MSELoss: 8.767371279342721e-07
#
# Epoch 6400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.996153443105318e-07
# test MSELoss: 8.683954206389899e-07
#
# Epoch 6500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.889721812551175e-07
# test MSELoss: 8.511183030653531e-07
#
# Epoch 6600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.815113591562643e-07
# test MSELoss: 8.428746127719933e-07
#
# Epoch 6700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.730725172125647e-07
# test MSELoss: 8.30602724969746e-07
#
# Epoch 6800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.656101826913085e-07
# test MSELoss: 8.222492586658821e-07
#
# Epoch 6900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.582479575106534e-07
# test MSELoss: 8.149708264681977e-07
#
# Epoch 7000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.514884771211782e-07
# test MSELoss: 8.078071914496832e-07
#
# Epoch 7100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.4401163722731e-07
# test MSELoss: 8.003670700418297e-07
#
# Epoch 7200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.371167769118529e-07
# test MSELoss: 7.929772588492294e-07
#
# Epoch 7300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.302788912796102e-07
# test MSELoss: 7.853626319350345e-07
#
# Epoch 7400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.234090310116272e-07
# test MSELoss: 7.77044476762967e-07
#
# Epoch 7500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.17033327405295e-07
# test MSELoss: 7.722237910456897e-07
#
# Epoch 7600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.106835322071054e-07
# test MSELoss: 7.653443617527955e-07
#
# Epoch 7700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 7.044501319181434e-07
# test MSELoss: 7.583789814210225e-07
#
# Epoch 7800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.981810504764967e-07
# test MSELoss: 7.501213341735517e-07
#
# Epoch 7900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.925768048185789e-07
# test MSELoss: 7.470311932896341e-07
#
# Epoch 8000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.864491241455547e-07
# test MSELoss: 7.397241840105077e-07
#
# Epoch 8100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.80540814038761e-07
# test MSELoss: 7.320186985756057e-07
#
# Epoch 8200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.747721541075694e-07
# test MSELoss: 7.243849305874998e-07
#
# Epoch 8300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.691509212451757e-07
# test MSELoss: 7.186399254048108e-07
#
# Epoch 8400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.639916851832544e-07
# test MSELoss: 7.134916018003423e-07
#
# Epoch 8500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.58720085440583e-07
# test MSELoss: 7.075200414874416e-07
#
# Epoch 8600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.535659145856207e-07
# test MSELoss: 7.022222234809306e-07
#
# Epoch 8700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.485799866657125e-07
# test MSELoss: 6.970628570949581e-07
#
# Epoch 8800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.437880140429954e-07
# test MSELoss: 6.920586732424757e-07
#
# Epoch 8900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.39374593782913e-07
# test MSELoss: 6.887051995363436e-07
#
# Epoch 9000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.342450761029911e-07
# test MSELoss: 6.820619167532034e-07
#
# Epoch 9100/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.299867239571645e-07
# test MSELoss: 6.781820009867564e-07
#
# Epoch 9200/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.257926427230118e-07
# test MSELoss: 6.731189879853143e-07
#
# Epoch 9300/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.209933650358259e-07
# test MSELoss: 6.67833387524297e-07
#
# Epoch 9400/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.174559573335172e-07
# test MSELoss: 6.647504127007172e-07
#
# Epoch 9500/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.139177686130287e-07
# test MSELoss: 6.604300779144979e-07
#
# Epoch 9600/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.087222716002754e-07
# test MSELoss: 6.553399506022591e-07
#
# Epoch 9700/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.051944753735242e-07
# test MSELoss: 6.521608611365081e-07
#
# Epoch 9800/10000, Learning rate 1e-05
# ----------
# train MSELoss: 6.022055427320953e-07
# test MSELoss: 6.481443582136611e-07
#
# Epoch 9900/10000, Learning rate 1e-05
# ----------
# train MSELoss: 5.980839439683239e-07
# test MSELoss: 6.446085194511397e-07
#
# Epoch 10000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 5.956698579540153e-07
# test MSELoss: 6.415838242901373e-07
#
# Epoch 10000/10000, Learning rate 1e-05
# ----------
# train MSELoss: 5.956698579540153e-07
# test MSELoss: 6.415838242901373e-07
#
# No early stopping: 10000th training complete in 1h 38m 31s
# ----------
# Best train MSELoss: 5.943213068348996e-07
# Best test MSELoss: 6.404321804135785e-07
#
# Saving after 10000th training to ./wave_temp/ex23_AE_6_swish_temp_seed_0.pkl
#
# checkpoint removed
#
# --------model restored--------

# %%
# delete checkpoint
try:
    os.remove(PATH)
    print()
    print("checkpoint removed")
except:
    print("no checkpoint exists") 

# release gpu memory
torch.cuda.empty_cache()

# plot train and test loss
plt.figure(figsize=(10,5))
plt.semilogy(loss_hist['train'],linestyle='dotted',linewidth=2)
plt.semilogy(loss_hist['test'],linestyle='dashdot',linewidth=2)
plt.legend(['train','test'],fontsize=24)
plt.xlabel("Epochs",fontsize=28)
plt.ylabel("MSE",fontsize=28)
# plt.show()   
plt.savefig(loss_fig_name)
# Out:
# no checkpoint exists

# %%
for i in range(len(f_list)):
    f = f_list[i] # latent dimension
    
    loss_hist_name="./wave_result/ex23_AE_"+str(f)+"_swish_loss_seed_"+str(seed)+".p"
    loss_fig_name="./wave_result/ex23_AE_"+str(f)+"_swish_loss_seed_"+str(seed)+".png"
    
    with open(loss_hist_name,'rb') as f6:
        loss_hist_name=pickle.load(f6)
    
    plt.figure(figsize=(10,5))
    plt.semilogy(loss_hist['train'],linestyle='dotted',linewidth=2)
    plt.semilogy(loss_hist['test'],linestyle='dashdot',linewidth=2)
    plt.legend(['train','test'],fontsize=24)
    plt.xlabel("Epochs",fontsize=28)
    plt.ylabel("MSE",fontsize=28)
    # plt.show()   
    plt.savefig(loss_fig_name)

# %% [markdown]
# # AE MSE loss

# %%
# training_params = np.arange(80,121,5)

# load snapshot
snapshot = np.array([])
for i in training_params:
    ex = np.load('./wave_data/ex23_interp_{}.npz'.format(i), allow_pickle = True)
    ex = ex.f.arr_0
    snapshot = np.append(snapshot, ex)
snapshot = snapshot.reshape(len(training_params)*(nt+1),-1).astype('float32')

# number of data points
ndata = snapshot.shape[0]

orig_data_u=np.copy(snapshot)

# f_list=np.array([3,4,5,6])
print("Latent Sapce Dim.: {}".format(f_list))
for i in range(len(f_list)):
    f = f_list[i] # latent dimension

    # Set file names
    file_name_AE="./wave_model/ex23_AE_"+str(f)+"_swish_seed_"+str(seed)+".p"
    print(file_name_AE)

    with open(file_name_AE,'rb') as fff:
        AE = pickle.load(fff)

    en_wu1=AE['en_wu1']
    en_bu1=AE['en_bu1']
    en_wu2=AE['en_wu2']
    de_wu1=AE['de_wu1']
    de_bu1=AE['de_bu1']
    de_wu2=AE['de_wu2']
    de_wu1T=AE['de_wu1T']
    de_wu2T=AE['de_wu2T']
    de_wu2_sp=AE['de_wu2_sp']
    de_wu2T_sp=AE['de_wu2T_sp']
    u_ref=AE['u_ref']

    latent_dim=de_wu1.shape[1]

    # numpy version of AE
    def sigmoid_np(input):
        return (1.0/(1.0+np.exp(-input))).astype('float32')

    def encoder_u_np_forward(x):
        z1 = en_wu1.dot(x) + en_bu1
        a1 = z1 * sigmoid_np(z1)
        y = en_wu2.dot(a1)   
        return y

    def decoder_u_np_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = de_wu2.dot(a1)  
        return y

    def decoder_u_sp_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(de_wu2_sp,a1)
        return y

    def decoder_u_np_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = de_wu2.dot(a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(de_wu2T)   
        return y,dydxT

    def decoder_u_sp_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(de_wu2_sp,a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,de_wu2T_sp)
        return y,dydxT

    # compute MSELoss
    comp_orig_data_u=np.zeros((ndata,f))
    rest_orig_data_u=np.zeros(orig_data_u.shape)

    for k in range(ndata):
        comp_orig_data_u[k]=encoder_u_np_forward(orig_data_u[k]-u_ref)
        rest_orig_data_u[k]=decoder_u_sp_forward(comp_orig_data_u[k]) + u_ref

    print("MSELoss of AE (rescaled): {:.8e}".format(
        np.linalg.norm(orig_data_u-rest_orig_data_u)**2/np.prod(orig_data_u.shape)))
# Out:
# Latent Sapce Dim.: [3 4 5 6]
# ./wave_model/ex23_AE_3_swish_seed_0.p
# MSELoss of AE (rescaled): 2.95186806e-05
# ./wave_model/ex23_AE_4_swish_seed_0.p
# MSELoss of AE (rescaled): 2.41810155e-06
# ./wave_model/ex23_AE_5_swish_seed_0.p
# MSELoss of AE (rescaled): 1.12464976e-06
# ./wave_model/ex23_AE_6_swish_seed_0.p
# MSELoss of AE (rescaled): 6.03525112e-07

# %% [markdown]
# # Projection Error and Residual Snapshot

# %%
f_list=np.array([3,4,5,6]); 
# seed=0
for i in range(len(f_list)):
    f = f_list[i] # latent dimension

    # Set file names
    file_name_AE="./wave_model/ex23_AE_"+str(f)+"_swish_seed_"+str(seed)+".p"
    file_path_prj_result = "./wave_result/ex23_AE_"+str(f)+"_swish_proj_result_seed_"+str(seed)+".p"
    file_path_residual="./wave_result/ex23_AE_"+str(f)+"_swish_residual_seed_"+str(seed)+".p"
    file_path_residual_SVD="./wave_model/ex23_AE_"+str(f)+"_swish_residual_SVD_seed_"+str(seed)+".p"

    print(file_name_AE)
    print(file_path_prj_result)
    print(file_path_residual)
    print(file_path_residual_SVD)
    
    with open(file_name_AE,'rb') as fff:
        AE = pickle.load(fff)

    en_wu1=AE['en_wu1']
    en_bu1=AE['en_bu1']
    en_wu2=AE['en_wu2']
    de_wu1=AE['de_wu1']
    de_bu1=AE['de_bu1']
    de_wu2=AE['de_wu2']
    de_wu1T=AE['de_wu1T']
    de_wu2T=AE['de_wu2T']
    de_wu2_sp=AE['de_wu2_sp']
    de_wu2T_sp=AE['de_wu2T_sp']
    u_ref=AE['u_ref']

    latent_dim=de_wu1.shape[1]

    # numpy version of AE
    def sigmoid_np(input):
        return (1.0/(1.0+np.exp(-input))).astype('float32')

    def encoder_u_np_forward(x):
        z1 = en_wu1.dot(x) + en_bu1
        a1 = z1 * sigmoid_np(z1)
        y = en_wu2.dot(a1)   
        return y

    def decoder_u_np_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = de_wu2.dot(a1)  
        return y

    def decoder_u_sp_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(de_wu2_sp,a1)
        return y

    def decoder_u_np_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = de_wu2.dot(a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(de_wu2T)   
        return y,dydxT

    def decoder_u_sp_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(de_wu2_sp,a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,de_wu2T_sp)
        return y,dydxT
    
    results={'avg_rel_err':[],'rel_err':[],'elapsed_time':[]}
    residual_snapshot=[]

    for FOM_parameter in training_params:
        # Load FOM solution
        ex = np.load('./wave_data/ex23_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1).astype('float32')

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_hat0=encoder_u_np_forward(u0.astype('float32')-u_ref)

        # gappyAE
        t_start_gappyAE=time.time()

        # solution
        u_reduced=np.zeros((nt+1,latent_dim))
        u_gappyAE=np.zeros((nt+1,ny*nx))

        # IC
        u_reduced[0]=np.copy(u_hat0)
        u_gappyAE[0]=np.copy(u0)

        residual=u_full[0]-(u_ref+decoder_u_sp_forward(u_hat0))
        residual_snapshot.append(residual)
        for k in range(nt):
#             print("")
#             print(k,"th time step:")

            u_hatw=np.copy(u_reduced[k])

            umw,Jg_umT=decoder_u_sp_forward_backwardT(u_hatw)

            umw += u_ref[msmt_idx]

            Jg_um_pinv=np.linalg.pinv(Jg_umT.T)

            r_um_hat = um[k+1]-umw

            res = np.linalg.norm(Jg_umT.dot(r_um_hat))
            res_hist=[res]
            residual=u_full[k+1]-(u_ref+decoder_u_sp_forward(u_hatw))
            residual_snapshot.append(residual)
            for itr in range(maxitr):
                du_hatw = Jg_um_pinv.dot(r_um_hat)

                u_hatw += du_hatw

                umw,Jg_umT=decoder_u_sp_forward_backwardT(u_hatw)

                umw += u_ref[msmt_idx]

                Jg_um_pinv=np.linalg.pinv(Jg_umT.T)

                r_um_hat = um[k+1]-umw

                res = np.linalg.norm(Jg_umT.dot(r_um_hat))
                res_hist.append(res)
                residual=u_full[k+1]-(u_ref+decoder_u_sp_forward(u_hatw))
                residual_snapshot.append(residual)
#                 print(itr,"th Newton iteration", "res:", "{:.8e}".format(np.linalg.norm(residual)))

                if res<tol:
                    break

            u_reduced[k+1]=u_hatw.copy()
            u_gappyAE[k+1]=u_ref+decoder_u_sp_forward(u_reduced[k+1])

        # elapsed time
        t_elapsed_gappyAE=time.time()-t_start_gappyAE
        print()
        print('Time elapsed: {} sec'.format(t_elapsed_gappyAE))

        # error
        u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)/np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100

        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))

        # save result
        results['avg_rel_err'].append(u_avg_rel_err)
        results['rel_err'].append(u_rel_err_gappyAE)
        results['elapsed_time'].append(t_elapsed_gappyAE)

    results['avg_rel_err']=np.array(results['avg_rel_err'])
    results['rel_err']=np.array(results['rel_err'])
    results['elapsed_time']=np.array(results['elapsed_time'])

    with open(file=file_path_prj_result, mode='wb') as ff:
        pickle.dump(results, ff)
        print(file_path_prj_result)

    residual_snapshot=np.array(residual_snapshot)    
    with open(file=file_path_residual, mode='wb') as fff:
        pickle.dump(residual_snapshot, fff)
        print(file_path_residual)

    # do svd decomposition
    U,S,VT=np.linalg.svd(residual_snapshot.T,full_matrices=False)

    SVD={'U':U,'S':S,'VT':VT}

    with open(file=file_path_residual_SVD, mode='wb') as fff:
        pickle.dump(SVD,fff)  
        print(file_path_residual_SVD)
# Out:
# ./wave_model/ex23_AE_3_swish_seed_0.p
# ./wave_result/ex23_AE_3_swish_proj_result_seed_0.p
# ./wave_result/ex23_AE_3_swish_residual_seed_0.p
# ./wave_model/ex23_AE_3_swish_residual_SVD_seed_0.p
#
# Time elapsed: 1124.4406881332397 sec
# average relative error of u: 0.9734025676035609%
# maximum relative error of u: 1.5462630464727536%
#
# Time elapsed: 1126.8728592395782 sec
# average relative error of u: 0.8973247230801262%
# maximum relative error of u: 1.4883413099022016%
#
# Time elapsed: 1123.7878165245056 sec
# average relative error of u: 0.998435825582543%
# maximum relative error of u: 2.0593685821908334%
#
# Time elapsed: 1117.6626348495483 sec
# average relative error of u: 1.210123352173332%
# maximum relative error of u: 2.882697037079826%
#
# Time elapsed: 1107.833208322525 sec
# average relative error of u: 1.4778669978556858%
# maximum relative error of u: 3.9295846827446237%
#
# Time elapsed: 1102.0142359733582 sec
# average relative error of u: 1.773182897143434%
# maximum relative error of u: 5.154358875968531%
#
# Time elapsed: 1124.3185939788818 sec
# average relative error of u: 2.0894244599417267%
# maximum relative error of u: 6.499476119827544%
#
# Time elapsed: 1128.0923354625702 sec
# average relative error of u: 2.4547955756658033%
# maximum relative error of u: 7.991014769100293%
#
# Time elapsed: 1123.0590121746063 sec
# average relative error of u: 2.8925134346508425%
# maximum relative error of u: 9.583002571686595%
# ./wave_result/ex23_AE_3_swish_proj_result_seed_0.p
# ./wave_result/ex23_AE_3_swish_residual_seed_0.p
# ./wave_model/ex23_AE_3_swish_residual_SVD_seed_0.p
# ./wave_model/ex23_AE_4_swish_seed_0.p
# ./wave_result/ex23_AE_4_swish_proj_result_seed_0.p
# ./wave_result/ex23_AE_4_swish_residual_seed_0.p
# ./wave_model/ex23_AE_4_swish_residual_SVD_seed_0.p
#
# Time elapsed: 1309.720507144928 sec
# average relative error of u: 0.6549709636747081%
# maximum relative error of u: 1.1837523085179702%
#
# Time elapsed: 1304.4186828136444 sec
# average relative error of u: 0.5683398367186916%
# maximum relative error of u: 1.023258973187151%
#
# Time elapsed: 1304.080079317093 sec
# average relative error of u: 0.5046966470212876%
# maximum relative error of u: 0.8866460385411026%
#
# Time elapsed: 1299.2595624923706 sec
# average relative error of u: 0.45570567586286037%
# maximum relative error of u: 0.7700384869858123%
#
# Time elapsed: 1302.947902917862 sec
# average relative error of u: 0.4164723436792363%
# maximum relative error of u: 0.671763676314717%
#
# Time elapsed: 1287.3155181407928 sec
# average relative error of u: 0.3861487705580964%
# maximum relative error of u: 0.6179682608147422%
#
# Time elapsed: 1284.4110887050629 sec
# average relative error of u: 0.36925427160002533%
# maximum relative error of u: 0.63051811415901%
#
# Time elapsed: 1282.285976409912 sec
# average relative error of u: 0.37749527892334905%
# maximum relative error of u: 0.7277494270263397%
#
# Time elapsed: 1279.0540924072266 sec
# average relative error of u: 0.42942403267087664%
# maximum relative error of u: 0.842704197481442%
# ./wave_result/ex23_AE_4_swish_proj_result_seed_0.p
# ./wave_result/ex23_AE_4_swish_residual_seed_0.p
# ./wave_model/ex23_AE_4_swish_residual_SVD_seed_0.p
# ./wave_model/ex23_AE_5_swish_seed_0.p
# ./wave_result/ex23_AE_5_swish_proj_result_seed_0.p
# ./wave_result/ex23_AE_5_swish_residual_seed_0.p
# ./wave_model/ex23_AE_5_swish_residual_SVD_seed_0.p
#
# Time elapsed: 1482.5695261955261 sec
# average relative error of u: 0.4732334941152724%
# maximum relative error of u: 0.8624489972251774%
#
# Time elapsed: 1482.077782869339 sec
# average relative error of u: 0.3886290748529453%
# maximum relative error of u: 0.7131048012950838%
#
# Time elapsed: 1475.586126089096 sec
# average relative error of u: 0.33286967155514846%
# maximum relative error of u: 0.5781401867708525%
#
# Time elapsed: 1455.5803763866425 sec
# average relative error of u: 0.2962335379328425%
# maximum relative error of u: 0.5095181406282243%
#
# Time elapsed: 1443.7144539356232 sec
# average relative error of u: 0.27025878414436516%
# maximum relative error of u: 0.45523497135796553%
#
# Time elapsed: 1467.2173900604248 sec
# average relative error of u: 0.24940230296985527%
# maximum relative error of u: 0.4416209060834747%
#
# Time elapsed: 1296.9924705028534 sec
# average relative error of u: 0.23464047902413215%
# maximum relative error of u: 0.45237939985340625%
#
# Time elapsed: 1078.5094363689423 sec
# average relative error of u: 0.23776537855315197%
# maximum relative error of u: 0.45697779569022956%
#
# Time elapsed: 1083.8053386211395 sec
# average relative error of u: 0.27894031233070726%
# maximum relative error of u: 0.4985802974125703%
# ./wave_result/ex23_AE_5_swish_proj_result_seed_0.p
# ./wave_result/ex23_AE_5_swish_residual_seed_0.p
# ./wave_model/ex23_AE_5_swish_residual_SVD_seed_0.p
# ./wave_model/ex23_AE_6_swish_seed_0.p
# ./wave_result/ex23_AE_6_swish_proj_result_seed_0.p
# ./wave_result/ex23_AE_6_swish_residual_seed_0.p
# ./wave_model/ex23_AE_6_swish_residual_SVD_seed_0.p
#
# Time elapsed: 1209.4693381786346 sec
# average relative error of u: 0.31549371623776%
# maximum relative error of u: 0.5766670283712902%
#
# Time elapsed: 1209.04385471344 sec
# average relative error of u: 0.27453305673988876%
# maximum relative error of u: 0.5118017308323292%
#
# Time elapsed: 1213.6710691452026 sec
# average relative error of u: 0.24818359637137008%
# maximum relative error of u: 0.4539081347431789%
#
# Time elapsed: 1076.8340103626251 sec
# average relative error of u: 0.22976249673439483%
# maximum relative error of u: 0.4017531998853779%
#
# Time elapsed: 779.101443529129 sec
# average relative error of u: 0.21491461004172754%
# maximum relative error of u: 0.3562505910425924%
#
# Time elapsed: 782.8804500102997 sec
# average relative error of u: 0.20107560865128427%
# maximum relative error of u: 0.31340691345068483%
#
# Time elapsed: 780.3919653892517 sec
# average relative error of u: 0.1885954522242381%
# maximum relative error of u: 0.2872427067455219%
#
# Time elapsed: 778.1649553775787 sec
# average relative error of u: 0.18419453456605422%
# maximum relative error of u: 0.29329227780785794%
#
# Time elapsed: 778.4438626766205 sec
# average relative error of u: 0.20447237342657051%
# maximum relative error of u: 0.34206475991022917%
# ./wave_result/ex23_AE_6_swish_proj_result_seed_0.p
# ./wave_result/ex23_AE_6_swish_residual_seed_0.p
# ./wave_model/ex23_AE_6_swish_residual_SVD_seed_0.p

# %% [markdown]
# # Plot other cases together

# %%
plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=24)     # fontsize of the axes title
plt.rc('axes', labelsize=24)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=28)  # fontsize of the figure title

linestyle=['solid','dotted','dashed','dashdot']

# %%
f_list=np.array([3,4,5,6])

plt.figure(num=1,figsize=(10,6))
plt.figure(num=2,figsize=(10,6))
for i in range(len(f_list)):
    f = f_list[i]
    file_path_prj_result = "./wave_result/ex23_AE_"+str(f)+"_swish_proj_result_seed_"+str(seed)+".p"
    with open(file=file_path_prj_result, mode='rb') as ff:
        results=pickle.load(ff)   
    plt.figure(num=1)
    plt.plot(training_params/100,results['avg_rel_err'],linestyle=linestyle[i],linewidth=4)

    plt.figure(num=2)
    plt.plot(training_params/100,results['rel_err'].max(axis=1),linestyle=linestyle[i],linewidth=4)

plt.figure(num=1)    
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list])
plt.savefig("./wave_result/ex23_AE_swish_proj_avg_rel_err_seed_"+str(seed)+".png")

plt.figure(num=2)
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list])
plt.savefig("./wave_result/ex23_AE_swish_proj_max_rel_err_seed_"+str(seed)+".png")

# %%
print(f_list)
print(training_params)
# Out:
# [3 4 5 6]
# [ 80  85  90  95 100 105 110 115 120]

# %%
# i=3; j=-1        
# f=f_list[i]
# param=training_params[j]

# file_path_prj_result = "./wave_result/ex23_AE_"+str(f)+"_swish_proj_result_seed_"+str(seed)+".p"
# with open(file=file_path_prj_result, mode='rb') as ff:
#     results=pickle.load(ff)

# u_rel_err_gappyAE=results['rel_err'][j,1:]
# plt.figure(figsize=(10,5))

# plt.plot(u_rel_err_gappyAE.flatten())
# plt.xlabel('Data Point')
# plt.ylabel('Relative Error (%)')
# plt.title('Proj. Err. Latent Space Dim.={}, Param = {}'.format(f,param))
# plt.show()

# # plot original data
# vmin=-1; vmax=1

# # AE
# plt.figure(figsize=(20,4))

# plt.subplot(1,5,1)
# plt.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[0].reshape(ny,nx),vmin=vmin,vmax=vmax)
# plt.axis('square')
# plt.title('AE @ t=0')

# plt.subplot(1,5,2)
# plt.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[int(nt/4)].reshape(ny,nx),vmin=vmin,vmax=vmax)
# plt.axis('square')
# plt.title('AE @ t={}'.format(dt*int(nt/4)))

# plt.subplot(1,5,3)
# plt.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[int(nt/4)*2].reshape(ny,nx),vmin=vmin,vmax=vmax)
# plt.axis('square')
# plt.title('AE @ t={}'.format(dt*int(nt/4)*2))

# plt.subplot(1,5,4)
# plt.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[int(nt/4)*3].reshape(ny,nx),vmin=vmin,vmax=vmax)
# plt.axis('square')
# plt.title('AE @ t={}'.format(dt*int(nt/4)*3))

# plt.subplot(1,5,5)
# plt.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[nt].reshape(ny,nx),vmin=vmin,vmax=vmax)
# plt.axis('square')
# plt.title('AE @ t={}'.format(dt*nt))

# plt.show()

# # FOM
# plt.figure(figsize=(20,4))

# plt.subplot(1,5,1)
# plt.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[0].reshape(ny,nx),vmin=vmin,vmax=vmax)
# plt.axis('square')
# plt.title('FOM @ t=0')

# plt.subplot(1,5,2)
# plt.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)].reshape(ny,nx),vmin=vmin,vmax=vmax)
# plt.axis('square')
# plt.title('FOM @ t={}'.format(dt*int(nt/4)))

# plt.subplot(1,5,3)
# plt.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*2].reshape(ny,nx),vmin=vmin,vmax=vmax)
# plt.axis('square')
# plt.title('FOM @ t={}'.format(dt*int(nt/4)*2))

# plt.subplot(1,5,4)
# plt.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*3].reshape(ny,nx),vmin=vmin,vmax=vmax)
# plt.axis('square')
# plt.title('FOM @ t={}'.format(dt*int(nt/4)*3))

# plt.subplot(1,5,5)
# plt.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[nt].reshape(ny,nx),vmin=vmin,vmax=vmax)
# plt.axis('square')
# plt.title('FOM @ t={}'.format(dt*nt))

# plt.show()
