# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle
import torch
import torch.nn as nn

# %%
# Given parameters
nx = 60
ny = 60
tf = 1.0
dt = 2.0e-3
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims = (ny,nx)

# latent space dim.
f_list=np.array([3,4,5,6])
print('Latent Sapce Dim. {}'.format(f_list))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_SOPT_result = "./diffusion_result/ex16_AE_swish_gappy_inner_SOPT_result_seed_{}.p".format(seed)
print(file_path_gappy_SOPT_result)

# Gauss-Newton params
maxitr=4
tol=1e-8

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# Latent Sapce Dim. [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]
# ./diffusion_result/ex16_AE_swish_gappy_inner_SOPT_result_seed_5.p

# %%
# S-OPT
file_path_SOPT="/home/test/pylibROM_docker/pylibROM/tests/model/ex16_AE_inner_SOPT_no_oversampling.p"
with open(file=file_path_SOPT, mode='rb') as ff:  
        msmt_idx_list = pickle.load(ff)

# %%
for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))

    # file path
    file_name_AE="./diffusion_model/ex16_AE_{}_swish_seed_{}.p".format(f,seed)
    file_path_residual_SVD="./diffusion_model/ex16_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)

    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig("./diffusion_result/ex16_AE_{}_swish_inner_SOPT_{}_samples_seed_{}.png".format(f,num_msmt,seed))
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [  61  201  416  963 1318 1891 2095 2607 2945 3111 3142 3178]
# Dim. of latent space is 4
# # of measurments: 12
# [  61  182  356  732 1766 1862 3178 3217 3401 3407 3487 3500]
# Dim. of latent space is 5
# # of measurments: 12
# [  61  199  545  726  731 1922 2158 2253 3058 3231 3390 3477]
# Dim. of latent space is 6
# # of measurments: 12
# [  61  183  430  734 1375 1807 3079 3293 3469 3502 3512 3538]

# %% [markdown]
# # gappyAE

# %%
solution=np.zeros((len(f_list),len(FOM_parameters),nt+1,nx*ny))
reduced=np.zeros((len(f_list),len(FOM_parameters),nt+1,f_list[-1]))
avg_rel_err=np.zeros((len(f_list),len(FOM_parameters)))
rel_err=np.zeros((len(f_list),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(f_list),len(FOM_parameters)))

for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))
    
    # file path
    file_name_AE="./diffusion_model/ex16_AE_{}_swish_seed_{}.p".format(f,seed)
    file_path_residual_SVD="./diffusion_model/ex16_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)
    
    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)
    
    # precompute
    with open(file=file_path_residual_SVD, mode='rb') as fff:
        SVD=pickle.load(fff)
    U=SVD['U']
    phi_r=U[:,:num_msmt]

    ZTphi_r=phi_r[msmt_idx]
    ZTphi_r_pinv=np.linalg.pinv(ZTphi_r)
    phi_rZTphi_r_pinv=phi_r.dot(ZTphi_r_pinv)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
        
    with open(file=file_name_AE, mode='rb') as ff:    
        AE = pickle.load(ff)

    en_wu1=AE['en_wu1']
    en_bu1=AE['en_bu1']
    en_wu2=AE['en_wu2']
    de_wu1=AE['de_wu1']
    de_bu1=AE['de_bu1']
    de_wu2=AE['de_wu2']
    de_wu1T=AE['de_wu1T']
    de_wu2T=AE['de_wu2T']
    de_wu2_sp=AE['de_wu2_sp']
    de_wu2T_sp=AE['de_wu2T_sp']
    u_ref=AE['u_ref']

    latent_dim=de_wu1.shape[1]
    
    # numpy version of AE
    def sigmoid_np(input):
        return (1.0/(1.0+np.exp(-input))).astype('float32')

    def encoder_u_np_forward(x):
        z1 = en_wu1.dot(x) + en_bu1
        a1 = z1 * sigmoid_np(z1)
        y = en_wu2.dot(a1)   
        return y

    def decoder_u_np_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = de_wu2.dot(a1)  
        return y

    def decoder_u_sp_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(de_wu2_sp,a1)
        return y

    def decoder_u_np_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = de_wu2.dot(a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(de_wu2T)   
        return y,dydxT

    def decoder_u_sp_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(de_wu2_sp,a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,de_wu2T_sp)
        return y,dydxT
    
    m,M2=de_wu2.shape

    class Decoder_U_FC(nn.Module):

        def __init__(self,):
            super(Decoder_U_FC, self).__init__()
            self.fc1 = nn.Linear(latent_dim,M2)
            self.fc1.weight = nn.Parameter(torch.ones(de_wu1.shape))
            self.fc1.bias = nn.Parameter(torch.ones(de_bu1.shape))
    #         self.fc1.weight = nn.Parameter(torch.tensor(de_wu1))
    #         self.fc1.bias = nn.Parameter(torch.tensor(de_bu1))

            self.fc2 = nn.Linear(M2,m,bias=False)
            self.fc2.weight = nn.Parameter(torch.ones(de_wu2.shape))
    #         self.fc2.weight = nn.Parameter(torch.tensor(de_wu2))

        def forward(self, x):
            x = self.fc1(x)
            x = self.fc2(x)
            return x

    model = Decoder_U_FC()

    x_in=torch.ones(latent_dim)
    y_out=model(x_in)

    p_hr=msmt_idx

    upstream=torch.zeros_like(y_out)
    upstream[p_hr]=1.0

    y_out.backward(upstream)

    # masks for subnet
    wu1_mask=model.fc1.weight.grad
    wu2_mask=model.fc2.weight.grad

    bu1_mask=model.fc1.bias.grad

    # subnet sparse weight
    idx1=wu1_mask.to_sparse()._indices()
    i1=idx1.numpy()[0]
    j1=idx1.numpy()[1]
    v1=de_wu1[i1,j1]
    wu1_sb_sp=sp.csr_matrix(sp.csr_matrix((v1,(i1,j1)),shape=wu1_mask.shape).toarray())

    idx2=wu2_mask.to_sparse()._indices()
    i2=idx2.numpy()[0]
    j2=idx2.numpy()[1]
    v2=de_wu2[i2,j2]
    wu2_sb_sp=sp.csr_matrix(sp.csr_matrix((v2,(i2,j2)),shape=wu2_mask.shape).toarray())

    # subnet compressed weight
    i1,j1,v1=sp.find(wu1_sb_sp)
    i1_unique,i1_inverse=np.unique(i1,return_inverse=True)
    i1_comp=np.arange(i1_unique.size)
    i1_comp=i1_comp[i1_inverse]
    j1_unique,j1_inverse=np.unique(j1,return_inverse=True)
    j1_comp=np.arange(j1_unique.size)
    j1_comp=j1_comp[j1_inverse]
    wu1_sb_comp_sp=sp.csr_matrix((v1,(i1_comp,j1_comp)),shape=(i1_unique.size,j1_unique.size))

    i2,j2,v2=sp.find(wu2_sb_sp)
    i2_unique,i2_inverse=np.unique(i2,return_inverse=True)
    i2_comp=np.arange(i2_unique.size)
    i2_comp=i2_comp[i2_inverse]
    j2_unique,j2_inverse=np.unique(j2,return_inverse=True)
    j2_comp=np.arange(j2_unique.size)
    j2_comp=j2_comp[j2_inverse]
    wu2_sb_comp_sp=sp.csr_matrix((v2,(i2_comp,j2_comp)),shape=(i2_unique.size,j2_unique.size))

    wu1_sb_comp_dense=wu1_sb_comp_sp.toarray()
    wu1_sb_comp_dense=wu1_sb_comp_dense[j2_unique]
    wu2_sb_comp_dense=wu2_sb_comp_sp.toarray()

    wu1_sb_comp_denseT=wu1_sb_comp_dense.T
    wu2_sb_comp_denseT=wu2_sb_comp_dense.T

    # subnet compressed bias
    bu1_sb_comp_dense=de_bu1[i1_unique]
    bu1_sb_comp_dense=bu1_sb_comp_dense[j2_unique]

    # Using sparse matrix
    wu2_sb_comp_sp=sp.csr_matrix(wu2_sb_comp_dense,dtype='float32')
    wu2_sb_comp_spT=sp.csr_matrix(wu2_sb_comp_denseT,dtype='float32')

    def decoder_u_sb_np_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = wu2_sb_comp_dense.dot(a1)  
        return y

    def decoder_u_sb_np_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = wu2_sb_comp_dense.dot(a1) 

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(wu2_sb_comp_denseT)
        return y,dydxT

    def decoder_u_sb_sp_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)
        return y

    def decoder_u_sb_sp_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,wu2_sb_comp_spT)
        return y,dydxT

    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('./diffusion_data/ex16_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1).astype('float32')

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_hat0=encoder_u_np_forward(u0.astype('float32')-u_ref)

        # gappyAE
        t_start_gappyAE=time.time()

        # solution
        u_reduced=np.zeros((nt+1,latent_dim))
        u_gappyAE=np.zeros((nt+1,ny*nx))

        # IC
        u_reduced[0]=np.copy(u_hat0)
        u_gappyAE[0]=np.copy(u0)

        for k in range(nt):
#             print("")
#             print(k,"th time step:")

            u_hatw=np.copy(u_reduced[k])

            umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

            umw += u_ref[msmt_idx]

            J_r=-Jg_umT.T
            J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

            r_um_hat = um[k+1]-umw

            res = np.linalg.norm(J_pinv.dot(r_um_hat))
#             res = np.linalg.norm(r_um_hat)
            res_hist=[res]
            for itr in range(maxitr):
                du_hatw = J_pinv.dot(r_um_hat)

                u_hatw -= du_hatw

                umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

                umw += u_ref[msmt_idx]

                J_r=-Jg_umT.T
                J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

                r_um_hat = um[k+1]-umw

                res = np.linalg.norm(J_pinv.dot(r_um_hat))
#                 res = np.linalg.norm(r_um_hat)
                res_hist.append(res)
#                 print(itr,"th Newton iteration", "res:", "{:.8e}".format(res))

                if res<tol:
                    break

            u_reduced[k+1]=u_hatw.copy()
            u_gappyAE[k+1]=u_ref+decoder_u_sp_forward(u_reduced[k+1])

        # elapsed time    
        t_elapsed_gappyAE=time.time()-t_start_gappyAE
        print('Time elapsed: {} sec'.format(t_elapsed_gappyAE))

        # error
        u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                         /np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
                     /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
        print()

        # save result
        solution[ii,jj]=u_gappyAE
        reduced[ii,jj,:,:f]=u_reduced
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyAE
        elapsed_time[ii,jj]=t_elapsed_gappyAE
    
results={'solution':solution,'reduced':reduced,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_SOPT_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [  61  201  416  963 1318 1891 2095 2607 2945 3111 3142 3178]
# Param is 75
# Time elapsed: 31.133631706237793 sec
# average relative error of u: 0.2013360698981051%
# maximum relative error of u: 0.46813661148407254%
#
# Param is 76
# Time elapsed: 32.136549949645996 sec
# average relative error of u: 0.15663925341321247%
# maximum relative error of u: 0.44680265356327037%
#
# Param is 77
# Time elapsed: 28.540159702301025 sec
# average relative error of u: 0.12044416315022118%
# maximum relative error of u: 0.4325313693140504%
#
# Param is 78
# Time elapsed: 31.63801074028015 sec
# average relative error of u: 0.09275474102643151%
# maximum relative error of u: 0.4217367269075448%
#
# Param is 79
# Time elapsed: 26.7994122505188 sec
# average relative error of u: 0.07344882280406241%
# maximum relative error of u: 0.4120449859081943%
#
# Param is 80
# Time elapsed: 29.000209093093872 sec
# average relative error of u: 0.06180993601457152%
# maximum relative error of u: 0.4022662465188302%
#
# Param is 81
# Time elapsed: 28.87351703643799 sec
# average relative error of u: 0.05614638323158392%
# maximum relative error of u: 0.392087202623181%
#
# Param is 82
# Time elapsed: 31.850421667099 sec
# average relative error of u: 0.054163862225276506%
# maximum relative error of u: 0.38163467333522894%
#
# Param is 83
# Time elapsed: 30.33397674560547 sec
# average relative error of u: 0.05390278297887633%
# maximum relative error of u: 0.37130138458336226%
#
# Param is 84
# Time elapsed: 30.541513204574585 sec
# average relative error of u: 0.05419595625030663%
# maximum relative error of u: 0.3615183060748473%
#
# Param is 85
# Time elapsed: 33.214869022369385 sec
# average relative error of u: 0.054521294874072083%
# maximum relative error of u: 0.3526624719077953%
#
# Param is 86
# Time elapsed: 32.74532747268677 sec
# average relative error of u: 0.05472325954860021%
# maximum relative error of u: 0.3450579522965019%
#
# Param is 87
# Time elapsed: 29.35365390777588 sec
# average relative error of u: 0.0548149748326235%
# maximum relative error of u: 0.33887794754514255%
#
# Param is 88
# Time elapsed: 26.213347911834717 sec
# average relative error of u: 0.05488986913334113%
# maximum relative error of u: 0.3342656279025857%
#
# Param is 89
# Time elapsed: 26.043686866760254 sec
# average relative error of u: 0.055067134452465326%
# maximum relative error of u: 0.33120393489171845%
#
# Param is 90
# Time elapsed: 26.71527934074402 sec
# average relative error of u: 0.05546317335322863%
# maximum relative error of u: 0.3296300347738234%
#
# Param is 91
# Time elapsed: 33.91807842254639 sec
# average relative error of u: 0.05614992845825387%
# maximum relative error of u: 0.3292917975559229%
#
# Param is 92
# Time elapsed: 30.111661434173584 sec
# average relative error of u: 0.057127407161859045%
# maximum relative error of u: 0.3298575040010578%
#
# Param is 93
# Time elapsed: 28.806079149246216 sec
# average relative error of u: 0.05830844365995946%
# maximum relative error of u: 0.330902673194914%
#
# Param is 94
# Time elapsed: 29.85849690437317 sec
# average relative error of u: 0.059534474887992836%
# maximum relative error of u: 0.3320116640647122%
#
# Param is 95
# Time elapsed: 29.956161499023438 sec
# average relative error of u: 0.060617676080670035%
# maximum relative error of u: 0.33283389082884784%
#
# Param is 96
# Time elapsed: 31.783751964569092 sec
# average relative error of u: 0.06139795658724336%
# maximum relative error of u: 0.3332418162006835%
#
# Param is 97
# Time elapsed: 28.7668399810791 sec
# average relative error of u: 0.061794179392549275%
# maximum relative error of u: 0.33339784933292066%
#
# Param is 98
# Time elapsed: 27.30887222290039 sec
# average relative error of u: 0.06184542896888591%
# maximum relative error of u: 0.3337635369067106%
#
# Param is 99
# Time elapsed: 30.46918797492981 sec
# average relative error of u: 0.061725487109074405%
# maximum relative error of u: 0.33511404886121304%
#
# Param is 100
# Time elapsed: 29.19099712371826 sec
# average relative error of u: 0.06172480965136512%
# maximum relative error of u: 0.33855161128238553%
#
# Param is 101
# Time elapsed: 30.54404878616333 sec
# average relative error of u: 0.06218233259915433%
# maximum relative error of u: 0.34537621704703786%
#
# Param is 102
# Time elapsed: 28.485273838043213 sec
# average relative error of u: 0.06336642934207486%
# maximum relative error of u: 0.35704074903360333%
#
# Param is 103
# Time elapsed: 28.99251389503479 sec
# average relative error of u: 0.065365863805001%
# maximum relative error of u: 0.3750374012541624%
#
# Param is 104
# Time elapsed: 28.23712730407715 sec
# average relative error of u: 0.06803886726250635%
# maximum relative error of u: 0.40058008359191144%
#
# Param is 105
# Time elapsed: 29.3518328666687 sec
# average relative error of u: 0.0710923879237654%
# maximum relative error of u: 0.43447084434626015%
#
# Param is 106
# Time elapsed: 31.813206672668457 sec
# average relative error of u: 0.07420252550328243%
# maximum relative error of u: 0.47645768769548535%
#
# Param is 107
# Time elapsed: 28.359811544418335 sec
# average relative error of u: 0.07714645905104012%
# maximum relative error of u: 0.5254024282792165%
#
# Param is 108
# Time elapsed: 26.506660223007202 sec
# average relative error of u: 0.07982967158289249%
# maximum relative error of u: 0.5788716945943003%
#
# Param is 109
# Time elapsed: 28.392982006072998 sec
# average relative error of u: 0.0822775908152639%
# maximum relative error of u: 0.6337497778934856%
#
# Param is 110
# Time elapsed: 29.125605821609497 sec
# average relative error of u: 0.0845901306842642%
# maximum relative error of u: 0.6863030792350666%
#
# Param is 111
# Time elapsed: 29.234529972076416 sec
# average relative error of u: 0.08687474886588765%
# maximum relative error of u: 0.732616886735198%
#
# Param is 112
# Time elapsed: 27.548171758651733 sec
# average relative error of u: 0.08918905817386974%
# maximum relative error of u: 0.7694720525736813%
#
# Param is 113
# Time elapsed: 27.09494185447693 sec
# average relative error of u: 0.0914432320947407%
# maximum relative error of u: 0.79402727547534%
#
# Param is 114
# Time elapsed: 26.6811101436615 sec
# average relative error of u: 0.09338450267926764%
# maximum relative error of u: 0.8049295994448289%
#
# Param is 115
# Time elapsed: 28.886290311813354 sec
# average relative error of u: 0.09460124981506282%
# maximum relative error of u: 0.8019393158714934%
#
# Param is 116
# Time elapsed: 30.135310649871826 sec
# average relative error of u: 0.09464829231773698%
# maximum relative error of u: 0.7865132904263142%
#
# Param is 117
# Time elapsed: 30.83384656906128 sec
# average relative error of u: 0.09330617435509266%
# maximum relative error of u: 0.7614323383278468%
#
# Param is 118
# Time elapsed: 29.8462016582489 sec
# average relative error of u: 0.09115050053800931%
# maximum relative error of u: 0.7322676078414573%
#
# Param is 119
# Time elapsed: 28.532702684402466 sec
# average relative error of u: 0.09058664693707441%
# maximum relative error of u: 0.707625234387529%
#
# Param is 120
# Time elapsed: 29.70252513885498 sec
# average relative error of u: 0.09697641164317906%
# maximum relative error of u: 0.7014592294102489%
#
# Param is 121
# Time elapsed: 29.87571406364441 sec
# average relative error of u: 0.1174472817090412%
# maximum relative error of u: 0.7321291899188144%
#
# Param is 122
# Time elapsed: 30.05982208251953 sec
# average relative error of u: 0.15666753376083206%
# maximum relative error of u: 0.8174906155415296%
#
# Param is 123
# Time elapsed: 31.42269802093506 sec
# average relative error of u: 0.21580708933754078%
# maximum relative error of u: 0.9677545155511681%
#
# Param is 124
# Time elapsed: 31.365529775619507 sec
# average relative error of u: 0.29506448162362076%
# maximum relative error of u: 1.1845935932562128%
#
# Param is 125
# Time elapsed: 32.726146936416626 sec
# average relative error of u: 0.39499899128173%
# maximum relative error of u: 1.4655290108770533%
#
# Dim. of latent space is 4
# # of measurments: 12
# [  61  182  356  732 1766 1862 3178 3217 3401 3407 3487 3500]
# Param is 75
# Time elapsed: 31.339370727539062 sec
# average relative error of u: 0.20628045636945208%
# maximum relative error of u: 0.8044571555554133%
#
# Param is 76
# Time elapsed: 28.82007622718811 sec
# average relative error of u: 0.15834411805132487%
# maximum relative error of u: 0.682443753751331%
#
# Param is 77
# Time elapsed: 33.80292820930481 sec
# average relative error of u: 0.11911914167776173%
# maximum relative error of u: 0.5796549258919719%
#
# Param is 78
# Time elapsed: 29.972318172454834 sec
# average relative error of u: 0.08883804296509284%
# maximum relative error of u: 0.4966978678387114%
#
# Param is 79
# Time elapsed: 31.254770517349243 sec
# average relative error of u: 0.06758772800160179%
# maximum relative error of u: 0.4332076204841287%
#
# Param is 80
# Time elapsed: 32.64819025993347 sec
# average relative error of u: 0.05491594507172967%
# maximum relative error of u: 0.38743529027930906%
#
# Param is 81
# Time elapsed: 28.677746772766113 sec
# average relative error of u: 0.04911290809055455%
# maximum relative error of u: 0.3564850991150455%
#
# Param is 82
# Time elapsed: 31.098381757736206 sec
# average relative error of u: 0.0473847471294894%
# maximum relative error of u: 0.3366840423906893%
#
# Param is 83
# Time elapsed: 27.914642572402954 sec
# average relative error of u: 0.04727212836830717%
# maximum relative error of u: 0.3243786421755013%
#
# Param is 84
# Time elapsed: 23.229135036468506 sec
# average relative error of u: 0.04746204979721136%
# maximum relative error of u: 0.3165708402266568%
#
# Param is 85
# Time elapsed: 21.20787024497986 sec
# average relative error of u: 0.04753109736962465%
# maximum relative error of u: 0.3112164292622372%
#
# Param is 86
# Time elapsed: 22.92527961730957 sec
# average relative error of u: 0.047477998813944274%
# maximum relative error of u: 0.3071575650502006%
#
# Param is 87
# Time elapsed: 22.23200273513794 sec
# average relative error of u: 0.047401725443314204%
# maximum relative error of u: 0.30387731254527867%
#
# Param is 88
# Time elapsed: 22.28608727455139 sec
# average relative error of u: 0.04735800860336429%
# maximum relative error of u: 0.30129286451291104%
#
# Param is 89
# Time elapsed: 22.59620761871338 sec
# average relative error of u: 0.0473407938664553%
# maximum relative error of u: 0.29951513920555467%
#
# Param is 90
# Time elapsed: 21.84394097328186 sec
# average relative error of u: 0.047332391295074216%
# maximum relative error of u: 0.29880598666353253%
#
# Param is 91
# Time elapsed: 21.51948380470276 sec
# average relative error of u: 0.04734948634042559%
# maximum relative error of u: 0.2994148550213092%
#
# Param is 92
# Time elapsed: 19.031694650650024 sec
# average relative error of u: 0.04745618717150108%
# maximum relative error of u: 0.30149687464769015%
#
# Param is 93
# Time elapsed: 19.9752094745636 sec
# average relative error of u: 0.04772810440237266%
# maximum relative error of u: 0.30487025737795176%
#
# Param is 94
# Time elapsed: 18.14969253540039 sec
# average relative error of u: 0.04820898750055919%
# maximum relative error of u: 0.3090543656667477%
#
# Param is 95
# Time elapsed: 17.770992517471313 sec
# average relative error of u: 0.04887685978795564%
# maximum relative error of u: 0.31327266610082466%
#
# Param is 96
# Time elapsed: 17.631190538406372 sec
# average relative error of u: 0.049666111679675815%
# maximum relative error of u: 0.3166211499514342%
#
# Param is 97
# Time elapsed: 18.125946044921875 sec
# average relative error of u: 0.05049832344367433%
# maximum relative error of u: 0.31843224207166326%
#
# Param is 98
# Time elapsed: 18.04491424560547 sec
# average relative error of u: 0.051321253106972005%
# maximum relative error of u: 0.3183230390449065%
#
# Param is 99
# Time elapsed: 17.27181601524353 sec
# average relative error of u: 0.05212632740898261%
# maximum relative error of u: 0.31632534997420947%
#
# Param is 100
# Time elapsed: 15.840007066726685 sec
# average relative error of u: 0.05294638441787772%
# maximum relative error of u: 0.3127942733474083%
#
# Param is 101
# Time elapsed: 15.64384412765503 sec
# average relative error of u: 0.053838430031957416%
# maximum relative error of u: 0.30839025380266694%
#
# Param is 102
# Time elapsed: 15.070544719696045 sec
# average relative error of u: 0.0548671157586054%
# maximum relative error of u: 0.3039053621730874%
#
# Param is 103
# Time elapsed: 15.096152544021606 sec
# average relative error of u: 0.056079110419277205%
# maximum relative error of u: 0.30021128522809515%
#
# Param is 104
# Time elapsed: 16.922699689865112 sec
# average relative error of u: 0.057494000235251086%
# maximum relative error of u: 0.29796157034605897%
#
# Param is 105
# Time elapsed: 17.818869829177856 sec
# average relative error of u: 0.05910244188019551%
# maximum relative error of u: 0.29774672457171464%
#
# Param is 106
# Time elapsed: 17.342410564422607 sec
# average relative error of u: 0.060872480222239664%
# maximum relative error of u: 0.2998332908702593%
#
# Param is 107
# Time elapsed: 15.906610250473022 sec
# average relative error of u: 0.06276953250803945%
# maximum relative error of u: 0.30443995003411417%
#
# Param is 108
# Time elapsed: 17.991167545318604 sec
# average relative error of u: 0.06476242304489326%
# maximum relative error of u: 0.311589721366342%
#
# Param is 109
# Time elapsed: 18.412667751312256 sec
# average relative error of u: 0.06684582307625078%
# maximum relative error of u: 0.3213594201624855%
#
# Param is 110
# Time elapsed: 18.468945264816284 sec
# average relative error of u: 0.06903067483048737%
# maximum relative error of u: 0.33382894489392656%
#
# Param is 111
# Time elapsed: 18.300514221191406 sec
# average relative error of u: 0.07132972501908208%
# maximum relative error of u: 0.3490328512931459%
#
# Param is 112
# Time elapsed: 18.13221001625061 sec
# average relative error of u: 0.07372104527969088%
# maximum relative error of u: 0.3670267993933389%
#
# Param is 113
# Time elapsed: 18.211316347122192 sec
# average relative error of u: 0.07609075834087131%
# maximum relative error of u: 0.3878417560886053%
#
# Param is 114
# Time elapsed: 17.16257905960083 sec
# average relative error of u: 0.07819261478739643%
# maximum relative error of u: 0.41162482644557546%
#
# Param is 115
# Time elapsed: 15.847079753875732 sec
# average relative error of u: 0.07966719725983512%
# maximum relative error of u: 0.43890091537673853%
#
# Param is 116
# Time elapsed: 16.850123643875122 sec
# average relative error of u: 0.08015478476177458%
# maximum relative error of u: 0.4710102714310096%
#
# Param is 117
# Time elapsed: 17.45526432991028 sec
# average relative error of u: 0.07960624958545501%
# maximum relative error of u: 0.5105114919217226%
#
# Param is 118
# Time elapsed: 16.76736569404602 sec
# average relative error of u: 0.07893304633526663%
# maximum relative error of u: 0.5615678196897427%
#
# Param is 119
# Time elapsed: 17.001970767974854 sec
# average relative error of u: 0.08109014677461016%
# maximum relative error of u: 0.629853596274873%
#
# Param is 120
# Time elapsed: 16.730864763259888 sec
# average relative error of u: 0.09166646149601532%
# maximum relative error of u: 0.7219178648495649%
#
# Param is 121
# Time elapsed: 17.057421445846558 sec
# average relative error of u: 0.11661208881247655%
# maximum relative error of u: 0.8440308773318895%
#
# Param is 122
# Time elapsed: 18.08679437637329 sec
# average relative error of u: 0.15893896717749112%
# maximum relative error of u: 1.0014172802605636%
#
# Param is 123
# Time elapsed: 17.58012628555298 sec
# average relative error of u: 0.21931495337728021%
# maximum relative error of u: 1.197551865598394%
#
# Param is 124
# Time elapsed: 17.153692722320557 sec
# average relative error of u: 0.2980782604073373%
# maximum relative error of u: 1.434680411711879%
#
# Param is 125
# Time elapsed: 18.02507209777832 sec
# average relative error of u: 0.3958777557870581%
# maximum relative error of u: 1.7139384698135383%
#
# Dim. of latent space is 5
# # of measurments: 12
# [  61  199  545  726  731 1922 2158 2253 3058 3231 3390 3477]
# Param is 75
# Time elapsed: 18.048568964004517 sec
# average relative error of u: 0.24276308859646206%
# maximum relative error of u: 0.5792192224823061%
#
# Param is 76
# Time elapsed: 17.94837474822998 sec
# average relative error of u: 0.18136487261280038%
# maximum relative error of u: 0.5136175839306771%
#
# Param is 77
# Time elapsed: 18.094538688659668 sec
# average relative error of u: 0.13183752048425423%
# maximum relative error of u: 0.46821987742712984%
#
# Param is 78
# Time elapsed: 17.528571844100952 sec
# average relative error of u: 0.09455352304596021%
# maximum relative error of u: 0.4390678301739184%
#
# Param is 79
# Time elapsed: 17.832255601882935 sec
# average relative error of u: 0.06989574190085113%
# maximum relative error of u: 0.4215313554413219%
#
# Param is 80
# Time elapsed: 17.51234531402588 sec
# average relative error of u: 0.05735426003752235%
# maximum relative error of u: 0.41139973402236585%
#
# Param is 81
# Time elapsed: 17.63256597518921 sec
# average relative error of u: 0.0537340464977531%
# maximum relative error of u: 0.405667935092801%
#
# Param is 82
# Time elapsed: 15.378921031951904 sec
# average relative error of u: 0.05416161316907387%
# maximum relative error of u: 0.4024932746037546%
#
# Param is 83
# Time elapsed: 18.08351159095764 sec
# average relative error of u: 0.05524428306148743%
# maximum relative error of u: 0.4011407978877933%
#
# Param is 84
# Time elapsed: 17.57038426399231 sec
# average relative error of u: 0.05567125234778582%
# maximum relative error of u: 0.4012485634676275%
#
# Param is 85
# Time elapsed: 18.887067794799805 sec
# average relative error of u: 0.05530405628292813%
# maximum relative error of u: 0.40272945774035873%
#
# Param is 86
# Time elapsed: 18.636182069778442 sec
# average relative error of u: 0.05446094618685585%
# maximum relative error of u: 0.40553715415613734%
#
# Param is 87
# Time elapsed: 18.104995250701904 sec
# average relative error of u: 0.053560114038003794%
# maximum relative error of u: 0.40948868167960006%
#
# Param is 88
# Time elapsed: 17.302621841430664 sec
# average relative error of u: 0.05296430992660214%
# maximum relative error of u: 0.4144268159748098%
#
# Param is 89
# Time elapsed: 16.762725114822388 sec
# average relative error of u: 0.052906140883018135%
# maximum relative error of u: 0.4199968988524514%
#
# Param is 90
# Time elapsed: 16.174152135849 sec
# average relative error of u: 0.053461193649154595%
# maximum relative error of u: 0.4260722610169865%
#
# Param is 91
# Time elapsed: 17.03870725631714 sec
# average relative error of u: 0.05455570771197475%
# maximum relative error of u: 0.43208462174241036%
#
# Param is 92
# Time elapsed: 18.52005958557129 sec
# average relative error of u: 0.056012048040169%
# maximum relative error of u: 0.43766883007260726%
#
# Param is 93
# Time elapsed: 18.62555503845215 sec
# average relative error of u: 0.05760288290114375%
# maximum relative error of u: 0.44253724369386616%
#
# Param is 94
# Time elapsed: 18.18233871459961 sec
# average relative error of u: 0.05910245604331538%
# maximum relative error of u: 0.4464935113959857%
#
# Param is 95
# Time elapsed: 17.66773509979248 sec
# average relative error of u: 0.0603316261975806%
# maximum relative error of u: 0.44980383276176494%
#
# Param is 96
# Time elapsed: 17.768868446350098 sec
# average relative error of u: 0.06118988287659012%
# maximum relative error of u: 0.4531460045384714%
#
# Param is 97
# Time elapsed: 18.355433225631714 sec
# average relative error of u: 0.06170041866279337%
# maximum relative error of u: 0.45738761229428737%
#
# Param is 98
# Time elapsed: 17.996389150619507 sec
# average relative error of u: 0.06205905576307176%
# maximum relative error of u: 0.46312048037666276%
#
# Param is 99
# Time elapsed: 17.06323790550232 sec
# average relative error of u: 0.06261220573452628%
# maximum relative error of u: 0.4708107784143224%
#
# Param is 100
# Time elapsed: 16.889756679534912 sec
# average relative error of u: 0.0637292847889306%
# maximum relative error of u: 0.48031543324226933%
#
# Param is 101
# Time elapsed: 16.907420873641968 sec
# average relative error of u: 0.06554315510192094%
# maximum relative error of u: 0.4908946607571559%
#
# Param is 102
# Time elapsed: 16.70834517478943 sec
# average relative error of u: 0.0677953449230207%
# maximum relative error of u: 0.5013794431172781%
#
# Param is 103
# Time elapsed: 16.495178937911987 sec
# average relative error of u: 0.06994199279919099%
# maximum relative error of u: 0.5104060630228304%
#
# Param is 104
# Time elapsed: 16.509814739227295 sec
# average relative error of u: 0.07144538554175658%
# maximum relative error of u: 0.5167537564967368%
#
# Param is 105
# Time elapsed: 16.57985758781433 sec
# average relative error of u: 0.07205828177673956%
# maximum relative error of u: 0.5195161835919883%
#
# Param is 106
# Time elapsed: 17.176839113235474 sec
# average relative error of u: 0.0719621609937186%
# maximum relative error of u: 0.5186009959379637%
#
# Param is 107
# Time elapsed: 17.067460775375366 sec
# average relative error of u: 0.07170603303350565%
# maximum relative error of u: 0.5144878715510819%
#
# Param is 108
# Time elapsed: 17.885257959365845 sec
# average relative error of u: 0.07198837510796208%
# maximum relative error of u: 0.5083577248778902%
#
# Param is 109
# Time elapsed: 17.890069007873535 sec
# average relative error of u: 0.07336545337344169%
# maximum relative error of u: 0.5016889889437847%
#
# Param is 110
# Time elapsed: 17.73773455619812 sec
# average relative error of u: 0.07599954857038535%
# maximum relative error of u: 0.49618103822519727%
#
# Param is 111
# Time elapsed: 18.077123403549194 sec
# average relative error of u: 0.07961041094354875%
# maximum relative error of u: 0.49332688527077667%
#
# Param is 112
# Time elapsed: 17.882177114486694 sec
# average relative error of u: 0.08357906108252862%
# maximum relative error of u: 0.49404594463954166%
#
# Param is 113
# Time elapsed: 18.147298336029053 sec
# average relative error of u: 0.08718281820360677%
# maximum relative error of u: 0.4987614451279961%
#
# Param is 114
# Time elapsed: 18.985737562179565 sec
# average relative error of u: 0.08969731746621477%
# maximum relative error of u: 0.5073870477654876%
#
# Param is 115
# Time elapsed: 18.991189002990723 sec
# average relative error of u: 0.09051801665620883%
# maximum relative error of u: 0.5194715234992239%
#
# Param is 116
# Time elapsed: 18.882909774780273 sec
# average relative error of u: 0.0892638898562912%
# maximum relative error of u: 0.5346109834216617%
#
# Param is 117
# Time elapsed: 16.67926526069641 sec
# average relative error of u: 0.08600315208125958%
# maximum relative error of u: 0.5528449368356521%
#
# Param is 118
# Time elapsed: 18.389795064926147 sec
# average relative error of u: 0.0817885718026838%
# maximum relative error of u: 0.5752316979763085%
#
# Param is 119
# Time elapsed: 18.478673934936523 sec
# average relative error of u: 0.07971520493738225%
# maximum relative error of u: 0.6045681672503279%
#
# Param is 120
# Time elapsed: 18.49437665939331 sec
# average relative error of u: 0.08595286271125864%
# maximum relative error of u: 0.6462087185973574%
#
# Param is 121
# Time elapsed: 19.41213345527649 sec
# average relative error of u: 0.10768521326681357%
# maximum relative error of u: 0.7084656128201838%
#
# Param is 122
# Time elapsed: 18.450883626937866 sec
# average relative error of u: 0.1488117174989472%
# maximum relative error of u: 0.8021835865382916%
#
# Param is 123
# Time elapsed: 19.50139808654785 sec
# average relative error of u: 0.2107950473826795%
# maximum relative error of u: 0.9388735952036091%
#
# Param is 124
# Time elapsed: 19.107032537460327 sec
# average relative error of u: 0.29555133923703325%
# maximum relative error of u: 1.1289392926438417%
#
# Param is 125
# Time elapsed: 19.370814323425293 sec
# average relative error of u: 0.4060871780334683%
# maximum relative error of u: 1.3801844111648758%
#
# Dim. of latent space is 6
# # of measurments: 12
# [  61  183  430  734 1375 1807 3079 3293 3469 3502 3512 3538]
# Param is 75
# Time elapsed: 20.288121461868286 sec
# average relative error of u: 0.21951554649763858%
# maximum relative error of u: 0.8538637544414055%
#
# Param is 76
# Time elapsed: 20.858241081237793 sec
# average relative error of u: 0.1640893504075089%
# maximum relative error of u: 0.6928642418402993%
#
# Param is 77
# Time elapsed: 20.47083830833435 sec
# average relative error of u: 0.1212499602749744%
# maximum relative error of u: 0.5827687546392364%
#
# Param is 78
# Time elapsed: 19.781192541122437 sec
# average relative error of u: 0.0909067011278519%
# maximum relative error of u: 0.5129224046452784%
#
# Param is 79
# Time elapsed: 18.034910678863525 sec
# average relative error of u: 0.07209826558998592%
# maximum relative error of u: 0.46902685329792504%
#
# Param is 80
# Time elapsed: 16.802324533462524 sec
# average relative error of u: 0.06253479205805627%
# maximum relative error of u: 0.4391408555206644%
#
# Param is 81
# Time elapsed: 16.672499895095825 sec
# average relative error of u: 0.058758511297028575%
# maximum relative error of u: 0.41557847330566017%
#
# Param is 82
# Time elapsed: 19.388606309890747 sec
# average relative error of u: 0.05762237527946402%
# maximum relative error of u: 0.3945762631353668%
#
# Param is 83
# Time elapsed: 21.32831621170044 sec
# average relative error of u: 0.057310821325947246%
# maximum relative error of u: 0.37467835216143275%
#
# Param is 84
# Time elapsed: 19.533465147018433 sec
# average relative error of u: 0.057121980215758796%
# maximum relative error of u: 0.35564885444043803%
#
# Param is 85
# Time elapsed: 19.841087102890015 sec
# average relative error of u: 0.05691697096587159%
# maximum relative error of u: 0.3376018569241773%
#
# Param is 86
# Time elapsed: 19.536700963974 sec
# average relative error of u: 0.056726380084671776%
# maximum relative error of u: 0.32074682281129197%
#
# Param is 87
# Time elapsed: 15.976904153823853 sec
# average relative error of u: 0.05658999778527705%
# maximum relative error of u: 0.30527855116862396%
#
# Param is 88
# Time elapsed: 19.529902696609497 sec
# average relative error of u: 0.05651873681831242%
# maximum relative error of u: 0.2914073409617386%
#
# Param is 89
# Time elapsed: 19.329850912094116 sec
# average relative error of u: 0.05650497674158445%
# maximum relative error of u: 0.279259586242417%
#
# Param is 90
# Time elapsed: 15.83402943611145 sec
# average relative error of u: 0.05653514221995238%
# maximum relative error of u: 0.26880021271809623%
#
# Param is 91
# Time elapsed: 16.039069652557373 sec
# average relative error of u: 0.05659184855119091%
# maximum relative error of u: 0.25966342373141715%
#
# Param is 92
# Time elapsed: 19.861029386520386 sec
# average relative error of u: 0.05662729489261163%
# maximum relative error of u: 0.2511194062520363%
#
# Param is 93
# Time elapsed: 20.173264026641846 sec
# average relative error of u: 0.0565592520465728%
# maximum relative error of u: 0.24596902051250766%
#
# Param is 94
# Time elapsed: 18.892005681991577 sec
# average relative error of u: 0.05628607017567601%
# maximum relative error of u: 0.24598177606115265%
#
# Param is 95
# Time elapsed: 18.870800495147705 sec
# average relative error of u: 0.05574681519303514%
# maximum relative error of u: 0.24502113071710527%
#
# Param is 96
# Time elapsed: 19.308346033096313 sec
# average relative error of u: 0.054976862018145715%
# maximum relative error of u: 0.23720233922759065%
#
# Param is 97
# Time elapsed: 19.975757360458374 sec
# average relative error of u: 0.05414721495475846%
# maximum relative error of u: 0.22587875767359683%
#
# Param is 98
# Time elapsed: 20.01571488380432 sec
# average relative error of u: 0.05351167965785128%
# maximum relative error of u: 0.2375882999589509%
#
# Param is 99
# Time elapsed: 19.68715476989746 sec
# average relative error of u: 0.053289331156495236%
# maximum relative error of u: 0.25114686813535053%
#
# Param is 100
# Time elapsed: 19.143911123275757 sec
# average relative error of u: 0.05354668932737377%
# maximum relative error of u: 0.259381632841146%
#
# Param is 101
# Time elapsed: 18.48319721221924 sec
# average relative error of u: 0.054236796692773634%
# maximum relative error of u: 0.25894733950920523%
#
# Param is 102
# Time elapsed: 18.59296226501465 sec
# average relative error of u: 0.055293388175630905%
# maximum relative error of u: 0.25191135837808976%
#
# Param is 103
# Time elapsed: 18.540488481521606 sec
# average relative error of u: 0.05666495623007749%
# maximum relative error of u: 0.2439554820839952%
#
# Param is 104
# Time elapsed: 17.35376214981079 sec
# average relative error of u: 0.058255317375924674%
# maximum relative error of u: 0.24067678817973323%
#
# Param is 105
# Time elapsed: 18.27413272857666 sec
# average relative error of u: 0.05985717141162121%
# maximum relative error of u: 0.24501492311088546%
#
# Param is 106
# Time elapsed: 18.703128814697266 sec
# average relative error of u: 0.06123360772167344%
# maximum relative error of u: 0.2565394556656352%
#
# Param is 107
# Time elapsed: 19.052303552627563 sec
# average relative error of u: 0.06215383073045409%
# maximum relative error of u: 0.27302032495201545%
#
# Param is 108
# Time elapsed: 18.65782117843628 sec
# average relative error of u: 0.06250812288084676%
# maximum relative error of u: 0.2922348676730204%
#
# Param is 109
# Time elapsed: 18.947391510009766 sec
# average relative error of u: 0.062340535941370415%
# maximum relative error of u: 0.3126733857910048%
#
# Param is 110
# Time elapsed: 18.617061376571655 sec
# average relative error of u: 0.06186408519890225%
# maximum relative error of u: 0.33377285749091035%
#
# Param is 111
# Time elapsed: 19.88871431350708 sec
# average relative error of u: 0.06144964581292269%
# maximum relative error of u: 0.35549683321505615%
#
# Param is 112
# Time elapsed: 19.17640709877014 sec
# average relative error of u: 0.06155037877263651%
# maximum relative error of u: 0.37826830971689634%
#
# Param is 113
# Time elapsed: 19.040011644363403 sec
# average relative error of u: 0.06255924615792798%
# maximum relative error of u: 0.4025377417055186%
#
# Param is 114
# Time elapsed: 18.750007152557373 sec
# average relative error of u: 0.06460587169286808%
# maximum relative error of u: 0.4287878954088953%
#
# Param is 115
# Time elapsed: 19.10362982749939 sec
# average relative error of u: 0.06742084879645588%
# maximum relative error of u: 0.45729155967290475%
#
# Param is 116
# Time elapsed: 18.70103406906128 sec
# average relative error of u: 0.07037693725969366%
# maximum relative error of u: 0.48833360239714224%
#
# Param is 117
# Time elapsed: 17.12917995452881 sec
# average relative error of u: 0.07278240169378022%
# maximum relative error of u: 0.522485870974157%
#
# Param is 118
# Time elapsed: 17.061755895614624 sec
# average relative error of u: 0.07448210361508358%
# maximum relative error of u: 0.5612559897102848%
#
# Param is 119
# Time elapsed: 15.055920124053955 sec
# average relative error of u: 0.07701072605397506%
# maximum relative error of u: 0.6077474909957137%
#
# Param is 120
# Time elapsed: 14.951149463653564 sec
# average relative error of u: 0.08515626441526537%
# maximum relative error of u: 0.6677374186021825%
#
# Param is 121
# Time elapsed: 14.418212413787842 sec
# average relative error of u: 0.10661354906858493%
# maximum relative error of u: 0.7499628131349778%
#
# Param is 122
# Time elapsed: 14.139355182647705 sec
# average relative error of u: 0.1476730746608635%
# maximum relative error of u: 0.8654176837989855%
#
# Param is 123
# Time elapsed: 14.173401355743408 sec
# average relative error of u: 0.21104900193398804%
# maximum relative error of u: 1.0256176794481364%
#
# Param is 124
# Time elapsed: 14.10364294052124 sec
# average relative error of u: 0.2980138263835115%
# maximum relative error of u: 1.2407789326378926%
#
# Param is 125
# Time elapsed: 14.361625909805298 sec
# average relative error of u: 0.40987536333090857%
# maximum relative error of u: 1.5187491772322075%

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

idx=[0,1,2,3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./diffusion_result/ex16_AE_inner_SOPT_avg_rel_err_seed_{}.png".format(seed))

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./diffusion_result/ex16_AE_inner_SOPT_max_rel_err_seed_{}.png".format(seed))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

idx = [3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
plt.show()

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
plt.show()

# %%
print(f_list)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=3; j=-1        
f=f_list[i]
param=FOM_parameters[j]

u_gappyAE=results['solution'][i,j]

ex = np.load('./diffusion_data/ex16_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("Latent Dim: {}, Param: {}".format(f,param))
plt.show()

# error
u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                 /np.linalg.norm(u_full,ord=2,axis=1)*100
u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
             /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
print("average relative error of u: {}%".format(u_avg_rel_err))
print()
print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
    
# plot original data
vmin=0; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy AE @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./diffusion_result/ex16_AE_{}_inner_SOPT_SOL_seed_{}.png".format(f,seed))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./diffusion_result/ex16_ground_truth.png")
# Out:
# average relative error of u: 0.40987536333090857%
#
# maximum relative error of u: 1.5187491772322075%

# %%
i=3; j=-1
f=f_list[i]; param=FOM_parameters[j]
print("f={}".format(f))
print("param={}".format(param))
plt.plot(results['reduced'][i,j][:,:f])
plt.legend(np.arange(f))
plt.show()
# Out:
# f=6
# param=125
