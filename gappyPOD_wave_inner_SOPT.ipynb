# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle

# %%
# Given parameters
nx = 60
ny = 60
tf = 5.0
dt = 1.0e-2
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims=(nx,ny)

# POD basis
num_basis=np.array([3,4,5,6])
print('num_basis {}'.format(num_basis))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_SOPT_result = "./wave_result/ex23_POD_inner_SOPT_gappy_result.p"
file_name_SVD="./wave_model/ex23_SVD.p"

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# num_basis [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %%
file_path_SOPT="/home/test/pylibROM_docker/pylibROM/tests/model/ex23_POD_inner_SOPT_oversampling.p"
with open(file=file_path_SOPT, mode='rb') as ff:  
        msmt_idx_list = pickle.load(ff)
        
for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    
    # S-OPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.savefig("./wave_result/ex23_POD_{}_inner_SOPT_{}_samples.png".format(POD_basis,num_msmt))
# Out:
# # of measurments: 12
# [ 118 1236 1592 1709 1711 1769 1770 1829 1830 1831 1888 1891]
# # of measurments: 12
# [  74   86  118  210  879  941 1592 1678 1831 2038 2218 2638]
# # of measurments: 12
# [  79   80  118  259  641  824 1243 1592 1831 1911 2458 2638]
# # of measurments: 12
# [  77   79   85  118  526 1231 1592 1666 1831 1851 2633 2638]

# %% [markdown]
# # gappyPOD

# %%
solution=np.zeros((len(num_basis),len(FOM_parameters),nt+1,nx*ny))
avg_rel_err=np.zeros((len(num_basis),len(FOM_parameters)))
rel_err=np.zeros((len(num_basis),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(num_basis),len(FOM_parameters)))

with open(file=file_name_SVD, mode='rb') as ff:  
    SVD = pickle.load(ff)

for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    print("# of POD basis is {}".format(POD_basis))
    
    # SOPT
    msmt_idx=msmt_idx_list[ii]
    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.show()
    
    # Basis matrix
    phi_u = SVD['U'][:,:POD_basis]

    phim_u=phi_u[msmt_idx]
    phim_u_pinv=np.linalg.pinv(phim_u)
    
    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('./wave_data/ex23_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1)

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_ref = u0

        # Gappy POD
        t_start_gappyPOD=time.time()

        # solution
        u_gappyPOD=np.zeros((nt+1,ny*nx))
        u_hat=np.zeros((nt+1,POD_basis))

        # IC
        u_hat0=np.zeros(POD_basis)
        u_gappyPOD[0]=np.copy(u0)

        for n in range(nt):
            u_hat[n+1] = phim_u_pinv.dot(um[n+1]-u_ref[msmt_idx])
            u_gappyPOD[n+1] = u_ref + phi_u.dot(u_hat[n+1])

        # elapsed time
        t_elapsed_gappyPOD=time.time()-t_start_gappyPOD
        print('Time elapsed: {} sec'.format(t_elapsed_gappyPOD))

        # error
        u_rel_err_gappyPOD=np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)/np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyPOD)))
        print()

        # save result
        solution[ii,jj]=u_gappyPOD
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyPOD
        elapsed_time[ii,jj]=t_elapsed_gappyPOD
    
results={'solution':solution,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_SOPT_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# # of POD basis is 3
# # of measurments: 12
# [ 118 1236 1592 1709 1711 1769 1770 1829 1830 1831 1888 1891]
# Param is 75
# Time elapsed: 1.314871072769165 sec
# average relative error of u: 7.500188085180505%
# maximum relative error of u: 16.36155991053116%
#
# Param is 76
# Time elapsed: 1.385538101196289 sec
# average relative error of u: 7.079409048318129%
# maximum relative error of u: 15.920867490815024%
#
# Param is 77
# Time elapsed: 1.5277342796325684 sec
# average relative error of u: 6.713092677543169%
# maximum relative error of u: 15.53297102209159%
#
# Param is 78
# Time elapsed: 1.7142689228057861 sec
# average relative error of u: 6.4139875187203%
# maximum relative error of u: 15.203765458012764%
#
# Param is 79
# Time elapsed: 1.6803250312805176 sec
# average relative error of u: 6.196210010137835%
# maximum relative error of u: 14.941991444097798%
#
# Param is 80
# Time elapsed: 1.4923591613769531 sec
# average relative error of u: 6.07229998400478%
# maximum relative error of u: 14.755000119300934%
#
# Param is 81
# Time elapsed: 1.598602533340454 sec
# average relative error of u: 6.052320712080089%
# maximum relative error of u: 14.650144610890498%
#
# Param is 82
# Time elapsed: 1.5979535579681396 sec
# average relative error of u: 6.1403332966194%
# maximum relative error of u: 14.630714090145966%
#
# Param is 83
# Time elapsed: 1.8304908275604248 sec
# average relative error of u: 6.335398491709185%
# maximum relative error of u: 14.70182338017389%
#
# Param is 84
# Time elapsed: 1.715444564819336 sec
# average relative error of u: 6.631299522847376%
# maximum relative error of u: 14.865514665940852%
#
# Param is 85
# Time elapsed: 1.6723992824554443 sec
# average relative error of u: 7.017907343196733%
# maximum relative error of u: 15.12124516201981%
#
# Param is 86
# Time elapsed: 1.4877357482910156 sec
# average relative error of u: 7.4837487518794195%
# maximum relative error of u: 15.467493992004682%
#
# Param is 87
# Time elapsed: 1.5516676902770996 sec
# average relative error of u: 8.017251707733726%
# maximum relative error of u: 15.901599348236372%
#
# Param is 88
# Time elapsed: 1.4840483665466309 sec
# average relative error of u: 8.607701785295873%
# maximum relative error of u: 17.134483716246464%
#
# Param is 89
# Time elapsed: 1.560173511505127 sec
# average relative error of u: 9.246037949279234%
# maximum relative error of u: 18.516930459301616%
#
# Param is 90
# Time elapsed: 1.5842790603637695 sec
# average relative error of u: 9.924427157581263%
# maximum relative error of u: 19.968388504104222%
#
# Param is 91
# Time elapsed: 1.5666592121124268 sec
# average relative error of u: 10.636636019435839%
# maximum relative error of u: 21.472523084093453%
#
# Param is 92
# Time elapsed: 1.7152502536773682 sec
# average relative error of u: 11.377405324276019%
# maximum relative error of u: 23.021564823338597%
#
# Param is 93
# Time elapsed: 1.6325547695159912 sec
# average relative error of u: 12.142666263364976%
# maximum relative error of u: 24.61290402391072%
#
# Param is 94
# Time elapsed: 1.6444902420043945 sec
# average relative error of u: 12.928808816024%
# maximum relative error of u: 26.239263216770652%
#
# Param is 95
# Time elapsed: 1.6879005432128906 sec
# average relative error of u: 13.733001027178604%
# maximum relative error of u: 27.89687962391691%
#
# Param is 96
# Time elapsed: 1.593839406967163 sec
# average relative error of u: 14.553213521510258%
# maximum relative error of u: 29.584462282291813%
#
# Param is 97
# Time elapsed: 2.1523361206054688 sec
# average relative error of u: 15.387043432183159%
# maximum relative error of u: 31.29717176192693%
#
# Param is 98
# Time elapsed: 2.26203989982605 sec
# average relative error of u: 16.23318144776095%
# maximum relative error of u: 33.0346134159983%
#
# Param is 99
# Time elapsed: 2.217325210571289 sec
# average relative error of u: 17.09018870282643%
# maximum relative error of u: 34.79416578041402%
#
# Param is 100
# Time elapsed: 2.1627237796783447 sec
# average relative error of u: 17.956884087078418%
# maximum relative error of u: 36.574367562777475%
#
# Param is 101
# Time elapsed: 1.9407377243041992 sec
# average relative error of u: 18.832000958031934%
# maximum relative error of u: 38.37279644488891%
#
# Param is 102
# Time elapsed: 1.9195988178253174 sec
# average relative error of u: 19.714915324567787%
# maximum relative error of u: 40.18830798726396%
#
# Param is 103
# Time elapsed: 1.8009135723114014 sec
# average relative error of u: 20.60494280575631%
# maximum relative error of u: 42.02158140546188%
#
# Param is 104
# Time elapsed: 1.7573120594024658 sec
# average relative error of u: 21.500997702986453%
# maximum relative error of u: 43.86903061414745%
#
# Param is 105
# Time elapsed: 1.7092022895812988 sec
# average relative error of u: 22.40269414156934%
# maximum relative error of u: 45.73065167759338%
#
# Param is 106
# Time elapsed: 1.586012840270996 sec
# average relative error of u: 23.309537821649222%
# maximum relative error of u: 47.60635021390453%
#
# Param is 107
# Time elapsed: 1.6381969451904297 sec
# average relative error of u: 24.220892426295492%
# maximum relative error of u: 49.49479088198475%
#
# Param is 108
# Time elapsed: 1.6557114124298096 sec
# average relative error of u: 25.13629185836136%
# maximum relative error of u: 51.39459252822833%
#
# Param is 109
# Time elapsed: 1.7206125259399414 sec
# average relative error of u: 26.055441104403364%
# maximum relative error of u: 53.30521142661482%
#
# Param is 110
# Time elapsed: 1.8477451801300049 sec
# average relative error of u: 26.977763564467576%
# maximum relative error of u: 55.22634159322425%
#
# Param is 111
# Time elapsed: 1.7989437580108643 sec
# average relative error of u: 27.903068902594686%
# maximum relative error of u: 57.15639881443857%
#
# Param is 112
# Time elapsed: 1.6429271697998047 sec
# average relative error of u: 28.830740102323237%
# maximum relative error of u: 59.09576872955359%
#
# Param is 113
# Time elapsed: 1.6032352447509766 sec
# average relative error of u: 29.760940409491752%
# maximum relative error of u: 61.04333535857266%
#
# Param is 114
# Time elapsed: 1.68587064743042 sec
# average relative error of u: 30.69283713147715%
# maximum relative error of u: 62.99823209175327%
#
# Param is 115
# Time elapsed: 1.6120288372039795 sec
# average relative error of u: 31.626415600111507%
# maximum relative error of u: 64.96019943856535%
#
# Param is 116
# Time elapsed: 1.7754464149475098 sec
# average relative error of u: 32.56143381395862%
# maximum relative error of u: 66.9288468664635%
#
# Param is 117
# Time elapsed: 1.5499529838562012 sec
# average relative error of u: 33.497674800234314%
# maximum relative error of u: 68.9034943885541%
#
# Param is 118
# Time elapsed: 1.7381980419158936 sec
# average relative error of u: 34.4347411646353%
# maximum relative error of u: 70.8828992773969%
#
# Param is 119
# Time elapsed: 1.6052517890930176 sec
# average relative error of u: 35.372306758652385%
# maximum relative error of u: 72.86701811438073%
#
# Param is 120
# Time elapsed: 1.429027795791626 sec
# average relative error of u: 36.310470189031534%
# maximum relative error of u: 74.85605045238081%
#
# Param is 121
# Time elapsed: 1.7651114463806152 sec
# average relative error of u: 37.24894165296867%
# maximum relative error of u: 76.84889638050039%
#
# Param is 122
# Time elapsed: 1.7973370552062988 sec
# average relative error of u: 38.18752495758858%
# maximum relative error of u: 78.84483605874061%
#
# Param is 123
# Time elapsed: 1.7385759353637695 sec
# average relative error of u: 39.12602446986446%
# maximum relative error of u: 80.84360956695728%
#
# Param is 124
# Time elapsed: 1.7671144008636475 sec
# average relative error of u: 40.06407035719957%
# maximum relative error of u: 82.84529895682185%
#
# Param is 125
# Time elapsed: 1.7829136848449707 sec
# average relative error of u: 41.001899081571835%
# maximum relative error of u: 84.84892712307021%
#
# # of POD basis is 4
# # of measurments: 12
# [  74   86  118  210  879  941 1592 1678 1831 2038 2218 2638]
# Param is 75
# Time elapsed: 1.4443550109863281 sec
# average relative error of u: 3.85976497393202%
# maximum relative error of u: 5.264264166090089%
#
# Param is 76
# Time elapsed: 1.543219804763794 sec
# average relative error of u: 3.7663633033822945%
# maximum relative error of u: 5.136395042302852%
#
# Param is 77
# Time elapsed: 1.643366813659668 sec
# average relative error of u: 3.6785391669553054%
# maximum relative error of u: 5.0264900603812865%
#
# Param is 78
# Time elapsed: 1.5849130153656006 sec
# average relative error of u: 3.597352137561512%
# maximum relative error of u: 4.924049354533214%
#
# Param is 79
# Time elapsed: 1.5216505527496338 sec
# average relative error of u: 3.524038711414738%
# maximum relative error of u: 4.830421044855364%
#
# Param is 80
# Time elapsed: 1.5378096103668213 sec
# average relative error of u: 3.45977920427775%
# maximum relative error of u: 4.746922010732065%
#
# Param is 81
# Time elapsed: 1.4918649196624756 sec
# average relative error of u: 3.4058264168674843%
# maximum relative error of u: 4.674954236301643%
#
# Param is 82
# Time elapsed: 1.6489999294281006 sec
# average relative error of u: 3.363384538372955%
# maximum relative error of u: 4.615829190598479%
#
# Param is 83
# Time elapsed: 1.60074782371521 sec
# average relative error of u: 3.333645956380941%
# maximum relative error of u: 4.570962241150748%
#
# Param is 84
# Time elapsed: 1.6929931640625 sec
# average relative error of u: 3.3176486847624584%
# maximum relative error of u: 4.54159105338882%
#
# Param is 85
# Time elapsed: 1.5922667980194092 sec
# average relative error of u: 3.316289436884839%
# maximum relative error of u: 4.547891526142097%
#
# Param is 86
# Time elapsed: 1.4293749332427979 sec
# average relative error of u: 3.3303076176684496%
# maximum relative error of u: 4.6409758903925455%
#
# Param is 87
# Time elapsed: 1.5311400890350342 sec
# average relative error of u: 3.3601545106925266%
# maximum relative error of u: 4.794979107784987%
#
# Param is 88
# Time elapsed: 1.8124520778656006 sec
# average relative error of u: 3.4061051264587867%
# maximum relative error of u: 4.98904603451251%
#
# Param is 89
# Time elapsed: 1.7481870651245117 sec
# average relative error of u: 3.4680934319319157%
# maximum relative error of u: 5.235202973796997%
#
# Param is 90
# Time elapsed: 1.8657512664794922 sec
# average relative error of u: 3.545931295788319%
# maximum relative error of u: 5.522012716792876%
#
# Param is 91
# Time elapsed: 1.6956853866577148 sec
# average relative error of u: 3.6391567577515755%
# maximum relative error of u: 5.8421073003019455%
#
# Param is 92
# Time elapsed: 1.7226715087890625 sec
# average relative error of u: 3.747161265084094%
# maximum relative error of u: 6.197070447447365%
#
# Param is 93
# Time elapsed: 1.8667995929718018 sec
# average relative error of u: 3.8692112051368284%
# maximum relative error of u: 6.575533862085789%
#
# Param is 94
# Time elapsed: 2.0708703994750977 sec
# average relative error of u: 4.00452726218742%
# maximum relative error of u: 6.98129530218459%
#
# Param is 95
# Time elapsed: 2.054582357406616 sec
# average relative error of u: 4.152277166205377%
# maximum relative error of u: 7.404802466870949%
#
# Param is 96
# Time elapsed: 2.095437526702881 sec
# average relative error of u: 4.311589173715406%
# maximum relative error of u: 7.847594535852929%
#
# Param is 97
# Time elapsed: 2.1512956619262695 sec
# average relative error of u: 4.4816276241824635%
# maximum relative error of u: 8.308836168994544%
#
# Param is 98
# Time elapsed: 2.2766098976135254 sec
# average relative error of u: 4.661611402000701%
# maximum relative error of u: 8.783695569866316%
#
# Param is 99
# Time elapsed: 2.1225149631500244 sec
# average relative error of u: 4.850755203747208%
# maximum relative error of u: 9.271194437915712%
#
# Param is 100
# Time elapsed: 1.898834466934204 sec
# average relative error of u: 5.04837473169436%
# maximum relative error of u: 9.770527028922903%
#
# Param is 101
# Time elapsed: 1.9506044387817383 sec
# average relative error of u: 5.253799903390079%
# maximum relative error of u: 10.280961864989766%
#
# Param is 102
# Time elapsed: 1.8785440921783447 sec
# average relative error of u: 5.466454138834992%
# maximum relative error of u: 10.805522923786615%
#
# Param is 103
# Time elapsed: 1.8131890296936035 sec
# average relative error of u: 5.685738459473067%
# maximum relative error of u: 11.339752472944433%
#
# Param is 104
# Time elapsed: 1.8050153255462646 sec
# average relative error of u: 5.911184479712557%
# maximum relative error of u: 11.88316815511483%
#
# Param is 105
# Time elapsed: 1.8629331588745117 sec
# average relative error of u: 6.142322925419301%
# maximum relative error of u: 12.435263429812778%
#
# Param is 106
# Time elapsed: 1.7974090576171875 sec
# average relative error of u: 6.3787494387856745%
# maximum relative error of u: 12.995689616451775%
#
# Param is 107
# Time elapsed: 2.125405788421631 sec
# average relative error of u: 6.620076290361082%
# maximum relative error of u: 13.56401397666443%
#
# Param is 108
# Time elapsed: 2.3071370124816895 sec
# average relative error of u: 6.865982348191271%
# maximum relative error of u: 14.139924465316255%
#
# Param is 109
# Time elapsed: 2.048105001449585 sec
# average relative error of u: 7.1161157107522595%
# maximum relative error of u: 14.723037633194592%
#
# Param is 110
# Time elapsed: 1.924736738204956 sec
# average relative error of u: 7.370226616605169%
# maximum relative error of u: 15.313052827274012%
#
# Param is 111
# Time elapsed: 1.8549764156341553 sec
# average relative error of u: 7.628046629462331%
# maximum relative error of u: 15.909711141335459%
#
# Param is 112
# Time elapsed: 2.562861204147339 sec
# average relative error of u: 7.889324894784523%
# maximum relative error of u: 16.512684178424447%
#
# Param is 113
# Time elapsed: 1.755401372909546 sec
# average relative error of u: 8.153849830670925%
# maximum relative error of u: 17.121753054288103%
#
# Param is 114
# Time elapsed: 2.2118823528289795 sec
# average relative error of u: 8.421422636560646%
# maximum relative error of u: 17.736645299068424%
#
# Param is 115
# Time elapsed: 1.2006299495697021 sec
# average relative error of u: 8.691844992308734%
# maximum relative error of u: 18.357128201884798%
#
# Param is 116
# Time elapsed: 1.166395664215088 sec
# average relative error of u: 8.964969461117231%
# maximum relative error of u: 18.98295121632749%
#
# Param is 117
# Time elapsed: 1.0421934127807617 sec
# average relative error of u: 9.240610651706707%
# maximum relative error of u: 19.61391220881285%
#
# Param is 118
# Time elapsed: 5.210256814956665 sec
# average relative error of u: 9.518644913903824%
# maximum relative error of u: 20.24977783217428%
#
# Param is 119
# Time elapsed: 4.235302925109863 sec
# average relative error of u: 9.798919262578918%
# maximum relative error of u: 20.890363049119255%
#
# Param is 120
# Time elapsed: 1.674457311630249 sec
# average relative error of u: 10.081312148328285%
# maximum relative error of u: 21.53543724200938%
#
# Param is 121
# Time elapsed: 1.7039885520935059 sec
# average relative error of u: 10.365684610341237%
# maximum relative error of u: 22.18478507316039%
#
# Param is 122
# Time elapsed: 1.4713993072509766 sec
# average relative error of u: 10.651961686993268%
# maximum relative error of u: 22.838268653924185%
#
# Param is 123
# Time elapsed: 6.14585280418396 sec
# average relative error of u: 10.939994502964053%
# maximum relative error of u: 23.495638273179004%
#
# Param is 124
# Time elapsed: 1.5844459533691406 sec
# average relative error of u: 11.22970865034163%
# maximum relative error of u: 24.15675843782131%
#
# Param is 125
# Time elapsed: 1.339967966079712 sec
# average relative error of u: 11.521001749925048%
# maximum relative error of u: 24.821404814056297%
#
# # of POD basis is 5
# # of measurments: 12
# [  79   80  118  259  641  824 1243 1592 1831 1911 2458 2638]
# Param is 75
# Time elapsed: 1.4667329788208008 sec
# average relative error of u: 3.232989539426575%
# maximum relative error of u: 5.000228061416459%
#
# Param is 76
# Time elapsed: 1.361600399017334 sec
# average relative error of u: 3.187272916876263%
# maximum relative error of u: 4.9361194165055995%
#
# Param is 77
# Time elapsed: 1.2526545524597168 sec
# average relative error of u: 3.141658618360547%
# maximum relative error of u: 4.87233636699357%
#
# Param is 78
# Time elapsed: 11.17755651473999 sec
# average relative error of u: 3.096182871438734%
# maximum relative error of u: 4.808943025885825%
#
# Param is 79
# Time elapsed: 2.599457263946533 sec
# average relative error of u: 3.0509596038676166%
# maximum relative error of u: 4.7460663947155695%
#
# Param is 80
# Time elapsed: 1.2696757316589355 sec
# average relative error of u: 3.005983573017347%
# maximum relative error of u: 4.6838576143498365%
#
# Param is 81
# Time elapsed: 1.3945331573486328 sec
# average relative error of u: 2.961357677512145%
# maximum relative error of u: 4.622449610999301%
#
# Param is 82
# Time elapsed: 1.235846996307373 sec
# average relative error of u: 2.9171154266564905%
# maximum relative error of u: 4.561862011298369%
#
# Param is 83
# Time elapsed: 2.621129274368286 sec
# average relative error of u: 2.8733415243549225%
# maximum relative error of u: 4.502406972410559%
#
# Param is 84
# Time elapsed: 6.009348392486572 sec
# average relative error of u: 2.830056451541033%
# maximum relative error of u: 4.443928137069178%
#
# Param is 85
# Time elapsed: 7.496957540512085 sec
# average relative error of u: 2.7873397547189103%
# maximum relative error of u: 4.38680232536389%
#
# Param is 86
# Time elapsed: 1.248311996459961 sec
# average relative error of u: 2.745282602352991%
# maximum relative error of u: 4.331176458845092%
#
# Param is 87
# Time elapsed: 1.880488634109497 sec
# average relative error of u: 2.703879630717919%
# maximum relative error of u: 4.276862533747875%
#
# Param is 88
# Time elapsed: 11.31805419921875 sec
# average relative error of u: 2.663227945292159%
# maximum relative error of u: 4.224196073343465%
#
# Param is 89
# Time elapsed: 1.5394086837768555 sec
# average relative error of u: 2.623392063963501%
# maximum relative error of u: 4.173380717477369%
#
# Param is 90
# Time elapsed: 1.6570441722869873 sec
# average relative error of u: 2.5844163382045515%
# maximum relative error of u: 4.124378905247235%
#
# Param is 91
# Time elapsed: 2.093876600265503 sec
# average relative error of u: 2.546383717156381%
# maximum relative error of u: 4.077414189334585%
#
# Param is 92
# Time elapsed: 6.120266675949097 sec
# average relative error of u: 2.5093369083769628%
# maximum relative error of u: 4.032537127093027%
#
# Param is 93
# Time elapsed: 22.55582571029663 sec
# average relative error of u: 2.4733452657702233%
# maximum relative error of u: 3.9899704221422874%
#
# Param is 94
# Time elapsed: 2.042381525039673 sec
# average relative error of u: 2.43847510933773%
# maximum relative error of u: 3.949792631547889%
#
# Param is 95
# Time elapsed: 1.4394760131835938 sec
# average relative error of u: 2.404847164565044%
# maximum relative error of u: 3.912269160661376%
#
# Param is 96
# Time elapsed: 4.167724609375 sec
# average relative error of u: 2.3724795937444134%
# maximum relative error of u: 3.8772888068257427%
#
# Param is 97
# Time elapsed: 1.3894355297088623 sec
# average relative error of u: 2.3414821431361164%
# maximum relative error of u: 3.8453216838649893%
#
# Param is 98
# Time elapsed: 1.34725022315979 sec
# average relative error of u: 2.311925420904597%
# maximum relative error of u: 3.816264828903128%
#
# Param is 99
# Time elapsed: 11.394187927246094 sec
# average relative error of u: 2.2838908741272625%
# maximum relative error of u: 3.790393725078831%
#
# Param is 100
# Time elapsed: 1.7725605964660645 sec
# average relative error of u: 2.257457231126545%
# maximum relative error of u: 3.767817028381241%
#
# Param is 101
# Time elapsed: 1.6738195419311523 sec
# average relative error of u: 2.2327508388705564%
# maximum relative error of u: 3.7486817556927363%
#
# Param is 102
# Time elapsed: 1.5015926361083984 sec
# average relative error of u: 2.2098188634967175%
# maximum relative error of u: 3.7330945497742385%
#
# Param is 103
# Time elapsed: 1.6081039905548096 sec
# average relative error of u: 2.188817275203625%
# maximum relative error of u: 3.7214423172748936%
#
# Param is 104
# Time elapsed: 1.4406559467315674 sec
# average relative error of u: 2.1697725697845667%
# maximum relative error of u: 3.7135928431478926%
#
# Param is 105
# Time elapsed: 1.4338881969451904 sec
# average relative error of u: 2.1528717725664777%
# maximum relative error of u: 3.7099939565759077%
#
# Param is 106
# Time elapsed: 1.5634231567382812 sec
# average relative error of u: 2.138179570374222%
# maximum relative error of u: 3.7106536888680313%
#
# Param is 107
# Time elapsed: 1.4282574653625488 sec
# average relative error of u: 2.125790830474642%
# maximum relative error of u: 3.715667282801073%
#
# Param is 108
# Time elapsed: 1.534975528717041 sec
# average relative error of u: 2.1157998604337185%
# maximum relative error of u: 3.7252215506152395%
#
# Param is 109
# Time elapsed: 1.611131191253662 sec
# average relative error of u: 2.1083100592973785%
# maximum relative error of u: 3.7395178932280317%
#
# Param is 110
# Time elapsed: 1.6599574089050293 sec
# average relative error of u: 2.103428292771166%
# maximum relative error of u: 3.7585774221130177%
#
# Param is 111
# Time elapsed: 1.7073650360107422 sec
# average relative error of u: 2.101305972950811%
# maximum relative error of u: 3.782760936940019%
#
# Param is 112
# Time elapsed: 3.3532047271728516 sec
# average relative error of u: 2.1019725880416127%
# maximum relative error of u: 3.8120434446100497%
#
# Param is 113
# Time elapsed: 6.00426983833313 sec
# average relative error of u: 2.1055255025517217%
# maximum relative error of u: 3.8463723567199812%
#
# Param is 114
# Time elapsed: 4.036421298980713 sec
# average relative error of u: 2.1121009594847537%
# maximum relative error of u: 3.8875184794130817%
#
# Param is 115
# Time elapsed: 1.1385612487792969 sec
# average relative error of u: 2.1216813674330877%
# maximum relative error of u: 3.9350257764330556%
#
# Param is 116
# Time elapsed: 1.6583130359649658 sec
# average relative error of u: 2.134403830564486%
# maximum relative error of u: 3.988340676868305%
#
# Param is 117
# Time elapsed: 0.8084549903869629 sec
# average relative error of u: 2.150292277586305%
# maximum relative error of u: 4.047099296025189%
#
# Param is 118
# Time elapsed: 7.958673000335693 sec
# average relative error of u: 2.16939322293549%
# maximum relative error of u: 4.111640845553014%
#
# Param is 119
# Time elapsed: 10.918402433395386 sec
# average relative error of u: 2.1917968185343377%
# maximum relative error of u: 4.182062435138119%
#
# Param is 120
# Time elapsed: 13.17185664176941 sec
# average relative error of u: 2.217473088121382%
# maximum relative error of u: 4.258160101915796%
#
# Param is 121
# Time elapsed: 7.6249098777771 sec
# average relative error of u: 2.246532919901272%
# maximum relative error of u: 4.340247975772615%
#
# Param is 122
# Time elapsed: 13.746275901794434 sec
# average relative error of u: 2.278871248317108%
# maximum relative error of u: 4.42822248499065%
#
# Param is 123
# Time elapsed: 5.771178960800171 sec
# average relative error of u: 2.3145644366876392%
# maximum relative error of u: 4.521983041486594%
#
# Param is 124
# Time elapsed: 1.8755440711975098 sec
# average relative error of u: 2.35355895875851%
# maximum relative error of u: 4.621675355699257%
#
# Param is 125
# Time elapsed: 0.924567461013794 sec
# average relative error of u: 2.3958982323288596%
# maximum relative error of u: 4.727196189912342%
#
# # of POD basis is 6
# # of measurments: 12
# [  77   79   85  118  526 1231 1592 1666 1831 1851 2633 2638]
# Param is 75
# Time elapsed: 8.626833200454712 sec
# average relative error of u: 4.017440966034061%
# maximum relative error of u: 6.566834232299208%
#
# Param is 76
# Time elapsed: 1.470353126525879 sec
# average relative error of u: 3.9702575972209537%
# maximum relative error of u: 6.491592952552789%
#
# Param is 77
# Time elapsed: 1.3986849784851074 sec
# average relative error of u: 3.922191703516183%
# maximum relative error of u: 6.41497640291149%
#
# Param is 78
# Time elapsed: 3.024219512939453 sec
# average relative error of u: 3.8731479233655692%
# maximum relative error of u: 6.336727976081047%
#
# Param is 79
# Time elapsed: 1.3210523128509521 sec
# average relative error of u: 3.8234348752081933%
# maximum relative error of u: 6.257410113731912%
#
# Param is 80
# Time elapsed: 1.426581859588623 sec
# average relative error of u: 3.772997354093815%
# maximum relative error of u: 6.1767137581992735%
#
# Param is 81
# Time elapsed: 1.3334929943084717 sec
# average relative error of u: 3.7217365652926584%
# maximum relative error of u: 6.094838308066448%
#
# Param is 82
# Time elapsed: 1.6889519691467285 sec
# average relative error of u: 3.669867447651306%
# maximum relative error of u: 6.011916645502392%
#
# Param is 83
# Time elapsed: 1.5079872608184814 sec
# average relative error of u: 3.6175300194991538%
# maximum relative error of u: 5.9281882270873565%
#
# Param is 84
# Time elapsed: 18.734591722488403 sec
# average relative error of u: 3.564499298043238%
# maximum relative error of u: 5.843232343887136%
#
# Param is 85
# Time elapsed: 5.407965183258057 sec
# average relative error of u: 3.511044870641803%
# maximum relative error of u: 5.757597753307282%
#
# Param is 86
# Time elapsed: 1.6046273708343506 sec
# average relative error of u: 3.4570511563026187%
# maximum relative error of u: 5.671088532932906%
#
# Param is 87
# Time elapsed: 1.0596108436584473 sec
# average relative error of u: 3.4027411799911906%
# maximum relative error of u: 5.583972383711494%
#
# Param is 88
# Time elapsed: 1.1680092811584473 sec
# average relative error of u: 3.3479937307918353%
# maximum relative error of u: 5.496072992895105%
#
# Param is 89
# Time elapsed: 8.454030275344849 sec
# average relative error of u: 3.292905419571361%
# maximum relative error of u: 5.407547788330486%
#
# Param is 90
# Time elapsed: 1.3333590030670166 sec
# average relative error of u: 3.237801505138698%
# maximum relative error of u: 5.318850268718837%
#
# Param is 91
# Time elapsed: 1.2912616729736328 sec
# average relative error of u: 3.1823017113391416%
# maximum relative error of u: 5.229407199360623%
#
# Param is 92
# Time elapsed: 1.5208525657653809 sec
# average relative error of u: 3.1266793944270033%
# maximum relative error of u: 5.139596464307205%
#
# Param is 93
# Time elapsed: 1.0563323497772217 sec
# average relative error of u: 3.0709590868020493%
# maximum relative error of u: 5.049658989043376%
#
# Param is 94
# Time elapsed: 1.0268518924713135 sec
# average relative error of u: 3.0152041896845465%
# maximum relative error of u: 4.959207856412083%
#
# Param is 95
# Time elapsed: 0.8247995376586914 sec
# average relative error of u: 2.959530090053144%
# maximum relative error of u: 4.8688846777550125%
#
# Param is 96
# Time elapsed: 0.9761738777160645 sec
# average relative error of u: 2.903965729258806%
# maximum relative error of u: 4.778505929018824%
#
# Param is 97
# Time elapsed: 1.1373388767242432 sec
# average relative error of u: 2.848525353107557%
# maximum relative error of u: 4.687858296798858%
#
# Param is 98
# Time elapsed: 1.4136528968811035 sec
# average relative error of u: 2.793322935821512%
# maximum relative error of u: 4.597256561286072%
#
# Param is 99
# Time elapsed: 1.4489669799804688 sec
# average relative error of u: 2.738406370063083%
# maximum relative error of u: 4.506820883794466%
#
# Param is 100
# Time elapsed: 1.747260570526123 sec
# average relative error of u: 2.683914504181091%
# maximum relative error of u: 4.416732234979516%
#
# Param is 101
# Time elapsed: 1.6394987106323242 sec
# average relative error of u: 2.6299402842897215%
# maximum relative error of u: 4.326868885766639%
#
# Param is 102
# Time elapsed: 1.3047502040863037 sec
# average relative error of u: 2.576462333090236%
# maximum relative error of u: 4.237221102620137%
#
# Param is 103
# Time elapsed: 9.921728610992432 sec
# average relative error of u: 2.523656289301366%
# maximum relative error of u: 4.148242589854393%
#
# Param is 104
# Time elapsed: 3.2266719341278076 sec
# average relative error of u: 2.4717523003841486%
# maximum relative error of u: 4.05984692919618%
#
# Param is 105
# Time elapsed: 1.129059076309204 sec
# average relative error of u: 2.420685736084539%
# maximum relative error of u: 3.9720655821219224%
#
# Param is 106
# Time elapsed: 1.1063432693481445 sec
# average relative error of u: 2.3706071907178154%
# maximum relative error of u: 3.8849903222781577%
#
# Param is 107
# Time elapsed: 11.826047897338867 sec
# average relative error of u: 2.3217583461354647%
# maximum relative error of u: 3.798871778570287%
#
# Param is 108
# Time elapsed: 1.8632409572601318 sec
# average relative error of u: 2.274193073717793%
# maximum relative error of u: 3.7139181285908243%
#
# Param is 109
# Time elapsed: 1.9615321159362793 sec
# average relative error of u: 2.2281474725841894%
# maximum relative error of u: 3.6300702815835204%
#
# Param is 110
# Time elapsed: 1.8524816036224365 sec
# average relative error of u: 2.183764092962209%
# maximum relative error of u: 3.5475873683434944%
#
# Param is 111
# Time elapsed: 6.3967812061309814 sec
# average relative error of u: 2.14118800353317%
# maximum relative error of u: 3.466449948230472%
#
# Param is 112
# Time elapsed: 0.2652137279510498 sec
# average relative error of u: 2.1006095903981636%
# maximum relative error of u: 3.3872217799479736%
#
# Param is 113
# Time elapsed: 0.2032489776611328 sec
# average relative error of u: 2.0623094975848457%
# maximum relative error of u: 3.309607954314571%
#
# Param is 114
# Time elapsed: 0.20981264114379883 sec
# average relative error of u: 2.0264788810366166%
# maximum relative error of u: 3.234360777499564%
#
# Param is 115
# Time elapsed: 0.21483683586120605 sec
# average relative error of u: 1.9932527725842093%
# maximum relative error of u: 3.161293585003739%
#
# Param is 116
# Time elapsed: 0.2174222469329834 sec
# average relative error of u: 1.9628881744097826%
# maximum relative error of u: 3.0906545248243056%
#
# Param is 117
# Time elapsed: 0.20191669464111328 sec
# average relative error of u: 1.935741967946623%
# maximum relative error of u: 3.022935643920468%
#
# Param is 118
# Time elapsed: 0.2156965732574463 sec
# average relative error of u: 1.912008769550378%
# maximum relative error of u: 2.9583727115670104%
#
# Param is 119
# Time elapsed: 0.20930194854736328 sec
# average relative error of u: 1.8918078539891179%
# maximum relative error of u: 2.8971630276259686%
#
# Param is 120
# Time elapsed: 0.24322056770324707 sec
# average relative error of u: 1.8754652516634809%
# maximum relative error of u: 2.839531466940978%
#
# Param is 121
# Time elapsed: 0.22632670402526855 sec
# average relative error of u: 1.8631908920635838%
# maximum relative error of u: 2.7860974263347695%
#
# Param is 122
# Time elapsed: 0.2390453815460205 sec
# average relative error of u: 1.855169844840852%
# maximum relative error of u: 2.736887195729242%
#
# Param is 123
# Time elapsed: 0.19700169563293457 sec
# average relative error of u: 1.8515793460465144%
# maximum relative error of u: 2.711325309794293%
#
# Param is 124
# Time elapsed: 0.26248955726623535 sec
# average relative error of u: 1.8525250204703672%
# maximum relative error of u: 2.747175873952573%
#
# Param is 125
# Time elapsed: 0.2330024242401123 sec
# average relative error of u: 1.8581355516299878%
# maximum relative error of u: 2.811213533424038%

# %%
print(num_basis)
idx=[0,1,2,3]
num_basis[idx]
# Out:
# [3 4 5 6]
# array([3, 4, 5, 6])

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_inner_SOPT_avg_rel_err.png")

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_inner_SOPT_max_rel_err.png")
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
idx=[3]
POD_basis=num_basis[idx]
print(POD_basis)
# Out:
# [6]

# %%
# with open(file=file_path_gappy_SOPT_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_{}_inner_SOPT_avg_rel_err.png".format(POD_basis)

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_{}_inner_SOPT_max_rel_err.png".format(POD_basis)
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
print(num_basis)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=3;j=-1
POD_basis=num_basis[i]                 
param=FOM_parameters[j]

u_gappyPOD=results['solution'][i,j]

ex = np.load('./wave_data/ex23_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("POD basis: {} Param: {}".format(POD_basis,param))
plt.show()

# plot original data
vmin=-1; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyPOD[int(nt/4)*i].reshape(ny,nx))#,vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy POD @ t={}'.format(int(nt/4)*i*dt),fontsize=20)
    fig.colorbar(pcm, ax=ax,shrink=0.8)

# fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_POD_{}_param_{}_inner_SOPT_SOL.png".format(POD_basis,param))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx))#,vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)
    fig.colorbar(pcm, ax=ax,shrink=0.8)

# fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_param_{}_ground_truth.png".format(param))
