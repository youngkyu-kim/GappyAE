# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle
import torch
import torch.nn as nn

# %%
# seed=0 # Use the same seed when training

# Given parameters
nx = 60
ny = 60
tf = 5.0
dt = 1.0e-2
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims = (ny,nx)

# latent space dim.
f_list=np.array([3,4,5,6])
print('Latent Sapce Dim. {}'.format(f_list))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_DEIM_result = "./wave_result/ex23_AE_swish_inner_DEIM_gappy_result_seed_{}.p".format(seed)
print(file_path_gappy_DEIM_result)

# Gauss-Newton params
maxitr=4
tol=1e-8

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# Latent Sapce Dim. [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]
# ./wave_result/ex23_AE_swish_inner_DEIM_gappy_result_seed_0.p

# %%
# Jessi 알고리즘
def DEIM(phi_f, nfeval, unseen=np.array([])):
    
    ninf=np.NINF
    n,m=np.shape(phi_f)
    
    l=0
    u=np.reshape(phi_f[:,l],(n,1))
    r=np.abs(u)
    if len(unseen) >0 :
        r[unseen]=ninf
    p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
    p=p_temp
    U=u
    
    ns=int(np.ceil((nfeval-1)/(m-1)))
    for l in range(1,m):
        u=np.reshape(phi_f[:,l],(n,1))
        for k in range(ns):
            if len(p)==nfeval:
                return p
            c=np.linalg.lstsq(U[p,:],u[p,:],rcond=None)[0]
            r=np.abs(u-U@c)
            r[p]=ninf
            if len(unseen) > 0:
                r[unseen]=ninf
            p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
            p=np.sort(np.append(p,p_temp))
        U=np.concatenate((U,u),axis=1)
         
    return p

# %%
for ii in range(len(f_list)):
    f=f_list[ii]
    print("Latent Space Dimension: {}".format(f))
    
    # file path
    file_name_AE="./wave_model/ex23_AE_{}_swish_seed_{}.p".format(f,seed)
    file_path_residual_SVD="./wave_model/ex23_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)
    
    with open(file=file_path_residual_SVD, mode='rb') as fff:
        SVD=pickle.load(fff)

     # DEIM
    num_msmt=12
    phi_r=SVD['U'][:,:num_msmt]
    msmt_idx=DEIM(phi_r,num_msmt,bc_raveled_indicies)
    msmt_idx.sort()

    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(num_msmt))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.savefig("./wave_result/ex23_AE_{}_swish_inner_DEIM_{}_samples_seed_{}.png".format(f,num_msmt,seed))
# Out:
# Latent Space Dimension: 3
# # of measurments: 12
# [  61  108  118  549  817 1036 1523 1747 2581 3108 3512 3538]
# Latent Space Dimension: 4
# # of measurments: 12
# [ 241  346  510  549  914 1100 1501 2525 2742 3062 3418 3481]
# Latent Space Dimension: 5
# # of measurments: 12
# [ 118  122  427  671  856 1001 1438 2502 2641 3051 3182 3478]
# Latent Space Dimension: 6
# # of measurments: 12
# [  61  108  274  366  732  831  915 1089 1801 2930 3302 3538]

# %% [markdown]
# # gappyAE

# %%
solution=np.zeros((len(f_list),len(FOM_parameters),nt+1,nx*ny))
reduced=np.zeros((len(f_list),len(FOM_parameters),nt+1,f_list[-1]))
avg_rel_err=np.zeros((len(f_list),len(FOM_parameters)))
rel_err=np.zeros((len(f_list),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(f_list),len(FOM_parameters)))

for ii in range(len(f_list)):
    f=f_list[ii]
    print("Dim. of latent space is {}".format(f))
    
    # file path
    file_name_AE="./wave_model/ex23_AE_{}_swish_seed_{}.p".format(f,seed)
    file_path_residual_SVD="./wave_model/ex23_AE_{}_swish_residual_SVD_seed_{}.p".format(f,seed)
    
    with open(file=file_path_residual_SVD, mode='rb') as fff:
        SVD=pickle.load(fff)

     # DEIM
    num_msmt=12
    phi_r=SVD['U'][:,:num_msmt]
    msmt_idx=DEIM(phi_r,num_msmt,bc_raveled_indicies)
    msmt_idx.sort()

    # precompute
    ZTphi_r=phi_r[msmt_idx]
    ZTphi_r_pinv=np.linalg.pinv(ZTphi_r)
    phi_rZTphi_r_pinv=phi_r.dot(ZTphi_r_pinv)

    num_msmt=len(msmt_idx)
    print("# of measurments: {}".format(len(msmt_idx)))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
        
    with open(file=file_name_AE, mode='rb') as ff:    
        AE = pickle.load(ff)

    en_wu1=AE['en_wu1']
    en_bu1=AE['en_bu1']
    en_wu2=AE['en_wu2']
    de_wu1=AE['de_wu1']
    de_bu1=AE['de_bu1']
    de_wu2=AE['de_wu2']
    de_wu1T=AE['de_wu1T']
    de_wu2T=AE['de_wu2T']
    de_wu2_sp=AE['de_wu2_sp']
    de_wu2T_sp=AE['de_wu2T_sp']
    u_ref=AE['u_ref']

    latent_dim=de_wu1.shape[1]
    
    # numpy version of AE
    def sigmoid_np(input):
        return (1.0/(1.0+np.exp(-input))).astype('float32')

    def encoder_u_np_forward(x):
        z1 = en_wu1.dot(x) + en_bu1
        a1 = z1 * sigmoid_np(z1)
        y = en_wu2.dot(a1)   
        return y

    def decoder_u_np_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = de_wu2.dot(a1)  
        return y

    def decoder_u_sp_forward(x):
        z1 = de_wu1.dot(x) + de_bu1
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(de_wu2_sp,a1)
        return y

    def decoder_u_np_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = de_wu2.dot(a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(de_wu2T)   
        return y,dydxT

    def decoder_u_sp_forward_backwardT(x):
        z1 = de_wu1.dot(x) + de_bu1
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(de_wu2_sp,a1)

        dout = de_wu1T
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,de_wu2T_sp)
        return y,dydxT
    
    m,M2=de_wu2.shape

    class Decoder_U_FC(nn.Module):

        def __init__(self,):
            super(Decoder_U_FC, self).__init__()
            self.fc1 = nn.Linear(latent_dim,M2)
            self.fc1.weight = nn.Parameter(torch.ones(de_wu1.shape))
            self.fc1.bias = nn.Parameter(torch.ones(de_bu1.shape))
    #         self.fc1.weight = nn.Parameter(torch.tensor(de_wu1))
    #         self.fc1.bias = nn.Parameter(torch.tensor(de_bu1))

            self.fc2 = nn.Linear(M2,m,bias=False)
            self.fc2.weight = nn.Parameter(torch.ones(de_wu2.shape))
    #         self.fc2.weight = nn.Parameter(torch.tensor(de_wu2))

        def forward(self, x):
            x = self.fc1(x)
            x = self.fc2(x)
            return x

    model = Decoder_U_FC()

    x_in=torch.ones(latent_dim)
    y_out=model(x_in)

    p_hr=msmt_idx

    upstream=torch.zeros_like(y_out)
    upstream[p_hr]=1.0

    y_out.backward(upstream)

    # masks for subnet
    wu1_mask=model.fc1.weight.grad
    wu2_mask=model.fc2.weight.grad

    bu1_mask=model.fc1.bias.grad

    # subnet sparse weight
    idx1=wu1_mask.to_sparse()._indices()
    i1=idx1.numpy()[0]
    j1=idx1.numpy()[1]
    v1=de_wu1[i1,j1]
    wu1_sb_sp=sp.csr_matrix(sp.csr_matrix((v1,(i1,j1)),shape=wu1_mask.shape).toarray())

    idx2=wu2_mask.to_sparse()._indices()
    i2=idx2.numpy()[0]
    j2=idx2.numpy()[1]
    v2=de_wu2[i2,j2]
    wu2_sb_sp=sp.csr_matrix(sp.csr_matrix((v2,(i2,j2)),shape=wu2_mask.shape).toarray())

    # subnet compressed weight
    i1,j1,v1=sp.find(wu1_sb_sp)
    i1_unique,i1_inverse=np.unique(i1,return_inverse=True)
    i1_comp=np.arange(i1_unique.size)
    i1_comp=i1_comp[i1_inverse]
    j1_unique,j1_inverse=np.unique(j1,return_inverse=True)
    j1_comp=np.arange(j1_unique.size)
    j1_comp=j1_comp[j1_inverse]
    wu1_sb_comp_sp=sp.csr_matrix((v1,(i1_comp,j1_comp)),shape=(i1_unique.size,j1_unique.size))

    i2,j2,v2=sp.find(wu2_sb_sp)
    i2_unique,i2_inverse=np.unique(i2,return_inverse=True)
    i2_comp=np.arange(i2_unique.size)
    i2_comp=i2_comp[i2_inverse]
    j2_unique,j2_inverse=np.unique(j2,return_inverse=True)
    j2_comp=np.arange(j2_unique.size)
    j2_comp=j2_comp[j2_inverse]
    wu2_sb_comp_sp=sp.csr_matrix((v2,(i2_comp,j2_comp)),shape=(i2_unique.size,j2_unique.size))

    wu1_sb_comp_dense=wu1_sb_comp_sp.toarray()
    wu1_sb_comp_dense=wu1_sb_comp_dense[j2_unique]
    wu2_sb_comp_dense=wu2_sb_comp_sp.toarray()

    wu1_sb_comp_denseT=wu1_sb_comp_dense.T
    wu2_sb_comp_denseT=wu2_sb_comp_dense.T

    # subnet compressed bias
    bu1_sb_comp_dense=de_bu1[i1_unique]
    bu1_sb_comp_dense=bu1_sb_comp_dense[j2_unique]

    # Using sparse matrix
    wu2_sb_comp_sp=sp.csr_matrix(wu2_sb_comp_dense,dtype='float32')
    wu2_sb_comp_spT=sp.csr_matrix(wu2_sb_comp_denseT,dtype='float32')

    def decoder_u_sb_np_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = wu2_sb_comp_dense.dot(a1)  
        return y

    def decoder_u_sb_np_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = wu2_sb_comp_dense.dot(a1) 

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = dout.dot(wu2_sb_comp_denseT)
        return y,dydxT

    def decoder_u_sb_sp_forward(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        a1 = z1 * sigmoid_np(z1)
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)
        return y

    def decoder_u_sb_sp_forward_backwardT(x):
        z1 = wu1_sb_comp_dense.dot(x) + bu1_sb_comp_dense
        sigma = sigmoid_np(z1)
        a1 = z1 * sigma
        y = sp.csr_matrix.dot(wu2_sb_comp_sp,a1)

        dout = wu1_sb_comp_denseT
        dout = (sigma+a1*(1-sigma))*dout
        dydxT = sp.csr_matrix.dot(dout,wu2_sb_comp_spT)
        return y,dydxT

    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('./wave_data/ex23_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1).astype('float32')

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_hat0=encoder_u_np_forward(u0.astype('float32')-u_ref)

        # gappyAE
        t_start_gappyAE=time.time()

        # solution
        u_reduced=np.zeros((nt+1,latent_dim))
        u_gappyAE=np.zeros((nt+1,ny*nx))

        # IC
        u_reduced[0]=np.copy(u_hat0)
        u_gappyAE[0]=np.copy(u0)

        for k in range(nt):
#             print("")
#             print(k,"th time step:")

            u_hatw=np.copy(u_reduced[k])

            umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

            umw += u_ref[msmt_idx]

            J_r=-Jg_umT.T
            J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

            r_um_hat = um[k+1]-umw

            res = np.linalg.norm(J_pinv.dot(r_um_hat))
#             res = np.linalg.norm(r_um_hat)
            res_hist=[res]
            for itr in range(maxitr):
                du_hatw = J_pinv.dot(r_um_hat)

                u_hatw -= du_hatw

                umw,Jg_umT=decoder_u_sb_sp_forward_backwardT(u_hatw)

                umw += u_ref[msmt_idx]

                J_r=-Jg_umT.T
                J_pinv=np.linalg.pinv(ZTphi_r_pinv.dot(J_r)).dot(ZTphi_r_pinv)

                r_um_hat = um[k+1]-umw

                res = np.linalg.norm(J_pinv.dot(r_um_hat))
#                 res = np.linalg.norm(r_um_hat)
                res_hist.append(res)
#                 print(itr,"th Newton iteration", "res:", "{:.8e}".format(res))

                if res<tol:
                    break

            u_reduced[k+1]=u_hatw.copy()
            u_gappyAE[k+1]=u_ref+decoder_u_sp_forward(u_reduced[k+1])

        # elapsed time    
        t_elapsed_gappyAE=time.time()-t_start_gappyAE
        print('Time elapsed: {} sec'.format(t_elapsed_gappyAE))

        # error
        u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                         /np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
                     /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
        print()

        # save result
        solution[ii,jj]=u_gappyAE
        reduced[ii,jj,:,:f]=u_reduced
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyAE
        elapsed_time[ii,jj]=t_elapsed_gappyAE
    
results={'solution':solution,'reduced':reduced,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_DEIM_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# Dim. of latent space is 3
# # of measurments: 12
# [  61  108  118  549  817 1036 1523 1747 2581 3108 3512 3538]
# Param is 75
# Time elapsed: 23.83993124961853 sec
# average relative error of u: 1.2774864366027863%
# maximum relative error of u: 1.962106784264487%
#
# Param is 76
# Time elapsed: 27.6996648311615 sec
# average relative error of u: 1.2127601226260312%
# maximum relative error of u: 1.8699644979940817%
#
# Param is 77
# Time elapsed: 28.326539278030396 sec
# average relative error of u: 1.1535572706031452%
# maximum relative error of u: 1.7835682174318985%
#
# Param is 78
# Time elapsed: 25.421247482299805 sec
# average relative error of u: 1.1003617182023273%
# maximum relative error of u: 1.7034098055364058%
#
# Param is 79
# Time elapsed: 26.879324197769165 sec
# average relative error of u: 1.0536630051033824%
# maximum relative error of u: 1.6299839817424426%
#
# Param is 80
# Time elapsed: 23.547962188720703 sec
# average relative error of u: 1.0139366391664446%
# maximum relative error of u: 1.5637236053587271%
#
# Param is 81
# Time elapsed: 25.88238525390625 sec
# average relative error of u: 0.9815976951860773%
# maximum relative error of u: 1.5050153153165455%
#
# Param is 82
# Time elapsed: 26.11206889152527 sec
# average relative error of u: 0.9569694457441427%
# maximum relative error of u: 1.4565591383190368%
#
# Param is 83
# Time elapsed: 26.61685085296631 sec
# average relative error of u: 0.9402342369450263%
# maximum relative error of u: 1.4163097265813036%
#
# Param is 84
# Time elapsed: 26.35256052017212 sec
# average relative error of u: 0.9313980611504397%
# maximum relative error of u: 1.4154790543545717%
#
# Param is 85
# Time elapsed: 26.692051649093628 sec
# average relative error of u: 0.930283472509129%
# maximum relative error of u: 1.4931823343831068%
#
# Param is 86
# Time elapsed: 24.547432899475098 sec
# average relative error of u: 0.9365337958437777%
# maximum relative error of u: 1.5806876675260155%
#
# Param is 87
# Time elapsed: 27.465084314346313 sec
# average relative error of u: 0.9496514639714614%
# maximum relative error of u: 1.6809638041991573%
#
# Param is 88
# Time elapsed: 25.60263991355896 sec
# average relative error of u: 0.9690458956335909%
# maximum relative error of u: 1.7980707637075988%
#
# Param is 89
# Time elapsed: 25.459481716156006 sec
# average relative error of u: 0.9940909630672812%
# maximum relative error of u: 1.9253211760258861%
#
# Param is 90
# Time elapsed: 28.662755489349365 sec
# average relative error of u: 1.0241603570719215%
# maximum relative error of u: 2.0624952681035786%
#
# Param is 91
# Time elapsed: 29.00591516494751 sec
# average relative error of u: 1.058667190281069%
# maximum relative error of u: 2.209365157886376%
#
# Param is 92
# Time elapsed: 27.40990686416626 sec
# average relative error of u: 1.0970672618027328%
# maximum relative error of u: 2.365699048099263%
#
# Param is 93
# Time elapsed: 27.614792108535767 sec
# average relative error of u: 1.1388736573999252%
# maximum relative error of u: 2.5312686574580585%
#
# Param is 94
# Time elapsed: 24.490068197250366 sec
# average relative error of u: 1.1836487966163263%
# maximum relative error of u: 2.7058274339542385%
#
# Param is 95
# Time elapsed: 27.935139656066895 sec
# average relative error of u: 1.231006006244839%
# maximum relative error of u: 2.8891578698571725%
#
# Param is 96
# Time elapsed: 26.46693253517151 sec
# average relative error of u: 1.2806033629159626%
# maximum relative error of u: 3.081034126430583%
#
# Param is 97
# Time elapsed: 26.325965642929077 sec
# average relative error of u: 1.3321406761765855%
# maximum relative error of u: 3.2847732886682572%
#
# Param is 98
# Time elapsed: 24.605038166046143 sec
# average relative error of u: 1.3853541180271551%
# maximum relative error of u: 3.4978539733527563%
#
# Param is 99
# Time elapsed: 25.892964124679565 sec
# average relative error of u: 1.440015317717674%
# maximum relative error of u: 3.7185093111295275%
#
# Param is 100
# Time elapsed: 25.578625202178955 sec
# average relative error of u: 1.4959262327898186%
# maximum relative error of u: 3.946391803857346%
#
# Param is 101
# Time elapsed: 28.50973415374756 sec
# average relative error of u: 1.5529249603938269%
# maximum relative error of u: 4.181172943607768%
#
# Param is 102
# Time elapsed: 27.216158628463745 sec
# average relative error of u: 1.6108841861779282%
# maximum relative error of u: 4.422453631994861%
#
# Param is 103
# Time elapsed: 27.915126085281372 sec
# average relative error of u: 1.6697651062774714%
# maximum relative error of u: 4.669834047381176%
#
# Param is 104
# Time elapsed: 27.02006983757019 sec
# average relative error of u: 1.7296455826274566%
# maximum relative error of u: 4.922836444899479%
#
# Param is 105
# Time elapsed: 25.336414337158203 sec
# average relative error of u: 1.7902015594571812%
# maximum relative error of u: 5.180929189905627%
#
# Param is 106
# Time elapsed: 26.294605016708374 sec
# average relative error of u: 1.8512902777265823%
# maximum relative error of u: 5.443476349612285%
#
# Param is 107
# Time elapsed: 21.798723459243774 sec
# average relative error of u: 1.9135476826345774%
# maximum relative error of u: 5.709709728378946%
#
# Param is 108
# Time elapsed: 26.168447971343994 sec
# average relative error of u: 1.9773549756652364%
# maximum relative error of u: 5.978654428126972%
#
# Param is 109
# Time elapsed: 26.002835750579834 sec
# average relative error of u: 2.0411868708300513%
# maximum relative error of u: 6.249113599038146%
#
# Param is 110
# Time elapsed: 23.35637378692627 sec
# average relative error of u: 2.1052684487494813%
# maximum relative error of u: 6.5318057354384615%
#
# Param is 111
# Time elapsed: 29.632436990737915 sec
# average relative error of u: 2.176798898186642%
# maximum relative error of u: 6.823190715070138%
#
# Param is 112
# Time elapsed: 27.972342014312744 sec
# average relative error of u: 2.246344983726127%
# maximum relative error of u: 7.119233801721965%
#
# Param is 113
# Time elapsed: 27.961802005767822 sec
# average relative error of u: 2.313967302902068%
# maximum relative error of u: 7.419672704337521%
#
# Param is 114
# Time elapsed: 27.210472345352173 sec
# average relative error of u: 2.3975933399198%
# maximum relative error of u: 7.724261434736976%
#
# Param is 115
# Time elapsed: 28.55474543571472 sec
# average relative error of u: 2.4724689425351953%
# maximum relative error of u: 8.032792392844506%
#
# Param is 116
# Time elapsed: 27.983779191970825 sec
# average relative error of u: 2.5457216580136364%
# maximum relative error of u: 8.345052744317801%
#
# Param is 117
# Time elapsed: 28.367886543273926 sec
# average relative error of u: 2.645009561578032%
# maximum relative error of u: 8.660845503749508%
#
# Param is 118
# Time elapsed: 23.587478637695312 sec
# average relative error of u: 2.723139009003232%
# maximum relative error of u: 8.980040704646159%
#
# Param is 119
# Time elapsed: 29.137381315231323 sec
# average relative error of u: 2.825249398704781%
# maximum relative error of u: 9.302466896881379%
#
# Param is 120
# Time elapsed: 25.167187452316284 sec
# average relative error of u: 2.9142541665950294%
# maximum relative error of u: 9.62798504485329%
#
# Param is 121
# Time elapsed: 25.878036975860596 sec
# average relative error of u: 3.0015682821600786%
# maximum relative error of u: 9.956426079759717%
#
# Param is 122
# Time elapsed: 23.55558156967163 sec
# average relative error of u: 3.119837691913775%
# maximum relative error of u: 10.287547552823202%
#
# Param is 123
# Time elapsed: 24.377223014831543 sec
# average relative error of u: 3.210002241666543%
# maximum relative error of u: 10.620989614662564%
#
# Param is 124
# Time elapsed: 23.711927890777588 sec
# average relative error of u: 3.3403562940285925%
# maximum relative error of u: 10.956317218156387%
#
# Param is 125
# Time elapsed: 27.662890672683716 sec
# average relative error of u: 3.4432171538119576%
# maximum relative error of u: 11.292957557285312%
#
# Dim. of latent space is 4
# # of measurments: 12
# [ 241  346  510  549  914 1100 1501 2525 2742 3062 3418 3481]
# Param is 75
# Time elapsed: 26.072717905044556 sec
# average relative error of u: 0.9409643181055699%
# maximum relative error of u: 2.007270529653841%
#
# Param is 76
# Time elapsed: 27.442859649658203 sec
# average relative error of u: 0.9020570759474661%
# maximum relative error of u: 1.9320917815536947%
#
# Param is 77
# Time elapsed: 26.607696533203125 sec
# average relative error of u: 0.8653987203182488%
# maximum relative error of u: 1.8601056264383293%
#
# Param is 78
# Time elapsed: 22.127150774002075 sec
# average relative error of u: 0.8309972315229586%
# maximum relative error of u: 1.791387488344891%
#
# Param is 79
# Time elapsed: 19.82158589363098 sec
# average relative error of u: 0.7988699163944367%
# maximum relative error of u: 1.7255893648197507%
#
# Param is 80
# Time elapsed: 20.650679349899292 sec
# average relative error of u: 0.7690428461887462%
# maximum relative error of u: 1.662680815617628%
#
# Param is 81
# Time elapsed: 17.33282494544983 sec
# average relative error of u: 0.7415126611496421%
# maximum relative error of u: 1.6024042633198916%
#
# Param is 82
# Time elapsed: 15.669967412948608 sec
# average relative error of u: 0.7162620403299309%
# maximum relative error of u: 1.5447475181379016%
#
# Param is 83
# Time elapsed: 16.645492553710938 sec
# average relative error of u: 0.6932282709638377%
# maximum relative error of u: 1.4894348840537106%
#
# Param is 84
# Time elapsed: 15.192174911499023 sec
# average relative error of u: 0.6723100088274264%
# maximum relative error of u: 1.4364456885352972%
#
# Param is 85
# Time elapsed: 15.580431938171387 sec
# average relative error of u: 0.6533681613502044%
# maximum relative error of u: 1.3856356670445409%
#
# Param is 86
# Time elapsed: 15.407044410705566 sec
# average relative error of u: 0.6362346332644416%
# maximum relative error of u: 1.3369360171524414%
#
# Param is 87
# Time elapsed: 15.728776693344116 sec
# average relative error of u: 0.6207173231782751%
# maximum relative error of u: 1.2901617037955626%
#
# Param is 88
# Time elapsed: 16.96959662437439 sec
# average relative error of u: 0.6066183839338072%
# maximum relative error of u: 1.2452990925271972%
#
# Param is 89
# Time elapsed: 17.924169540405273 sec
# average relative error of u: 0.5937344286119105%
# maximum relative error of u: 1.2022304828166033%
#
# Param is 90
# Time elapsed: 18.132864713668823 sec
# average relative error of u: 0.5818773969606916%
# maximum relative error of u: 1.1608631654854606%
#
# Param is 91
# Time elapsed: 18.38094425201416 sec
# average relative error of u: 0.5708714777888115%
# maximum relative error of u: 1.1212843317836614%
#
# Param is 92
# Time elapsed: 18.137076139450073 sec
# average relative error of u: 0.5605644263664046%
# maximum relative error of u: 1.0832779929135525%
#
# Param is 93
# Time elapsed: 17.91476607322693 sec
# average relative error of u: 0.5508198023576859%
# maximum relative error of u: 1.0468288400618686%
#
# Param is 94
# Time elapsed: 17.911912202835083 sec
# average relative error of u: 0.5415350267086767%
# maximum relative error of u: 1.0120114587719513%
#
# Param is 95
# Time elapsed: 18.40705895423889 sec
# average relative error of u: 0.5326237436115636%
# maximum relative error of u: 0.9786604168525418%
#
# Param is 96
# Time elapsed: 17.764033555984497 sec
# average relative error of u: 0.5240201268097567%
# maximum relative error of u: 0.9468687903840654%
#
# Param is 97
# Time elapsed: 17.72023630142212 sec
# average relative error of u: 0.5156874520709427%
# maximum relative error of u: 0.9166005530215212%
#
# Param is 98
# Time elapsed: 17.299879789352417 sec
# average relative error of u: 0.5075999371401893%
# maximum relative error of u: 0.887725357204536%
#
# Param is 99
# Time elapsed: 19.299155473709106 sec
# average relative error of u: 0.4997561772796681%
# maximum relative error of u: 0.8604988687235474%
#
# Param is 100
# Time elapsed: 18.249346494674683 sec
# average relative error of u: 0.4921631156952491%
# maximum relative error of u: 0.8346721847614117%
#
# Param is 101
# Time elapsed: 17.96174693107605 sec
# average relative error of u: 0.48484891652826767%
# maximum relative error of u: 0.8131767599877079%
#
# Param is 102
# Time elapsed: 17.874866724014282 sec
# average relative error of u: 0.4778518750895755%
# maximum relative error of u: 0.806398256704514%
#
# Param is 103
# Time elapsed: 18.07557988166809 sec
# average relative error of u: 0.4712282785003462%
# maximum relative error of u: 0.8039791272191373%
#
# Param is 104
# Time elapsed: 18.09239959716797 sec
# average relative error of u: 0.4650444420795252%
# maximum relative error of u: 0.7996609809791735%
#
# Param is 105
# Time elapsed: 18.048340559005737 sec
# average relative error of u: 0.4593848609579317%
# maximum relative error of u: 0.7928613769074789%
#
# Param is 106
# Time elapsed: 18.37273621559143 sec
# average relative error of u: 0.4543456559223045%
# maximum relative error of u: 0.7839484695437828%
#
# Param is 107
# Time elapsed: 14.406992673873901 sec
# average relative error of u: 0.4500495613642414%
# maximum relative error of u: 0.7727614733957585%
#
# Param is 108
# Time elapsed: 15.528753757476807 sec
# average relative error of u: 0.44663562037804266%
# maximum relative error of u: 0.7814121611883684%
#
# Param is 109
# Time elapsed: 17.073183059692383 sec
# average relative error of u: 0.4442583685886071%
# maximum relative error of u: 0.7894034386250064%
#
# Param is 110
# Time elapsed: 18.075182676315308 sec
# average relative error of u: 0.4431027938968262%
# maximum relative error of u: 0.7950235136484058%
#
# Param is 111
# Time elapsed: 17.104289531707764 sec
# average relative error of u: 0.44338753280280285%
# maximum relative error of u: 0.7988702135896872%
#
# Param is 112
# Time elapsed: 16.504833221435547 sec
# average relative error of u: 0.4453476237331532%
# maximum relative error of u: 0.8160227882893584%
#
# Param is 113
# Time elapsed: 16.622414350509644 sec
# average relative error of u: 0.4492463338696304%
# maximum relative error of u: 0.8396255687223795%
#
# Param is 114
# Time elapsed: 16.477230310440063 sec
# average relative error of u: 0.4553816763951417%
# maximum relative error of u: 0.8669566221918165%
#
# Param is 115
# Time elapsed: 16.79641079902649 sec
# average relative error of u: 0.4640604585030213%
# maximum relative error of u: 0.8976776706978616%
#
# Param is 116
# Time elapsed: 16.563217401504517 sec
# average relative error of u: 0.47561569247608315%
# maximum relative error of u: 0.9499615024092334%
#
# Param is 117
# Time elapsed: 15.935738563537598 sec
# average relative error of u: 0.4903890676956712%
# maximum relative error of u: 1.0240502831709692%
#
# Param is 118
# Time elapsed: 15.575268030166626 sec
# average relative error of u: 0.5087208960116789%
# maximum relative error of u: 1.1057413459990968%
#
# Param is 119
# Time elapsed: 15.746972799301147 sec
# average relative error of u: 0.530948335652962%
# maximum relative error of u: 1.1952989432777958%
#
# Param is 120
# Time elapsed: 15.335628032684326 sec
# average relative error of u: 0.5573958211822582%
# maximum relative error of u: 1.2929539117915452%
#
# Param is 121
# Time elapsed: 14.74104642868042 sec
# average relative error of u: 0.5883675961619629%
# maximum relative error of u: 1.3988327430623269%
#
# Param is 122
# Time elapsed: 16.064661502838135 sec
# average relative error of u: 0.62415153145052%
# maximum relative error of u: 1.5128044745602587%
#
# Param is 123
# Time elapsed: 14.37612509727478 sec
# average relative error of u: 0.665000424609467%
# maximum relative error of u: 1.6346525158603644%
#
# Param is 124
# Time elapsed: 14.204350709915161 sec
# average relative error of u: 0.7111481899044599%
# maximum relative error of u: 1.7638443349813175%
#
# Param is 125
# Time elapsed: 14.508387804031372 sec
# average relative error of u: 0.7627946311678293%
# maximum relative error of u: 1.9041206675809539%
#
# Dim. of latent space is 5
# # of measurments: 12
# [ 118  122  427  671  856 1001 1438 2502 2641 3051 3182 3478]
# Param is 75
# Time elapsed: 13.700644254684448 sec
# average relative error of u: 0.6824231968849753%
# maximum relative error of u: 1.102712394322126%
#
# Param is 76
# Time elapsed: 13.122531414031982 sec
# average relative error of u: 0.6490148799539097%
# maximum relative error of u: 1.0687061874505681%
#
# Param is 77
# Time elapsed: 13.541909217834473 sec
# average relative error of u: 0.6181289930429839%
# maximum relative error of u: 1.0342706768213705%
#
# Param is 78
# Time elapsed: 14.578238725662231 sec
# average relative error of u: 0.5896228028806505%
# maximum relative error of u: 0.9993728734405125%
#
# Param is 79
# Time elapsed: 14.64343786239624 sec
# average relative error of u: 0.5633578091070334%
# maximum relative error of u: 0.9641304048219007%
#
# Param is 80
# Time elapsed: 14.508501052856445 sec
# average relative error of u: 0.539195361992483%
# maximum relative error of u: 0.9287512511735405%
#
# Param is 81
# Time elapsed: 14.757524490356445 sec
# average relative error of u: 0.5170010827754814%
# maximum relative error of u: 0.8990300358376165%
#
# Param is 82
# Time elapsed: 14.761338949203491 sec
# average relative error of u: 0.49664984046860633%
# maximum relative error of u: 0.8704636959342806%
#
# Param is 83
# Time elapsed: 14.749911546707153 sec
# average relative error of u: 0.4780186969797041%
# maximum relative error of u: 0.841362680300372%
#
# Param is 84
# Time elapsed: 14.653820991516113 sec
# average relative error of u: 0.460990254643298%
# maximum relative error of u: 0.8118543143784235%
#
# Param is 85
# Time elapsed: 14.782704830169678 sec
# average relative error of u: 0.44545009743080205%
# maximum relative error of u: 0.7820123754055965%
#
# Param is 86
# Time elapsed: 14.62502408027649 sec
# average relative error of u: 0.43129597180796797%
# maximum relative error of u: 0.7519501777011727%
#
# Param is 87
# Time elapsed: 14.699632406234741 sec
# average relative error of u: 0.4184192683347027%
# maximum relative error of u: 0.7217678424367805%
#
# Param is 88
# Time elapsed: 14.651273965835571 sec
# average relative error of u: 0.4067252859446013%
# maximum relative error of u: 0.6914038133776044%
#
# Param is 89
# Time elapsed: 14.719139575958252 sec
# average relative error of u: 0.39610703687250326%
# maximum relative error of u: 0.666046384031288%
#
# Param is 90
# Time elapsed: 14.637078523635864 sec
# average relative error of u: 0.38646804288152875%
# maximum relative error of u: 0.6576228573798651%
#
# Param is 91
# Time elapsed: 14.127101421356201 sec
# average relative error of u: 0.3777086618332113%
# maximum relative error of u: 0.6502956944858032%
#
# Param is 92
# Time elapsed: 13.420782327651978 sec
# average relative error of u: 0.36972871199418383%
# maximum relative error of u: 0.6438002314317397%
#
# Param is 93
# Time elapsed: 12.758353471755981 sec
# average relative error of u: 0.362436863349765%
# maximum relative error of u: 0.6380473070418161%
#
# Param is 94
# Time elapsed: 12.51088547706604 sec
# average relative error of u: 0.35572717969807083%
# maximum relative error of u: 0.6326599655707513%
#
# Param is 95
# Time elapsed: 12.736824989318848 sec
# average relative error of u: 0.3495140642738239%
# maximum relative error of u: 0.6274696969485886%
#
# Param is 96
# Time elapsed: 12.447813510894775 sec
# average relative error of u: 0.34370534166709%
# maximum relative error of u: 0.6225028222748926%
#
# Param is 97
# Time elapsed: 12.59006643295288 sec
# average relative error of u: 0.33821845985914106%
# maximum relative error of u: 0.61732740342941%
#
# Param is 98
# Time elapsed: 12.56060528755188 sec
# average relative error of u: 0.33297147243337594%
# maximum relative error of u: 0.6117930761455467%
#
# Param is 99
# Time elapsed: 12.715960025787354 sec
# average relative error of u: 0.32790677795037726%
# maximum relative error of u: 0.6059829295158571%
#
# Param is 100
# Time elapsed: 12.41627287864685 sec
# average relative error of u: 0.3229590800934856%
# maximum relative error of u: 0.5996241265054606%
#
# Param is 101
# Time elapsed: 12.570662021636963 sec
# average relative error of u: 0.31808733854782917%
# maximum relative error of u: 0.5928165086949161%
#
# Param is 102
# Time elapsed: 12.621445894241333 sec
# average relative error of u: 0.3132675628366959%
# maximum relative error of u: 0.5852924532450694%
#
# Param is 103
# Time elapsed: 12.781613826751709 sec
# average relative error of u: 0.3084858940730727%
# maximum relative error of u: 0.5772027786955638%
#
# Param is 104
# Time elapsed: 12.433537006378174 sec
# average relative error of u: 0.3037529122122181%
# maximum relative error of u: 0.5685453130684358%
#
# Param is 105
# Time elapsed: 12.889307498931885 sec
# average relative error of u: 0.2991023721858978%
# maximum relative error of u: 0.5593905857518191%
#
# Param is 106
# Time elapsed: 12.900891065597534 sec
# average relative error of u: 0.29459131318607124%
# maximum relative error of u: 0.5667720056536247%
#
# Param is 107
# Time elapsed: 12.76133108139038 sec
# average relative error of u: 0.2903028117348095%
# maximum relative error of u: 0.5793840154376148%
#
# Param is 108
# Time elapsed: 12.892735719680786 sec
# average relative error of u: 0.28636425178041164%
# maximum relative error of u: 0.5910017359075886%
#
# Param is 109
# Time elapsed: 12.831721782684326 sec
# average relative error of u: 0.2829179929217365%
# maximum relative error of u: 0.6017551725222561%
#
# Param is 110
# Time elapsed: 12.010398626327515 sec
# average relative error of u: 0.2801563881076047%
# maximum relative error of u: 0.6115436226655611%
#
# Param is 111
# Time elapsed: 11.933747291564941 sec
# average relative error of u: 0.2782944995111973%
# maximum relative error of u: 0.6202495102372375%
#
# Param is 112
# Time elapsed: 12.043462038040161 sec
# average relative error of u: 0.27758832044853454%
# maximum relative error of u: 0.6280792692054886%
#
# Param is 113
# Time elapsed: 11.950731039047241 sec
# average relative error of u: 0.2783068755880452%
# maximum relative error of u: 0.635152904110009%
#
# Param is 114
# Time elapsed: 12.519513368606567 sec
# average relative error of u: 0.2807373156105881%
# maximum relative error of u: 0.6412000547804758%
#
# Param is 115
# Time elapsed: 13.327996492385864 sec
# average relative error of u: 0.28515918846482285%
# maximum relative error of u: 0.6466941400158763%
#
# Param is 116
# Time elapsed: 12.923802614212036 sec
# average relative error of u: 0.29183586827007735%
# maximum relative error of u: 0.6514341069506486%
#
# Param is 117
# Time elapsed: 12.887427568435669 sec
# average relative error of u: 0.30098667564777287%
# maximum relative error of u: 0.6555678835505029%
#
# Param is 118
# Time elapsed: 12.804255485534668 sec
# average relative error of u: 0.312793764352254%
# maximum relative error of u: 0.6595903420683383%
#
# Param is 119
# Time elapsed: 13.001139163970947 sec
# average relative error of u: 0.3273760043628156%
# maximum relative error of u: 0.664121565839528%
#
# Param is 120
# Time elapsed: 12.764482975006104 sec
# average relative error of u: 0.34480330377010404%
# maximum relative error of u: 0.6712179606963294%
#
# Param is 121
# Time elapsed: 12.800048589706421 sec
# average relative error of u: 0.3650943801468796%
# maximum relative error of u: 0.6785732205920151%
#
# Param is 122
# Time elapsed: 12.681642532348633 sec
# average relative error of u: 0.3882313051132264%
# maximum relative error of u: 0.6865956392603066%
#
# Param is 123
# Time elapsed: 12.793572902679443 sec
# average relative error of u: 0.4141737177828407%
# maximum relative error of u: 0.6955458537102055%
#
# Param is 124
# Time elapsed: 12.665992975234985 sec
# average relative error of u: 0.4428588606957067%
# maximum relative error of u: 0.7058597670631406%
#
# Param is 125
# Time elapsed: 12.760677576065063 sec
# average relative error of u: 0.47422070536690447%
# maximum relative error of u: 0.7452640981779709%
#
# Dim. of latent space is 6
# # of measurments: 12
# [  61  108  274  366  732  831  915 1089 1801 2930 3302 3538]
# Param is 75
# Time elapsed: 14.519651174545288 sec
# average relative error of u: 0.5415543515778583%
# maximum relative error of u: 1.211092886195645%
#
# Param is 76
# Time elapsed: 14.323499202728271 sec
# average relative error of u: 0.5191473075239281%
# maximum relative error of u: 1.1519728221621324%
#
# Param is 77
# Time elapsed: 14.54408597946167 sec
# average relative error of u: 0.49882875704311225%
# maximum relative error of u: 1.095687506457034%
#
# Param is 78
# Time elapsed: 14.104966640472412 sec
# average relative error of u: 0.48046512077058273%
# maximum relative error of u: 1.0423167428811977%
#
# Param is 79
# Time elapsed: 14.22020149230957 sec
# average relative error of u: 0.4638997131180868%
# maximum relative error of u: 0.9914172897561104%
#
# Param is 80
# Time elapsed: 14.68746280670166 sec
# average relative error of u: 0.4490098082404846%
# maximum relative error of u: 0.9431633875291281%
#
# Param is 81
# Time elapsed: 13.91736102104187 sec
# average relative error of u: 0.43567215615108856%
# maximum relative error of u: 0.8971703879314106%
#
# Param is 82
# Time elapsed: 12.667140245437622 sec
# average relative error of u: 0.423778297036442%
# maximum relative error of u: 0.8534870128957347%
#
# Param is 83
# Time elapsed: 12.927046775817871 sec
# average relative error of u: 0.4132217185476219%
# maximum relative error of u: 0.8120840575649715%
#
# Param is 84
# Time elapsed: 12.96474552154541 sec
# average relative error of u: 0.4039090953578157%
# maximum relative error of u: 0.7866902076070702%
#
# Param is 85
# Time elapsed: 13.203726768493652 sec
# average relative error of u: 0.3957567112301856%
# maximum relative error of u: 0.7681229114426091%
#
# Param is 86
# Time elapsed: 13.299226522445679 sec
# average relative error of u: 0.3886764689345954%
# maximum relative error of u: 0.7492477626486673%
#
# Param is 87
# Time elapsed: 13.06180214881897 sec
# average relative error of u: 0.38260095461554866%
# maximum relative error of u: 0.7303900988277439%
#
# Param is 88
# Time elapsed: 13.001790046691895 sec
# average relative error of u: 0.3774534020057546%
# maximum relative error of u: 0.728114193727245%
#
# Param is 89
# Time elapsed: 13.334620475769043 sec
# average relative error of u: 0.3731614076435726%
# maximum relative error of u: 0.7351303360296065%
#
# Param is 90
# Time elapsed: 13.368409395217896 sec
# average relative error of u: 0.36964057224038344%
# maximum relative error of u: 0.7434054364689135%
#
# Param is 91
# Time elapsed: 14.331243515014648 sec
# average relative error of u: 0.36682517178745205%
# maximum relative error of u: 0.752606091175966%
#
# Param is 92
# Time elapsed: 14.733427286148071 sec
# average relative error of u: 0.36462828494525934%
# maximum relative error of u: 0.7628534919494565%
#
# Param is 93
# Time elapsed: 14.591564655303955 sec
# average relative error of u: 0.3629701994615568%
# maximum relative error of u: 0.7738498786176241%
#
# Param is 94
# Time elapsed: 14.168361186981201 sec
# average relative error of u: 0.36176015593115435%
# maximum relative error of u: 0.7904880553237535%
#
# Param is 95
# Time elapsed: 13.991938829421997 sec
# average relative error of u: 0.360905485441401%
# maximum relative error of u: 0.8284967360913661%
#
# Param is 96
# Time elapsed: 14.234920263290405 sec
# average relative error of u: 0.3603268639568144%
# maximum relative error of u: 0.8637395123302684%
#
# Param is 97
# Time elapsed: 14.132694005966187 sec
# average relative error of u: 0.359929939281676%
# maximum relative error of u: 0.8957043275805001%
#
# Param is 98
# Time elapsed: 14.109129190444946 sec
# average relative error of u: 0.3596365263294416%
# maximum relative error of u: 0.9235371798878369%
#
# Param is 99
# Time elapsed: 14.066790580749512 sec
# average relative error of u: 0.35937022763605336%
# maximum relative error of u: 0.9462477396064685%
#
# Param is 100
# Time elapsed: 14.07265329360962 sec
# average relative error of u: 0.359077847663683%
# maximum relative error of u: 0.9642739698112487%
#
# Param is 101
# Time elapsed: 14.238672018051147 sec
# average relative error of u: 0.35871071019939205%
# maximum relative error of u: 0.9759757819150056%
#
# Param is 102
# Time elapsed: 14.05235242843628 sec
# average relative error of u: 0.3582504778838057%
# maximum relative error of u: 0.981957350348522%
#
# Param is 103
# Time elapsed: 14.23665738105774 sec
# average relative error of u: 0.35767427663885815%
# maximum relative error of u: 0.9818493687402221%
#
# Param is 104
# Time elapsed: 14.133814811706543 sec
# average relative error of u: 0.3570005293682513%
# maximum relative error of u: 0.9756315713827308%
#
# Param is 105
# Time elapsed: 14.130409717559814 sec
# average relative error of u: 0.3562562074437997%
# maximum relative error of u: 0.963177715594694%
#
# Param is 106
# Time elapsed: 13.737803220748901 sec
# average relative error of u: 0.3554850254847681%
# maximum relative error of u: 0.9918153408670952%
#
# Param is 107
# Time elapsed: 14.475542783737183 sec
# average relative error of u: 0.354746622129665%
# maximum relative error of u: 1.0328976535895849%
#
# Param is 108
# Time elapsed: 15.073894262313843 sec
# average relative error of u: 0.35410087782671823%
# maximum relative error of u: 1.0718888491727818%
#
# Param is 109
# Time elapsed: 14.987684726715088 sec
# average relative error of u: 0.35361772301741934%
# maximum relative error of u: 1.1078294287289208%
#
# Param is 110
# Time elapsed: 14.89972186088562 sec
# average relative error of u: 0.35337952136790207%
# maximum relative error of u: 1.1397822028207663%
#
# Param is 111
# Time elapsed: 14.984236478805542 sec
# average relative error of u: 0.3534614563726761%
# maximum relative error of u: 1.166757320159585%
#
# Param is 112
# Time elapsed: 14.090240478515625 sec
# average relative error of u: 0.35396763068596376%
# maximum relative error of u: 1.1872912236672477%
#
# Param is 113
# Time elapsed: 14.260646104812622 sec
# average relative error of u: 0.3550145357040221%
# maximum relative error of u: 1.201062924887657%
#
# Param is 114
# Time elapsed: 14.09691047668457 sec
# average relative error of u: 0.3567474086181743%
# maximum relative error of u: 1.2073721520189193%
#
# Param is 115
# Time elapsed: 14.211832046508789 sec
# average relative error of u: 0.359360081819038%
# maximum relative error of u: 1.2055116127832388%
#
# Param is 116
# Time elapsed: 14.163088083267212 sec
# average relative error of u: 0.3631097749491467%
# maximum relative error of u: 1.1955451286760819%
#
# Param is 117
# Time elapsed: 14.247101068496704 sec
# average relative error of u: 0.3683394791269874%
# maximum relative error of u: 1.1782821051263308%
#
# Param is 118
# Time elapsed: 13.995008707046509 sec
# average relative error of u: 0.37547512898265567%
# maximum relative error of u: 1.1554289355097995%
#
# Param is 119
# Time elapsed: 14.161219358444214 sec
# average relative error of u: 0.38505456116027326%
# maximum relative error of u: 1.1240394288993998%
#
# Param is 120
# Time elapsed: 14.071293354034424 sec
# average relative error of u: 0.3976623894952393%
# maximum relative error of u: 1.1502925686372591%
#
# Param is 121
# Time elapsed: 14.065315008163452 sec
# average relative error of u: 0.41398640393150504%
# maximum relative error of u: 1.1858942473048326%
#
# Param is 122
# Time elapsed: 13.975742816925049 sec
# average relative error of u: 0.4347397841446751%
# maximum relative error of u: 1.2224704733752512%
#
# Param is 123
# Time elapsed: 14.085031270980835 sec
# average relative error of u: 0.4605471362060281%
# maximum relative error of u: 1.2603249368746925%
#
# Param is 124
# Time elapsed: 14.067235231399536 sec
# average relative error of u: 0.4919538459459475%
# maximum relative error of u: 1.299761178272285%
#
# Param is 125
# Time elapsed: 14.29747462272644 sec
# average relative error of u: 0.5292306703095496%
# maximum relative error of u: 1.340919550769918%

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

idx=[0,1,2,3]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_AE_inner_DEIM_avg_rel_err_seed_{}.png".format(seed))

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_AE_inner_DEIM_max_rel_err_seed_{}.png".format(seed))
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

idx = [2]

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:  
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['avg_rel_err'][i][p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
plt.show()

# figure rel.err vs data points
plt.figure(figsize=(10,5)) 
for i in idx:  
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
#     plt.scatter(FOM_parameters[p_inter:-p_inter:p_inter],results['rel_err'][i].max(axis=1)[p_inter:-p_inter:p_inter], color = 'blue')
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["Latent Space Dim. "+str(f) for f in f_list[idx]])
plt.title('Max. Rel. Err. vs Parameters')
plt.show()

# %%
print(f_list)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=3; j=-1        
f=f_list[i]
param=FOM_parameters[j]

u_gappyAE=results['solution'][i,j]

ex = np.load('./wave_data/ex23_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("Latent Dim: {}, Param: {}".format(f,param))
plt.show()

# error
u_rel_err_gappyAE=np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)\
                 /np.linalg.norm(u_full,ord=2,axis=1)*100
u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyAE,ord=2,axis=1)**2))\
             /np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
print("average relative error of u: {}%".format(u_avg_rel_err))
print()
print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyAE)))
    
# plot original data
vmin=-1; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyAE[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy AE @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_AE_{}_param_{}_inner_DEIM_SOL_seed_{}.png".format(f,param,seed))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx),vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)

fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_param_{}_ground_truth.png".format(param))
# Out:
# average relative error of u: 0.5292306703095496%
#
# maximum relative error of u: 1.340919550769918%

# %%
i=3; j=-1
f=f_list[i]; param=FOM_parameters[j]
print("f={}".format(f))
print("param={}".format(param))
plt.plot(results['reduced'][i,j][:,:f])
plt.legend(np.arange(f))
plt.show()
# Out:
# f=6
# param=125
