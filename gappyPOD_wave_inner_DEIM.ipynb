# %%
import numpy as np
from scipy import sparse as sp
from scipy.sparse.linalg import spsolve
from matplotlib import pyplot as plt
from matplotlib.ticker import IndexLocator
import time, sys
import pickle

# %%
# Given parameters
nx = 60
ny = 60
tf = 5.0
dt = 1.0e-2
nt = int(tf/dt)
xmin = 0; xmax = 1
ymin = 0; ymax = 1
dims=(nx,ny)

# POD basis
num_basis=np.array([3,4,5,6])
print('num_basis {}'.format(num_basis))

# parameters
p_inter=5
FOM_parameters = np.arange(75,125+1,1,dtype=int)
print("Prediction Parameters: {}".format(FOM_parameters))
print("training parameters={}".format(FOM_parameters[p_inter:-p_inter:p_inter]))

# generate mesh grid
[xv,yv]=np.meshgrid(np.linspace(xmin,xmax,nx),np.linspace(ymin,ymax,ny),indexing='xy')
x=xv.flatten()
y=yv.flatten()

# file path
file_path_gappy_DEIM_result = "./wave_result/ex23_POD_inner_DEIM_gappy_result.p"
file_name_SVD="./wave_model/ex23_SVD.p"

# full, inner, bc index
multi_index_i,multi_index_j=np.meshgrid(np.arange(nx),np.arange(ny),indexing='xy')
full_multi_index=(multi_index_j.flatten(),multi_index_i.flatten())
x0_multi_index=(multi_index_j[:,0].flatten(),multi_index_i[:,0].flatten())
x1_multi_index=(multi_index_j[:,-1].flatten(),multi_index_i[:,-1].flatten())
y0_multi_index=(multi_index_j[0,:].flatten(),multi_index_i[0,:].flatten())
y1_multi_index=(multi_index_j[-1,:].flatten(),multi_index_i[-1,:].flatten())

dims=(ny,nx)
full_raveled_indicies=np.ravel_multi_index(full_multi_index,dims)
x0_raveled_indicies=np.ravel_multi_index(x0_multi_index,dims)
x1_raveled_indicies=np.ravel_multi_index(x1_multi_index,dims)
y0_raveled_indicies=np.ravel_multi_index(y0_multi_index,dims)
y1_raveled_indicies=np.ravel_multi_index(y1_multi_index,dims)
bc_raveled_indicies=np.unique(np.concatenate((x0_raveled_indicies,x1_raveled_indicies,
                                              y0_raveled_indicies,y1_raveled_indicies)))
inner_raveled_indicies=np.setdiff1d(full_raveled_indicies,bc_raveled_indicies)
# Out:
# num_basis [3 4 5 6]
# Prediction Parameters: [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]
# training parameters=[ 80  85  90  95 100 105 110 115 120]

# %%
# Jessi 알고리즘
def DEIM(phi_f, nfeval, unseen=np.array([])):
    
    ninf=np.NINF
    n,m=np.shape(phi_f)
    
    l=0
    u=np.reshape(phi_f[:,l],(n,1))
    r=np.abs(u)
    if len(unseen) >0 :
        r[unseen]=ninf
    p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
    p=p_temp
    U=u
    
    ns=int(np.ceil((nfeval-1)/(m-1)))
    for l in range(1,m):
        u=np.reshape(phi_f[:,l],(n,1))
        for k in range(ns):
            if len(p)==nfeval:
                return p
            c=np.linalg.lstsq(U[p,:],u[p,:],rcond=None)[0]
            r=np.abs(u-U@c)
            r[p]=ninf
            if len(unseen) > 0:
                r[unseen]=ninf
            p_temp=np.argsort(-r,axis=0,kind='stable')[:1][0]
            p=np.sort(np.append(p,p_temp))
        U=np.concatenate((U,u),axis=1)
         
    return p

# %%
with open(file=file_name_SVD, mode='rb') as ff:  
    SVD = pickle.load(ff)

for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    
    # DEIM
    num_msmt=12

    phi_DEIM=SVD['U'][:,:POD_basis]

    msmt_idx=DEIM(phi_DEIM,num_msmt,bc_raveled_indicies)
    msmt_idx.sort()

    print("# of measurments: {}".format(len(msmt_idx)))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.savefig("./wave_result/ex23_POD_{}_inner_DEIM_{}_samples.png".format(POD_basis,num_msmt))
# Out:
# # of measurments: 12
# [  61   62  117  118  121  178 3421 3478 3481 3482 3537 3538]
# # of measurments: 12
# [  61   62  117  118 1892 1951 1952 3421 3478 3481 3537 3538]
# # of measurments: 12
# [  61   62   89   90  117  118 1892 1951 1952 3478 3481 3538]
# # of measurments: 12
# [  61   62   89   90  117  118 1892 1951 1952 3478 3481 3538]

# %% [markdown]
# # gappyPOD

# %%
solution=np.zeros((len(num_basis),len(FOM_parameters),nt+1,nx*ny))
avg_rel_err=np.zeros((len(num_basis),len(FOM_parameters)))
rel_err=np.zeros((len(num_basis),len(FOM_parameters),nt+1))
elapsed_time=np.zeros((len(num_basis),len(FOM_parameters)))

with open(file=file_name_SVD, mode='rb') as ff:  
    SVD = pickle.load(ff)

for ii in range(len(num_basis)):
    POD_basis=num_basis[ii]
    print("# of POD basis is {}".format(POD_basis))
    
    # DEIM
    num_msmt=12
    
    phi_DEIM=SVD['U'][:,:POD_basis]

    msmt_idx=DEIM(phi_DEIM,num_msmt,bc_raveled_indicies)
    msmt_idx.sort()

    print("# of measurments: {}".format(len(msmt_idx)))
    print(msmt_idx)

    # plot measuremnt positions
    plt.figure()
    plt.scatter(x[msmt_idx],y[msmt_idx], color = 'blue')
    plt.axis('square')
    plt.axis([xmin,xmax,ymin,ymax])
    plt.show()
    
    # Basis matrix
    phi_u = SVD['U'][:,:POD_basis]

    phim_u=phi_u[msmt_idx]
    phim_u_pinv=np.linalg.pinv(phim_u)
    
    for jj in range(len(FOM_parameters)):
        FOM_parameter=FOM_parameters[jj]
        print("Param is {}".format(FOM_parameter))
        
        # Load FOM solution
        ex = np.load('./wave_data/ex23_interp_{}.npz'.format(FOM_parameter), allow_pickle = True)
        ex = ex.f.arr_0
        u_full = ex.reshape(nt+1,-1)

        # take measurments
        um = u_full[:,msmt_idx]

        # Initial condition
        u0=u_full[0]
        u_ref = u0

        # Gappy POD
        t_start_gappyPOD=time.time()

        # solution
        u_gappyPOD=np.zeros((nt+1,ny*nx))
        u_hat=np.zeros((nt+1,POD_basis))

        # IC
        u_hat0=np.zeros(POD_basis)
        u_gappyPOD[0]=np.copy(u0)

        for n in range(nt):
            u_hat[n+1] = phim_u_pinv.dot(um[n+1]-u_ref[msmt_idx])
            u_gappyPOD[n+1] = u_ref + phi_u.dot(u_hat[n+1])

        # elapsed time
        t_elapsed_gappyPOD=time.time()-t_start_gappyPOD
        print('Time elapsed: {} sec'.format(t_elapsed_gappyPOD))

        # error
        u_rel_err_gappyPOD=np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)/np.linalg.norm(u_full,ord=2,axis=1)*100
        u_avg_rel_err=np.sqrt(np.sum(np.linalg.norm(u_full-u_gappyPOD,ord=2,axis=1)**2))/np.sqrt(np.sum(np.linalg.norm(u_full,ord=2,axis=1)**2))*100
        print("average relative error of u: {}%".format(u_avg_rel_err))
        print("maximum relative error of u: {}%".format(np.max(u_rel_err_gappyPOD)))
        print()

        # save result
        solution[ii,jj]=u_gappyPOD
        avg_rel_err[ii,jj]=u_avg_rel_err
        rel_err[ii,jj]=u_rel_err_gappyPOD
        elapsed_time[ii,jj]=t_elapsed_gappyPOD
    
results={'solution':solution,'avg_rel_err':avg_rel_err,'rel_err':rel_err,'elapsed_time':elapsed_time}
with open(file=file_path_gappy_DEIM_result, mode='wb') as ff:
    pickle.dump(results, ff)
# Out:
# # of POD basis is 3
# # of measurments: 12
# [  61   62  117  118  121  178 3421 3478 3481 3482 3537 3538]
# Param is 75
# Time elapsed: 1.5600407123565674 sec
# average relative error of u: 5.644636138694371%
# maximum relative error of u: 7.4841108634327815%
#
# Param is 76
# Time elapsed: 1.601029634475708 sec
# average relative error of u: 5.279056180141298%
# maximum relative error of u: 7.0807907861930435%
#
# Param is 77
# Time elapsed: 1.6295971870422363 sec
# average relative error of u: 4.9496980267298065%
# maximum relative error of u: 6.718047597470071%
#
# Param is 78
# Time elapsed: 1.5961203575134277 sec
# average relative error of u: 4.667433902235145%
# maximum relative error of u: 6.390233272978968%
#
# Param is 79
# Time elapsed: 1.7931432723999023 sec
# average relative error of u: 4.444830653399405%
# maximum relative error of u: 6.13599888876341%
#
# Param is 80
# Time elapsed: 1.5778546333312988 sec
# average relative error of u: 4.294625613167622%
# maximum relative error of u: 5.9394257157449895%
#
# Param is 81
# Time elapsed: 1.5853557586669922 sec
# average relative error of u: 4.227995585717093%
# maximum relative error of u: 5.796013222715344%
#
# Param is 82
# Time elapsed: 1.3719594478607178 sec
# average relative error of u: 4.252271632737003%
# maximum relative error of u: 5.809995585211672%
#
# Param is 83
# Time elapsed: 1.4070136547088623 sec
# average relative error of u: 4.369073671196198%
# maximum relative error of u: 6.328933065539669%
#
# Param is 84
# Time elapsed: 1.2529308795928955 sec
# average relative error of u: 4.574326838832952%
# maximum relative error of u: 7.11800784580486%
#
# Param is 85
# Time elapsed: 1.3723857402801514 sec
# average relative error of u: 4.859455131985186%
# maximum relative error of u: 8.056561495445026%
#
# Param is 86
# Time elapsed: 1.4557421207427979 sec
# average relative error of u: 5.21388847354594%
# maximum relative error of u: 9.092784402068782%
#
# Param is 87
# Time elapsed: 1.9263842105865479 sec
# average relative error of u: 5.626670514696498%
# maximum relative error of u: 10.197571939503531%
#
# Param is 88
# Time elapsed: 1.7370924949645996 sec
# average relative error of u: 6.0879605232885545%
# maximum relative error of u: 11.344071800394897%
#
# Param is 89
# Time elapsed: 1.4569001197814941 sec
# average relative error of u: 6.589258803829856%
# maximum relative error of u: 12.525863905828082%
#
# Param is 90
# Time elapsed: 1.4956386089324951 sec
# average relative error of u: 7.123766605777917%
# maximum relative error of u: 13.74353110025216%
#
# Param is 91
# Time elapsed: 1.594264268875122 sec
# average relative error of u: 7.685896249227353%
# maximum relative error of u: 14.991306701834246%
#
# Param is 92
# Time elapsed: 1.6671714782714844 sec
# average relative error of u: 8.271315319383193%
# maximum relative error of u: 16.262990021841368%
#
# Param is 93
# Time elapsed: 1.6225953102111816 sec
# average relative error of u: 8.876523553639922%
# maximum relative error of u: 17.556813644191603%
#
# Param is 94
# Time elapsed: 1.4901559352874756 sec
# average relative error of u: 9.498728655286182%
# maximum relative error of u: 18.87127403065873%
#
# Param is 95
# Time elapsed: 1.6230137348175049 sec
# average relative error of u: 10.135766022753717%
# maximum relative error of u: 20.20501373929701%
#
# Param is 96
# Time elapsed: 1.3896124362945557 sec
# average relative error of u: 10.785750667056508%
# maximum relative error of u: 21.557155116465502%
#
# Param is 97
# Time elapsed: 1.4150748252868652 sec
# average relative error of u: 11.447275667168443%
# maximum relative error of u: 22.926690710947078%
#
# Param is 98
# Time elapsed: 1.7095756530761719 sec
# average relative error of u: 12.119074173759472%
# maximum relative error of u: 24.313041857573296%
#
# Param is 99
# Time elapsed: 1.687591314315796 sec
# average relative error of u: 12.800180353435639%
# maximum relative error of u: 25.715389112070746%
#
# Param is 100
# Time elapsed: 1.7126755714416504 sec
# average relative error of u: 13.489640027281133%
# maximum relative error of u: 27.132944900307184%
#
# Param is 101
# Time elapsed: 1.7704689502716064 sec
# average relative error of u: 14.186811636465094%
# maximum relative error of u: 28.565424980557115%
#
# Param is 102
# Time elapsed: 1.5661773681640625 sec
# average relative error of u: 14.890970447348389%
# maximum relative error of u: 30.012073100944182%
#
# Param is 103
# Time elapsed: 1.6057755947113037 sec
# average relative error of u: 15.601680650364278%
# maximum relative error of u: 31.472566066068914%
#
# Param is 104
# Time elapsed: 1.6170759201049805 sec
# average relative error of u: 16.318347200348736%
# maximum relative error of u: 32.9462535556104%
#
# Param is 105
# Time elapsed: 1.4202604293823242 sec
# average relative error of u: 17.040548213784493%
# maximum relative error of u: 34.43266576382082%
#
# Param is 106
# Time elapsed: 1.4806602001190186 sec
# average relative error of u: 17.767991179262225%
# maximum relative error of u: 35.93146362169912%
#
# Param is 107
# Time elapsed: 1.3460626602172852 sec
# average relative error of u: 18.500186145110746%
# maximum relative error of u: 37.44216972802266%
#
# Param is 108
# Time elapsed: 1.3557405471801758 sec
# average relative error of u: 19.236926115136377%
# maximum relative error of u: 38.964325654590525%
#
# Param is 109
# Time elapsed: 1.2914152145385742 sec
# average relative error of u: 19.97787010551222%
# maximum relative error of u: 40.497571057342526%
#
# Param is 110
# Time elapsed: 1.3713586330413818 sec
# average relative error of u: 20.72277518937659%
# maximum relative error of u: 42.04144922151218%
#
# Param is 111
# Time elapsed: 1.4636821746826172 sec
# average relative error of u: 21.47140595845566%
# maximum relative error of u: 43.59567930562345%
#
# Param is 112
# Time elapsed: 1.3228464126586914 sec
# average relative error of u: 22.22343524853404%
# maximum relative error of u: 45.159671726502886%
#
# Param is 113
# Time elapsed: 1.491647720336914 sec
# average relative error of u: 22.978806859521633%
# maximum relative error of u: 46.73317483651988%
#
# Param is 114
# Time elapsed: 1.5396935939788818 sec
# average relative error of u: 23.737185339704098%
# maximum relative error of u: 48.31583304629981%
#
# Param is 115
# Time elapsed: 1.568927526473999 sec
# average relative error of u: 24.498478721075188%
# maximum relative error of u: 49.907196307942634%
#
# Param is 116
# Time elapsed: 1.5604431629180908 sec
# average relative error of u: 25.26245151258855%
# maximum relative error of u: 51.50695832609682%
#
# Param is 117
# Time elapsed: 1.399688720703125 sec
# average relative error of u: 26.028971006638248%
# maximum relative error of u: 53.114751133783%
#
# Param is 118
# Time elapsed: 1.6869041919708252 sec
# average relative error of u: 26.797857024611815%
# maximum relative error of u: 54.73015376489202%
#
# Param is 119
# Time elapsed: 1.5925779342651367 sec
# average relative error of u: 27.56894991574929%
# maximum relative error of u: 56.35287949479353%
#
# Param is 120
# Time elapsed: 1.7027733325958252 sec
# average relative error of u: 28.342133782411327%
# maximum relative error of u: 57.98249192245329%
#
# Param is 121
# Time elapsed: 1.7180588245391846 sec
# average relative error of u: 29.11719378983185%
# maximum relative error of u: 59.618632610892895%
#
# Param is 122
# Time elapsed: 1.8316123485565186 sec
# average relative error of u: 29.894092876338547%
# maximum relative error of u: 61.26108533654132%
#
# Param is 123
# Time elapsed: 1.8675813674926758 sec
# average relative error of u: 30.67273412853692%
# maximum relative error of u: 62.91323562295168%
#
# Param is 124
# Time elapsed: 1.6748602390289307 sec
# average relative error of u: 31.452828692314554%
# maximum relative error of u: 64.57497466462853%
#
# Param is 125
# Time elapsed: 1.4579541683197021 sec
# average relative error of u: 32.23441594566502%
# maximum relative error of u: 66.24234990341003%
#
# # of POD basis is 4
# # of measurments: 12
# [  61   62  117  118 1892 1951 1952 3421 3478 3481 3537 3538]
# Param is 75
# Time elapsed: 1.8231661319732666 sec
# average relative error of u: 4.228954966034965%
# maximum relative error of u: 6.041234284567423%
#
# Param is 76
# Time elapsed: 2.0233850479125977 sec
# average relative error of u: 4.1461414974112785%
# maximum relative error of u: 5.96453240179819%
#
# Param is 77
# Time elapsed: 1.9116065502166748 sec
# average relative error of u: 4.076872175469429%
# maximum relative error of u: 5.888884171843245%
#
# Param is 78
# Time elapsed: 1.8645071983337402 sec
# average relative error of u: 4.023379465181982%
# maximum relative error of u: 5.814529465026375%
#
# Param is 79
# Time elapsed: 1.6815478801727295 sec
# average relative error of u: 3.9879258717645896%
# maximum relative error of u: 5.741473893446046%
#
# Param is 80
# Time elapsed: 1.4746387004852295 sec
# average relative error of u: 3.972560931971182%
# maximum relative error of u: 5.686645873472645%
#
# Param is 81
# Time elapsed: 1.4497146606445312 sec
# average relative error of u: 3.9791208039687977%
# maximum relative error of u: 5.766323615537546%
#
# Param is 82
# Time elapsed: 1.4511122703552246 sec
# average relative error of u: 4.0091745364050455%
# maximum relative error of u: 5.908699893974032%
#
# Param is 83
# Time elapsed: 1.6271421909332275 sec
# average relative error of u: 4.063720712501545%
# maximum relative error of u: 6.117402003297653%
#
# Param is 84
# Time elapsed: 1.6469810009002686 sec
# average relative error of u: 4.143445139472677%
# maximum relative error of u: 6.400723651180272%
#
# Param is 85
# Time elapsed: 1.8494126796722412 sec
# average relative error of u: 4.248366807643716%
# maximum relative error of u: 6.77189080159429%
#
# Param is 86
# Time elapsed: 1.7708892822265625 sec
# average relative error of u: 4.378258098343347%
# maximum relative error of u: 7.22055837051495%
#
# Param is 87
# Time elapsed: 1.6718642711639404 sec
# average relative error of u: 4.53230405528197%
# maximum relative error of u: 7.731451247856752%
#
# Param is 88
# Time elapsed: 1.6067068576812744 sec
# average relative error of u: 4.7095994236777186%
# maximum relative error of u: 8.291917026127836%
#
# Param is 89
# Time elapsed: 1.6588919162750244 sec
# average relative error of u: 4.908871595967522%
# maximum relative error of u: 8.894201028744595%
#
# Param is 90
# Time elapsed: 1.6878180503845215 sec
# average relative error of u: 5.128847288046783%
# maximum relative error of u: 9.526643873793542%
#
# Param is 91
# Time elapsed: 1.6475398540496826 sec
# average relative error of u: 5.368123716810215%
# maximum relative error of u: 10.188024055772257%
#
# Param is 92
# Time elapsed: 1.7096374034881592 sec
# average relative error of u: 5.625407131390292%
# maximum relative error of u: 10.877045324987687%
#
# Param is 93
# Time elapsed: 1.5789451599121094 sec
# average relative error of u: 5.899388202637705%
# maximum relative error of u: 11.587920756409808%
#
# Param is 94
# Time elapsed: 1.512955665588379 sec
# average relative error of u: 6.188832055001773%
# maximum relative error of u: 12.319561374530242%
#
# Param is 95
# Time elapsed: 1.6388778686523438 sec
# average relative error of u: 6.492663041120933%
# maximum relative error of u: 13.070868818638107%
#
# Param is 96
# Time elapsed: 1.6953823566436768 sec
# average relative error of u: 6.809773854855989%
# maximum relative error of u: 13.841110295392442%
#
# Param is 97
# Time elapsed: 1.6638586521148682 sec
# average relative error of u: 7.139297888076043%
# maximum relative error of u: 14.629530773958784%
#
# Param is 98
# Time elapsed: 1.7129957675933838 sec
# average relative error of u: 7.480355872238621%
# maximum relative error of u: 15.439431842624094%
#
# Param is 99
# Time elapsed: 1.8713104724884033 sec
# average relative error of u: 7.832198566996561%
# maximum relative error of u: 16.26615171923664%
#
# Param is 100
# Time elapsed: 2.079582691192627 sec
# average relative error of u: 8.194099215681756%
# maximum relative error of u: 17.108933119058722%
#
# Param is 101
# Time elapsed: 1.752868890762329 sec
# average relative error of u: 8.565488239120153%
# maximum relative error of u: 17.967440412472005%
#
# Param is 102
# Time elapsed: 1.7333705425262451 sec
# average relative error of u: 8.945734393181763%
# maximum relative error of u: 18.841207314643622%
#
# Param is 103
# Time elapsed: 1.5580494403839111 sec
# average relative error of u: 9.334440657213596%
# maximum relative error of u: 19.729736436709892%
#
# Param is 104
# Time elapsed: 1.516913652420044 sec
# average relative error of u: 9.731058778036413%
# maximum relative error of u: 20.632649591694264%
#
# Param is 105
# Time elapsed: 1.83404541015625 sec
# average relative error of u: 10.135190537377943%
# maximum relative error of u: 21.54962431085872%
#
# Param is 106
# Time elapsed: 1.8213512897491455 sec
# average relative error of u: 10.546513137070821%
# maximum relative error of u: 22.480263488744136%
#
# Param is 107
# Time elapsed: 1.7814843654632568 sec
# average relative error of u: 10.964573962299031%
# maximum relative error of u: 23.42411936258301%
#
# Param is 108
# Time elapsed: 1.8916840553283691 sec
# average relative error of u: 11.389142672117703%
# maximum relative error of u: 24.38106228526208%
#
# Param is 109
# Time elapsed: 1.964019775390625 sec
# average relative error of u: 11.819894857217738%
# maximum relative error of u: 25.350637357771582%
#
# Param is 110
# Time elapsed: 1.9764950275421143 sec
# average relative error of u: 12.256557250870694%
# maximum relative error of u: 26.332562176362305%
#
# Param is 111
# Time elapsed: 1.9609837532043457 sec
# average relative error of u: 12.698900213620348%
# maximum relative error of u: 27.32653516900231%
#
# Param is 112
# Time elapsed: 2.1422977447509766 sec
# average relative error of u: 13.146601880825019%
# maximum relative error of u: 28.332056936522783%
#
# Param is 113
# Time elapsed: 1.9847090244293213 sec
# average relative error of u: 13.599578630826892%
# maximum relative error of u: 29.349167078761525%
#
# Param is 114
# Time elapsed: 2.113002300262451 sec
# average relative error of u: 14.057515792501032%
# maximum relative error of u: 30.37735610833641%
#
# Param is 115
# Time elapsed: 1.6556694507598877 sec
# average relative error of u: 14.520290551358459%
# maximum relative error of u: 31.416347583267708%
#
# Param is 116
# Time elapsed: 1.7945597171783447 sec
# average relative error of u: 14.987682529895608%
# maximum relative error of u: 32.46591610029489%
#
# Param is 117
# Time elapsed: 1.9145500659942627 sec
# average relative error of u: 15.45954974064189%
# maximum relative error of u: 33.52579739552035%
#
# Param is 118
# Time elapsed: 2.4949657917022705 sec
# average relative error of u: 15.935685232060603%
# maximum relative error of u: 34.595601395675416%
#
# Param is 119
# Time elapsed: 1.9640777111053467 sec
# average relative error of u: 16.41597758556978%
# maximum relative error of u: 35.675149178508754%
#
# Param is 120
# Time elapsed: 1.429546594619751 sec
# average relative error of u: 16.900254983200654%
# maximum relative error of u: 36.764104371593085%
#
# Param is 121
# Time elapsed: 1.1775059700012207 sec
# average relative error of u: 17.388349196291436%
# maximum relative error of u: 37.86217663453833%
#
# Param is 122
# Time elapsed: 11.335565328598022 sec
# average relative error of u: 17.880163718165544%
# maximum relative error of u: 38.96913240464533%
#
# Param is 123
# Time elapsed: 13.52357268333435 sec
# average relative error of u: 18.37563605282983%
# maximum relative error of u: 40.08481077649249%
#
# Param is 124
# Time elapsed: 2.4955766201019287 sec
# average relative error of u: 18.87447715369493%
# maximum relative error of u: 41.20869927709676%
#
# Param is 125
# Time elapsed: 1.3058509826660156 sec
# average relative error of u: 19.376703035868957%
# maximum relative error of u: 42.34072704993717%
#
# # of POD basis is 5
# # of measurments: 12
# [  61   62   89   90  117  118 1892 1951 1952 3478 3481 3538]
# Param is 75
# Time elapsed: 1.185922622680664 sec
# average relative error of u: 4.309208508881593%
# maximum relative error of u: 6.2177993656059956%
#
# Param is 76
# Time elapsed: 2.2942469120025635 sec
# average relative error of u: 4.250127513346443%
# maximum relative error of u: 6.126005073805345%
#
# Param is 77
# Time elapsed: 1.4469852447509766 sec
# average relative error of u: 4.190532056231444%
# maximum relative error of u: 6.0338725663444865%
#
# Param is 78
# Time elapsed: 7.202203035354614 sec
# average relative error of u: 4.130448947704325%
# maximum relative error of u: 5.941528919876066%
#
# Param is 79
# Time elapsed: 11.473732471466064 sec
# average relative error of u: 4.069989124498319%
# maximum relative error of u: 5.84899944309928%
#
# Param is 80
# Time elapsed: 1.2861945629119873 sec
# average relative error of u: 4.009173593621415%
# maximum relative error of u: 5.756450420204277%
#
# Param is 81
# Time elapsed: 1.3026623725891113 sec
# average relative error of u: 3.948008084718558%
# maximum relative error of u: 5.663827973211771%
#
# Param is 82
# Time elapsed: 1.4968795776367188 sec
# average relative error of u: 3.886640540081257%
# maximum relative error of u: 5.571418991667087%
#
# Param is 83
# Time elapsed: 1.3286774158477783 sec
# average relative error of u: 3.8250865685265887%
# maximum relative error of u: 5.479214436991754%
#
# Param is 84
# Time elapsed: 1.8516814708709717 sec
# average relative error of u: 3.76341273641302%
# maximum relative error of u: 5.387307027212704%
#
# Param is 85
# Time elapsed: 6.437719345092773 sec
# average relative error of u: 3.7016792371407052%
# maximum relative error of u: 5.29583525091797%
#
# Param is 86
# Time elapsed: 10.199286699295044 sec
# average relative error of u: 3.639967290857757%
# maximum relative error of u: 5.204874127867255%
#
# Param is 87
# Time elapsed: 1.2974250316619873 sec
# average relative error of u: 3.5782898560352194%
# maximum relative error of u: 5.114526912292994%
#
# Param is 88
# Time elapsed: 4.535155534744263 sec
# average relative error of u: 3.5168443601148693%
# maximum relative error of u: 5.025042805097072%
#
# Param is 89
# Time elapsed: 1.295356273651123 sec
# average relative error of u: 3.455626845273343%
# maximum relative error of u: 4.936361917152608%
#
# Param is 90
# Time elapsed: 1.2493672370910645 sec
# average relative error of u: 3.3947209935069473%
# maximum relative error of u: 4.848719074283765%
#
# Param is 91
# Time elapsed: 1.391017198562622 sec
# average relative error of u: 3.3342274808162236%
# maximum relative error of u: 4.762184921915271%
#
# Param is 92
# Time elapsed: 1.2680163383483887 sec
# average relative error of u: 3.2742944566731285%
# maximum relative error of u: 4.677007213032647%
#
# Param is 93
# Time elapsed: 1.8654065132141113 sec
# average relative error of u: 3.215019944700003%
# maximum relative error of u: 4.593288727598116%
#
# Param is 94
# Time elapsed: 1.7510783672332764 sec
# average relative error of u: 3.156458735485951%
# maximum relative error of u: 4.51117122512691%
#
# Param is 95
# Time elapsed: 1.9045960903167725 sec
# average relative error of u: 3.0988640867474864%
# maximum relative error of u: 4.430977185576728%
#
# Param is 96
# Time elapsed: 2.3214306831359863 sec
# average relative error of u: 3.0422385508298366%
# maximum relative error of u: 4.352737435668475%
#
# Param is 97
# Time elapsed: 1.2900183200836182 sec
# average relative error of u: 2.986875327799807%
# maximum relative error of u: 4.276774587371257%
#
# Param is 98
# Time elapsed: 3.6150600910186768 sec
# average relative error of u: 2.9328761920968835%
# maximum relative error of u: 4.203290124798175%
#
# Param is 99
# Time elapsed: 1.1760571002960205 sec
# average relative error of u: 2.8804422827477647%
# maximum relative error of u: 4.132512787466118%
#
# Param is 100
# Time elapsed: 1.1450154781341553 sec
# average relative error of u: 2.82977799693219%
# maximum relative error of u: 4.064756263709146%
#
# Param is 101
# Time elapsed: 1.091660737991333 sec
# average relative error of u: 2.781114139585248%
# maximum relative error of u: 4.000331521667835%
#
# Param is 102
# Time elapsed: 1.677262306213379 sec
# average relative error of u: 2.734664677934474%
# maximum relative error of u: 3.9394100137882915%
#
# Param is 103
# Time elapsed: 1.2978744506835938 sec
# average relative error of u: 2.690713939578426%
# maximum relative error of u: 3.8824746175015226%
#
# Param is 104
# Time elapsed: 3.1961565017700195 sec
# average relative error of u: 2.649533663765904%
# maximum relative error of u: 3.8297656233499344%
#
# Param is 105
# Time elapsed: 0.6594510078430176 sec
# average relative error of u: 2.6113695087885183%
# maximum relative error of u: 3.7816123671393953%
#
# Param is 106
# Time elapsed: 0.9412317276000977 sec
# average relative error of u: 2.5765833093828205%
# maximum relative error of u: 3.7384678896871284%
#
# Param is 107
# Time elapsed: 3.705629825592041 sec
# average relative error of u: 2.5454348550311137%
# maximum relative error of u: 3.700534845637044%
#
# Param is 108
# Time elapsed: 1.5210623741149902 sec
# average relative error of u: 2.5182611253273217%
# maximum relative error of u: 3.668320222765685%
#
# Param is 109
# Time elapsed: 1.7608275413513184 sec
# average relative error of u: 2.495383620372096%
# maximum relative error of u: 3.6421683746200797%
#
# Param is 110
# Time elapsed: 1.4928793907165527 sec
# average relative error of u: 2.477122795207148%
# maximum relative error of u: 3.622371272592509%
#
# Param is 111
# Time elapsed: 1.1893553733825684 sec
# average relative error of u: 2.4638025777921855%
# maximum relative error of u: 3.6275150419115736%
#
# Param is 112
# Time elapsed: 1.4831693172454834 sec
# average relative error of u: 2.4556826327660897%
# maximum relative error of u: 3.6606864019514114%
#
# Param is 113
# Time elapsed: 1.7378106117248535 sec
# average relative error of u: 2.453092205967583%
# maximum relative error of u: 3.706002238674127%
#
# Param is 114
# Time elapsed: 1.4433848857879639 sec
# average relative error of u: 2.4562488775596605%
# maximum relative error of u: 3.7627412657067323%
#
# Param is 115
# Time elapsed: 13.395167589187622 sec
# average relative error of u: 2.465394992716787%
# maximum relative error of u: 3.832928509836571%
#
# Param is 116
# Time elapsed: 1.8820075988769531 sec
# average relative error of u: 2.48070539587918%
# maximum relative error of u: 3.9171552952602875%
#
# Param is 117
# Time elapsed: 1.2337243556976318 sec
# average relative error of u: 2.502312269103537%
# maximum relative error of u: 4.0129998894289765%
#
# Param is 118
# Time elapsed: 11.069530725479126 sec
# average relative error of u: 2.5303149398334077%
# maximum relative error of u: 4.120397044851519%
#
# Param is 119
# Time elapsed: 1.5990595817565918 sec
# average relative error of u: 2.564780422737329%
# maximum relative error of u: 4.240816470407503%
#
# Param is 120
# Time elapsed: 1.704469919204712 sec
# average relative error of u: 2.6057238291247775%
# maximum relative error of u: 4.373534704351797%
#
# Param is 121
# Time elapsed: 1.7164411544799805 sec
# average relative error of u: 2.653125015285803%
# maximum relative error of u: 4.517120084337747%
#
# Param is 122
# Time elapsed: 1.5959441661834717 sec
# average relative error of u: 2.706857756741767%
# maximum relative error of u: 4.671204091670321%
#
# Param is 123
# Time elapsed: 1.5238432884216309 sec
# average relative error of u: 2.766915727101054%
# maximum relative error of u: 4.835731158824172%
#
# Param is 124
# Time elapsed: 1.7309515476226807 sec
# average relative error of u: 2.833068600854579%
# maximum relative error of u: 5.01013802291247%
#
# Param is 125
# Time elapsed: 1.78422212600708 sec
# average relative error of u: 2.9052384541353593%
# maximum relative error of u: 5.194330381786829%
#
# # of POD basis is 6
# # of measurments: 12
# [  61   62   89   90  117  118 1892 1951 1952 3478 3481 3538]
# Param is 75
# Time elapsed: 1.5430870056152344 sec
# average relative error of u: 4.140307801188772%
# maximum relative error of u: 7.136674723096462%
#
# Param is 76
# Time elapsed: 1.4895954132080078 sec
# average relative error of u: 4.091843174461078%
# maximum relative error of u: 7.063057359385288%
#
# Param is 77
# Time elapsed: 2.0310726165771484 sec
# average relative error of u: 4.042496231782917%
# maximum relative error of u: 6.987528323143821%
#
# Param is 78
# Time elapsed: 1.5738623142242432 sec
# average relative error of u: 3.991724351793306%
# maximum relative error of u: 6.910193424294684%
#
# Param is 79
# Time elapsed: 3.241455078125 sec
# average relative error of u: 3.9408382161513296%
# maximum relative error of u: 6.831368887925302%
#
# Param is 80
# Time elapsed: 1.076331615447998 sec
# average relative error of u: 3.8887515404811897%
# maximum relative error of u: 6.750557456268291%
#
# Param is 81
# Time elapsed: 0.9737379550933838 sec
# average relative error of u: 3.835479111258545%
# maximum relative error of u: 6.668485841288013%
#
# Param is 82
# Time elapsed: 1.3573057651519775 sec
# average relative error of u: 3.782333615688048%
# maximum relative error of u: 6.586085610045879%
#
# Param is 83
# Time elapsed: 1.0673131942749023 sec
# average relative error of u: 3.727796877347934%
# maximum relative error of u: 6.500276262379992%
#
# Param is 84
# Time elapsed: 1.177915096282959 sec
# average relative error of u: 3.6731031828392298%
# maximum relative error of u: 6.415108568849087%
#
# Param is 85
# Time elapsed: 1.3929789066314697 sec
# average relative error of u: 3.6178162725969547%
# maximum relative error of u: 6.328350065896584%
#
# Param is 86
# Time elapsed: 7.3829474449157715 sec
# average relative error of u: 3.5622543446068327%
# maximum relative error of u: 6.244354900251042%
#
# Param is 87
# Time elapsed: 3.152594804763794 sec
# average relative error of u: 3.5059652434310182%
# maximum relative error of u: 6.158430866764672%
#
# Param is 88
# Time elapsed: 1.1650784015655518 sec
# average relative error of u: 3.449558574301148%
# maximum relative error of u: 6.0734094869421%
#
# Param is 89
# Time elapsed: 1.2518861293792725 sec
# average relative error of u: 3.39263201623126%
# maximum relative error of u: 5.984780364504709%
#
# Param is 90
# Time elapsed: 1.029646396636963 sec
# average relative error of u: 3.3354367027418785%
# maximum relative error of u: 5.8977817070981455%
#
# Param is 91
# Time elapsed: 8.752912044525146 sec
# average relative error of u: 3.278785869719767%
# maximum relative error of u: 5.8105560493689055%
#
# Param is 92
# Time elapsed: 1.044050693511963 sec
# average relative error of u: 3.22190601011627%
# maximum relative error of u: 5.7234697613688335%
#
# Param is 93
# Time elapsed: 1.6713507175445557 sec
# average relative error of u: 3.16468270747188%
# maximum relative error of u: 5.63372114624583%
#
# Param is 94
# Time elapsed: 1.1162075996398926 sec
# average relative error of u: 3.10846473907664%
# maximum relative error of u: 5.5479133172154755%
#
# Param is 95
# Time elapsed: 1.0573806762695312 sec
# average relative error of u: 3.0520881227908787%
# maximum relative error of u: 5.460586339369183%
#
# Param is 96
# Time elapsed: 1.087475299835205 sec
# average relative error of u: 2.996161151207348%
# maximum relative error of u: 5.389626971333731%
#
# Param is 97
# Time elapsed: 1.154951810836792 sec
# average relative error of u: 2.9411366311474163%
# maximum relative error of u: 5.318458194851145%
#
# Param is 98
# Time elapsed: 3.3333840370178223 sec
# average relative error of u: 2.8869368478137334%
# maximum relative error of u: 5.2496174697078475%
#
# Param is 99
# Time elapsed: 1.4603469371795654 sec
# average relative error of u: 2.8339727798939833%
# maximum relative error of u: 5.1814428071561744%
#
# Param is 100
# Time elapsed: 1.4056637287139893 sec
# average relative error of u: 2.782115402602667%
# maximum relative error of u: 5.113395425099092%
#
# Param is 101
# Time elapsed: 1.1881227493286133 sec
# average relative error of u: 2.731561522833131%
# maximum relative error of u: 5.045787989714856%
#
# Param is 102
# Time elapsed: 1.287505865097046 sec
# average relative error of u: 2.6825243829830896%
# maximum relative error of u: 4.979196665180327%
#
# Param is 103
# Time elapsed: 1.224919319152832 sec
# average relative error of u: 2.6359232978840343%
# maximum relative error of u: 4.915308984501353%
#
# Param is 104
# Time elapsed: 1.2245237827301025 sec
# average relative error of u: 2.590781999639588%
# maximum relative error of u: 4.851029973066952%
#
# Param is 105
# Time elapsed: 1.3347172737121582 sec
# average relative error of u: 2.548546694536603%
# maximum relative error of u: 4.789578314229983%
#
# Param is 106
# Time elapsed: 14.444082736968994 sec
# average relative error of u: 2.509447144087381%
# maximum relative error of u: 4.731038696357741%
#
# Param is 107
# Time elapsed: 3.2989184856414795 sec
# average relative error of u: 2.4729815326398294%
# maximum relative error of u: 4.671077141068952%
#
# Param is 108
# Time elapsed: 1.2891509532928467 sec
# average relative error of u: 2.4402660113591765%
# maximum relative error of u: 4.616074522993439%
#
# Param is 109
# Time elapsed: 1.5300993919372559 sec
# average relative error of u: 2.4114391886947932%
# maximum relative error of u: 4.562863713762476%
#
# Param is 110
# Time elapsed: 1.2869858741760254 sec
# average relative error of u: 2.385936513882023%
# maximum relative error of u: 4.510787339040276%
#
# Param is 111
# Time elapsed: 3.154294490814209 sec
# average relative error of u: 2.3662134954832594%
# maximum relative error of u: 4.461363511436735%
#
# Param is 112
# Time elapsed: 5.127049207687378 sec
# average relative error of u: 2.3508677911636693%
# maximum relative error of u: 4.424279542531935%
#
# Param is 113
# Time elapsed: 1.5506396293640137 sec
# average relative error of u: 2.340620873233654%
# maximum relative error of u: 4.413486939560124%
#
# Param is 114
# Time elapsed: 1.4082117080688477 sec
# average relative error of u: 2.336846640389658%
# maximum relative error of u: 4.4137294312587105%
#
# Param is 115
# Time elapsed: 1.2304491996765137 sec
# average relative error of u: 2.3380578272206702%
# maximum relative error of u: 4.4227680596874315%
#
# Param is 116
# Time elapsed: 11.191315174102783 sec
# average relative error of u: 2.3457266815482694%
# maximum relative error of u: 4.440838560058183%
#
# Param is 117
# Time elapsed: 1.2051424980163574 sec
# average relative error of u: 2.3592282640355613%
# maximum relative error of u: 4.4691028117798455%
#
# Param is 118
# Time elapsed: 1.203253984451294 sec
# average relative error of u: 2.380482613553263%
# maximum relative error of u: 4.51016360828243%
#
# Param is 119
# Time elapsed: 1.244455099105835 sec
# average relative error of u: 2.4076677543582496%
# maximum relative error of u: 4.560476542637084%
#
# Param is 120
# Time elapsed: 1.0088682174682617 sec
# average relative error of u: 2.4412250583604944%
# maximum relative error of u: 4.6217212633284115%
#
# Param is 121
# Time elapsed: 1.3848373889923096 sec
# average relative error of u: 2.4816173790107325%
# maximum relative error of u: 4.694231001527387%
#
# Param is 122
# Time elapsed: 4.972600221633911 sec
# average relative error of u: 2.5289246934379617%
# maximum relative error of u: 4.778854883191392%
#
# Param is 123
# Time elapsed: 6.3217010498046875 sec
# average relative error of u: 2.5826865601369855%
# maximum relative error of u: 4.875090253087212%
#
# Param is 124
# Time elapsed: 2.319892406463623 sec
# average relative error of u: 2.6426563336128646%
# maximum relative error of u: 4.981609608620937%
#
# Param is 125
# Time elapsed: 1.274662733078003 sec
# average relative error of u: 2.709285813128014%
# maximum relative error of u: 5.100029798324485%

# %%
print(num_basis)
idx=[0,1,2,3]
num_basis[idx]
# Out:
# [3 4 5 6]
# array([3, 4, 5, 6])

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])

ax=plt.gca()
ax.xaxis.set_major_locator(IndexLocator(p_inter,0))
ax.xaxis.set_minor_locator(IndexLocator(p_inter,p_inter))
ax.tick_params(axis='x',which='minor',labelcolor='blue',labelsize=20)
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_inner_DEIM_avg_rel_err.png")

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_inner_DEIM_max_rel_err.png")
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
idx=[3]
POD_basis=num_basis[idx]
print(POD_basis)
# Out:
# [6]

# %%
# with open(file=file_path_gappy_DEIM_result, mode='rb') as ff:
#     results=pickle.load(ff)    

# figure avg.rel.err vs params
plt.figure(figsize=(10,5))
for i in idx:   
    plt.plot(FOM_parameters,results['avg_rel_err'][i])
plt.xlabel('FOM parameter')
plt.ylabel('Avg. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Avg. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_{}_inner_DEIM_avg_rel_err.png".format(POD_basis)

# figure rel.err vs data points
plt.figure(figsize=(10,5))
plt_inter=1
for i in idx:   
    plt.plot(FOM_parameters,results['rel_err'][i].max(axis=1))
plt.xlabel('FOM parameter')
plt.ylabel('Max. Rel. Err.')
plt.legend(["POD basis "+str(POD_basis) for POD_basis in num_basis[idx]])
plt.title('Max. Rel. Err. vs Parameters')
# plt.savefig("./wave_result/ex23_POD_{}_inner_DEIM_max_rel_err.png".format(POD_basis)
# Out:
# Text(0.5, 1.0, 'Max. Rel. Err. vs Parameters')

# %%
print(num_basis)
print(FOM_parameters)
# Out:
# [3 4 5 6]
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125]

# %%
# figure rel.err vs at given param and POD basis
i=3;j=-1
POD_basis=num_basis[i]                 
param=FOM_parameters[j]

u_gappyPOD=results['solution'][i,j]

ex = np.load('./wave_data/ex23_interp_{}.npz'.format(param), allow_pickle = True)
ex = ex.f.arr_0
u_full = ex.reshape(nt+1,-1)

plt.figure(figsize=(10,5))
plt.plot(np.arange(1,nt+1),results['rel_err'][i,j,1:].flatten())
plt.xlabel('Time Step')
plt.ylabel('Rel. Err.')
plt.title("POD basis: {} Param: {}".format(POD_basis,param))
plt.show()

# plot original data
vmin=-1; vmax=1
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_gappyPOD[int(nt/4)*i].reshape(ny,nx))#,vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Gappy POD @ t={}'.format(int(nt/4)*i*dt),fontsize=20)
    fig.colorbar(pcm, ax=ax,shrink=0.8)

# fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_POD_{}_param_{}_inner_DEIM_SOL.png".format(POD_basis,param))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(35,7),layout='constrained')
for i in range(len(axes)):
    ax=axes[i]
    pcm = ax.pcolor(x.reshape(ny,nx), y.reshape(ny,nx), u_full[int(nt/4)*i].reshape(ny,nx))#,vmin=vmin,vmax=vmax)
    ax.axis('square')
    ax.set_xlabel('x',fontsize=20)
    ax.set_ylabel('y',fontsize=20)
    ax.set_title('Ground Truth @ t={}'.format(int(nt/4)*i*dt),fontsize=20)
    fig.colorbar(pcm, ax=ax,shrink=0.8)

# fig.colorbar(pcm, ax=axes.tolist(),shrink=0.8)
# plt.savefig("./wave_result/ex23_param_{}_ground_truth.png".format(param))
